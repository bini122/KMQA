# %%
# !pip3 install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 58.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 28.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 110.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.15.1 tokenizers-0.13.3 transformers-4.29.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/korquad/')
os.getcwd()
# Out:
# '/content/drive/MyDrive/korquad'

# %%
# !python ./task_1/run_QA.py \
    --model_type roberta \
    --model_name_or_path klue/roberta-large \
    --output_dir klue_roberta-KMQA \
    --data_dir data \
    --data_name KMQA \
    --train_file KMQA_train_v5.1.json \
    --predict_file KMQA_dev_v5.1.json \
    --max_seq_length 512 \
    --doc_stride 128 \
    --max_query_length 64 \
    --do_train \
    --do_eval \
    --evaluate_during_training \
    --per_gpu_train_batch_size=4 \
    --per_gpu_eval_batch_size=4 \
    --learning_rate 5e-5 \
    --gradient_accumulation_steps 1 \
    --weight_decay 0.0 \
    --adam_epsilon 1e-8 \
    --max_grad_norm 1.0 \
    --num_train_epochs 3 \
    --max_steps -1 \
    --warmup_steps 0 \
    --n_best_size 20 \
    --max_answer_length 30 \
    --verbose_logging \
    --logging_steps 1000 \
    --save_steps 1000 \
    --eval_all_checkpoints \
    --overwrite_output_dir \
    --seed 42 \
    --local_rank -1 \
    --threads 4
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,225 >> Length not equal after stripping spaces: '주십시요.설명은여기에있으니,유의하여보시기바랍니다.<o:p></o:p><o:p> </o:p>감사합니다.<o:p></o:p>' vs '주십시요.설명은여기에있으니,유의하여보시기바랍니다.<o:p></o:p><o:p></o:p>감사합니다.<o:p></o:p>'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,226 >> Length not equal after stripping spaces: '바랍니다.<o:p></o:p><o:p> </o:p>감사합니다.<o:p></o:p>' vs '바랍니다.<o:p></o:p><o:p></o:p>감사합니다.<o:p></o:p>'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,226 >> Unable to find text: '##요 . 설명은 여기에 있으니 , 유의하여 보시기 바랍니다' in '주십시요.설명은 여기에 있으니, 유의하여 보시기 바랍니다.<o:p></o:p><o:p> </o:p>감사합니다.<o:p></o:p>'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,226 >> Unable to find text: '##요' in '주십시요.설명은'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,226 >> Length not equal after stripping spaces: '주십시요.설명은여기에있으니,유의하여보시기바랍니다.<o:p></o:p><o:p> </o:p>감사합니다.<o:p></o:p>' vs '주십시요.설명은여기에있으니,유의하여보시기바랍니다.<o:p></o:p><o:p></o:p>감사합니다.<o:p></o:p>'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,226 >> Length not equal after stripping spaces: '주십시요.설명은여기에있으니,유의하여보시기바랍니다.<o:p></o:p><o:p> </o:p>감사합니다.<o:p></o:p>' vs '주십시요.설명은여기에있으니,유의하여보시기바랍니다.<o:p></o:p><o:p></o:p>감사합니다.<o:p></o:p>'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,227 >> Length not equal after stripping spaces: '바랍니다.<o:p></o:p><o:p> </o:p>감사합니다.<o:p></o:p>' vs '바랍니다.<o:p></o:p><o:p></o:p>감사합니다.<o:p></o:p>'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,227 >> Unable to find text: '##요 . 설명은 여기에 있으니 , 유의하여 보시기 바랍니다 .' in '주십시요.설명은 여기에 있으니, 유의하여 보시기 바랍니다.<o:p></o:p><o:p> </o:p>감사합니다.<o:p></o:p>'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,230 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,231 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,231 >> Unable to find text: '##니다' in '있습니다.가장'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,232 >> Unable to find text: '##니다 .' in '있습니다.가장'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,232 >> Unable to find text: '##입니다 .' in '것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,232 >> Unable to find text: '##입니다' in '것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,233 >> Unable to find text: '##니다 . 가장' in '있습니다.가장'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,233 >> Unable to find text: '##적으로 공황장애 등 심리적인 것에 의한 빈맥은' in '일반적으로 공황장애 등 심리적인 것에 의한 빈맥은'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,238 >> Unable to find text: '##합니다' in '권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,238 >> Unable to find text: '##합니다 .' in '권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,239 >> Unable to find text: '##합니다 . 감사합니다' in '권유합니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,241 >> Unable to find text: '##과 진료를 받는다고 해서 이직시 문제될 것은 전혀 없습니다 .' in '정신과 진료를 받는다고 해서 이직시 문제될 것은 전혀 없습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,242 >> Unable to find text: '##합니다' in '권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,242 >> Unable to find text: '##니다 .' in '없습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,242 >> Unable to find text: '##합니다 .' in '권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,242 >> Unable to find text: '##니다' in '없습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,244 >> Unable to find text: '##니다' in '편입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,244 >> Unable to find text: '##립니다 . 공황장애는 회복이 빠른 편입니다' in '권유드립니다.공황장애는 회복이 빠른 편입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,244 >> Unable to find text: '##니다 . 정신건강의학과 상담 받으신 후 치료 받으시길 권유드립니다 . 공황장애는 회복이 빠른 편입니다' in '많습니다.정신건강의학과 상담 받으신 후 치료 받으시길 권유드립니다.공황장애는 회복이 빠른 편입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,245 >> Unable to find text: '##립니다 .' in '권유드립니다.공황장애는'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,246 >> Unable to find text: '##니다 .' in '사료됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,246 >> Unable to find text: '##니다 .' in '사료됩니다.마음을'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,246 >> Unable to find text: '##니다' in '사료됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,246 >> Unable to find text: '##니다 . 빠른 쾌유를 바랍니다' in '사료됩니다. 빠른 쾌유를 바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,247 >> Unable to find text: '##를 바랍니다' in '쾌유를 바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,247 >> Unable to find text: '##니다' in '사료됩니다.마음을'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,247 >> Unable to find text: '##니다 . 빠른 쾌유를 바랍니다 .' in '사료됩니다. 빠른 쾌유를 바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,249 >> Unable to find text: '##니다 . 진료받고 치료가 필요한 부분은 치료받고 빨리 회복하시면 됩니다' in '있습니다. 진료받고 치료가 필요한 부분은 치료받고 빨리 회복하시면 됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,249 >> Unable to find text: '##니다 . 진료받고 치료가 필요한 부분은 치료받고 빨리 회복하시면 됩니다 .' in '있습니다. 진료받고 치료가 필요한 부분은 치료받고 빨리 회복하시면 됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,251 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,251 >> Unable to find text: '##니다 . 때문에 무분별하게 드시는 것은 안 됩니다' in '있습니다. 때문에 무분별하게 드시는 것은 안 됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,255 >> Unable to find text: '##는데' in '있는데'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,255 >> Unable to find text: '##는데 .' in '있는데 ..님의'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,255 >> Unable to find text: '##는데 . . 님의 경우 특별한 원인은 없어 보이네요' in '있는데 ..님의 경우 특별한 원인은 없어 보이네요.수면'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,256 >> Unable to find text: '##니다 .' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,256 >> Unable to find text: '##니다' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,256 >> Unable to find text: '##요' in '보이네요.수면'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,273 >> Unable to find text: '##니다' in '있습니다.여자분들은'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,274 >> Unable to find text: '##니다' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,275 >> Unable to find text: '##니다 .' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,276 >> Unable to find text: '##니다' in '있습니다.렉사프로는'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,276 >> Unable to find text: '##니다 . 렉사프로는 가장 자주 쓰이는 항우울제 중의 한가지 입니다' in '있습니다.렉사프로는 가장 자주 쓰이는 항우울제 중의 한가지 입니다.우울한'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,279 >> Unable to find text: '[UNK]' in '관옇압니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,279 >> Unable to find text: '##합니다' in '관여합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,280 >> Unable to find text: '##합니다 .' in '관여합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,280 >> Unable to find text: '[UNK] .' in '관옇압니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,280 >> Unable to find text: '##울제와 항불안제는 단순히 우울감 , 불안감만 해소하는 약물들이 아닙니다 .' in '항우울제와 항불안제는 단순히 우울감, 불안감만 해소하는 약물들이 아닙니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,280 >> Unable to find text: '##울제와 항불안제는 단순히 우울감 , 불안감만 해소하는 약물들이 아닙니다' in '항우울제와 항불안제는 단순히 우울감, 불안감만 해소하는 약물들이 아닙니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,282 >> Unable to find text: '##어요' in '수있어요.진료를'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,282 >> Unable to find text: '##어요 . 진료를 받아보시는 것이 좋겠네요' in '수있어요.진료를 받아보시는 것이 좋겠네요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,282 >> Unable to find text: '##요' in '좋겠네요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,283 >> Unable to find text: '##요 . 공황장애는 죽을것 같은 느낌이 동반되는 것이 특징입니다 . 이런 게 없다면 불안증상이죠' in '좋겠네요. 공황장애는 죽을것 같은 느낌이 동반되는 것이 특징입니다.이런 게 없다면 불안증상이죠.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,283 >> Unable to find text: '##죠' in '불안증상이죠.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,285 >> Unable to find text: '##니다' in '알려드리겠습니다.수면은'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,286 >> Unable to find text: '##니다 . 이제 밤낮 바꾸는 법에 대해 알려드리겠습니다' in '생각됩니다. 이제 밤낮 바꾸는 법에 대해 알려드리겠습니다.수면은'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,286 >> Unable to find text: '##니다 . 수면은 리듬입니다 . 따라서 아침 기상시각을 일정하게 고정시키고 지키는 것이 가장 중요한 첫 단추입니다' in '알려드리겠습니다.수면은 리듬입니다. 따라서 아침 기상시각을 일정하게 고정시키고 지키는 것이 가장 중요한 첫 단추입니다.아무리'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,287 >> Unable to find text: '##입니다' in '단추입니다.아무리'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,287 >> Unable to find text: '##세요' in '지켜보세요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,289 >> Unable to find text: '##합니다' in '감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,290 >> Length not equal after stripping spaces: '것입니다.많이먹고토하는것이반복되기때문에,식도염이나후두염그리고치아에이상이생기기도합니다. 폭식증이' vs '것입니다.많이먹고토하는것이반복되기때문에,식도염이나후두염그리고치아에이상이생기기도합니다.폭식증이'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,290 >> Length not equal after stripping spaces: '합니다. 폭식증이있는분들에게는우울증이동반되는경우도많습니다.혼자서' vs '합니다.폭식증이있는분들에게는우울증이동반되는경우도많습니다.혼자서'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,290 >> Length not equal after stripping spaces: '때문에,식도염이나후두염그리고치아에이상이생기기도합니다. 폭식증이' vs '때문에,식도염이나후두염그리고치아에이상이생기기도합니다.폭식증이'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,291 >> Length not equal after stripping spaces: '합니다. 폭식증이' vs '합니다.폭식증이'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,291 >> Length not equal after stripping spaces: '것입니다.많이먹고토하는것이반복되기때문에,식도염이나후두염그리고치아에이상이생기기도합니다. 폭식증이' vs '것입니다.많이먹고토하는것이반복되기때문에,식도염이나후두염그리고치아에이상이생기기도합니다.폭식증이'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,291 >> Unable to find text: '##입니다 . 많이 먹고 토하는 것이 반복되기 때문에 , 식도염이나 후두염 그리고 치아에 이상이 생기기도 합니다' in '것입니다.많이 먹고 토하는 것이 반복되기 때문에,식도염이나 후두염 그리고 치아에 이상이 생기기도 합니다. 폭식증이'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,291 >> Length not equal after stripping spaces: '합니다. 폭식증이있는분들에게는우울증이동반되는경우도많습니다.혼자서' vs '합니다.폭식증이있는분들에게는우울증이동반되는경우도많습니다.혼자서'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,292 >> Length not equal after stripping spaces: '합니다. 폭식증이있는분들에게는우울증이동반되는경우도많습니다.혼자서' vs '합니다.폭식증이있는분들에게는우울증이동반되는경우도많습니다.혼자서'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,292 >> Unable to find text: '##니다' in '많습니다.혼자서'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,292 >> Length not equal after stripping spaces: '합니다. 폭식증이있는분들에게는우울증이동반되는경우도많습니다.혼자서' vs '합니다.폭식증이있는분들에게는우울증이동반되는경우도많습니다.혼자서'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,293 >> Length not equal after stripping spaces: '것입니다.많이먹고토하는것이반복되기때문에,식도염이나후두염그리고치아에이상이생기기도합니다. 폭식증이' vs '것입니다.많이먹고토하는것이반복되기때문에,식도염이나후두염그리고치아에이상이생기기도합니다.폭식증이'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,293 >> Unable to find text: '##니다 . 혼자서 해결이 어렵다면 치료를 받는 것이 좋습니다' in '많습니다.혼자서 해결이 어렵다면 치료를 받는 것이 좋습니다.꾸준히'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,293 >> Unable to find text: '##니다' in '좋습니다.꾸준히'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,294 >> Unable to find text: '##입니다' in '의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,294 >> Unable to find text: '##합니다 . 즉 , 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다' in '발생합니다. 즉, 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,295 >> Unable to find text: '##합니다' in '발생합니다.규칙적인'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,295 >> Unable to find text: '##합니다 .' in '발생합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,295 >> Unable to find text: '##입니다 .' in '의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,296 >> Unable to find text: '##니다 . 불면증은 근본적으로 수면과 각성을 조절하는 뇌 신경계의 기능이상으로 발생합니다 .' in '있습니다. 불면증은 근본적으로 수면과 각성을 조절하는 뇌 신경계의 기능이상으로 발생합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,296 >> Unable to find text: '##합니다' in '발생합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,296 >> Unable to find text: '##합니다 . 즉 , 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다 .' in '발생합니다. 즉, 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,296 >> Unable to find text: '##니다 . 불면증은 근본적으로 수면과 각성을 조절하는 뇌 신경계의 기능이상으로 발생합니다' in '있습니다. 불면증은 근본적으로 수면과 각성을 조절하는 뇌 신경계의 기능이상으로 발생합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,298 >> Unable to find text: '[UNK] 시간동안 나타나는 극심한 공포 반응과 불안 , 죽응에 대한 두려움 등이 동반되곤 합니다' in '짦은 시간동안 나타나는 극심한 공포 반응과 불안, 죽응에 대한 두려움 등이 동반되곤 합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,298 >> Unable to find text: '##립니다 .' in '권유드립니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,298 >> Unable to find text: '##립니다' in '권유드립니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,298 >> Unable to find text: '##7' in '흉통7.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,299 >> Unable to find text: '##7 . 미식거림이나 복부 불편감8 . 어지럼증9 . 비현실감10' in '흉통7. 미식거림이나 복부 불편감8. 어지럼증9. 비현실감10.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,299 >> Unable to find text: '##7 . 미식거림이나 복부 불편감8 . 어지럼증9' in '흉통7. 미식거림이나 복부 불편감8. 어지럼증9.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,300 >> Length not equal after stripping spaces: '수면질환중하나이며 몽유병과비슷하지만다른질환입니다.퇴행성뇌질환으로이어질위험도있습니다.수면다원검사를' vs '수면질환중하나이며몽유병과비슷하지만다른질환입니다.퇴행성뇌질환으로이어질위험도있습니다.수면다원검사를'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,300 >> Unable to find text: '##니다' in '있습니다.수면다원검사를'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,300 >> Length not equal after stripping spaces: '수면질환중하나이며 몽유병과비슷하지만다른질환입니다.퇴행성' vs '수면질환중하나이며몽유병과비슷하지만다른질환입니다.퇴행성'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,301 >> Length not equal after stripping spaces: '꿈을많이꾸고 특히수면' vs '꿈을많이꾸고특히수면'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,301 >> Length not equal after stripping spaces: '꾸고 특히수면중폭력적인행동이동반되는경우에는렘수면행동장애일가능성이높습니다.' vs '꾸고특히수면중폭력적인행동이동반되는경우에는렘수면행동장애일가능성이높습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,301 >> Unable to find text: '##니다 . 수면다원검사를 통해서 진단하고 치료하게 됩니다' in '있습니다.수면다원검사를 통해서 진단하고 치료하게 됩니다.수면클리닉'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,302 >> Length not equal after stripping spaces: '높습니다.수면질환중하나이며 몽유병과비슷하지만다른질환입니다.퇴행성' vs '높습니다.수면질환중하나이며몽유병과비슷하지만다른질환입니다.퇴행성'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,302 >> Length not equal after stripping spaces: '많이꾸고 특히수면중폭력적인행동이동반되는경우에는렘수면행동장애일가능성이높습니다.' vs '많이꾸고특히수면중폭력적인행동이동반되는경우에는렘수면행동장애일가능성이높습니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,302 >> Length not equal after stripping spaces: '수면질환중하나이며 몽유병과비슷하지만다른질환입니다.퇴행성' vs '수면질환중하나이며몽유병과비슷하지만다른질환입니다.퇴행성'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,304 >> Unable to find text: '##합니다' in '중요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,304 >> Unable to find text: '##합니다 . 과도한 불안 , 우울 , 스트레스가 가장 흔한 수면장애의 원인이 되기도 합니다' in '중요합니다. 과도한 불안, 우울, 스트레스가 가장 흔한 수면장애의 원인이 되기도 합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,305 >> Unable to find text: '##합니다' in '중요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,306 >> Unable to find text: '##니다 . 본인이 스스로 스트레스를 줄이려는 노력이 필요 합니다' in '많습니다.본인이 스스로 스트레스를 줄이려는 노력이 필요 합니다.운동도'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,308 >> Unable to find text: '##니다 . 본인이 스스로 스트레스를 줄이려는 노력이 필요 합니다 . 운동도 하고 취미 생활도 하고 인생을 즐기려고 하셔야 합니다' in '많습니다.본인이 스스로 스트레스를 줄이려는 노력이 필요 합니다.운동도 하고 취미 생활도 하고 인생을 즐기려고 하셔야 합니다.치료하시는'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,309 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,309 >> Unable to find text: '##니다 . 루게릭병의 증상과는 다른 점이 많습니다' in '있습니다. 루게릭병의 증상과는 다른 점이 많습니다.프레가발린은'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,309 >> Unable to find text: '##니다' in '많습니다.프레가발린은'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,310 >> Unable to find text: '##니다 . 인근에서 요천추부신경총에 대한 치료를 적극적으로 받으시면 증상이 호전될 수 있습니다' in '많습니다. 인근에서 요천추부신경총에 대한 치료를 적극적으로 받으시면 증상이 호전될 수 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,310 >> Unable to find text: '##니다' in '좋겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,310 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,310 >> Unable to find text: '##니다 .' in '좋겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,310 >> Unable to find text: '##니다 . 인근에서 요천추부신경총에 대한 치료를 적극적으로 받으시면 증상이 호전될 수 있습니다 .' in '많습니다. 인근에서 요천추부신경총에 대한 치료를 적극적으로 받으시면 증상이 호전될 수 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,311 >> Unable to find text: '##니다 .' in '많습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,311 >> Unable to find text: '##니다 . 루게릭병의 증상과는 다른 점이 많습니다 .' in '있습니다. 루게릭병의 증상과는 다른 점이 많습니다.프레가발린은'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,311 >> Unable to find text: '##니다 .' in '많습니다.프레가발린은'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,311 >> Unable to find text: '##니다' in '많습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,312 >> Unable to find text: '##니다 .' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,312 >> Unable to find text: '##입니다 .' in '증상입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,313 >> Unable to find text: '##니다' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,313 >> Unable to find text: '##합니다' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,313 >> Unable to find text: '##니다 . 감사합니다' in '같습니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,313 >> Unable to find text: '##합니다 .' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,313 >> Unable to find text: '##니다 . 감사합니다 .' in '같습니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,314 >> Unable to find text: '##니다' in '않습니다'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,315 >> Unable to find text: '##합니다 . 심리적인 문제일 가능성 확인은 필요할 수 있으며 , 한의원 방문은 딱히 권유하지 않습니다' in '아닌듯합니다. 심리적인 문제일 가능성 확인은 필요할 수 있으며, 한의원 방문은 딱히 권유하지 않습니다'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,374 >> Unable to find text: '##니다' in '좋겠습니다'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,375 >> Unable to find text: '##요 좋은 결과 있으셨으면 좋겠습니다' in '같아요 좋은 결과 있으셨으면 좋겠습니다'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,375 >> Unable to find text: '##요' in '같아요'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,376 >> Unable to find text: '##을 믿고 따라가보시고 그 결과를 다시 상담하시는 편이 좋을 것 같아요' in '하셨나요?선생님을 믿고 따라가보시고 그 결과를 다시 상담하시는 편이 좋을 것 같아요'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,376 >> Unable to find text: '##님을 믿고 따라가보시고 그 결과를 다시 상담하시는 편이 좋을 것 같아요' in '하셨나요?선생님을 믿고 따라가보시고 그 결과를 다시 상담하시는 편이 좋을 것 같아요'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,379 >> Unable to find text: '##니다' in '같습니다.피해망상증상은'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,379 >> Unable to find text: '##니다' in '있습니다.진단을'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,380 >> Unable to find text: '##니다' in '있습니다.환자분을'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,382 >> Unable to find text: '##합니다 .' in '생각합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,382 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,382 >> Unable to find text: '##합니다' in '생각합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,383 >> Unable to find text: '##니다 . 그리고 언니의 동의가 있다면 식구들에게 도움을 청하는 것도 한 방법이 될 수 있을 것으로 생각합니다' in '같습니다. 그리고 언니의 동의가 있다면 식구들에게 도움을 청하는 것도 한 방법이 될 수 있을 것으로 생각합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,383 >> Unable to find text: '##니다 .' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,385 >> Unable to find text: '##데요' in '상황인건데요.현재'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,385 >> Unable to find text: '##입니다 . 신경이 예민하게 반응하는 상황인건데요' in '한가지입니다. 신경이 예민하게 반응하는 상황인건데요.현재'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,386 >> Unable to find text: '##데요 . 현재 아이를 키우는 상황이 힘들어서 스트레스가 되고 있는건 아닌지 모르겠네요' in '상황인건데요.현재 아이를 키우는 상황이 힘들어서 스트레스가 되고 있는건 아닌지 모르겠네요.수유를'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,386 >> Unable to find text: '##요 . 수유를 하고있지 않다면 잠시나마 다시 약물치료나 상담을 받아보시는건 어떨까 싶습니다' in '모르겠네요.수유를 하고있지 않다면 잠시나마 다시 약물치료나 상담을 받아보시는건 어떨까 싶습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,386 >> Unable to find text: '##니다' in '싶습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,386 >> Unable to find text: '##요' in '모르겠네요.수유를'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,387 >> Unable to find text: '##요 . 수유를 하고있지 않다면 잠시나마 다시 약물치료나 상담을 받아보시는건 어떨까 싶습니다 .' in '모르겠네요.수유를 하고있지 않다면 잠시나마 다시 약물치료나 상담을 받아보시는건 어떨까 싶습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,387 >> Unable to find text: '##니다 .' in '싶습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,388 >> Unable to find text: '##립니다' in '권유드립니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,388 >> Unable to find text: '##니다 . 종합병원급 신경과 진료를 권유드립니다' in '생각됩니다. 종합병원급 신경과 진료를 권유드립니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,389 >> Unable to find text: '##니다 .' in '생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,389 >> Unable to find text: '##립니다 .' in '권유드립니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,390 >> Unable to find text: '##니다 . 종합병원급 신경과 진료를 권유드립니다 .' in '생각됩니다. 종합병원급 신경과 진료를 권유드립니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,390 >> Unable to find text: '##니다' in '생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,391 >> Unable to find text: '##입니다' in '것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,392 >> Unable to find text: '##합니다 .' in '필요합니다.그러나'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,392 >> Unable to find text: '##니다 . 심적인 문제 , 극한 스트레스 , 공황장애여부도 감별이 필요합니다 .' in '있습니다.심적인 문제, 극한 스트레스, 공황장애여부도 감별이 필요합니다.그러나'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,393 >> Unable to find text: '##입니다 .' in '것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,394 >> Unable to find text: '##니다 .' in '높습니다.성조숙증시'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,394 >> Unable to find text: '##니다' in '높습니다.성조숙증시'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,395 >> Unable to find text: '##합니다' in '필요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,395 >> Unable to find text: '##합니다 .' in '필요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,396 >> Unable to find text: '##입니다 .' in '것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,396 >> Unable to find text: '##합니다' in '필요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,397 >> Unable to find text: '##입니다 . 단약이 많이 힘든일이기도 하지만 불가능한 것은 아닙니다' in '것입니다. 단약이 많이 힘든일이기도 하지만 불가능한 것은 아닙니다.또한'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,397 >> Unable to find text: '##합니다 .' in '필요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,399 >> Unable to find text: '##입니다 .' in '경우입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,399 >> Unable to find text: '##입니다 .' in '필수적입니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,400 >> Length not equal after stripping spaces: '모두치료를통해많이좋아질수있습니다. ' vs '모두치료를통해많이좋아질수있습니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,401 >> Length not equal after stripping spaces: '두가지모두치료를통해많이좋아질수있습니다. ' vs '두가지모두치료를통해많이좋아질수있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,401 >> Unable to find text: '##니다' in '같습니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,401 >> Length not equal after stripping spaces: '모두치료를통해많이좋아질수있습니다. 치료는약물치료와상담치료를함께하는것입니다.감사합니다.' vs '모두치료를통해많이좋아질수있습니다.치료는약물치료와상담치료를함께하는것입니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,401 >> Unable to find text: '##니다' in '있습니다. '
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,402 >> Length not equal after stripping spaces: '입니다.두가지모두치료를통해많이좋아질수있습니다. ' vs '입니다.두가지모두치료를통해많이좋아질수있습니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,402 >> Length not equal after stripping spaces: '모두치료를통해많이좋아질수있습니다. 치료는약물치료와상담치료를함께하는것입니다.' vs '모두치료를통해많이좋아질수있습니다.치료는약물치료와상담치료를함께하는것입니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,402 >> Length not equal after stripping spaces: '두가지모두치료를통해많이좋아질수있습니다. 치료는약물치료와상담치료를함께하는것입니다.감사합니다.' vs '두가지모두치료를통해많이좋아질수있습니다.치료는약물치료와상담치료를함께하는것입니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,403 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,404 >> Unable to find text: '##니다' in '많습니다.정신건강의학과'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,404 >> Unable to find text: '##니다 . 정신건강의학과 치료는 지금 질문자 분께서 고민하시는 증상을 효과적으로 도와 드릴 수 있습니다' in '많습니다.정신건강의학과 치료는 지금 질문자 분께서 고민하시는 증상을 효과적으로 도와 드릴 수 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,404 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,404 >> Unable to find text: '##니다 . 좀 더 편한 마음으로 가까운 정신건강의학과를 방문하셔서 치료를 시작해 보시기를 권유 드립니다' in '있습니다. 좀 더 편한 마음으로 가까운 정신건강의학과를 방문하셔서 치료를 시작해 보시기를 권유 드립니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,405 >> Unable to find text: '##니다 . 좀 더 편한 마음으로 가까운 정신건강의학과를 방문하셔서 치료를 시작해 보시기를 권유 드립니다 .' in '있습니다. 좀 더 편한 마음으로 가까운 정신건강의학과를 방문하셔서 치료를 시작해 보시기를 권유 드립니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,405 >> Unable to find text: '##니다 .' in '많습니다.정신건강의학과'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,405 >> Unable to find text: '##니다 . 정신건강의학과 치료는 지금 질문자 분께서 고민하시는 증상을 효과적으로 도와 드릴 수 있습니다 .' in '많습니다.정신건강의학과 치료는 지금 질문자 분께서 고민하시는 증상을 효과적으로 도와 드릴 수 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,405 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,408 >> Unable to find text: '##합니다 . 현재 불안증 진단 이후 약물 복용하시는 정신과 선생님과 다시 한번 상담해보시는게 가장 좋을 듯 합니다' in '불가능합니다. 현재 불안증 진단 이후 약물 복용하시는 정신과 선생님과 다시 한번 상담해보시는게 가장 좋을 듯 합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,408 >> Unable to find text: '##합니다 .' in '불가능합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,408 >> Unable to find text: '##입니다 . 정신과적 영역의 진단을 온라인으로 하는것은 거의 불가능합니다 .' in '한재병입니다. 정신과적 영역의 진단을 온라인으로 하는것은 거의 불가능합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,409 >> Length not equal after stripping spaces: '고통스러우시겠습니다.먼저단순한폭식과병적인폭식장애를구분할필요가있습니다. 단순한' vs '고통스러우시겠습니다.먼저단순한폭식과병적인폭식장애를구분할필요가있습니다.단순한'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,410 >> Length not equal after stripping spaces: '고통스러우시겠습니다.먼저단순한폭식과병적인폭식장애를구분할필요가있습니다. 단순한' vs '고통스러우시겠습니다.먼저단순한폭식과병적인폭식장애를구분할필요가있습니다.단순한'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,410 >> Length not equal after stripping spaces: '고통스러우시겠습니다.먼저단순한폭식과병적인폭식장애를구분할필요가있습니다. 단순한' vs '고통스러우시겠습니다.먼저단순한폭식과병적인폭식장애를구분할필요가있습니다.단순한'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,410 >> Unable to find text: '식이장애를 극복하기 위해서는 무엇보다도 식사와 체형에 대한 왜곡된 생각 ( 나는 정말 살이 [UNK]' in '합니다. 식이장애를 극복하기 위해서는 무엇보다도 식사와 체형에 대한 왜곡된 생각(나는 정말 살이 쪘다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,410 >> Length not equal after stripping spaces: '있습니다. 단순한' vs '있습니다.단순한'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,411 >> Unable to find text: '##합니다' in '필요합니다.대개'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,411 >> Unable to find text: '##합니다 .' in '필요합니다.대개'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,411 >> Length not equal after stripping spaces: '좋습니다.  이상식이행동을대체할수있는취미나 운동(무리하지않는)을선택하여실시하는것을권합니다.이런 대체행동은' vs '좋습니다.이상식이행동을대체할수있는취미나운동(무리하지않는)을선택하여실시하는것을권합니다.이런대체행동은'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,411 >> Unable to find text: '##합니다 . 대개 폭식을 하게 되는 주된 이유는식사습관이 나쁘고 스트레스를 많이 받는 것입니다' in '필요합니다.대개 폭식을 하게 되는 주된 이유는식사습관이 나쁘고 스트레스를 많이 받는 것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,411 >> Unable to find text: '##입니다' in '것입니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,412 >> Length not equal after stripping spaces: '좋습니다.  이상식이행동을대체할수있는취미나 운동(무리하지않는)을선택하여실시하는것을권합니다.이런 대체행동은' vs '좋습니다.이상식이행동을대체할수있는취미나운동(무리하지않는)을선택하여실시하는것을권합니다.이런대체행동은'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,412 >> Length not equal after stripping spaces: '단순한폭식과병적인폭식장애를구분할필요가있습니다. 단순한' vs '단순한폭식과병적인폭식장애를구분할필요가있습니다.단순한'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,412 >> Length not equal after stripping spaces: '없습니다.스스로조절하기어려우시다면 어려워마시고꼭전문가를찾아보실것을권합니다.잘 극복하시기를' vs '없습니다.스스로조절하기어려우시다면어려워마시고꼭전문가를찾아보실것을권합니다.잘극복하시기를'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,412 >> Length not equal after stripping spaces: '합니다.일반적인스트레스를줄이기위한어떤노력도도움이될수있습니다.  질문자님,' vs '합니다.일반적인스트레스를줄이기위한어떤노력도도움이될수있습니다.질문자님,'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,412 >> Length not equal after stripping spaces: '단순한폭식과병적인폭식장애를구분할필요가있습니다. 단순한' vs '단순한폭식과병적인폭식장애를구분할필요가있습니다.단순한'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,413 >> Length not equal after stripping spaces: '일반적인스트레스를줄이기위한어떤노력도도움이될수있습니다.  질문자님,' vs '일반적인스트레스를줄이기위한어떤노력도도움이될수있습니다.질문자님,'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,413 >> Unable to find text: '##합니다' in '여쭤봐야할듯합니다'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,473 >> Unable to find text: '##합니다 . 좀 더 자세한 내용은 담당선생님께 여쭤봐야할듯합니다' in '처방한듯합니다. 좀 더 자세한 내용은 담당선생님께 여쭤봐야할듯합니다'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,476 >> Unable to find text: '##합니다 .' in '처방한듯합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,479 >> Unable to find text: '##요' in '하십시요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,480 >> Unable to find text: '##요 .' in '하십시요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,480 >> Unable to find text: '##니다 . 2 . 약물 치료를 유지 하십시요' in '안됩니다. 2. 약물 치료를 유지 하십시요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,484 >> Unable to find text: '##합니다' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,485 >> Unable to find text: '##니다 .' in '때가있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,488 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,489 >> Unable to find text: '##입니다' in '것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,489 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,490 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,490 >> Unable to find text: '##요' in '보십시요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,490 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,491 >> Unable to find text: '##니다 . 치료결과에 대한 기준을 낮추고 통증 경감을 위해서 꾸준히 치료 받아 보십시요' in '어렵습니다. 치료결과에 대한 기준을 낮추고 통증 경감을 위해서 꾸준히 치료 받아 보십시요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,491 >> Unable to find text: '##요 . 감사합니다' in '보십시요. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,491 >> Unable to find text: '##입니다 . MRI 를 시행하는 이유는 목디스크로 인한 원인인지를 배제하기 위해서 입니다' in '것입니다. MRI 를 시행하는 이유는 목디스크로 인한 원인인지를 배제하기 위해서 입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,491 >> Unable to find text: '##합니다' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,491 >> Unable to find text: '##요 .' in '보십시요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,493 >> Unable to find text: '##니다' in '있습니다.너무'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,494 >> Unable to find text: '##니다 . 어떤 병이건 조기에 치료하면 빨리 나으실 수 있습니다' in '좋겠습니다. 어떤 병이건 조기에 치료하면 빨리 나으실 수 있습니다.너무'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,495 >> Unable to find text: '##니다 .' in '좋겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,496 >> Unable to find text: '##니다 . 가급적이면 정신과 전문의를 찾아약물치료 및 상담치료를 받는 것이 좋겠습니다 .' in '의심됩니다.가급적이면 정신과 전문의를 찾아약물치료 및 상담치료를 받는 것이 좋겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,497 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,497 >> Unable to find text: '##입니다 . 사람도 알아보고 시간도 알아보는데 왜 정신병이냐고 묻는 분도 있습니다' in '정상입니다. 사람도 알아보고 시간도 알아보는데 왜 정신병이냐고 묻는 분도 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,499 >> Unable to find text: '##입니다 .' in '정상입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,499 >> Unable to find text: '##입니다 .' in '생각입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,499 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,500 >> Unable to find text: '##입니다' in '생각입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,500 >> Unable to find text: '##입니다' in '정상입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,501 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,502 >> Unable to find text: '##합니다' in '치료합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,502 >> Unable to find text: '정상적인 수면 과정에서도 5 ~ 6회 정도 잠을 [UNK] 수 있습니다 .' in '정상적인 수면 과정에서도 5~6회 정도 잠을 깰 수 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,503 >> Unable to find text: '##합니다' in '발생합니다.수면무호흡,'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,503 >> Unable to find text: '정상적인 수면 과정에서도 5 ~ 6회 정도 잠을 [UNK] 수 있습니다' in '정상적인 수면 과정에서도 5~6회 정도 잠을 깰 수 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,504 >> Unable to find text: '##합니다 .' in '치료합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,504 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,506 >> Unable to find text: '##요 . 비타민주사 몇번 맞으시면서 경과를 지켜보시면 어떨까요 ?' in '싶네요. 비타민주사 몇번 맞으시면서 경과를 지켜보시면 어떨까요?'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,507 >> Unable to find text: '##요 . 비타민주사 몇번 맞으시면서 경과를 지켜보시면 어떨까요 ? 혹시 지병이 있으신가요 ?' in '싶네요. 비타민주사 몇번 맞으시면서 경과를 지켜보시면 어떨까요? 혹시 지병이 있으신가요?'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,508 >> Unable to find text: '##입니다 . 큰 수술 후에 회복이 잘 안되시는것은 아닌가 싶네요 .' in '홍인표입니다. 큰 수술 후에 회복이 잘 안되시는것은 아닌가 싶네요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,508 >> Unable to find text: '##요 .' in '싶네요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,511 >> Unable to find text: '##니다 . 너무 걱정하지 마시고 근처의 정신건강의학과 방문하시어 검사하시고 치료하세요' in '편입니다.너무 걱정하지 마시고 근처의 정신건강의학과 방문하시어 검사하시고 치료하세요.불안장애는'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,511 >> Unable to find text: '##세요' in '치료하세요.불안장애는'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,511 >> Unable to find text: '##니다' in '편입니다.너무'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,512 >> Unable to find text: '##세요 . 불안장애는 우울증과 동반하는 경우가 많으니 꼭 검사하시고 치료받으시길 바랍니다' in '치료하세요.불안장애는 우울증과 동반하는 경우가 많으니 꼭 검사하시고 치료받으시길 바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,512 >> Unable to find text: '##니다 .' in '편입니다.너무'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,515 >> Unable to find text: '##니다 .' in '같습니다.과량을'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,519 >> Unable to find text: '##니다 .' in '생각됩니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,520 >> Unable to find text: '##입니다 . 일시적인 공황장애 이거나 위장장애등 다른 요인이 아닐까 생각됩니다 .' in '떨어져보입니다.일시적인 공황장애 이거나 위장장애등 다른 요인이 아닐까 생각됩니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,521 >> Unable to find text: '##제를 사용하지 않은 사태에서 CT 를 찍었다고 하시면 CT 와의관련성은 떨어져보입니다 .' in '조영제를 사용하지 않은 사태에서 CT 를 찍었다고 하시면 CT 와의관련성은 떨어져보입니다.일시적인'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,522 >> Unable to find text: '##합니다' in '생각됩니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,522 >> Unable to find text: '##니다 . 감사합니다' in '생각됩니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,526 >> Unable to find text: '##니다' in '가깝습니다.조현병(정신분열병)의'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,527 >> Unable to find text: '##랍니다' in '마찬가지랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,527 >> Unable to find text: '##니다 .' in '가깝습니다.조현병(정신분열병)의'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,528 >> Unable to find text: '##요' in '보세요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,528 >> Unable to find text: '##요 .' in '보세요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,529 >> Unable to find text: '##니다' in '있습니다.증상이'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,529 >> Unable to find text: '##니다 .' in '있습니다.증상이'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,529 >> Unable to find text: '##니다 .' in '있습니다.다만'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,529 >> Unable to find text: '##니다' in '있습니다.다만'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,529 >> Unable to find text: '##니다 . 증상' in '있습니다.증상이'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,529 >> Unable to find text: '##니다 . 다만 그런 안정상태' in '있습니다.다만 그런 안정상태에'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,530 >> Unable to find text: '##는' in '약물치료는'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,530 >> Unable to find text: '##치료는' in '약물치료는'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,531 >> Unable to find text: '##님께 말씀드려야 할 것 같습니다 . 몸에 이상이없는지 검사가 필요합니다 .' in '부모님께 말씀드려야 할 것 같습니다. 몸에 이상이없는지 검사가 필요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,531 >> Unable to find text: '##께 말씀드려야 할 것 같습니다 . 몸에 이상이없는지 검사가 필요합니다 .' in '부모님께 말씀드려야 할 것 같습니다. 몸에 이상이없는지 검사가 필요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,531 >> Unable to find text: '##합니다 .' in '필요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,532 >> Unable to find text: '##니다 . 몸에 이상이없는지 검사가 필요합니다 .' in '같습니다. 몸에 이상이없는지 검사가 필요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,534 >> Unable to find text: '##니다' in '있습니다.),'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,535 >> Length not equal after stripping spaces: '급성기의뇌출혈,아급성기의뇌경색, 뇌종양(조영제사용해야명확합니다.' vs '급성기의뇌출혈,아급성기의뇌경색,뇌종양(조영제사용해야명확합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,535 >> Unable to find text: '##니다' in '판단됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,535 >> Unable to find text: '##세요' in '시행해보세요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,535 >> Unable to find text: '##니다 .' in '있습니다.),'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,535 >> Unable to find text: '##세요 .' in '시행해보세요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,535 >> Unable to find text: '##합니다' in '명확합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,536 >> Unable to find text: '##니다 .' in '판단됩니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,536 >> Length not equal after stripping spaces: '생각합니다.급성기의뇌출혈,아급성기의뇌경색, 뇌종양(조영제사용해야명확합니다.' vs '생각합니다.급성기의뇌출혈,아급성기의뇌경색,뇌종양(조영제사용해야명확합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,536 >> Unable to find text: '##합니다 . 급성기의 뇌출혈 , 아급성기의 뇌경색 , 뇌종양 ( 조영제 사용해야 명확합니다' in '생각합니다. 급성기의 뇌출혈, 아급성기의 뇌경색,  뇌종양(조영제 사용해야 명확합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,536 >> Unable to find text: '##니다 . )' in '있습니다.),'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,538 >> Unable to find text: '##니다' in '있습니다.하지만'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,538 >> Unable to find text: '##니다 .' in '있습니다.지금이라도'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,538 >> Unable to find text: '##니다 .' in '있습니다.하지만'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,539 >> Unable to find text: '##니다 . 지금이라도 끊었다니 다행이고 약으로 채워지던 만큼을 무엇으로 대체할지를 찾는 것이 급선무 입니다' in '있습니다.지금이라도 끊었다니 다행이고 약으로 채워지던 만큼을 무엇으로 대체할지를 찾는 것이 급선무 입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,543 >> Unable to find text: '##은 아닙니다 .' in '내일은 아닙니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,543 >> Unable to find text: '##요 내일은 아닙니다 .' in '가세요 내일은 아닙니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,543 >> Length not equal after stripping spaces: '태풍지나가면가세요내일은아닙니다.답변을참고하시기전에 1.' vs '태풍지나가면가세요내일은아닙니다.답변을참고하시기전에1.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,545 >> Unable to find text: '##니다' in '처방됩니다.우울증은'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,545 >> Unable to find text: '##니다' in '선호됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,546 >> Unable to find text: '##니다 .' in '처방됩니다.우울증은'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,546 >> Unable to find text: '##니다 .' in '선호됩니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,546 >> Length not equal after stripping spaces: '있을까요.증상 -머리를짖누르는두통 가슴이답답하고심하면호흡곤란까지생깁니다. ' vs '있을까요.증상-머리를짖누르는두통가슴이답답하고심하면호흡곤란까지생깁니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,566 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,566 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,574 >> Unable to find text: '##은 그 약물의 종류에 따라 여러 증상들이 발생할 가능성은 있습니다 .' in '중단은 그 약물의 종류에 따라 여러 증상들이 발생할 가능성은 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,576 >> Unable to find text: '##합니다' in '발생합니다.즉,'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,577 >> Unable to find text: '##합니다 . 즉 , 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다' in '발생합니다.즉, 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,577 >> Unable to find text: '##입니다' in '의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,577 >> Unable to find text: '##죠 . 불면증은 근본적으로 수면과 각성을 조절하는 뇌 신경계의 기능이상으로 발생합니다' in '되죠.불면증은 근본적으로 수면과 각성을 조절하는 뇌 신경계의 기능이상으로 발생합니다.즉,'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,578 >> Unable to find text: '##합니다' in '발생합니다.규칙적인'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,578 >> Unable to find text: '##합니다 .' in '발생합니다.즉,'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,578 >> Unable to find text: '##죠' in '되죠.불면증은'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,579 >> Unable to find text: '##합니다 . 즉 , 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다 .' in '발생합니다.즉, 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,579 >> Unable to find text: '##죠 .' in '되죠.불면증은'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,579 >> Unable to find text: '##죠 . 불면증은 근본적으로 수면과 각성을 조절하는 뇌 신경계의 기능이상으로 발생합니다 .' in '되죠.불면증은 근본적으로 수면과 각성을 조절하는 뇌 신경계의 기능이상으로 발생합니다.즉,'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,580 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,581 >> Unable to find text: '##니다 . MRI는 볼 수 있을 것으로 생각되나 보험 문제가 있을 수 있습니다 .' in '없습니다.MRI는 볼 수 있을 것으로 생각되나 보험 문제가 있을 수 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,581 >> Unable to find text: '##니다 .' in '없습니다.MRI는'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,582 >> Unable to find text: '##합니다' in '발생합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,583 >> Unable to find text: '##합니다 . 즉 , 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다' in '발생합니다. 즉, 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,583 >> Unable to find text: '##입니다' in '의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,583 >> Unable to find text: '##합니다' in '발생합니다.규칙적인'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,584 >> Unable to find text: '##합니다 .' in '발생합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,584 >> Unable to find text: '##합니다 . 즉 , 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다 .' in '발생합니다. 즉, 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,584 >> Unable to find text: '##입니다 .' in '의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,586 >> Unable to find text: '##입니다 . 내과 검사에서 이상이 없다면 공황장애 일 가능성 높아 보입니다 .' in '송슬기입니다. 내과 검사에서 이상이 없다면 공황장애 일 가능성 높아 보입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,586 >> Unable to find text: '##에서 이상이 없다면 공황장애 일 가능성 높아 보입니다 .' in '검사에서 이상이 없다면 공황장애 일 가능성 높아 보입니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,590 >> Length not equal after stripping spaces: '있습니다.즉, 1)완벽주의적강박양상 2)' vs '있습니다.즉,1)완벽주의적강박양상2)'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,590 >> Length not equal after stripping spaces: '1)완벽주의적강박양상 2)' vs '1)완벽주의적강박양상2)'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,590 >> Unable to find text: '##니다' in '하겠습니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,590 >> Length not equal after stripping spaces: '드리자면,두가지의요소가같이있습니다.즉, 1)완벽주의적강박양상 2)' vs '드리자면,두가지의요소가같이있습니다.즉,1)완벽주의적강박양상2)'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,590 >> Length not equal after stripping spaces: '완벽주의적강박양상 2)' vs '완벽주의적강박양상2)'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,591 >> Unable to find text: '##니다 . 내가 살고 봐야지 . . . ^ ^ ; ; ; 내가 살아 있어야 세상도 있는 것이지요' in '하겠습니다. 내가 살고 봐야지...^^;;; 내가 살아 있어야 세상도 있는 것이지요.템포를'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,593 >> Length not equal after stripping spaces: '또한,구취및가래의증상은역류성식도염의증상일수있으므로내시경적확인이도움이되겠습니다. ' vs '또한,구취및가래의증상은역류성식도염의증상일수있으므로내시경적확인이도움이되겠습니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,593 >> Length not equal after stripping spaces: '또한,구취및가래의증상은역류성식도염의증상일수있으므로내시경적확인이도움이되겠습니다. ' vs '또한,구취및가래의증상은역류성식도염의증상일수있으므로내시경적확인이도움이되겠습니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,593 >> Length not equal after stripping spaces: '구취및가래의증상은역류성식도염의증상일수있으므로내시경적확인이도움이되겠습니다. ' vs '구취및가래의증상은역류성식도염의증상일수있으므로내시경적확인이도움이되겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,593 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,594 >> Length not equal after stripping spaces: '오심,구역,소화불량, 복부팽만은 가벼운위염부터심한위궤양등다양한질병에서보일수있습니다.' vs '오심,구역,소화불량,복부팽만은가벼운위염부터심한위궤양등다양한질병에서보일수있습니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,594 >> Length not equal after stripping spaces: '의뢰인의나이 및증상의기간과중증도를 감안하면크게중한병으로판단되지는않습니다.' vs '의뢰인의나이및증상의기간과중증도를감안하면크게중한병으로판단되지는않습니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,594 >> Length not equal after stripping spaces: '구취및가래의증상은역류성식도염의증상일수있으므로내시경적확인이도움이되겠습니다. ' vs '구취및가래의증상은역류성식도염의증상일수있으므로내시경적확인이도움이되겠습니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,594 >> Length not equal after stripping spaces: '있겠습니다. 또한,구취및가래의증상은역류성식도염의증상일수있으므로내시경적확인이도움이되겠습니다. ' vs '있겠습니다.또한,구취및가래의증상은역류성식도염의증상일수있으므로내시경적확인이도움이되겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,594 >> Unable to find text: '##니다' in '되겠습니다. '
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,595 >> Unable to find text: '##니다' in '있겠습니다. '
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,595 >> Unable to find text: '##니다 . 내과 전문의와 상의하여 약물 치료 및 검사에 대해 상의하시길 바랍니다' in '되겠습니다.  내과 전문의와 상의하여 약물 치료 및 검사에 대해 상의하시길 바랍니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,595 >> Length not equal after stripping spaces: '하지만의뢰인의나이 및증상의기간과중증도를 감안하면크게중한병으로판단되지는않습니다.' vs '하지만의뢰인의나이및증상의기간과중증도를감안하면크게중한병으로판단되지는않습니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,595 >> Length not equal after stripping spaces: '있겠습니다. ' vs '있겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,595 >> Unable to find text: '##니다 .' in '있겠습니다. '
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,595 >> Unable to find text: '##니다 .' in '되겠습니다. '
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,595 >> Unable to find text: '##니다 . 내과 전문의와 상의하여 약물 치료 및 검사에 대해 상의하시길 바랍니다 .' in '되겠습니다.  내과 전문의와 상의하여 약물 치료 및 검사에 대해 상의하시길 바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,596 >> Unable to find text: '##니다 . 하지만 의뢰인의 나이 및 증상의 기간과 중증도를 감안하면 크게 중한 병으로 판단되지는 않습니다' in '있습니다. 하지만 의뢰인의 나이 및 증상의 기간과 중증도를 감안하면 크게 중한 병으로 판단되지는 않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,596 >> Unable to find text: '##니다 . 내과 전문의와 상의하여 약물 치료 및 검사에 대해 상의하시길 바랍니다 . 감사합니다' in '되겠습니다.  내과 전문의와 상의하여 약물 치료 및 검사에 대해 상의하시길 바랍니다. 감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,596 >> Length not equal after stripping spaces: '의뢰인의나이 및증상의기간과중증도를 감안하면크게중한병으로판단되지는않습니다.' vs '의뢰인의나이및증상의기간과중증도를감안하면크게중한병으로판단되지는않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,596 >> Unable to find text: '##니다 . 내과 전문의와 상의하여 약물 치료 및 검사에 대해 상의하시길 바랍니다 . 감사합니다 .' in '되겠습니다.  내과 전문의와 상의하여 약물 치료 및 검사에 대해 상의하시길 바랍니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,597 >> Unable to find text: '##니다' in '생각됩니다'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,598 >> Unable to find text: '##요 . 최근 스트레스가 심하고 수면시간이 3 - 4시간으로 많이 부족하여 집중력도 떨어지면서 나타나는 증상으로 생각됩니다' in '힘드시겠네요. 최근 스트레스가 심하고 수면시간이 3-4시간으로 많이 부족하여 집중력도 떨어지면서 나타나는 증상으로 생각됩니다'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,598 >> Unable to find text: '##으로 생각됩니다' in '증상으로 생각됩니다'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,600 >> Unable to find text: '##니다' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,600 >> Unable to find text: '##낙스와 자낙스XR의 성분은 같습니다' in '해야합니다.자낙스와 자낙스XR의 성분은 같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,600 >> Unable to find text: '##합니다 . 자낙스와 자낙스XR의 성분은 같습니다' in '해야합니다.자낙스와 자낙스XR의 성분은 같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,602 >> Unable to find text: '##세요 .' in '몰두해보세요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,602 >> Unable to find text: '##니다 . 스마트폰을 멀리하고 일상에 다시 몰두해보세요 .' in '있습니다. 스마트폰을 멀리하고 일상에 다시 몰두해보세요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,603 >> Unable to find text: '##세요 . 그럼에도 불구하고 지속되면 염려증으로 번질 수 있으니 다시 질문주시기 바랍니다' in '몰두해보세요. 그럼에도 불구하고 지속되면 염려증으로 번질 수 있으니 다시 질문주시기 바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,603 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,603 >> Unable to find text: '##합니다' in '한답니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,605 >> Unable to find text: '##니다' in '있습니다.이명은'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,606 >> Unable to find text: '##니다 . 이명은 소리가 전달되는 경로 중 내이에서 뇌 사이의 청각시스템과 관련되어나타날 수 있습니다' in '있습니다.이명은 소리가 전달되는 경로 중 내이에서 뇌 사이의 청각시스템과 관련되어나타날 수 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:38,606 >> Unable to find text: '##니다 .' in '있습니다.이명은'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:38,609 >> Length not equal after stripping spaces: '면담평가및영상학적검사등을통해 치매가아니라면우울증치료를받으시는것이맞습니다.어머니가' vs '면담평가및영상학적검사등을통해치매가아니라면우울증치료를받으시는것이맞습니다.어머니가'
# ...
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:44,283 >> Length not equal after stripping spaces: '빠른쾌유를기원해드립니다. 감사합니다.' vs '빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,283 >> Unable to find text: '##구요 . 빠른 쾌유를 기원해드립니다' in '보시구요. 빠른 쾌유를 기원해드립니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,283 >> Unable to find text: '##구요 . 빠른 쾌유를 기원해드립니다 . 감사합니다' in '보시구요. 빠른 쾌유를 기원해드립니다. 감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:44,283 >> Length not equal after stripping spaces: '기원해드립니다. 감사합니다.' vs '기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,283 >> Unable to find text: '##합니다' in '기원해드립니다. 감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:44,284 >> Length not equal after stripping spaces: '보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,284 >> Unable to find text: '##립니다' in '기원해드립니다. 감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:44,284 >> Length not equal after stripping spaces: '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:44,284 >> Length not equal after stripping spaces: '보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,284 >> Unable to find text: '##립니다 . 감사합니다' in '기원해드립니다. 감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:44,284 >> Length not equal after stripping spaces: '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:44,284 >> Length not equal after stripping spaces: '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:44,285 >> Length not equal after stripping spaces: '빠른쾌유를기원해드립니다. 감사합니다.' vs '빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:44,285 >> Length not equal after stripping spaces: '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,285 >> Unable to find text: '##구요 . 빠른 쾌유를 기원해드립니다 . 감사합니다 .' in '보시구요. 빠른 쾌유를 기원해드립니다. 감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:44,285 >> Length not equal after stripping spaces: '기원해드립니다. 감사합니다.' vs '기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:44,285 >> Length not equal after stripping spaces: '기원해드립니다. 감사합니다.' vs '기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,285 >> Unable to find text: '##합니다 .' in '기원해드립니다. 감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:44,286 >> Length not equal after stripping spaces: '보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,286 >> Unable to find text: '##립니다 . 감사합니다 .' in '기원해드립니다. 감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:44,286 >> Length not equal after stripping spaces: '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:44,286 >> Length not equal after stripping spaces: '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,286 >> Unable to find text: '##구요 . 빠른 쾌유를 기원해드립니다 .' in '보시구요. 빠른 쾌유를 기원해드립니다. 감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:44,286 >> Length not equal after stripping spaces: '입니다. 물론극도의스트레스로인해서도그럴수있지만공황장애의가능성도생각해보셔야합니다.그외' vs '입니다.물론극도의스트레스로인해서도그럴수있지만공황장애의가능성도생각해보셔야합니다.그외'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,287 >> Unable to find text: '##합니다 .' in '권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,288 >> Unable to find text: '##를 권유합니다 .' in '받아보시기를 권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,288 >> Unable to find text: '##합니다' in '권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,288 >> Unable to find text: '##입니다 . 현재' in '한재병입니다. 현재'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,289 >> Unable to find text: '##를 권유합니다' in '받아보시기를 권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,291 >> Unable to find text: '##합니다' in '차지합니다.가까운'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,291 >> Unable to find text: '##니다 . 오히려 면담 중 임상적인 판단이 설문지보다 훨씬 중요한 요소를 차지합니다' in '없습니다. 오히려 면담 중 임상적인 판단이 설문지보다 훨씬 중요한 요소를 차지합니다.가까운'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,291 >> Unable to find text: '##니다' in '생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,292 >> Unable to find text: '##합니다 . 가까운 정신건강의학과 전문의를 찾아 내원하여 상담하시고 , 도움을 받으시기 바랍니다' in '차지합니다.가까운 정신건강의학과 전문의를 찾아 내원하여 상담하시고, 도움을 받으시기 바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,292 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,295 >> Unable to find text: '##입니다 . 매일 약하게라도 불안감이 올라오는거라면 렉사프로 이외의 다른 약물로 변경이 필요해보입니다' in '것입니다. 매일 약하게라도 불안감이 올라오는거라면 렉사프로 이외의 다른 약물로 변경이 필요해보입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,296 >> Unable to find text: '##입니다' in '것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,296 >> Unable to find text: '##입니다 .' in '것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,296 >> Unable to find text: '##입니다 . 매일 약하게라도 불안감이 올라오는거라면 렉사프로 이외의 다른 약물로 변경이 필요해보입니다 .' in '것입니다. 매일 약하게라도 불안감이 올라오는거라면 렉사프로 이외의 다른 약물로 변경이 필요해보입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,297 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,298 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,298 >> Unable to find text: '##입니다' in '김정호입니다.이비인후과에서'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,298 >> Unable to find text: '##입니다 . 이비인후과에서 받으셨던 약이 무엇인지 알고 싶습니다' in '김정호입니다.이비인후과에서 받으셨던 약이 무엇인지 알고 싶습니다가래약이라'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,298 >> Unable to find text: '##약이라 하셨는데 , 알러지나 콧물' in '싶습니다가래약이라 하셨는데, 알러지나 콧물'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,300 >> Unable to find text: '##합니다' in '발생합니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,300 >> Unable to find text: '##합니다 . 만약 불면증이 며칠밖에 되지 않았다면 좀 더 지켜보아도 괜찮습니다' in '발생합니다.만약 불면증이 며칠밖에 되지 않았다면 좀 더 지켜보아도 괜찮습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,301 >> Unable to find text: '##합니다 .' in '발생합니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,302 >> Unable to find text: '##니다 .' in '없었습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,302 >> Unable to find text: '##니다' in '없었습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,303 >> Unable to find text: '##니다 . 감사합니다' in '없었습니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,303 >> Unable to find text: '##합니다' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,303 >> Unable to find text: '##니다 . 감사합니다 .' in '없었습니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,303 >> Unable to find text: '##합니다 .' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,303 >> Unable to find text: '##니다 .' in '편입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,305 >> Unable to find text: '##니다' in '있습니다'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,305 >> Unable to find text: '##습니다' in '있습니다'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,306 >> Unable to find text: '##입니다 . 함께' in '홍인표입니다. 함께'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,306 >> Unable to find text: '##표입니다 . 함께' in '홍인표입니다. 함께'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,310 >> Unable to find text: '##요' in '하고요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,310 >> Unable to find text: '##요 .' in '하고요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,310 >> Unable to find text: '##죠 . 그것이 축적되면 , 마치 일기장처럼 , 자신을 돌아볼 때에 도움이 되기도 하고요' in '것이죠.그것이 축적되면, 마치 일기장처럼, 자신을 돌아볼 때에 도움이 되기도 하고요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,311 >> Unable to find text: '##죠 . 그것이 축적되면 , 마치 일기장처럼 , 자신을 돌아볼 때에 도움이 되기도 하고요 .' in '것이죠.그것이 축적되면, 마치 일기장처럼, 자신을 돌아볼 때에 도움이 되기도 하고요.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,314 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,315 >> Unable to find text: '##니다 . 대개 1주일에 한 차례씩 정신과 전문의 선생님들이 무료로 상담을 해주십니다' in '있습니다. 대개 1주일에 한 차례씩 정신과 전문의 선생님들이 무료로 상담을 해주십니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,315 >> Unable to find text: '##십니다' in '해주십니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,317 >> Unable to find text: '##집니다' in '여겨집니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,317 >> Unable to find text: '##집니다 . 치료 초반이시라면 아직 주치의 선생님과 상의해서 조절해 볼 여지가 많을 것 같습니다' in '여겨집니다. 치료 초반이시라면 아직 주치의 선생님과 상의해서 조절해 볼 여지가 많을 것 같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,317 >> Unable to find text: '##니다' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,317 >> Unable to find text: '##집니다 .' in '여겨집니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,318 >> Unable to find text: '##집니다 . 치료 초반이시라면 아직 주치의 선생님과 상의해서 조절해 볼 여지가 많을 것 같습니다 .' in '여겨집니다. 치료 초반이시라면 아직 주치의 선생님과 상의해서 조절해 볼 여지가 많을 것 같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,318 >> Unable to find text: '##니다 .' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,318 >> Unable to find text: '##니다 .' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,319 >> Unable to find text: '##니다' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,319 >> Unable to find text: '##니다 . 조금이나마 도움이 되는 답변이였으면 좋겠습니다' in '같습니다. 조금이나마 도움이 되는 답변이였으면 좋겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,320 >> Unable to find text: '##합니다' in '정확합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,320 >> Unable to find text: '##합니다 . 증상이 지속된다면 가까운 영상의학과나 병원에서 검사를 하는 것이 좋습니다' in '정확합니다. 증상이 지속된다면 가까운 영상의학과나 병원에서 검사를 하는 것이 좋습니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,320 >> Unable to find text: '##니다' in '좋습니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,321 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,322 >> Unable to find text: '##합니다 . 증상이 지속된다면 가까운 영상의학과나 병원에서 검사를 하는 것이 좋습니다 .' in '정확합니다. 증상이 지속된다면 가까운 영상의학과나 병원에서 검사를 하는 것이 좋습니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,322 >> Unable to find text: '##니다 .' in '좋습니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,322 >> Unable to find text: '##니다 . MRI나 CT 검사 상 이상이 없다면 신경정신과 전문병원이나 한의원을 찾아보시는 것을 권합니다 . 감사합니다' in '있습니다. MRI나 CT 검사 상 이상이 없다면 신경정신과 전문병원이나 한의원을 찾아보시는 것을 권합니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,380 >> Unable to find text: '##니다 . MRI나 CT 검사 상 이상이 없다면 신경정신과 전문병원이나 한의원을 찾아보시는 것을 권합니다' in '있습니다. MRI나 CT 검사 상 이상이 없다면 신경정신과 전문병원이나 한의원을 찾아보시는 것을 권합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,384 >> Unable to find text: '##니다' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,386 >> Unable to find text: '##니다 . 증상 지속시 신경과 외래에 방문하셔서 상담하시기 바랍니다 .' in '있습니다.증상 지속시 신경과 외래에 방문하셔서 상담하시기 바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,386 >> Unable to find text: '##합니다' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,387 >> Unable to find text: '##니다 . 증상 지속시 신경과 외래에 방문하셔서 상담하시기 바랍니다 . 감사합니다' in '있습니다.증상 지속시 신경과 외래에 방문하셔서 상담하시기 바랍니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,388 >> Unable to find text: '##입니다' in '증거입니다.요즘'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,389 >> Unable to find text: '##다 .' in '없다..즉'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,389 >> Unable to find text: '##다 . . 즉 심리적인 요인이 많다는 간접 증거입니다' in '없다..즉 심리적인 요인이 많다는 간접 증거입니다.요즘'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,389 >> Unable to find text: '##니다 . 좋아졌다 나빠졌다 한다는 얘기는 기질적인 문제가 없다 .' in '않습니다.좋아졌다 나빠졌다 한다는 얘기는 기질적인 문제가 없다..즉'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,390 >> Unable to find text: '##니다 . 좋아졌다 나빠졌다 한다는 얘기는 기질적인 문제가 없다 . . 즉 심리적인 요인이 많다는 간접 증거입니다' in '않습니다.좋아졌다 나빠졌다 한다는 얘기는 기질적인 문제가 없다..즉 심리적인 요인이 많다는 간접 증거입니다.요즘'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,390 >> Unable to find text: '##라면 증상이 저절로 좋아졌다 나빠졌다 하지 않습니다 . 좋아졌다 나빠졌다 한다는 얘기는 기질적인 문제가 없다 .' in '것이라면 증상이 저절로 좋아졌다 나빠졌다 하지 않습니다.좋아졌다 나빠졌다 한다는 얘기는 기질적인 문제가 없다..즉'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,393 >> Unable to find text: '##니다' in '있겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,394 >> Unable to find text: '##니다' in '있습니다.이러한'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,397 >> Unable to find text: '[UNK] 바로 잠이 든다면 아직은 큰 문제는 아닌 것으로 보입니다 .' in '입니다.깼다가 바로 잠이 든다면 아직은 큰 문제는 아닌 것으로 보입니다.다만'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,397 >> Unable to find text: '##합니다' in '발생합니다.즉,'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,398 >> Unable to find text: '[UNK] 바로 잠이 든다면 아직은 큰 문제는 아닌 것으로 보입니다' in '입니다.깼다가 바로 잠이 든다면 아직은 큰 문제는 아닌 것으로 보입니다.다만'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,398 >> Unable to find text: '[UNK]' in '입니다.깼다가'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,398 >> Unable to find text: '##합니다 . 즉 , 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다' in '발생합니다.즉, 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,398 >> Unable to find text: '##합니다' in '발생합니다.규칙적인'
# [INFO|squad_metrics.py:314] 2023-06-04 16:58:44,398 >> Length not equal after stripping spaces: '되고, 불면증이나기면증과같은수면장애와함께우울증,만성피로,기억력저하등이함께발생합니다.규칙적인' vs '되고,불면증이나기면증과같은수면장애와함께우울증,만성피로,기억력저하등이함께발생합니다.규칙적인'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,399 >> Unable to find text: '##입니다 .' in '방법입니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,399 >> Unable to find text: '##입니다' in '의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,402 >> Unable to find text: '##합니다' in '곤란합니다.걱정이'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,403 >> Unable to find text: '##니다 . 1년에 2 - 3회 증상이 있으면 적극적인 치료가 곤란합니다' in '있습니다. 1년에 2-3회 증상이 있으면 적극적인 치료가 곤란합니다.걱정이'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,404 >> Unable to find text: '##합니다 . 걱정이 되시는 부분에 대한 검사는 대학병원 신경과가 적당합니다' in '곤란합니다.걱정이 되시는 부분에 대한 검사는 대학병원 신경과가 적당합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,404 >> Unable to find text: '##합니다' in '적당합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,405 >> Unable to find text: '##합니다 . 걱정이 되시는 부분에 대한 검사는 대학병원 신경과가 적당합니다 .' in '곤란합니다.걱정이 되시는 부분에 대한 검사는 대학병원 신경과가 적당합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,405 >> Unable to find text: '##합니다 .' in '적당합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,406 >> Unable to find text: '##합니다 .' in '곤란합니다.걱정이'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,406 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,407 >> Unable to find text: '##합니다 .' in '권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,408 >> Unable to find text: '##합니다' in '권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,409 >> Unable to find text: '##합니다 .' in '분인듯합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,409 >> Unable to find text: '##입니다 . 불안장애가 있으신 분인듯합니다 .' in '한재병입니다. 불안장애가 있으신 분인듯합니다.'
# [INFO|squad_metrics.py:305] 2023-06-04 16:58:44,409 >> Unable to find text: '##듯합니다 .' in '분인듯합니다.'
# 06/04/2023 16:58:45 - INFO - __main__ - Results: {'exact_1000': 7.697974217311234, 'f1_1000': 38.29825463607087, 'total_1000': 2715, 'HasAns_exact_1000': 7.697974217311234, 'HasAns_f1_1000': 38.29825463607087, 'HasAns_total_1000': 2715, 'best_exact_1000': 7.697974217311234, 'best_exact_thresh_1000': 0.0, 'best_f1_1000': 38.29825463607087, 'best_f1_thresh_1000': 0.0, 'exact_2000': 9.465930018416206, 'f1_2000': 37.252697220988146, 'total_2000': 2715, 'HasAns_exact_2000': 9.465930018416206, 'HasAns_f1_2000': 37.252697220988146, 'HasAns_total_2000': 2715, 'best_exact_2000': 9.465930018416206, 'best_exact_thresh_2000': 0.0, 'best_f1_2000': 37.252697220988146, 'best_f1_thresh_2000': 0.0, 'exact_KMQA': 9.576427255985267, 'f1_KMQA': 35.881495079092005, 'total_KMQA': 2715, 'HasAns_exact_KMQA': 9.576427255985267, 'HasAns_f1_KMQA': 35.881495079092005, 'HasAns_total_KMQA': 2715, 'best_exact_KMQA': 9.576427255985267, 'best_exact_thresh_KMQA': 0.0, 'best_f1_KMQA': 35.881495079092005, 'best_f1_thresh_KMQA': 0.0}

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## 경로 변경

# %%
import os
os.chdir('/content/drive/MyDrive/korquad/')
os.getcwd()
# Out:
# '/content/drive/MyDrive/korquad'

# %%
from __future__ import print_function
from collections import Counter
import string
import re
import argparse
import json
import sys
import os

import pandas as pd
from transformers import AutoTokenizer

'''KorQuAD v1.0에 대한 공식 평가 스크립트 '''
'''본 스크립트는 SQuAD v1.1 평가 스크립트 https://rajpurkar.github.io/SQuAD-explorer/ 를 바탕으로 작성됨.'''

def normalize_answer(s):    
    def remove_(text):
        ''' 불필요한 기호 제거 '''
        text = re.sub("'", " ", text)
        text = re.sub('"', " ", text)
        text = re.sub('《', " ", text)
        text = re.sub('》', " ", text)
        text = re.sub('<', " ", text)
        text = re.sub('>', " ", text) 
        text = re.sub('〈', " ", text)
        text = re.sub('〉', " ", text)   
        text = re.sub("\(", " ", text)
        text = re.sub("\)", " ", text)
        text = re.sub("‘", " ", text)
        text = re.sub("’", " ", text)      
        return text

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return ''.join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_punc(lower(remove_(s))))


def f1_score(prediction, ground_truth):
    prediction_tokens = normalize_answer(prediction).split()
    ground_truth_tokens = normalize_answer(ground_truth).split()
   
    #F1 by character
    prediction_Char = []
    for tok in prediction_tokens:
        now = [a for a in tok]
        prediction_Char.extend(now)
        
    ground_truth_Char = []
    for tok in ground_truth_tokens:
        now = [a for a in tok]
        ground_truth_Char.extend(now)   
        
    common = Counter(prediction_Char) & Counter(ground_truth_Char)
    num_same = sum(common.values())
    if num_same == 0:
        return 0
    
    precision = 1.0 * num_same / len(prediction_Char)
    recall = 1.0 * num_same / len(ground_truth_Char)
    f1 = (2 * precision * recall) / (precision + recall)
    
    return f1


def exact_match_score(prediction, ground_truth):
    return (normalize_answer(prediction) == normalize_answer(ground_truth))


def metric_max_over_ground_truths(metric_fn, prediction, ground_truths):
    scores_for_ground_truths = []
    for ground_truth in ground_truths:
        score = metric_fn(prediction, ground_truth)
        scores_for_ground_truths.append(score)
    return max(scores_for_ground_truths)


def evaluate(dataset, predictions):
    f1 = exact_match = total = 0
    for article in dataset:
        for paragraph in article['paragraphs']:
            for qa in paragraph['qas']:
                total += 1
                if qa['id'] not in predictions:
                    message = 'Unanswered question ' + qa['id'] + \
                              ' will receive score 0.'
                    print(message, file=sys.stderr)
                    continue
                ground_truths = list(map(lambda x: x['text'], qa['answers']))
                prediction = predictions[qa['id']]
                exact_match += metric_max_over_ground_truths(
                    exact_match_score, prediction, ground_truths)
                f1 += metric_max_over_ground_truths(
                    f1_score, prediction, ground_truths)

    exact_match = 100.0 * exact_match / total
    f1 = 100.0 * f1 / total
    return {'exact_match': exact_match, 'f1': f1}


def evaluate_result(dataset_file, prediction_file):
    
    with open(dataset_file, encoding="utf-8") as f:
        dataset_json = json.load(f)
        dataset = dataset_json['data']
    with open(prediction_file, encoding="utf-8") as f:
        predictions = json.load(f)
    return evaluate(dataset, predictions)

# %% [markdown]
# ## 성능 확인

# %%
dataset_file = './data/KMQA_dev_v5.1.json'
prediction_file = './klue_roberta-KMQA/predictions_KMQA.json'
evaluate_result(dataset_file, prediction_file)
# Out:
# {'exact_match': 9.541284403669724, 'f1': 41.717264452369164}
