# %%
# !pip3 install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.1-py3-none-any.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 40.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.2-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 71.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.2 tokenizers-0.13.2 transformers-4.27.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/korquad/')
os.getcwd()
# Out:
# '/content/drive/MyDrive/korquad'

# %%
# !python ./run_QA.py \
    --model_type roberta \
    --model_name_or_path klue/roberta-large \
    --output_dir klue_roberta-KorQuAD \
    --data_dir data \
    --data_name KorQuAD \
    --train_file KorQuAD_v1.0_train.json \
    --predict_file KorQuAD_v1.0_dev.json \
    --max_seq_length 512 \
    --doc_stride 128 \
    --max_query_length 64 \
    --do_train \
    --do_eval \
    --evaluate_during_training \
    --per_gpu_train_batch_size=4 \
    --per_gpu_eval_batch_size=4 \
    --learning_rate 5e-5 \
    --gradient_accumulation_steps 1 \
    --weight_decay 0.0 \
    --adam_epsilon 1e-8 \
    --max_grad_norm 1.0 \
    --num_train_epochs 3 \
    --max_steps -1 \
    --warmup_steps 0 \
    --n_best_size 20 \
    --max_answer_length 30 \
    --verbose_logging \
    --logging_steps 1000 \
    --save_steps 1000 \
    --eval_all_checkpoints \
    --overwrite_output_dir \
    --seed 42 \
    --local_rank -1 \
    --threads 4
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,085 >> Unable to find text: '##정우회 주도로' in '유신정우회 주도로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,085 >> Unable to find text: '##우회 주도로 '' in '유신정우회 주도로 '(김영삼이)'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,087 >> Unable to find text: '##는 음모' in '조장하려는 음모라며'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,087 >> Unable to find text: '##려는 음모' in '조장하려는 음모라며'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,089 >> Unable to find text: '##은 ' 미국' in '김영삼은 '미국이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,091 >> Unable to find text: '##의 국회의원직' in '김영삼의 국회의원직을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,091 >> Unable to find text: '##이 ) 국회의원' in ''(김영삼이) 국회의원으로서'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,092 >> Unable to find text: '##하면 박정희' in '제명하면 박정희는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,093 >> Unable to find text: '##하면 박정희는' in '제명하면 박정희는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,093 >> Unable to find text: '##는' in '박정희는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,094 >> Unable to find text: '##지' in '뉴욕타임스지를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,094 >> Unable to find text: '##타임스지' in '뉴욕타임스지를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,094 >> Unable to find text: '##스지' in '뉴욕타임스지를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,094 >> Unable to find text: '##자 뉴욕 타임스' in '16일자 뉴욕 타임스에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,095 >> Unable to find text: '##지를' in '뉴욕타임스지를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,095 >> Unable to find text: '##타임스지를' in '뉴욕타임스지를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,095 >> Unable to find text: '##스지를' in '뉴욕타임스지를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,095 >> Unable to find text: '##지를 통해' in '뉴욕타임스지를 통해'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,095 >> Unable to find text: '##타임' in '뉴욕타임스지를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,095 >> Unable to find text: '##타임스지를 통해' in '뉴욕타임스지를 통해'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,095 >> Unable to find text: '##스지를 통해' in '뉴욕타임스지를 통해'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,095 >> Unable to find text: '##타임스' in '뉴욕타임스지를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,095 >> Unable to find text: '##스' in '뉴욕타임스지를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,095 >> Unable to find text: '##자 뉴욕 타임스에' in '16일자 뉴욕 타임스에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,095 >> Unable to find text: '##자 뉴욕' in '16일자 뉴욕'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,096 >> Unable to find text: '##당' in '공화당에서는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,097 >> Unable to find text: '##당에서' in '공화당에서는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,097 >> Unable to find text: '##당에서는' in '공화당에서는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,097 >> Unable to find text: '##에서' in '공화당에서는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,097 >> Unable to find text: '##에서는' in '공화당에서는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,097 >> Unable to find text: '##는' in '공화당에서는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,097 >> Unable to find text: '##당' in '신민당'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,097 >> Unable to find text: '##당에서는 그의 이 발언을 외세를 등에 업고' in '공화당에서는 그의 이 발언을 외세를 등에 업고'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,139 >> Unable to find text: '##당에서는 그의 이 발언을 외세를 등에 업고 사회분란과 내란' in '공화당에서는 그의 이 발언을 외세를 등에 업고 사회분란과 내란을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,139 >> Unable to find text: '##당에서는 그의 이 발언을 외세를 등에 업고 사회분란과 내란을 조장하려는 음모라며 공격' in '공화당에서는 그의 이 발언을 외세를 등에 업고 사회분란과 내란을 조장하려는 음모라며 공격을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,141 >> Unable to find text: '##학교' in '부산대학교'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,143 >> Unable to find text: '##학교 학생들에 의해 민주선언문이 배포되고 , 다음 날인 10월 16일에는 다른 대학교' in '부산대학교 학생들에 의해 민주선언문이 배포되고, 다음 날인 10월 16일에는 다른 대학교의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,145 >> Unable to find text: '##시위' in '반정부시위가'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,147 >> Unable to find text: '##은 상도동 자택에서 부산' in '김영삼은 상도동 자택에서 부산에서'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,148 >> Unable to find text: '##동 자택에서 부산' in '상도동 자택에서 부산에서'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,148 >> Unable to find text: '##은 상도동 자택' in '김영삼은 상도동 자택에서'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,148 >> Unable to find text: '##에서 부산' in '자택에서 부산에서'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,149 >> Unable to find text: '##학교' in '부산대학교'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,150 >> Unable to find text: '##일 부산대학교' in '15일 부산대학교'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,150 >> Unable to find text: '##학교 학생' in '부산대학교 학생들에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,150 >> Unable to find text: '##학교 학생들' in '부산대학교 학생들에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,150 >> Unable to find text: '##학교 학생들에 의해 민주선언문이 배포되고 , 다음 날인 10월 16일에는 다른 대학교' in '부산대학교 학생들에 의해 민주선언문이 배포되고, 다음 날인 10월 16일에는 다른 대학교의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,151 >> Unable to find text: '##학교 학생들에' in '부산대학교 학생들에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,151 >> Unable to find text: '##학교 학생들에 의해' in '부산대학교 학생들에 의해'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,151 >> Unable to find text: '##일 부산대' in '15일 부산대학교'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,151 >> Unable to find text: '##학교 학생들에 의해 민주선언문이' in '부산대학교 학생들에 의해 민주선언문이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,151 >> Unable to find text: '##학교 학생들에 의해 민주선언문' in '부산대학교 학생들에 의해 민주선언문이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,151 >> Unable to find text: '##학교 학생들에 의해 민주선언문이 배포' in '부산대학교 학생들에 의해 민주선언문이 배포되고,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,152 >> Unable to find text: '##시 및 창원시' in '마산시 및 창원시'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,152 >> Unable to find text: '##는 경상남도 마산시 및 창원시' in '19일에는 경상남도 마산시 및 창원시'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,153 >> Unable to find text: '##시 및 창원시 지역' in '마산시 및 창원시 지역으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,154 >> Unable to find text: '##은 부마 항쟁' in '제명은 부마 항쟁을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,156 >> Unable to find text: '##학교' in '부산대학교'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,157 >> Unable to find text: '##일 부산대학교' in '15일 부산대학교'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,158 >> Unable to find text: '##학교 학생들에 의해 민주선언문이 배포되고 , 다음 날인 10월 16일에는 다른 대학교' in '부산대학교 학생들에 의해 민주선언문이 배포되고, 다음 날인 10월 16일에는 다른 대학교의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,158 >> Unable to find text: '##학교 학생' in '부산대학교 학생들에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,158 >> Unable to find text: '##학교 학생들에 의해 민주선언문이 배포되고 , 다음 날인 10월 16일에는 다른 대학교의' in '부산대학교 학생들에 의해 민주선언문이 배포되고, 다음 날인 10월 16일에는 다른 대학교의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,158 >> Unable to find text: '##학교 학생들' in '부산대학교 학생들에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,158 >> Unable to find text: '##학교 학생들에 의해 민주선언문이 배포되고 , 다음 날인 10월 16일에는 다른' in '부산대학교 학생들에 의해 민주선언문이 배포되고, 다음 날인 10월 16일에는 다른'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,160 >> Unable to find text: '##고 부마 사태 소식을 접하였다 . 김영삼의 제명은 부마 항쟁' in '받고 부마 사태 소식을 접하였다. 김영삼의 제명은 부마 항쟁을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,160 >> Unable to find text: '##은 부마 항쟁' in '제명은 부마 항쟁을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,160 >> Unable to find text: '##을 접하였다 . 김영삼의 제명은 부마 항쟁' in '소식을 접하였다. 김영삼의 제명은 부마 항쟁을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,163 >> Unable to find text: '##는 김대중' in '총재는 김대중에게'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,164 >> Unable to find text: '##는 김대중에게 주며 , 4년 후에 가서 경선을 하자고 권유하였다 . 그러나 김영삼' in '총재는 김대중에게 주며, 4년 후에 가서 경선을 하자고 권유하였다. 그러나 김영삼은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,164 >> Unable to find text: '##는 김대중에게' in '총재는 김대중에게'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,165 >> Unable to find text: '##는 김대중에' in '총재는 김대중에게'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,165 >> Unable to find text: '##용' in '강원용의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,167 >> Unable to find text: '##용의' in '강원용의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,167 >> Unable to find text: '##의' in '강원용의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,167 >> Unable to find text: '##용의 연락을 받고 다음날 12월 13일 아침 남산에 있는 식당에서 면담하였다 . 김대중 , 김종필' in '강원용의 연락을 받고 다음날 12월 13일 아침 남산에 있는 식당에서 면담하였다. 김대중, 김종필과'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,168 >> Unable to find text: '##는 민주주의' in '"우리는 민주주의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,169 >> Unable to find text: '##은 " 우리는 민주주의' in '김영삼은 "우리는 민주주의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,171 >> Unable to find text: '##선은 다시 중재에 섰다 . 4월 7일 윤보선' in '윤보선은 다시 중재에 섰다. 4월 7일 윤보선의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,172 >> Unable to find text: '##선' in '윤보선의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,173 >> Unable to find text: '##봉길 생가' in '윤봉길 생가를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,173 >> Unable to find text: '##길 생가' in '윤봉길 생가를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,174 >> Unable to find text: '##당 내 동교동 의원들을 데리고 현충사 부근 윤봉길 생가' in '신민당 내 동교동 의원들을 데리고 현충사 부근 윤봉길 생가를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,174 >> Unable to find text: '##교동 의원들을 데리고 현충사 부근 윤봉길 생가' in '동교동 의원들을 데리고 현충사 부근 윤봉길 생가를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,174 >> Unable to find text: '##고 현충사 부근 윤봉길 생가' in '데리고 현충사 부근 윤봉길 생가를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,176 >> Unable to find text: '##당' in '신민당에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,176 >> Unable to find text: '##이 신민당' in '김대중이 신민당에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,176 >> Unable to find text: '##는 김대중이 신민당' in '그는 김대중이 신민당에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,176 >> Unable to find text: '##당에' in '신민당에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,176 >> Unable to find text: '##당에 입당해야 한다고 주장하였다 . 4월 7일 김대중은 신민당' in '신민당에 입당해야 한다고 주장하였다. 4월 7일 김대중은 신민당'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,177 >> Unable to find text: '##에' in '신민당에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,177 >> Unable to find text: '##당에 입당' in '신민당에 입당해야'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,177 >> Unable to find text: '##이 신민' in '김대중이 신민당에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,177 >> Unable to find text: '##당에 입당해야 한다고' in '신민당에 입당해야 한다고'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,177 >> Unable to find text: '##이 신민당에' in '김대중이 신민당에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,177 >> Unable to find text: '##에 입당해야 한다고 주장하였다 . 4월 7일 김대중은 신민당' in '신민당에 입당해야 한다고 주장하였다. 4월 7일 김대중은 신민당'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,177 >> Unable to find text: '##당에 입당해야' in '신민당에 입당해야'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,177 >> Unable to find text: '##에 입당' in '신민당에 입당해야'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,178 >> Unable to find text: '##이 신민당에 입당해야 한다고 주장하였다 . 4월 7일 김대중은 신민당' in '김대중이 신민당에 입당해야 한다고 주장하였다. 4월 7일 김대중은 신민당'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,178 >> Unable to find text: '##에 입당해야 한다고' in '신민당에 입당해야 한다고'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,178 >> Unable to find text: '##당에 입당해야 한다고 주장하였다 . 4월 7일 김대중은 신민' in '신민당에 입당해야 한다고 주장하였다. 4월 7일 김대중은 신민당'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,178 >> Unable to find text: '##는 김대중이 신민' in '그는 김대중이 신민당에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,178 >> Unable to find text: '##당' in '신민당'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,179 >> Unable to find text: '##이 신민당에 입당' in '김대중이 신민당에 입당해야'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,180 >> Unable to find text: '##선' in '윤보선은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,180 >> Unable to find text: '##보선' in '윤보선은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,181 >> Unable to find text: '##선은 다시 중재에 섰다 . 4월 7일 윤보선' in '윤보선은 다시 중재에 섰다. 4월 7일 윤보선의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,181 >> Unable to find text: '##선' in '윤보선의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,181 >> Unable to find text: '##보선은 다시 중재에 섰다 . 4월 7일 윤보선' in '윤보선은 다시 중재에 섰다. 4월 7일 윤보선의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,182 >> Unable to find text: '##봉길 생가' in '윤봉길 생가를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,182 >> Unable to find text: '##길 생가' in '윤봉길 생가를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,183 >> Unable to find text: '##사를 참배하자 같은 날 김대중은 신민당 내 동교동 의원들을 데리고 현충사 부근 윤봉길 생가' in '현충사를 참배하자 같은 날 김대중은 신민당 내 동교동 의원들을 데리고 현충사 부근 윤봉길 생가를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,183 >> Unable to find text: '##교동 의원들을 데리고 현충사 부근 윤봉길 생가' in '동교동 의원들을 데리고 현충사 부근 윤봉길 생가를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,183 >> Unable to find text: '##사 부근 윤봉길 생가' in '현충사 부근 윤봉길 생가를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,185 >> Unable to find text: '##선' in '윤보선도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,185 >> Unable to find text: '##선도 단념하고 그해 8월 정계 은퇴를 선언해버린다 . 한편 윤보선' in '윤보선도 단념하고 그해 8월 정계 은퇴를 선언해버린다. 한편 윤보선의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,185 >> Unable to find text: '##선' in '윤보선의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,185 >> Unable to find text: '##보선' in '윤보선도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,185 >> Unable to find text: '##김이 협력하지 않자 윤보선' in '양김이 협력하지 않자 윤보선도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,186 >> Unable to find text: '##보선도 단념하고 그해 8월 정계 은퇴를 선언해버린다 . 한편 윤보선' in '윤보선도 단념하고 그해 8월 정계 은퇴를 선언해버린다. 한편 윤보선의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,186 >> Unable to find text: '##보선' in '윤보선의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,186 >> Unable to find text: '##도 단념하고 그해 8월 정계 은퇴를 선언해버린다 . 한편 윤보선' in '윤보선도 단념하고 그해 8월 정계 은퇴를 선언해버린다. 한편 윤보선의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,186 >> Unable to find text: '##김이 협력하지 않자 윤보선도 단념하고 그해 8월 정계 은퇴를 선언해버린다 . 한편 윤보선' in '양김이 협력하지 않자 윤보선도 단념하고 그해 8월 정계 은퇴를 선언해버린다. 한편 윤보선의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,187 >> Unable to find text: '##사' in '현충사를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,187 >> Unable to find text: '##해 현충사' in '관련해 현충사를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,188 >> Unable to find text: '##일 김영삼이 신민당 당직자와 함께 대권과 관련해 현충사' in '28일 김영삼이 신민당 당직자와 함께 대권과 관련해 현충사를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,188 >> Unable to find text: '##이 신민당 당직자와 함께 대권과 관련해 현충사' in '김영삼이 신민당 당직자와 함께 대권과 관련해 현충사를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,188 >> Unable to find text: '##와 함께 대권과 관련해 현충사' in '당직자와 함께 대권과 관련해 현충사를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,191 >> Unable to find text: '##년 5월 17일 오전 10시' in '1980년 5월 17일 오전 10시,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,191 >> Unable to find text: '##시' in '10시,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,191 >> Unable to find text: '##일 오전 10시' in '17일 오전 10시,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,191 >> Unable to find text: '##월 17일 오전 10시' in '5월 17일 오전 10시,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,193 >> Unable to find text: '##거' in '폭거'라는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,194 >> Unable to find text: '##는 김대중 , 김종필' in '그는 김대중, 김종필'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,196 >> Unable to find text: '##의 쿠데타를 그리 걱정하지 않았고 , 결국 5 · 17 쿠데타' in '신군부의 쿠데타를 그리 걱정하지 않았고, 결국 5·17 쿠데타로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,196 >> Unable to find text: '##부의 쿠데타를 그리 걱정하지 않았고 , 결국 5 · 17 쿠데타' in '신군부의 쿠데타를 그리 걱정하지 않았고, 결국 5·17 쿠데타로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,197 >> Unable to find text: '##거' in '폭거'라는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,198 >> Unable to find text: '##한 5 · 17 폭거' in '배신한 5·17 폭거'라는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,199 >> Unable to find text: '##장 이학봉' in '대공처장 이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,199 >> Unable to find text: '##봉' in '이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,199 >> Unable to find text: '##처장 이학봉' in '대공처장 이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,200 >> Unable to find text: '##사 대공처장 이학봉' in '보안사 대공처장 이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,201 >> Unable to find text: '##회' in '민주산악회는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,202 >> Unable to find text: '##악회' in '민주산악회는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,202 >> Unable to find text: '##산악회' in '민주산악회는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,202 >> Unable to find text: '##한 민주산악회' in '출범한 민주산악회는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,240 >> Unable to find text: '##회' in '민주산악회를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,243 >> Unable to find text: '##장 이학봉' in '대공처장 이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,243 >> Unable to find text: '##봉' in '이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,243 >> Unable to find text: '##처장 이학봉' in '대공처장 이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,243 >> Unable to find text: '##사 대공처장 이학봉' in '보안사 대공처장 이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,243 >> Unable to find text: '##은 보안사 대공처장 이학봉' in '김영삼은 보안사 대공처장 이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,246 >> Unable to find text: '##회' in '민주산악회를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,246 >> Unable to find text: '##악회' in '민주산악회를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,246 >> Unable to find text: '##임을 조직하고 민주산악회' in '등산모임을 조직하고 민주산악회를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,246 >> Unable to find text: '##산악회' in '민주산악회를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,248 >> Unable to find text: '##임' in '등산모임을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,250 >> Unable to find text: '##은 김대중' in '정치인들은 김대중'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,251 >> Unable to find text: '##들은 김대중' in '정치인들은 김대중'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,251 >> Unable to find text: '##은 김대중 계열' in '정치인들은 김대중 계열까지'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,251 >> Unable to find text: '##들은 김대중 계열' in '정치인들은 김대중 계열까지'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,253 >> Unable to find text: '##5공화국' in '제5공화국'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,253 >> Unable to find text: '##공화국' in '제5공화국'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,253 >> Unable to find text: '##5공화국 정권' in '제5공화국 정권에서도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,253 >> Unable to find text: '##공화국 정권' in '제5공화국 정권에서도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,254 >> Unable to find text: '##의 제5공화국' in '전두환의 제5공화국'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,254 >> Unable to find text: '##의 제5공화국 정권' in '전두환의 제5공화국 정권에서도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,254 >> Unable to find text: '##5' in '제5공화국'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,254 >> Unable to find text: '##5공화국 정권에서' in '제5공화국 정권에서도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,254 >> Unable to find text: '##공화국 정권에서' in '제5공화국 정권에서도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,254 >> Unable to find text: '##5공화국 정권에서도' in '제5공화국 정권에서도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,255 >> Unable to find text: '##공화국 정권에서도' in '제5공화국 정권에서도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,255 >> Unable to find text: '##도' in '정권에서도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,255 >> Unable to find text: '##에서' in '정권에서도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,255 >> Unable to find text: '##에서도' in '정권에서도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,255 >> Unable to find text: '##의 제5' in '전두환의 제5공화국'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,255 >> Unable to find text: '##의 제5공화국 정권에서' in '전두환의 제5공화국 정권에서도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,256 >> Unable to find text: '##장 이학봉' in '대공처장 이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,256 >> Unable to find text: '##봉' in '이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,256 >> Unable to find text: '##처장 이학봉' in '대공처장 이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,257 >> Unable to find text: '##장 이학' in '대공처장 이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,257 >> Unable to find text: '##사 대공처장 이학봉' in '보안사 대공처장 이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,257 >> Unable to find text: '##장 이학봉의' in '대공처장 이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,257 >> Unable to find text: '##봉의' in '이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,257 >> Unable to find text: '##장' in '대공처장'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,257 >> Unable to find text: '##의' in '이학봉의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,257 >> Unable to find text: '##장 이학봉의 강요' in '대공처장 이학봉의 강요로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,258 >> Unable to find text: '##임' in '등산모임을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,259 >> Unable to find text: '##모임' in '등산모임을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,259 >> Unable to find text: '[UNK] [UNK] [UNK] ) · 김덕룡 ( 金 德 龍 ) 등 정치활동 규제에 묶여있는 재야 인사들과 함께 등산모임' in '이민우(李敏雨)·김동영(金東英)·최형우(崔炯佑)·김덕룡(金德龍) 등 정치활동 규제에 묶여있는 재야 인사들과 함께 등산모임을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,259 >> Unable to find text: '##룡 ( 金 德 龍 ) 등 정치활동 규제에 묶여있는 재야 인사들과 함께 등산모임' in '이민우(李敏雨)·김동영(金東英)·최형우(崔炯佑)·김덕룡(金德龍) 등 정치활동 규제에 묶여있는 재야 인사들과 함께 등산모임을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,260 >> Unable to find text: '##임을 조직하고 민주산악회' in '등산모임을 조직하고 민주산악회를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,260 >> Unable to find text: '##임을' in '등산모임을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,260 >> Unable to find text: '##모임을 조직하고 민주산악회' in '등산모임을 조직하고 민주산악회를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,260 >> Unable to find text: '##회' in '민주산악회를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,261 >> Unable to find text: '##자유당' in '민주자유당의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,261 >> Unable to find text: '##당' in '민주자유당의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,261 >> Unable to find text: '##당을 창당하였고 , 김영삼은 민주자유당' in '민주자유당을 창당하였고, 김영삼은 민주자유당의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,262 >> Unable to find text: '##자유당을 창당하였고 , 김영삼은 민주자유당' in '민주자유당을 창당하였고, 김영삼은 민주자유당의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,262 >> Unable to find text: '##은 민주자유당' in '김영삼은 민주자유당의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,262 >> Unable to find text: '##자유당의 대표로 취임하였다 . 한편 3당합당으로 민주자유당' in '민주자유당의 대표로 취임하였다. 한편 3당합당으로 민주자유당에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,262 >> Unable to find text: '##당의 대표로 취임하였다 . 한편 3당합당으로 민주자유당' in '민주자유당의 대표로 취임하였다. 한편 3당합당으로 민주자유당에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,262 >> Unable to find text: '##당' in '민주자유당에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,263 >> Unable to find text: '##당을 창당하였고 , 김영삼은 민주자유당의 대표로 취임하였다 . 한편 3당합당으로 민주자유당' in '민주자유당을 창당하였고, 김영삼은 민주자유당의 대표로 취임하였다. 한편 3당합당으로 민주자유당에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,263 >> Unable to find text: '##던 노태우' in '느끼던 노태우'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,264 >> Unable to find text: '##던 노태우 대통령' in '느끼던 노태우 대통령의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,264 >> Unable to find text: '##던 노태우 대통령의' in '느끼던 노태우 대통령의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,264 >> Unable to find text: '##의' in '대통령의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,265 >> Unable to find text: '##대 정국' in '여소야대 정국에서'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,266 >> Unable to find text: '##야대 정국' in '여소야대 정국에서'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,267 >> Unable to find text: '##자유당' in '민주자유당을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,267 >> Unable to find text: '##당' in '민주자유당을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,267 >> Unable to find text: '##하여 민주자유당' in '합당하여 민주자유당을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,268 >> Unable to find text: '##자유당을' in '민주자유당을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,268 >> Unable to find text: '##당을' in '민주자유당을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,268 >> Unable to find text: '##자유' in '민주자유당을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,268 >> Unable to find text: '##을' in '민주자유당을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,268 >> Unable to find text: '##자유당을 창당하였고 , 김영삼은 민주자유당' in '민주자유당을 창당하였고, 김영삼은 민주자유당의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,268 >> Unable to find text: '##하여 민주자유당을' in '합당하여 민주자유당을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,268 >> Unable to find text: '##당을 창당하였고 , 김영삼은 민주자유당' in '민주자유당을 창당하였고, 김영삼은 민주자유당의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,268 >> Unable to find text: '##자유당을 창당하였고 , 김영삼은 민주자유당의 대표로 취임하였다 . 한편 3당합당으로 민주자유당' in '민주자유당을 창당하였고, 김영삼은 민주자유당의 대표로 취임하였다. 한편 3당합당으로 민주자유당에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,269 >> Unable to find text: '##자유당을 창당' in '민주자유당을 창당하였고,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,270 >> Unable to find text: '##자' in '출신자들은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,270 >> Unable to find text: '##정권 출신자' in '군사정권 출신자들은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,270 >> Unable to find text: '##들' in '출신자들은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,270 >> Unable to find text: '##자들' in '출신자들은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,270 >> Unable to find text: '##정권 출신자들' in '군사정권 출신자들은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,271 >> Unable to find text: '##자유당' in '민주자유당을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,271 >> Unable to find text: '##당' in '민주자유당을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,271 >> Unable to find text: '##하여 민주자유당' in '합당하여 민주자유당을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,272 >> Unable to find text: '##자유당을' in '민주자유당을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,272 >> Unable to find text: '##당을' in '민주자유당을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,272 >> Unable to find text: '##자유' in '민주자유당을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,272 >> Unable to find text: '##자유당을 창당하였고 , 김영삼은 민주자유당' in '민주자유당을 창당하였고, 김영삼은 민주자유당의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,272 >> Unable to find text: '##을' in '민주자유당을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,272 >> Unable to find text: '##자유당을 창당하였고 , 김영삼은 민주자유당의 대표로 취임하였다 . 한편 3당합당으로 민주자유당' in '민주자유당을 창당하였고, 김영삼은 민주자유당의 대표로 취임하였다. 한편 3당합당으로 민주자유당에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,272 >> Unable to find text: '##당을 창당하였고 , 김영삼은 민주자유당' in '민주자유당을 창당하였고, 김영삼은 민주자유당의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,273 >> Unable to find text: '##당을 창당하였고 , 김영삼은 민주자유당의 대표로 취임하였다 . 한편 3당합당으로 민주자유당' in '민주자유당을 창당하였고, 김영삼은 민주자유당의 대표로 취임하였다. 한편 3당합당으로 민주자유당에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,273 >> Unable to find text: '##자유당을 창당' in '민주자유당을 창당하였고,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,273 >> Unable to find text: '##하여 민주자유당을' in '합당하여 민주자유당을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,273 >> Unable to find text: '##자유당을 창당하였고 ,' in '민주자유당을 창당하였고,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,273 >> Unable to find text: '##당을 창당' in '민주자유당을 창당하였고,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,273 >> Unable to find text: '##자유당을 창당하였고 , 김영삼' in '민주자유당을 창당하였고, 김영삼은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,275 >> Unable to find text: '##은' in '김영삼은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,275 >> Unable to find text: '##재의 구속으로 마음을 굳힌 김영삼의 통일민주당 , 그리고 내각제 개헌을 노리고 있던 김종필' in '서석재의 구속으로 마음을 굳힌 김영삼의 통일민주당, 그리고 내각제 개헌을 노리고 있던 김종필의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,275 >> Unable to find text: '##재의 구속으로 마음을 굳힌 김영삼' in '서석재의 구속으로 마음을 굳힌 김영삼의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,276 >> Unable to find text: '##자 마산' in '않자 마산으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,276 >> Unable to find text: '##으로' in '마산으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,276 >> Unable to find text: '##자 마산으로' in '않자 마산으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,277 >> Unable to find text: '##으로 낙향' in '마산으로 낙향해'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,279 >> Unable to find text: '##담' in '단독면담을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,279 >> Unable to find text: '##면담' in '단독면담을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,279 >> Unable to find text: '##게 단독면담' in '대통령에게 단독면담을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,280 >> Unable to find text: '##자 마산' in '않자 마산으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,281 >> Unable to find text: '##담을 요구하였다 . 그러나 노태우 대통령의 반응이 없고 , 사태 해결이 그의 의도대로 진행되지 않자 마산' in '단독면담을 요구하였다. 그러나 노태우 대통령의 반응이 없고, 사태 해결이 그의 의도대로 진행되지 않자 마산으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,281 >> Unable to find text: '##으로' in '마산으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,281 >> Unable to find text: '##자 마산으로' in '않자 마산으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,282 >> Unable to find text: '##담을 요구하였다 . 그러나 노태우 대통령의 반응이 없고 , 사태 해결이 그의 의도대로 진행되지 않자 마산으로' in '단독면담을 요구하였다. 그러나 노태우 대통령의 반응이 없고, 사태 해결이 그의 의도대로 진행되지 않자 마산으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,283 >> Unable to find text: '##원' in '최고위원은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,284 >> Unable to find text: '##원은' in '최고위원은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,284 >> Unable to find text: '##은' in '최고위원은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,285 >> Unable to find text: '##담을 요구하였다 . 그러나 노태우 대통령의 반응이 없고 , 사태 해결이 그의 의도대로 진행되지 않자 마산' in '단독면담을 요구하였다. 그러나 노태우 대통령의 반응이 없고, 사태 해결이 그의 의도대로 진행되지 않자 마산으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,285 >> Unable to find text: '##으로' in '마산으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,342 >> Unable to find text: '##으로 낙향' in '마산으로 낙향해'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,343 >> Unable to find text: '##으로 낙' in '마산으로 낙향해'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,343 >> Unable to find text: '##담을 요구하였다 . 그러나 노태우 대통령의 반응이 없고 , 사태 해결이 그의 의도대로 진행되지 않자 마산으로' in '단독면담을 요구하였다. 그러나 노태우 대통령의 반응이 없고, 사태 해결이 그의 의도대로 진행되지 않자 마산으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,344 >> Unable to find text: '##향' in '낙향해'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,345 >> Unable to find text: '##원' in '최고위원은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,345 >> Unable to find text: '##원은' in '최고위원은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,345 >> Unable to find text: '##은' in '최고위원은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,347 >> Unable to find text: '##양' in '윤석양'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,347 >> Unable to find text: '##양 이병' in '윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,348 >> Unable to find text: '##병 윤석양' in '탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,348 >> Unable to find text: '##병 윤석양 이병' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,348 >> Unable to find text: '##영병 윤석양' in '탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,348 >> Unable to find text: '##던 탈영병 윤석양' in '출신이었던 탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,348 >> Unable to find text: '##영병 윤석양 이병' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,348 >> Unable to find text: '##던 탈영병 윤석양 이병' in '출신이었던 탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,352 >> Unable to find text: '##양 이병' in '윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,353 >> Unable to find text: '##병 윤석양 이병' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,353 >> Unable to find text: '##양' in '윤석양'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,353 >> Unable to find text: '##병 윤석양' in '탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,353 >> Unable to find text: '##영병 윤석양 이병' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,353 >> Unable to find text: '##던 탈영병 윤석양 이병' in '출신이었던 탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,353 >> Unable to find text: '##영병 윤석양' in '탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,354 >> Unable to find text: '##던 탈영병 윤석양' in '출신이었던 탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,354 >> Unable to find text: '##병 윤석' in '탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,356 >> Unable to find text: '##선언' in '「양심선언」을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,357 >> Unable to find text: '##의회 인권위원회 사무실에서 「 양심선언' in '한국기독교교회협의회 인권위원회 사무실에서 「양심선언」을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,357 >> Unable to find text: '##원회 사무실에서 「 양심선언' in '인권위원회 사무실에서 「양심선언」을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,357 >> Unable to find text: '##교교회협의회 인권위원회 사무실에서 「 양심선언' in '한국기독교교회협의회 인권위원회 사무실에서 「양심선언」을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,359 >> Unable to find text: '##사' in '평민당사를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,359 >> Unable to find text: '##당사' in '평민당사를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,360 >> Unable to find text: '##에 평민당사' in '11일에 평민당사를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,360 >> Unable to find text: '##사를' in '평민당사를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,360 >> Unable to find text: '##당사를' in '평민당사를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,360 >> Unable to find text: '##당' in '평민당사를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,360 >> Unable to find text: '##사를 방문' in '평민당사를 방문해'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,360 >> Unable to find text: '##를' in '평민당사를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,360 >> Unable to find text: '##당사를 방문' in '평민당사를 방문해'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,361 >> Unable to find text: '##사를 방문해 단식 중인 김대중 총재' in '평민당사를 방문해 단식 중인 김대중 총재를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,361 >> Unable to find text: '##당사를 방문해 단식 중인 김대중 총재' in '평민당사를 방문해 단식 중인 김대중 총재를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,361 >> Unable to find text: '##사를 방문해 단식 중인 김대중 총재를 면회' in '평민당사를 방문해 단식 중인 김대중 총재를 면회하였다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,361 >> Unable to find text: '##사를 방문해 단식 중인 김대중' in '평민당사를 방문해 단식 중인 김대중'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,361 >> Unable to find text: '##사를 방문해' in '평민당사를 방문해'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,361 >> Unable to find text: '##당사를 방문해 단식 중인 김대중 총재를 면회' in '평민당사를 방문해 단식 중인 김대중 총재를 면회하였다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,361 >> Unable to find text: '##당사를 방문해 단식 중인 김대중' in '평민당사를 방문해 단식 중인 김대중'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,361 >> Unable to find text: '##당사를 방문해' in '평민당사를 방문해'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,361 >> Unable to find text: '##에 평민' in '11일에 평민당사를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,362 >> Unable to find text: '##에 평민당사를' in '11일에 평민당사를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,362 >> Unable to find text: '##를 방문' in '평민당사를 방문해'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,362 >> Unable to find text: '##사를 방문해 단식' in '평민당사를 방문해 단식'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,362 >> Unable to find text: '##에 평민당' in '11일에 평민당사를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,362 >> Unable to find text: '##당사를 방문해 단식' in '평민당사를 방문해 단식'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,363 >> Unable to find text: '##병 윤석양' in '탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,363 >> Unable to find text: '##양' in '윤석양'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,364 >> Unable to find text: '##병 윤석양 이병' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,364 >> Unable to find text: '##양 이병' in '윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,364 >> Unable to find text: '##던 탈영병 윤석양' in '출신이었던 탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,364 >> Unable to find text: '##던 탈영병 윤석양 이병' in '출신이었던 탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,364 >> Unable to find text: '##영병 윤석양' in '탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,364 >> Unable to find text: '##었던 탈영병 윤석양' in '출신이었던 탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,365 >> Unable to find text: '##영병 윤석양 이병' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,365 >> Unable to find text: '##병 윤석' in '탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,365 >> Unable to find text: '##양' in '윤석양은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,365 >> Unable to find text: '##었던 탈영병 윤석양 이병' in '출신이었던 탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,365 >> Unable to find text: '##병 윤석양 이병의' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,365 >> Unable to find text: '##양 이병의' in '윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,366 >> Unable to find text: '##훈' in '이상훈'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,368 >> Unable to find text: '##에서 이상훈' in '민자당사에서 이상훈'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,368 >> Unable to find text: '##훈 국방부장관' in '이상훈 국방부장관을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,368 >> Unable to find text: '##훈 국방부장관을' in '이상훈 국방부장관을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,368 >> Unable to find text: '##관' in '국방부장관을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,368 >> Unable to find text: '##을' in '국방부장관을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,368 >> Unable to find text: '##훈 국방부장' in '이상훈 국방부장관을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,368 >> Unable to find text: '##관을' in '국방부장관을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,368 >> Unable to find text: '##훈 국방부' in '이상훈 국방부장관을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,368 >> Unable to find text: '##장관' in '국방부장관을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,369 >> Unable to find text: '##훈 국방부장관을 면담 , 항의하기도 했다 . 사찰 파장으로 국방부장관은 경질되었다 .' in '이상훈 국방부장관을 면담, 항의하기도 했다. 사찰 파장으로 국방부장관은 경질되었다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,371 >> Unable to find text: '##용' in '정호용의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,371 >> Unable to find text: '##용이 그에 대한 지지를 촉구하여 일시적으로 봉합시키기도 했다 . 그러나 정호용' in '정호용이 그에 대한 지지를 촉구하여 일시적으로 봉합시키기도 했다. 그러나 정호용의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,372 >> Unable to find text: '##년' in '1960년'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,373 >> Unable to find text: '##년 자신의 어머니 박부련이 무장공비' in '1960년 자신의 어머니 박부련이 무장공비에게'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,373 >> Unable to find text: '##년 자신의 어머니 박부련이 무장공비에게 살해당한 점' in '1960년 자신의 어머니 박부련이 무장공비에게 살해당한 점을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,373 >> Unable to find text: '##년 자신의 어머니 박부련이 무장공비에게 살해당한' in '1960년 자신의 어머니 박부련이 무장공비에게 살해당한'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,373 >> Unable to find text: '##년 자신의 어머니 박부련이 무장공비에게 살해' in '1960년 자신의 어머니 박부련이 무장공비에게 살해당한'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,373 >> Unable to find text: '##년 자신의 어머니 박부련이 무장공비에게' in '1960년 자신의 어머니 박부련이 무장공비에게'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,373 >> Unable to find text: '##년 자신의 어머니 박부련이 무장공비에게 살해당' in '1960년 자신의 어머니 박부련이 무장공비에게 살해당한'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,374 >> Unable to find text: '##당' in '민자당내'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,374 >> Unable to find text: '##당내' in '민자당내'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,376 >> Unable to find text: '##용' in '정호용이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,377 >> Unable to find text: '##용이 그에 대한 지지를 촉구하여 일시적으로 봉합시키기도 했다 . 그러나 정호용' in '정호용이 그에 대한 지지를 촉구하여 일시적으로 봉합시키기도 했다. 그러나 정호용의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,377 >> Unable to find text: '##용' in '정호용의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,379 >> Unable to find text: '##자 ’ 는 만류에 의해 군사 정권 세력과 반공주의 세력은 김영삼 지지층과 김종필' in '지지하자’ 는 만류에 의해 군사 정권 세력과 반공주의 세력은 김영삼 지지층과 김종필'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,380 >> Unable to find text: '##용' in '정호용이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,381 >> Unable to find text: '##신의 군사정권 인사 정호용' in '경북출신의 군사정권 인사 정호용이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,381 >> Unable to find text: '##의 군사정권 인사 정호용' in '경북출신의 군사정권 인사 정호용이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,381 >> Unable to find text: '##출신의 군사정권 인사 정호용' in '경북출신의 군사정권 인사 정호용이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,382 >> Unable to find text: '##용이' in '정호용이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,382 >> Unable to find text: '##련' in '박부련이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,382 >> Unable to find text: '##부련' in '박부련이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,386 >> Unable to find text: '##가' in '남이가"라는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,386 >> Unable to find text: '##가 남이가' in '"우리가 남이가"라는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,387 >> Unable to find text: '##년' in '1992년'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,388 >> Unable to find text: '##년 14대 대선 당시 선거는' in '1992년 14대 대선 당시 선거는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,388 >> Unable to find text: '##년 14대 대선 당시' in '1992년 14대 대선 당시'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,388 >> Unable to find text: '##년 14' in '1992년 14대'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,388 >> Unable to find text: '##년 14대' in '1992년 14대'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,388 >> Unable to find text: '##년 14대 대선' in '1992년 14대 대선'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,389 >> Unable to find text: '##년 14대 대선 당시 선거는 김영삼 , 김대중 , 정주영 후보의 3파전으로 격돌하였다 .' in '1992년 14대 대선 당시 선거는 김영삼, 김대중, 정주영 후보의 3파전으로 격돌하였다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,389 >> Unable to find text: '##년 14대 대선 당시 선거' in '1992년 14대 대선 당시 선거는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,390 >> Unable to find text: '##은 불법 도청' in '후보측은 불법 도청으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,390 >> Unable to find text: '##측은 불법 도청' in '후보측은 불법 도청으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,392 >> Unable to find text: '##표' in '영남표를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,393 >> Unable to find text: '##집 사건 " 으로 불린다 . 지역감정을 부추기는 초원복집 사건에 대한 폭로가 오히려 영남표' in '"초원복집 사건"으로 불린다. 지역감정을 부추기는 초원복집 사건에 대한 폭로가 오히려 영남표를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,393 >> Unable to find text: '##복집 사건 " 으로 불린다 . 지역감정을 부추기는 초원복집 사건에 대한 폭로가 오히려 영남표' in '"초원복집 사건"으로 불린다. 지역감정을 부추기는 초원복집 사건에 대한 폭로가 오히려 영남표를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,393 >> Unable to find text: '##표를' in '영남표를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,395 >> Unable to find text: '##는 김영삼 , 김대중 , 정주영' in '선거는 김영삼, 김대중, 정주영'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,396 >> Unable to find text: '##복집 사건' in '"초원복집 사건"으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,396 >> Unable to find text: '##집 사건' in '"초원복집 사건"으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,398 >> Unable to find text: '##리' in '가오리,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,399 >> Unable to find text: '##매일신문' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,399 >> Unable to find text: '##일신문' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,399 >> Unable to find text: '##신문' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,400 >> Unable to find text: '##자 LA매일신문' in '20일자 LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,400 >> Unable to find text: '##일자 LA매일신문' in '20일자 LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,400 >> Unable to find text: '##당 대선후보 때였다 . 그 해 2월 20일자 LA매일신문' in '민자당 대선후보 때였다. 그 해 2월 20일자 LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,400 >> Unable to find text: '##매일신문에' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,445 >> Unable to find text: '##일신문에' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,445 >> Unable to find text: '##신문에' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,445 >> Unable to find text: '##매일' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,445 >> Unable to find text: '##일' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,445 >> Unable to find text: '##매' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,445 >> Unable to find text: '##자 LA매일신문에' in '20일자 LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,447 >> Unable to find text: '##후보' in '대선후보'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,448 >> Unable to find text: '##일신문' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,448 >> Unable to find text: '##신문' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,448 >> Unable to find text: '##매일신문' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,448 >> Unable to find text: '##자 LA매일신문' in '20일자 LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,448 >> Unable to find text: '##일자 LA매일신문' in '20일자 LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,448 >> Unable to find text: '##일신문에' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,449 >> Unable to find text: '##신문에' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,449 >> Unable to find text: '##일' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,449 >> Unable to find text: '##매일신문에' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,449 >> Unable to find text: '##자 LA매일신문에' in '20일자 LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,449 >> Unable to find text: '##에' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,449 >> Unable to find text: '##매일' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,449 >> Unable to find text: '##자 LA' in '20일자 LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,449 >> Unable to find text: '##자 LA매일' in '20일자 LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,450 >> Unable to find text: '##일신문' in 'LA매일신문'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,450 >> Unable to find text: '##신문' in 'LA매일신문'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,450 >> Unable to find text: '##일자 LA매일신문에' in '20일자 LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,450 >> Unable to find text: '##매일신문' in 'LA매일신문'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,450 >> Unable to find text: '##매' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,451 >> Unable to find text: '##리' in '가오리,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,452 >> Unable to find text: '##리 ,' in '가오리,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,453 >> Unable to find text: '##은' in '세력은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,455 >> Unable to find text: '##무 기자' in '손충무 기자의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,455 >> Unable to find text: '##충무 기자' in '손충무 기자의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,455 >> Unable to find text: '##무' in '손충무'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,455 >> Unable to find text: '##충무' in '손충무'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,455 >> Unable to find text: '##인 극우 언론인 손충무 기자' in '편집책임자인 극우 언론인 손충무 기자의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,455 >> Unable to find text: '##임자인 극우 언론인 손충무 기자' in '편집책임자인 극우 언론인 손충무 기자의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,456 >> Unable to find text: '##인 극우 언론인 손충무' in '편집책임자인 극우 언론인 손충무'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,456 >> Unable to find text: '##임자인 극우 언론인 손충무' in '편집책임자인 극우 언론인 손충무'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,456 >> Unable to find text: '##책임자인 극우 언론인 손충무 기자' in '편집책임자인 극우 언론인 손충무 기자의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,456 >> Unable to find text: '##신문의 편집책임자인 극우 언론인 손충무 기자' in 'LA매일신문의 편집책임자인 극우 언론인 손충무 기자의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,457 >> Unable to find text: '##자 보수 세력' in '보이자 보수 세력은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,457 >> Unable to find text: '##자 보수' in '보이자 보수'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,458 >> Unable to find text: '##은' in '세력은'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,458 >> Unable to find text: '##력' in '극우세력의'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:47,459 >> Unable to find text: '##충무 기자' in '손충무 기자의'
# ...
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,170 >> Unable to find text: '##이 50 Mbps' in 'Cat.6이 50 Mbps로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,171 >> Unable to find text: '갤럭시 S7과 같이 모든 기기의 통신 [UNK] 솔루션이 모바일 AP에 내장된 최초의 갤럭시 S 시리즈' in '갤럭시 S7과 같이 모든 기기의 통신 모뎀 솔루션이 모바일 AP에 내장된 최초의 갤럭시 S 시리즈'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,223 >> Unable to find text: '갤럭시 S7과 같이 모든 기기의 통신 [UNK] 솔루션이 모바일 AP에 내장된 최초의 갤럭시 S' in '갤럭시 S7과 같이 모든 기기의 통신 모뎀 솔루션이 모바일 AP에 내장된 최초의 갤럭시 S'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,224 >> Unable to find text: '##7' in 'S7과'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,225 >> Unable to find text: '갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK] 솔루션이 기본적으로 내장되어 있었으나 , 삼성 엑시노스 시리즈' in '갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀 솔루션이 기본적으로 내장되어 있었으나, 삼성 엑시노스 시리즈는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,225 >> Unable to find text: 'S7과 같이 모든 기기의 통신 [UNK] 솔루션이 모바일 AP에 내장된 최초의 갤럭시 S 시리즈' in 'S7과 같이 모든 기기의 통신 모뎀 솔루션이 모바일 AP에 내장된 최초의 갤럭시 S 시리즈'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,226 >> Unable to find text: '갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK] 솔루션이 기본적으로 내장되어 있었으나 , 삼성 엑시노스 시리즈' in '갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀 솔루션이 기본적으로 내장되어 있었으나, 삼성 엑시노스 시리즈는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,226 >> Unable to find text: '##노스 시리즈' in '엑시노스 시리즈는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,226 >> Unable to find text: '##시노스 시리즈' in '엑시노스 시리즈는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,226 >> Unable to find text: '기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK] 솔루션이 기본적으로 내장되어 있었으나 , 삼성 엑시노스 시리즈' in '기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀 솔루션이 기본적으로 내장되어 있었으나, 삼성 엑시노스 시리즈는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,227 >> Unable to find text: '통신 [UNK] 솔루션이 기본적으로 내장되어 있었으나 , 삼성 엑시노스 시리즈' in '통신 모뎀 솔루션이 기본적으로 내장되어 있었으나, 삼성 엑시노스 시리즈는'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,227 >> Unable to find text: '갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK] 솔루션이 기본적으로 내장되어 있었으나 , 삼성 엑시노스' in '갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀 솔루션이 기본적으로 내장되어 있었으나, 삼성 엑시노스'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,228 >> Unable to find text: '통신 [UNK] 솔루션' in '통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,228 >> Unable to find text: '퀄컴 스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK] 솔루션' in '퀄컴 스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,228 >> Unable to find text: '통신 [UNK] 솔루션이' in '통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,228 >> Unable to find text: '통신 [UNK]' in '통신 모뎀'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,228 >> Unable to find text: '스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK] 솔루션' in '스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,228 >> Unable to find text: '[UNK] 솔루션' in '모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,228 >> Unable to find text: '통신 [UNK] 솔루션이 기본적으로' in '통신 모뎀 솔루션이 기본적으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,228 >> Unable to find text: '통신 [UNK] 솔루션이 기본' in '통신 모뎀 솔루션이 기본적으로'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,228 >> Unable to find text: '갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK] 솔루션' in '갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,229 >> Unable to find text: '통신 [UNK] 솔루션이 기본적으로 내장되어 있었으나 , 삼성 엑시노스 시리즈는 플래그십 AP로는 삼성 엑시노스 8890' in '통신 모뎀 솔루션이 기본적으로 내장되어 있었으나, 삼성 엑시노스 시리즈는 플래그십 AP로는 삼성 엑시노스 8890이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,229 >> Unable to find text: '기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK] 솔루션' in '기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,229 >> Unable to find text: '시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK] 솔루션' in '시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,229 >> Unable to find text: '통신 [UNK] 솔루션이 모바일 AP에 내장된 최초의 갤럭시 S 시리즈 중 하나이다 . 이는 퀄컴 스냅드래곤 시리즈' in '통신 모뎀 솔루션이 모바일 AP에 내장된 최초의 갤럭시 S 시리즈 중 하나이다. 이는 퀄컴 스냅드래곤 시리즈를'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,229 >> Unable to find text: '통신 [UNK] 솔루션' in '통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,229 >> Unable to find text: '퀄컴 스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK] 솔루션이' in '퀄컴 스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,229 >> Unable to find text: '퀄컴 스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK]' in '퀄컴 스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,230 >> Unable to find text: '통신 [UNK] 솔루션이 모바일 AP' in '통신 모뎀 솔루션이 모바일 AP에'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,230 >> Unable to find text: '통신 [UNK] 솔루션이 모바일 AP에 내장된 최초의 갤럭시 S 시리즈 중 하나이다 . 이는 퀄컴 스냅드래곤' in '통신 모뎀 솔루션이 모바일 AP에 내장된 최초의 갤럭시 S 시리즈 중 하나이다. 이는 퀄컴 스냅드래곤'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,234 >> Unable to find text: '##at . 6 모델' in 'Cat.6 모델이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,235 >> Unable to find text: '##형 3600 mAh' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,235 >> Unable to find text: '##h' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,235 >> Unable to find text: '##Ah' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,235 >> Unable to find text: '##은 내장형 3600 mAh' in '용량은 내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,235 >> Unable to find text: '##형 3600' in '내장형 3600'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,235 >> Unable to find text: '##형 3600 mAh이다 .' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,235 >> Unable to find text: '##h이다 .' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,235 >> Unable to find text: '##형 3600 mA' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,236 >> Unable to find text: '##형 3600 mAh이다' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,236 >> Unable to find text: '##Ah이다 .' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,236 >> Unable to find text: '##h이다' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,236 >> Unable to find text: '##형 3600 m' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,236 >> Unable to find text: '##은 내장형 3600' in '용량은 내장형 3600'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,237 >> Unable to find text: '##충전 기술' in '무선충전 기술까지'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,237 >> Unable to find text: '##충전 솔루션을 내장했으며 갤럭시 S6 엣지 + 의 고속 무선충전 기술' in '무선충전 솔루션을 내장했으며 갤럭시 S6 엣지+의 고속 무선충전 기술까지'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,238 >> Unable to find text: '##h' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,239 >> Unable to find text: '##Ah' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,239 >> Unable to find text: '##형 3600 mAh' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,239 >> Unable to find text: '##은 내장형 3600 mAh' in '용량은 내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,239 >> Unable to find text: '##h이다 .' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,239 >> Unable to find text: '##Ah이다 .' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,243 >> Unable to find text: '##Ah' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,243 >> Unable to find text: '##h' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,243 >> Unable to find text: '##형 3600 mAh' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,244 >> Unable to find text: '##은 내장형 3600 mAh' in '용량은 내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,244 >> Unable to find text: '##Ah이다 .' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,244 >> Unable to find text: '##h이다 .' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,245 >> Unable to find text: '##Ah' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,245 >> Unable to find text: '##h' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,245 >> Unable to find text: '##은 내장형 3600 mAh' in '용량은 내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,245 >> Unable to find text: '##형 3600 mAh' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,248 >> Unable to find text: '##만' in '1,200만'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,249 >> Unable to find text: '##하여 1 , 200만' in '혼용하여 1,200만'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,249 >> Unable to find text: '##만 화소' in '1,200만 화소'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,250 >> Unable to find text: '##는 ' 셀피 플래시' in '하는 '셀피 플래시''
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,252 >> Unable to find text: '##만' in '1,200만'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,252 >> Unable to find text: '##만 화소' in '1,200만 화소'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,252 >> Unable to find text: '##하여 1 , 200만' in '혼용하여 1,200만'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,253 >> Unable to find text: '##튀' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,253 >> Unable to find text: '##툭튀' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,253 >> Unable to find text: '##는 일명 ' 카툭튀' in '돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,253 >> Unable to find text: '##되는 일명 ' 카툭튀' in '돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,253 >> Unable to find text: '##이 돌출되는 일명 ' 카툭튀' in '모듈이 돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,254 >> Unable to find text: '##튀 '' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,255 >> Unable to find text: '##도 전작인 갤럭시 S6 엣지나 갤럭시 S6 엣지 + 보다 약 25 %' in '면적도 전작인 갤럭시 S6 엣지나 갤럭시 S6 엣지+보다 약 25%가량'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,256 >> Unable to find text: '##IS 기술' in 'OIS 기술이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,256 >> Unable to find text: '##는 OIS 기술' in '카메라는 OIS 기술이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,256 >> Unable to find text: '##IS' in 'OIS'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,257 >> Unable to find text: '##는 OIS' in '카메라는 OIS'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,257 >> Unable to find text: '##IS 기술이' in 'OIS 기술이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,257 >> Unable to find text: '##는 OIS 기술이' in '카메라는 OIS 기술이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,258 >> Unable to find text: '##만 화소' in '1,200만 화소'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,258 >> Unable to find text: '##만' in '1,200만'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,260 >> Unable to find text: '##는 ' 셀피 플래시' in '하는 '셀피 플래시''
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,263 >> Unable to find text: '##은 IP68' in '등급은 IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,263 >> Unable to find text: '##68' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,264 >> Unable to find text: '##진' in '방진을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,265 >> Unable to find text: '##던 방수 방진' in '삭제되었던 방수 방진을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,265 >> Unable to find text: '##진을' in '방진을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,266 >> Unable to find text: '##은 IP68' in '등급은 IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,266 >> Unable to find text: '##68' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,267 >> Unable to find text: '##은 IP68로 , 이는 방진 등급으로나 방수 등급으로나 모두 최고레벨' in '등급은 IP68로, 이는 방진 등급으로나 방수 등급으로나 모두 최고레벨이며'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,267 >> Unable to find text: '##68로 , 이는 방진 등급으로나 방수 등급으로나 모두 최고레벨' in 'IP68로, 이는 방진 등급으로나 방수 등급으로나 모두 최고레벨이며'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,269 >> Unable to find text: '##진' in '방진을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,270 >> Unable to find text: '##던 방수 방진' in '삭제되었던 방수 방진을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,270 >> Unable to find text: '##진을' in '방진을'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,270 >> Unable to find text: '##진을 다시 지원' in '방진을 다시 지원한다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,270 >> Unable to find text: '##진을 다시 지원한다 .' in '방진을 다시 지원한다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,271 >> Unable to find text: '##은 IP68' in '등급은 IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,271 >> Unable to find text: '##68' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,272 >> Unable to find text: '##은 IP68로 , 이는 방진 등급으로나 방수 등급으로나 모두 최고레벨' in '등급은 IP68로, 이는 방진 등급으로나 방수 등급으로나 모두 최고레벨이며'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,273 >> Unable to find text: '##7 엣지' in 'S7 엣지가'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,274 >> Unable to find text: '##에서 갤럭시 S7 엣지' in '지역에서 갤럭시 S7 엣지가'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,275 >> Unable to find text: '##월' in '6개월'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,275 >> Unable to find text: '##개월' in '6개월'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,275 >> Unable to find text: '##가 갤럭시 S7 엣지 출시 이후 6개월' in '사고가 갤럭시 S7 엣지 출시 이후 6개월'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,276 >> Unable to find text: '##월 정도' in '6개월 정도가'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,276 >> Unable to find text: '##개월 정도' in '6개월 정도가'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,276 >> Unable to find text: '##년' in '2016년'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,278 >> Unable to find text: '##년 9월 4일' in '2016년 9월 4일'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,278 >> Unable to find text: '##년 9' in '2016년 9월'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,278 >> Unable to find text: '##년 9월 4일 중동 지역에서 갤럭시 S7 엣지가 폭발하는 사건이 발생했다 .' in '2016년 9월 4일 중동 지역에서 갤럭시 S7 엣지가 폭발하는 사건이 발생했다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,278 >> Unable to find text: '##년 9월 4일 중동 지역에서' in '2016년 9월 4일 중동 지역에서'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,278 >> Unable to find text: '##년 9월 4' in '2016년 9월 4일'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,278 >> Unable to find text: '##년 9월' in '2016년 9월'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,278 >> Unable to find text: '##년 9월 4일 중동 지역에서 갤럭시 S7 엣지가' in '2016년 9월 4일 중동 지역에서 갤럭시 S7 엣지가'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,279 >> Unable to find text: '##년 9월 4일 중동 지역에서 갤럭시 S7 엣지가 폭발하는 사건이 발생했다' in '2016년 9월 4일 중동 지역에서 갤럭시 S7 엣지가 폭발하는 사건이 발생했다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,325 >> Unable to find text: '##년 9월 4일 중동 지역에서 갤럭시 S7 엣지가 폭발하는 사건이 발생' in '2016년 9월 4일 중동 지역에서 갤럭시 S7 엣지가 폭발하는 사건이 발생했다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,325 >> Unable to find text: '##년 9월 4일 중동 지역에서 갤럭시 S7 엣지가 폭발하는 사건이 발생했' in '2016년 9월 4일 중동 지역에서 갤럭시 S7 엣지가 폭발하는 사건이 발생했다.'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,326 >> Unable to find text: '##년 9월 4일 중동 지역에서 갤럭시 S7 엣지가 폭발하는 사건' in '2016년 9월 4일 중동 지역에서 갤럭시 S7 엣지가 폭발하는 사건이'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,329 >> Unable to find text: '##일 중동' in '4일 중동'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,331 >> Unable to find text: '##일' in '18일만이며'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,333 >> Unable to find text: '##일 중동' in '4일 중동'
# [INFO|squad_metrics.py:305] 2023-03-20 13:02:51,334 >> Unable to find text: '##년 9월 4일 중동' in '2016년 9월 4일 중동'
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/korquad/./run_QA.py", line 852, in <module>
#     main()
#   File "/content/drive/MyDrive/korquad/./run_QA.py", line 841, in main
#     result = evaluate(args, model, tokenizer, prefix=global_step)
#   File "/content/drive/MyDrive/korquad/./run_QA.py", line 383, in evaluate
#     predictions = compute_predictions_logits(
#   File "/usr/local/lib/python3.9/dist-packages/transformers/data/metrics/squad_metrics.py", line 577, in compute_predictions_logits
#     with open(output_prediction_file, "w") as writer:
# OSError: [Errno 107] Transport endpoint is not connected: 'klue_roberta-KorQuAD/predictions_24000.json'

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## 경로 변경

# %%
import os
os.chdir('/content/drive/MyDrive/korquad/')
os.getcwd()
# Out:
# '/content/drive/MyDrive/korquad'

# %%
from __future__ import print_function
from collections import Counter
import string
import re
import argparse
import json
import sys
import os

import pandas as pd
from transformers import AutoTokenizer

'''KorQuAD v1.0에 대한 공식 평가 스크립트 '''
'''본 스크립트는 SQuAD v1.1 평가 스크립트 https://rajpurkar.github.io/SQuAD-explorer/ 를 바탕으로 작성됨.'''

def normalize_answer(s):    
    def remove_(text):
        ''' 불필요한 기호 제거 '''
        text = re.sub("'", " ", text)
        text = re.sub('"', " ", text)
        text = re.sub('《', " ", text)
        text = re.sub('》', " ", text)
        text = re.sub('<', " ", text)
        text = re.sub('>', " ", text) 
        text = re.sub('〈', " ", text)
        text = re.sub('〉', " ", text)   
        text = re.sub("\(", " ", text)
        text = re.sub("\)", " ", text)
        text = re.sub("‘", " ", text)
        text = re.sub("’", " ", text)      
        return text

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return ''.join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_punc(lower(remove_(s))))


def f1_score(prediction, ground_truth):
    prediction_tokens = normalize_answer(prediction).split()
    ground_truth_tokens = normalize_answer(ground_truth).split()
   
    #F1 by character
    prediction_Char = []
    for tok in prediction_tokens:
        now = [a for a in tok]
        prediction_Char.extend(now)
        
    ground_truth_Char = []
    for tok in ground_truth_tokens:
        now = [a for a in tok]
        ground_truth_Char.extend(now)   
        
    common = Counter(prediction_Char) & Counter(ground_truth_Char)
    num_same = sum(common.values())
    if num_same == 0:
        return 0
    
    precision = 1.0 * num_same / len(prediction_Char)
    recall = 1.0 * num_same / len(ground_truth_Char)
    f1 = (2 * precision * recall) / (precision + recall)
    
    return f1


def exact_match_score(prediction, ground_truth):
    return (normalize_answer(prediction) == normalize_answer(ground_truth))


def metric_max_over_ground_truths(metric_fn, prediction, ground_truths):
    scores_for_ground_truths = []
    for ground_truth in ground_truths:
        score = metric_fn(prediction, ground_truth)
        scores_for_ground_truths.append(score)
    return max(scores_for_ground_truths)


def evaluate(dataset, predictions):
    f1 = exact_match = total = 0
    for article in dataset:
        for paragraph in article['paragraphs']:
            for qa in paragraph['qas']:
                total += 1
                if qa['id'] not in predictions:
                    message = 'Unanswered question ' + qa['id'] + \
                              ' will receive score 0.'
                    print(message, file=sys.stderr)
                    continue
                ground_truths = list(map(lambda x: x['text'], qa['answers']))
                prediction = predictions[qa['id']]
                exact_match += metric_max_over_ground_truths(
                    exact_match_score, prediction, ground_truths)
                f1 += metric_max_over_ground_truths(
                    f1_score, prediction, ground_truths)

    exact_match = 100.0 * exact_match / total
    f1 = 100.0 * f1 / total
    return {'exact_match': exact_match, 'f1': f1}


def evaluate_result(dataset_file, prediction_file):
    
    with open(dataset_file, encoding="utf-8") as f:
        dataset_json = json.load(f)
        dataset = dataset_json['data']
    with open(prediction_file, encoding="utf-8") as f:
        predictions = json.load(f)
    return evaluate(dataset, predictions)

# %% [markdown]
# ## 성능 확인

# %%
dataset_file = './data/KorQuAD_v1.0_dev.json'
prediction_file = './klue_roberta-KorQuAD/predictions_KorQuAD.json' # 경로 변경 필요
evaluate_result(dataset_file, prediction_file)
# Out:
# {'exact_match': 20.074349442379184, 'f1': 46.62947412191146}
