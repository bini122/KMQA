# %%
# !pip3 install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 74.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 27.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 85.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.15.1 tokenizers-0.13.3 transformers-4.29.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/korquad/')
os.getcwd()
# Out:
# '/content/drive/MyDrive/korquad'

# %%
# !python ./task_1/run_QA.py \
    --model_type electra \
    --model_name_or_path monologg/koelectra-base-v3-discriminator \
    --output_dir koelectra-base-v3-KMQA \
    --data_dir data \
    --data_name KMQA \
    --train_file KMQA_train_v5.1.json \
    --predict_file KMQA_dev_v5.1.json \
    --max_seq_length 512 \
    --doc_stride 128 \
    --max_query_length 64 \
    --do_train \
    --do_eval \
    --evaluate_during_training \
    --per_gpu_train_batch_size=16 \
    --per_gpu_eval_batch_size=8 \
    --learning_rate 5e-5 \
    --gradient_accumulation_steps 1 \
    --weight_decay 0.0 \
    --adam_epsilon 1e-8 \
    --max_grad_norm 1.0 \
    --num_train_epochs 3 \
    --max_steps -1 \
    --warmup_steps 0 \
    --n_best_size 20 \
    --max_answer_length 30 \
    --verbose_logging \
    --logging_steps 1000 \
    --save_steps 1000 \
    --eval_all_checkpoints \
    --overwrite_output_dir \
    --seed 42 \
    --local_rank -1 \
    --threads 4
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,544 >> Unable to find text: '##요' in '병이겠지요.나중에는'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,544 >> Unable to find text: '##니다 .' in '있습니다.아마도,'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,545 >> Unable to find text: '##요 . 나중에는 어지럼증도 함께 말이지요' in '병이겠지요.나중에는 어지럼증도 함께 말이지요.신체'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,545 >> Unable to find text: '##신의 기능저하를 확인하기 위해서는 , 내과 중에서도 내분비 내과를 찾으시면 됩니다 .' in '부신의 기능저하를 확인하기 위해서는, 내과 중에서도 내분비 내과를 찾으시면 됩니다.이는'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,545 >> Unable to find text: '##요' in '말이지요.신체'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,548 >> Unable to find text: '##요' in '아니겠지요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,548 >> Unable to find text: '##니다' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,549 >> Unable to find text: '##니다 .' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,549 >> Unable to find text: '##요 .' in '아니겠지요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,550 >> Unable to find text: '##요 . 성격' in '아니겠지요. 성격'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,559 >> Length not equal after stripping spaces: '정신과에서의상담도보통10분에서20분정도를합니다. 1시간' vs '정신과에서의상담도보통10분에서20분정도를합니다.1시간'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,560 >> Length not equal after stripping spaces: '근데제가18살때?그때는돈을벌어야겠다는욕심이커서 일을너무' vs '근데제가18살때?그때는돈을벌어야겠다는욕심이커서일을너무'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,561 >> Length not equal after stripping spaces: '스트레스때문에여러가지신체증상이 나타난것같네요.우울하거나스트레스를받으면폭식증상이나타나기도합니다.' vs '스트레스때문에여러가지신체증상이나타난것같네요.우울하거나스트레스를받으면폭식증상이나타나기도합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,561 >> Length not equal after stripping spaces: '힘들다고죽을생각을하는것은잘못된것입니다.죽는것은우리가선택하는것이아닙니다. 아이를' vs '힘들다고죽을생각을하는것은잘못된것입니다.죽는것은우리가선택하는것이아닙니다.아이를'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,561 >> Length not equal after stripping spaces: '스트레스때문에여러가지신체증상이 나타난것같네요.' vs '스트레스때문에여러가지신체증상이나타난것같네요.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,561 >> Length not equal after stripping spaces: '너무열심히살아야하는 것이스트레스가된것같네요. 스트레스때문에여러가지신체증상이 나타난것같네요.' vs '너무열심히살아야하는것이스트레스가된것같네요.스트레스때문에여러가지신체증상이나타난것같네요.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,562 >> Length not equal after stripping spaces: '힘들다고죽을생각을하는것은잘못된것입니다.죽는것은우리가선택하는것이아닙니다. 아이를' vs '힘들다고죽을생각을하는것은잘못된것입니다.죽는것은우리가선택하는것이아닙니다.아이를'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,564 >> Unable to find text: '##니다 . 식사 조절을 하고 운동을 하면 조절되기는 합니다' in '같습니다.식사 조절을 하고 운동을 하면 조절되기는 합니다.조절이'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,565 >> Unable to find text: '##니다' in '좋습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,570 >> Unable to find text: '##이 .' in '보이듯이...그러나'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,573 >> Length not equal after stripping spaces: '검사를해서이상이없이나오면다는아니지만심리적인원인에서오는증상도고려해볼수있습니다. ' vs '검사를해서이상이없이나오면다는아니지만심리적인원인에서오는증상도고려해볼수있습니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,574 >> Length not equal after stripping spaces: '심리적인원인에서오는증상도고려해볼수있습니다. ' vs '심리적인원인에서오는증상도고려해볼수있습니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,574 >> Length not equal after stripping spaces: '있습니다. 증상이다양하게있는경우에도심리적인원인을의심해볼수있습니다.' vs '있습니다.증상이다양하게있는경우에도심리적인원인을의심해볼수있습니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,575 >> Length not equal after stripping spaces: '검사를해서이상이없이나오면다는아니지만심리적인원인에서오는증상도고려해볼수있습니다. ' vs '검사를해서이상이없이나오면다는아니지만심리적인원인에서오는증상도고려해볼수있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,575 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,575 >> Unable to find text: '##에도 심리적인 원인을 의심해볼 수 있습니다 .' in '있는경우에도 심리적인 원인을 의심해볼 수 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,575 >> Unable to find text: '##니다 . 증상이 다양하게 있는경우에도 심리적인 원인을 의심해볼 수 있습니다 .' in '있습니다.  증상이 다양하게 있는경우에도 심리적인 원인을 의심해볼 수 있습니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,575 >> Length not equal after stripping spaces: '있습니다. ' vs '있습니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,576 >> Length not equal after stripping spaces: '심리적인원인에서오는증상도고려해볼수있습니다. ' vs '심리적인원인에서오는증상도고려해볼수있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,576 >> Unable to find text: '##니다 .' in '있습니다. '
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,576 >> Length not equal after stripping spaces: '다는아니지만심리적인원인에서오는증상도고려해볼수있습니다. ' vs '다는아니지만심리적인원인에서오는증상도고려해볼수있습니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,576 >> Length not equal after stripping spaces: '이상이없이나오면다는아니지만심리적인원인에서오는증상도고려해볼수있습니다. ' vs '이상이없이나오면다는아니지만심리적인원인에서오는증상도고려해볼수있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,576 >> Unable to find text: '##도 고려해볼 수 있습니다 .' in '증상도 고려해볼 수 있습니다. '
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,579 >> Unable to find text: '##죠 ?' in '필요하겠죠?불면증은'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,580 >> Unable to find text: '##합니다' in '발생합니다.구체적으로'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,580 >> Unable to find text: '##죠 ? 불면증은 근본적으로 수면과 각성을 조절하는 뇌 신경계의 기능이상으로 발생합니다' in '필요하겠죠?불면증은 근본적으로 수면과 각성을 조절하는 뇌 신경계의 기능이상으로 발생합니다.구체적으로'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,583 >> Unable to find text: '##립니다 .' in '추천드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,584 >> Unable to find text: '##립니다 .' in '추천드립니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,584 >> Unable to find text: '##립니다 . 다만 고강도의 운동보다는 저강도의 유산소 운동부터 시작해주시는 것을 추천드립니다 .' in '추천드립니다. 다만 고강도의 운동보다는 저강도의 유산소 운동부터 시작해주시는 것을 추천드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,610 >> Unable to find text: '##입니다' in '대처입니다.그래도'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,611 >> Unable to find text: '##입니다 . 원인에 대한 파악은 필요하니까 적절한 대처입니다' in '것입니다. 원인에 대한 파악은 필요하니까 적절한 대처입니다.그래도'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,611 >> Unable to find text: '##입니다' in '것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,612 >> Unable to find text: '##입니다 . 그래도 통증이 해결되지 못한 부분이 안타깝습니다' in '대처입니다.그래도 통증이 해결되지 못한 부분이 안타깝습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,615 >> Unable to find text: '##2' in '교정2.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,615 >> Unable to find text: '##1 . 내과적 원인의 교정2' in '있습니다.치료는1. 내과적 원인의 교정2.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,616 >> Unable to find text: '##합니다' in '추정합니다.내과적'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,616 >> Unable to find text: '##1' in '있습니다.치료는1.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,616 >> Unable to find text: '##합니다 . 내과적 원인은 감기부터 암까지 모든 내과적 원인이 가능하며 , 보통 흔한 원인은 빈혈이나 전해질 이상입니다' in '추정합니다.내과적 원인은 감기부터 암까지 모든 내과적 원인이 가능하며,보통 흔한 원인은 빈혈이나 전해질 이상입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,617 >> Unable to find text: '##니다' in '경우가 많습니다.이것으로'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,617 >> Length not equal after stripping spaces: '심지어는비만클리닉에서체중감량을위해기본적으로100mg1정이 투여되는경우가 많습니다.이것으로' vs '심지어는비만클리닉에서체중감량을위해기본적으로100mg1정이투여되는경우가많습니다.이것으로'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,617 >> Length not equal after stripping spaces: '비만클리닉에서체중감량을위해기본적으로100mg1정이 투여되는경우가 많습니다.이것으로' vs '비만클리닉에서체중감량을위해기본적으로100mg1정이투여되는경우가많습니다.이것으로'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,617 >> Length not equal after stripping spaces: '굳이크게위험하지는않습니다 )MAOI란약제(항우울증약의종류)를사용해보게됩니다.그' vs '굳이크게위험하지는않습니다)MAOI란약제(항우울증약의종류)를사용해보게됩니다.그'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,617 >> Unable to find text: '##니다 .' in '경우가 많습니다.이것으로'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,618 >> Length not equal after stripping spaces: '심지어는비만클리닉에서체중감량을위해기본적으로100mg1정이 투여되는경우가 많습니다.이것으로' vs '심지어는비만클리닉에서체중감량을위해기본적으로100mg1정이투여되는경우가많습니다.이것으로'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,618 >> Length not equal after stripping spaces: '않습니다 )MAOI란약제(항우울증약의종류)를사용해보게됩니다.그' vs '않습니다)MAOI란약제(항우울증약의종류)를사용해보게됩니다.그'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,618 >> Length not equal after stripping spaces: '굳이크게위험하지는않습니다 )MAOI' vs '굳이크게위험하지는않습니다)MAOI'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,618 >> Length not equal after stripping spaces: '요즘추세로괜히좀위험하다고해서(사실굳이크게위험하지는않습니다 )MAOI' vs '요즘추세로괜히좀위험하다고해서(사실굳이크게위험하지는않습니다)MAOI'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,618 >> Length not equal after stripping spaces: '굳이크게위험하지는않습니다 )MAOI란약제(항우울증약의종류)를사용해보게됩니다.그' vs '굳이크게위험하지는않습니다)MAOI란약제(항우울증약의종류)를사용해보게됩니다.그'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,619 >> Length not equal after stripping spaces: '됩니다.그다음마지막단계는, 전기충격치료입니다.' vs '됩니다.그다음마지막단계는,전기충격치료입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,619 >> Length not equal after stripping spaces: '않습니다 )MAOI란약제(항우울증약의종류)를사용해보게됩니다.그다음마지막단계는, 전기충격치료입니다.' vs '않습니다)MAOI란약제(항우울증약의종류)를사용해보게됩니다.그다음마지막단계는,전기충격치료입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,619 >> Length not equal after stripping spaces: '경우가 많습니다.이것으로' vs '경우가많습니다.이것으로'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,619 >> Length not equal after stripping spaces: '됩니다.그다음마지막단계는, 전기충격치료입니다.' vs '됩니다.그다음마지막단계는,전기충격치료입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,619 >> Length not equal after stripping spaces: '비만클리닉에서체중감량을위해기본적으로100mg1정이 투여되는경우가 많습니다.이것으로' vs '비만클리닉에서체중감량을위해기본적으로100mg1정이투여되는경우가많습니다.이것으로'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,619 >> Length not equal after stripping spaces: '됩니다.그다음마지막단계는, 전기충격치료입니다.' vs '됩니다.그다음마지막단계는,전기충격치료입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,620 >> Length not equal after stripping spaces: '주치의님과면밀하게상의하시기바랍니다.필요시힘들겠지만,다시 연락주세요.' vs '주치의님과면밀하게상의하시기바랍니다.필요시힘들겠지만,다시연락주세요.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,620 >> Length not equal after stripping spaces: '않습니다 )MAOI란약제(항우울증약의종류)를사용해보게됩니다.그' vs '않습니다)MAOI란약제(항우울증약의종류)를사용해보게됩니다.그'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,620 >> Length not equal after stripping spaces: '경우가 많습니다.이것으로치료해보시고,여기서되지않을때에는,요즘추세로괜히좀위험하다고해서(사실굳이' vs '경우가많습니다.이것으로치료해보시고,여기서되지않을때에는,요즘추세로괜히좀위험하다고해서(사실굳이'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,620 >> Length not equal after stripping spaces: '됩니다.그다음마지막단계는, 전기충격치료입니다.>이에대해서는주치의님과면밀하게상의하시기바랍니다.' vs '됩니다.그다음마지막단계는,전기충격치료입니다.>이에대해서는주치의님과면밀하게상의하시기바랍니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,620 >> Length not equal after stripping spaces: '됩니다.그다음마지막단계는, 전기충격치료입니다.' vs '됩니다.그다음마지막단계는,전기충격치료입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,641 >> Length not equal after stripping spaces: '됩니다.그다음마지막단계는, 전기충격치료입니다.>이에대해서는주치의님과면밀하게상의하시기바랍니다.' vs '됩니다.그다음마지막단계는,전기충격치료입니다.>이에대해서는주치의님과면밀하게상의하시기바랍니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,642 >> Length not equal after stripping spaces: '주치의님과면밀하게상의하시기바랍니다.필요시힘들겠지만,다시 연락주세요.' vs '주치의님과면밀하게상의하시기바랍니다.필요시힘들겠지만,다시연락주세요.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,642 >> Length not equal after stripping spaces: '굳이크게위험하지는않습니다 )MAOI' vs '굳이크게위험하지는않습니다)MAOI'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,643 >> Length not equal after stripping spaces: '됩니다.그다음마지막단계는, 전기충격치료입니다.>이에대해서는주치의님과면밀하게상의하시기바랍니다.' vs '됩니다.그다음마지막단계는,전기충격치료입니다.>이에대해서는주치의님과면밀하게상의하시기바랍니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,643 >> Length not equal after stripping spaces: '요즘추세로괜히좀위험하다고해서(사실굳이크게위험하지는않습니다 )MAOI' vs '요즘추세로괜히좀위험하다고해서(사실굳이크게위험하지는않습니다)MAOI'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,643 >> Length not equal after stripping spaces: '됩니다.그다음마지막단계는, 전기충격치료입니다.>이에대해서는주치의님과면밀하게상의하시기바랍니다.' vs '됩니다.그다음마지막단계는,전기충격치료입니다.>이에대해서는주치의님과면밀하게상의하시기바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,645 >> Unable to find text: '##입니다' in '기분조절제입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,646 >> Unable to find text: '##입니다 . 다시 말씀드리지만 약이 조울증 치료에 가장 중요합니다' in '기분조절제입니다. 다시 말씀드리지만 약이 조울증 치료에 가장 중요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,646 >> Unable to find text: '##합니다' in '중요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,646 >> Unable to find text: '##으나 주된 치료 방법은 결국 기분조절제입니다' in '있으나 주된 치료 방법은 결국 기분조절제입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,648 >> Unable to find text: '##니다 . 계속되면 정신건강의학과 진료를 받아보셔야 합니다 .' in '같습니다. 계속되면 정신건강의학과 진료를 받아보셔야 합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,648 >> Unable to find text: '##은 아닌 것 같습니다 . 계속되면 정신건강의학과 진료를 받아보셔야 합니다 .' in '증상은 아닌 것 같습니다. 계속되면 정신건강의학과 진료를 받아보셔야 합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,650 >> Unable to find text: '##니다' in '있습니다.수면시에'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,651 >> Unable to find text: '##합니다' in '못합니다.통학시간이'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,651 >> Unable to find text: '##합니다 . 통학시간이 너무 많아 체력에 문제가 있다면 이에 대한 조절이 필요하리라 보이고요' in '못합니다.통학시간이 너무 많아 체력에 문제가 있다면 이에 대한 조절이 필요하리라 보이고요.아침식사를'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,651 >> Unable to find text: '##요' in '보이고요.아침식사를'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,651 >> Unable to find text: '##합니다 . 통학시간이 너무' in '못합니다.통학시간이 너무'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,651 >> Unable to find text: '##니다 .' in '있습니다.수면시에'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,653 >> Unable to find text: '##합니다' in '좋을듯합니다'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,653 >> Unable to find text: '##구요 . 약물 변경 등도 고려해 보시는게 좋을듯합니다' in '궁금하구요. 약물 변경 등도 고려해 보시는게 좋을듯합니다'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,653 >> Unable to find text: '##구요' in '궁금하구요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,654 >> Unable to find text: '##입니다 .' in '높아보입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,654 >> Unable to find text: '##구요 .' in '궁금하구요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,654 >> Unable to find text: '##입니다 . 현재까지 적어주신 내용으로 본다면 기질적인 문제는 없을 가능성이 높아보입니다 .' in '한재병입니다. 현재까지 적어주신 내용으로 본다면 기질적인 문제는 없을 가능성이 높아보입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,655 >> Unable to find text: '##립니다' in '권고드립니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,656 >> Unable to find text: '##립니다 . 어떤 원인에 의해서 호흡곤란이 있는지 원인을 찾아서 치료 해야할 상태로 판단됩니다 .' in '권고드립니다. 어떤 원인에 의해서 호흡곤란이 있는지 원인을 찾아서 치료 해야할 상태로 판단됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,656 >> Unable to find text: '##립니다 .' in '권고드립니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,657 >> Unable to find text: '##니다 . 가까운 내과에 가셔서 진료를 보고 흉부 사진과 혈액검사 . 폐기능 검사를받아 보시는 것을 권고드립니다' in '하셨습니다. 가까운 내과에 가셔서 진료를 보고 흉부 사진과 혈액검사. 폐기능 검사를받아 보시는 것을 권고드립니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,658 >> Unable to find text: '##니다 .' in '않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,659 >> Unable to find text: '##은 특별하게 필요할 것으로 보이지 않습니다 .' in '것은 특별하게 필요할 것으로 보이지 않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,659 >> Unable to find text: '##으니 안심하셔도 좋습니다 . 시간간격을 떼는 것은 특별하게 필요할 것으로 보이지 않습니다 .' in '없으니 안심하셔도 좋습니다. 시간간격을 떼는 것은 특별하게 필요할 것으로 보이지 않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,659 >> Unable to find text: '##니다 . 시간간격을 떼는 것은 특별하게 필요할 것으로 보이지 않습니다 .' in '좋습니다. 시간간격을 떼는 것은 특별하게 필요할 것으로 보이지 않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,659 >> Unable to find text: '##으니 안심하셔도 좋습니다 .' in '없으니 안심하셔도 좋습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,661 >> Unable to find text: '##구요 . 병원가셔서 혈액검사 시행해보시기 바랍니다' in '같구요. 병원가셔서 혈액검사 시행해보시기 바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,662 >> Unable to find text: '##구요 . 병원가셔서 혈액검사 시행해보시기 바랍니다 . 갑상선 기능 검사도 해보시는게 좋겠구요' in '같구요. 병원가셔서 혈액검사 시행해보시기 바랍니다. 갑상선 기능 검사도 해보시는게 좋겠구요..몸에'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,662 >> Unable to find text: '##구요' in '같구요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,665 >> Unable to find text: '##구요' in '있구요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,665 >> Unable to find text: '##죠' in '있는거죠.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,666 >> Unable to find text: '##세요 .' in '받아보세요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,666 >> Unable to find text: '##정신건강의학과 전문의를 찾아가 면담을 통해 정신상태평가를 받아보세요 .' in '준다면정신건강의학과 전문의를 찾아가 면담을 통해 정신상태평가를 받아보세요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,666 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,666 >> Unable to find text: '##세요' in '받아보세요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,667 >> Unable to find text: '##정신건강의학과 전문의를 찾아가 면담을 통해 정신상태평가를 받아보세요' in '준다면정신건강의학과 전문의를 찾아가 면담을 통해 정신상태평가를 받아보세요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,667 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,667 >> Unable to find text: '##2' in '섭취2)'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,668 >> Unable to find text: '##니다 .' in '생각됩니다 .'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,669 >> Unable to find text: '##니 공황장애라기 보다는 카페인의 분해 능력이 떨어지면서 나타나는 카페인 과민 증상으로 생각됩니다 .' in '증상이니 공황장애라기 보다는 카페인의 분해 능력이 떨어지면서 나타나는 카페인 과민 증상으로 생각됩니다 .'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,669 >> Unable to find text: '##는 카페인의 분해 능력이 떨어지면서 나타나는 카페인 과민 증상으로 생각됩니다 .' in '보다는 카페인의 분해 능력이 떨어지면서 나타나는 카페인 과민 증상으로 생각됩니다 .'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,669 >> Unable to find text: '##입니다 . 커피' in '홍인표입니다. 커피'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,670 >> Unable to find text: '##니다' in '생각됩니다'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,674 >> Unable to find text: '##니다 .' in '않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,674 >> Unable to find text: '##도 내성은 초기화되지 않습니다 .' in '중단해도 내성은 초기화되지 않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,675 >> Unable to find text: '##니다' in '있습니다.MRI'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,675 >> Unable to find text: '##니다 .' in '있습니다.MRI'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,676 >> Length not equal after stripping spaces: '다른데, 비교적최근이시라면 뇌졸중후우울증등을고려할수있습니다.' vs '다른데,비교적최근이시라면뇌졸중후우울증등을고려할수있습니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,676 >> Length not equal after stripping spaces: '있습니다.우선두번의출혈이어느시점이었느지에따라조금다른데, 비교적' vs '있습니다.우선두번의출혈이어느시점이었느지에따라조금다른데,비교적'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,676 >> Length not equal after stripping spaces: '최근이시라면 뇌졸중후우울증등을고려할수있습니다.' vs '최근이시라면뇌졸중후우울증등을고려할수있습니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,676 >> Length not equal after stripping spaces: '다른데, 비교적최근이시라면 뇌졸중후우울증등을고려할수있습니다.' vs '다른데,비교적최근이시라면뇌졸중후우울증등을고려할수있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,676 >> Unable to find text: '##니다 . MRI' in '있습니다.MRI'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,677 >> Length not equal after stripping spaces: '다른데, 비교적최근이시라면 뇌졸중후우울증등을고려할수있습니다.적어도' vs '다른데,비교적최근이시라면뇌졸중후우울증등을고려할수있습니다.적어도'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,677 >> Length not equal after stripping spaces: '최근이시라면 뇌졸중후우울증등을고려할수있습니다.' vs '최근이시라면뇌졸중후우울증등을고려할수있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,679 >> Unable to find text: '##니다' in '있습니다.진단은'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,679 >> Unable to find text: '##니다 . 진단은 꾸준히 상담하시는 선생님이 하는 것이 더 정확합니다' in '있습니다.진단은 꾸준히 상담하시는 선생님이 하는 것이 더 정확합니다.쿠에타핀을'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,679 >> Unable to find text: '##합니다' in '정확합니다.쿠에타핀을'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,680 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,680 >> Unable to find text: '##니다 . 진단은 꾸준히 상담하시는 선생님이 하는 것이 더 정확합니다 .' in '있습니다.진단은 꾸준히 상담하시는 선생님이 하는 것이 더 정확합니다.쿠에타핀을'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,680 >> Unable to find text: '##니다 .' in '있습니다.진단은'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,681 >> Unable to find text: '##합니다 .' in '정확합니다.쿠에타핀을'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,682 >> Unable to find text: '##세요' in '방문하세요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,683 >> Unable to find text: '##세요 .' in '방문하세요.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,684 >> Length not equal after stripping spaces: '게임을했건,모니터를그만큼바라 보고있었다면,발생할수있는현상이있습니다.' vs '게임을했건,모니터를그만큼바라보고있었다면,발생할수있는현상이있습니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,684 >> Length not equal after stripping spaces: '특이한것이아닙니다.게임을했건,모니터를그만큼바라 보고있었다면,발생할수있는현상이있습니다.' vs '특이한것이아닙니다.게임을했건,모니터를그만큼바라보고있었다면,발생할수있는현상이있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,686 >> Unable to find text: '##가 보기에는 공황장애 증상이 아닌가 하는생각이 듭니다 . 아마도 스트레스가 심하셨나 봅니다 .' in '제가 보기에는 공황장애 증상이 아닌가 하는생각이 듭니다. 아마도 스트레스가 심하셨나 봅니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,687 >> Unable to find text: '##는 공황장애 증상이 아닌가 하는생각이 듭니다 . 아마도 스트레스가 심하셨나 봅니다 .' in '보기에는 공황장애 증상이 아닌가 하는생각이 듭니다. 아마도 스트레스가 심하셨나 봅니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,687 >> Unable to find text: '##가 보기에는 공황장애 증상이 아닌가 하는생각이 듭니다 .' in '제가 보기에는 공황장애 증상이 아닌가 하는생각이 듭니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,691 >> Unable to find text: '##니다' in '같습니다.상황을'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,692 >> Unable to find text: '##니다 . 대인관계에 자신감을 잃으면서 우울한 것도 나타나기 시작 하는 것 같습니다' in '같습니다.대인관계에 자신감을 잃으면서 우울한 것도 나타나기 시작 하는 것 같습니다.상황을'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,692 >> Unable to find text: '##니다 . 상황을 이겨내려고 좀더 노력해 보세요' in '같습니다.상황을 이겨내려고 좀더 노력해 보세요.다른'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,692 >> Unable to find text: '##요' in '보세요.다른'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,692 >> Unable to find text: '##니다' in '같습니다.대인관계에'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,693 >> Unable to find text: '##니다 . 상황을 이겨내려고 좀더 노력해 보세요 . 다른 사람들은 .' in '같습니다.상황을 이겨내려고 좀더 노력해 보세요.다른 사람들은 ..님의'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,693 >> Unable to find text: '##요 . 다른 사람들은 .' in '보세요.다른 사람들은 ..님의'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,694 >> Unable to find text: '##니다' in '높습니다'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,694 >> Unable to find text: '##입니다 . 일단' in '홍인표입니다. 일단'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,695 >> Unable to find text: '##입니다 .' in '홍인표입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,695 >> Unable to find text: '전반적인 불안증의 치료는 비슷한 형태를 [UNK] . 우선 약물 치료를 시작하면서 불안감을 감소시킵니다' in '전반적인 불안증의 치료는 비슷한 형태를 띱니다. 우선 약물 치료를 시작하면서 불안감을 감소시킵니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,696 >> Unable to find text: '전반적인 불안증의 치료는 비슷한 형태를 [UNK]' in '전반적인 불안증의 치료는 비슷한 형태를 띱니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,696 >> Unable to find text: '전반적인 불안증의 치료는 비슷한 형태를 [UNK] .' in '전반적인 불안증의 치료는 비슷한 형태를 띱니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,696 >> Unable to find text: '전반적인 불안증의 치료는 비슷한 형태를 [UNK] . 우선 약물 치료를 시작하면서 불안감을 감소시킵니다 .' in '전반적인 불안증의 치료는 비슷한 형태를 띱니다. 우선 약물 치료를 시작하면서 불안감을 감소시킵니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,697 >> Unable to find text: '##니다 . 전반적인 불안증의 치료는 비슷한 형태를 [UNK] . 우선 약물 치료를 시작하면서 불안감을 감소시킵니다' in '같습니다. 전반적인 불안증의 치료는 비슷한 형태를 띱니다. 우선 약물 치료를 시작하면서 불안감을 감소시킵니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,697 >> Unable to find text: '##킵니다' in '감소시킵니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,697 >> Unable to find text: '##니다' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,697 >> Unable to find text: '불안증의 치료는 비슷한 형태를 [UNK] . 우선 약물 치료를 시작하면서 불안감을 감소시킵니다' in '불안증의 치료는 비슷한 형태를 띱니다. 우선 약물 치료를 시작하면서 불안감을 감소시킵니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,697 >> Unable to find text: '. 전반적인 불안증의 치료는 비슷한 형태를 [UNK] . 우선 약물 치료를 시작하면서 불안감을 감소시킵니다' in '같습니다. 전반적인 불안증의 치료는 비슷한 형태를 띱니다. 우선 약물 치료를 시작하면서 불안감을 감소시킵니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,744 >> Unable to find text: '##니다 .' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,745 >> Unable to find text: '##킵니다 . 짧게는 4주 길게는 8주 가량 약물 치료를 하면 증상의 많은 호전을 보일 수 있는데요' in '감소시킵니다. 짧게는 4주 길게는 8주 가량 약물 치료를 하면 증상의 많은 호전을 보일 수 있는데요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,746 >> Unable to find text: '##니다 . 전반적인 불안증의 치료는 비슷한 형태를 [UNK]' in '같습니다. 전반적인 불안증의 치료는 비슷한 형태를 띱니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,746 >> Unable to find text: '불안증의 치료는 비슷한 형태를 [UNK]' in '불안증의 치료는 비슷한 형태를 띱니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,746 >> Unable to find text: '. 전반적인 불안증의 치료는 비슷한 형태를 [UNK]' in '같습니다. 전반적인 불안증의 치료는 비슷한 형태를 띱니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,746 >> Unable to find text: '##니다 . 전반적인 불안증의 치료는 비슷한 형태를 [UNK] .' in '같습니다. 전반적인 불안증의 치료는 비슷한 형태를 띱니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,746 >> Unable to find text: '불안증의 치료는 비슷한 형태를 [UNK] .' in '불안증의 치료는 비슷한 형태를 띱니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,746 >> Unable to find text: '. 전반적인 불안증의 치료는 비슷한 형태를 [UNK] .' in '같습니다. 전반적인 불안증의 치료는 비슷한 형태를 띱니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,747 >> Unable to find text: '##니다 . 전반적인 불안증의 치료는 비슷한 형태를 [UNK] . 우선 약물 치료를 시작하면서 불안감을 감소시킵니다 .' in '같습니다. 전반적인 불안증의 치료는 비슷한 형태를 띱니다. 우선 약물 치료를 시작하면서 불안감을 감소시킵니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,747 >> Unable to find text: '##킵니다 .' in '감소시킵니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,747 >> Unable to find text: '불안증의 치료는 비슷한 형태를 [UNK] . 우선 약물 치료를 시작하면서 불안감을 감소시킵니다 .' in '불안증의 치료는 비슷한 형태를 띱니다. 우선 약물 치료를 시작하면서 불안감을 감소시킵니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,747 >> Unable to find text: '. 전반적인 불안증의 치료는 비슷한 형태를 [UNK] . 우선 약물 치료를 시작하면서 불안감을 감소시킵니다 .' in '같습니다. 전반적인 불안증의 치료는 비슷한 형태를 띱니다. 우선 약물 치료를 시작하면서 불안감을 감소시킵니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,757 >> Length not equal after stripping spaces: '입니다.심리적으로그분을많이의지하셨나봅니다. 많이의지한만큼헤어짐의충격도크기때문입니다.시.' vs '입니다.심리적으로그분을많이의지하셨나봅니다.많이의지한만큼헤어짐의충격도크기때문입니다.시.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,757 >> Length not equal after stripping spaces: '때문입니다.시.간이지나면조금씩회복될것입니다. 그' vs '때문입니다.시.간이지나면조금씩회복될것입니다.그'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,758 >> Length not equal after stripping spaces: '것입니다. 그분마음을돌리는것은쉽지않아보입니다.' vs '것입니다.그분마음을돌리는것은쉽지않아보입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,758 >> Length not equal after stripping spaces: '입니다.심리적으로그분을많이의지하셨나봅니다. 많이의지한만큼헤어짐의충격도크기때문입니다.시.' vs '입니다.심리적으로그분을많이의지하셨나봅니다.많이의지한만큼헤어짐의충격도크기때문입니다.시.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,758 >> Length not equal after stripping spaces: '때문입니다.시.간이지나면조금씩회복될것입니다. 그분마음을돌리는것은쉽지않아보입니다.' vs '때문입니다.시.간이지나면조금씩회복될것입니다.그분마음을돌리는것은쉽지않아보입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,759 >> Length not equal after stripping spaces: '같습니다. 다시만난다고해도지금과같은마음이면다시상처를받을가능성이많아보입니다. 님이' vs '같습니다.다시만난다고해도지금과같은마음이면다시상처를받을가능성이많아보입니다.님이'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,759 >> Length not equal after stripping spaces: '입니다.심리적으로그분을많이의지하셨나봅니다. 많이' vs '입니다.심리적으로그분을많이의지하셨나봅니다.많이'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,759 >> Unable to find text: '##입니다' in '것입니다. 그'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,759 >> Unable to find text: '##입니다 . 그 분 마음을 돌리는 것은 쉽지 않아 보입니다' in '것입니다. 그 분 마음을 돌리는 것은 쉽지 않아 보입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,760 >> Length not equal after stripping spaces: '보입니다.그분에대한마음을정리를하시는것이좋을것같습니다. 다시' vs '보입니다.그분에대한마음을정리를하시는것이좋을것같습니다.다시'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,760 >> Length not equal after stripping spaces: '입니다.심리적으로그분을많이의지하셨나봅니다. 많이의지한만큼헤어짐의충격도크기때문입니다.시.' vs '입니다.심리적으로그분을많이의지하셨나봅니다.많이의지한만큼헤어짐의충격도크기때문입니다.시.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,760 >> Length not equal after stripping spaces: '봅니다. 많이의지한만큼헤어짐의충격도크기때문입니다.시.간이지나면조금씩회복될것입니다. 그' vs '봅니다.많이의지한만큼헤어짐의충격도크기때문입니다.시.간이지나면조금씩회복될것입니다.그'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,761 >> Unable to find text: '##니다' in '같습니다. 다시'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,761 >> Length not equal after stripping spaces: '때문입니다.시.간이지나면조금씩회복될것입니다. 그' vs '때문입니다.시.간이지나면조금씩회복될것입니다.그'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,761 >> Length not equal after stripping spaces: '헤어짐의충격도크기때문입니다.시.간이지나면조금씩회복될것입니다. 그' vs '헤어짐의충격도크기때문입니다.시.간이지나면조금씩회복될것입니다.그'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,762 >> Unable to find text: '##니다 . 다시 만난다고 해도 지금과 같은 마음이면 다시 상처를 받을 가능성이 많아 보입니다' in '같습니다. 다시 만난다고 해도 지금과 같은 마음이면 다시 상처를 받을 가능성이 많아 보입니다. 님이'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,762 >> Unable to find text: '##입니다 . 시 . 간이 지나면 조금씩 회복 될 것입니다' in '때문입니다.시. 간이 지나면 조금씩 회복 될 것입니다. 그'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,762 >> Length not equal after stripping spaces: '때문입니다.시.간이지나면조금씩회복될것입니다. 그' vs '때문입니다.시.간이지나면조금씩회복될것입니다.그'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,762 >> Length not equal after stripping spaces: '그분에대한마음을정리를하시는것이좋을것같습니다. 다시' vs '그분에대한마음을정리를하시는것이좋을것같습니다.다시'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,763 >> Length not equal after stripping spaces: '때문입니다.시.간이지나면조금씩회복될것입니다. 그분마음을돌리는것은쉽지않아보입니다.' vs '때문입니다.시.간이지나면조금씩회복될것입니다.그분마음을돌리는것은쉽지않아보입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,763 >> Length not equal after stripping spaces: '보입니다. 님이' vs '보입니다.님이'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,763 >> Length not equal after stripping spaces: '지금과같은마음이면다시상처를받을가능성이많아보입니다. 님이' vs '지금과같은마음이면다시상처를받을가능성이많아보입니다.님이'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,763 >> Unable to find text: '##입니다 . 시 . 간이 지나면 조금씩 회복 될 것입니다 . 그 분 마음을 돌리는 것은 쉽지 않아 보입니다' in '때문입니다.시. 간이 지나면 조금씩 회복 될 것입니다. 그 분 마음을 돌리는 것은 쉽지 않아 보입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,764 >> Length not equal after stripping spaces: '때문입니다.시.간이지나면조금씩회복될것입니다. 그분마음을돌리는것은쉽지않아보입니다.' vs '때문입니다.시.간이지나면조금씩회복될것입니다.그분마음을돌리는것은쉽지않아보입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,764 >> Length not equal after stripping spaces: '보입니다. 님이빨리회복되는것이중요합니다.' vs '보입니다.님이빨리회복되는것이중요합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,764 >> Length not equal after stripping spaces: '때문입니다.시.간이지나면조금씩회복될것입니다. 그' vs '때문입니다.시.간이지나면조금씩회복될것입니다.그'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,764 >> Length not equal after stripping spaces: '같습니다. 다시만난다고해도지금과같은마음이면다시상처를받을가능성이많아보입니다. 님이' vs '같습니다.다시만난다고해도지금과같은마음이면다시상처를받을가능성이많아보입니다.님이'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,765 >> Length not equal after stripping spaces: '것입니다. 그분마음을돌리는것은쉽지않아보입니다.' vs '것입니다.그분마음을돌리는것은쉽지않아보입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,765 >> Length not equal after stripping spaces: '때문입니다.시.간이지나면조금씩회복될것입니다. 그분마음을돌리는것은쉽지않아보입니다.' vs '때문입니다.시.간이지나면조금씩회복될것입니다.그분마음을돌리는것은쉽지않아보입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,765 >> Length not equal after stripping spaces: '보입니다. 님이빨리회복되는것이중요합니다.' vs '보입니다.님이빨리회복되는것이중요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,765 >> Unable to find text: '##입니다 .' in '것입니다. 그'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,765 >> Length not equal after stripping spaces: '보입니다. 님이빨리회복되는것이중요합니다. 문의에도움이되었으면합니다.' vs '보입니다.님이빨리회복되는것이중요합니다.문의에도움이되었으면합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,766 >> Length not equal after stripping spaces: '보입니다. 님이빨리회복되는것이중요합니다. 문의에도움이되었으면합니다.' vs '보입니다.님이빨리회복되는것이중요합니다.문의에도움이되었으면합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,766 >> Length not equal after stripping spaces: '보입니다.그분에대한마음을정리를하시는것이좋을것같습니다. 다시' vs '보입니다.그분에대한마음을정리를하시는것이좋을것같습니다.다시'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,766 >> Length not equal after stripping spaces: '보입니다. 님이' vs '보입니다.님이'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,766 >> Unable to find text: '##입니다 . 그 분 마음을 돌리는 것은 쉽지 않아 보입니다 .' in '것입니다. 그 분 마음을 돌리는 것은 쉽지 않아 보입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,766 >> Unable to find text: '##니다 . 다시 만난다고 해도 지금과 같은 마음이면 다시 상처를 받을 가능성이 많아 보입니다 .' in '같습니다. 다시 만난다고 해도 지금과 같은 마음이면 다시 상처를 받을 가능성이 많아 보입니다. 님이'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,766 >> Unable to find text: '##니다 .' in '같습니다. 다시'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,767 >> Length not equal after stripping spaces: '봅니다. 많이의지한만큼헤어짐의충격도크기때문입니다.시.간이지나면조금씩회복될것입니다. 그' vs '봅니다.많이의지한만큼헤어짐의충격도크기때문입니다.시.간이지나면조금씩회복될것입니다.그'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,767 >> Length not equal after stripping spaces: '같습니다. 다시만난다고해도지금과같은마음이면다시상처를받을가능성이많아보입니다. 님이' vs '같습니다.다시만난다고해도지금과같은마음이면다시상처를받을가능성이많아보입니다.님이'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,767 >> Length not equal after stripping spaces: '보입니다. 님이빨리회복되는것이중요합니다.' vs '보입니다.님이빨리회복되는것이중요합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,767 >> Length not equal after stripping spaces: '보입니다. 님이' vs '보입니다.님이'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,768 >> Length not equal after stripping spaces: '지금과같은마음이면다시상처를받을가능성이많아보입니다. 님이빨리회복되는것이중요합니다.' vs '지금과같은마음이면다시상처를받을가능성이많아보입니다.님이빨리회복되는것이중요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,771 >> Unable to find text: '##니다' in '지닙니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,771 >> Unable to find text: '##니다 . 그리고 언제 공황장애 증상이 나타날지 몰라 불안감이 지속되어야 합니다' in '지닙니다. 그리고 언제 공황장애 증상이 나타날지 몰라 불안감이 지속되어야 합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,772 >> Unable to find text: '##합니다' in '진행합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,772 >> Unable to find text: '##니다 .' in '지닙니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,773 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,774 >> Unable to find text: '##니다' in '판단됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,774 >> Unable to find text: '##니다 . 만약 있다하더라도 , 그 가능성은 매우 낮을 것으로 판단됩니다' in '있습니다. 만약 있다하더라도, 그 가능성은 매우 낮을 것으로 판단됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,774 >> Unable to find text: '##니다 .' in '판단됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,775 >> Unable to find text: '##니다 . 만약 있다하더라도 , 그 가능성은 매우 낮을 것으로 판단됩니다 .' in '있습니다. 만약 있다하더라도, 그 가능성은 매우 낮을 것으로 판단됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,775 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,775 >> Unable to find text: '##니다 . 다만' in '판단됩니다. 다만,'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,776 >> Length not equal after stripping spaces: '우울증인경우약물치료가 필요합니다.' vs '우울증인경우약물치료가필요합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,776 >> Length not equal after stripping spaces: '수있지만,우울증은치료를하면많은변화가있을수있습니다.우울증인경우약물치료가 필요합니다.' vs '수있지만,우울증은치료를하면많은변화가있을수있습니다.우울증인경우약물치료가필요합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,777 >> Length not equal after stripping spaces: '우울증인경우약물치료가 필요합니다.' vs '우울증인경우약물치료가필요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,848 >> Unable to find text: '##면 .' in '보인다면...우울증'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,848 >> Length not equal after stripping spaces: '수있지만,우울증은치료를하면많은변화가있을수있습니다.우울증인경우약물치료가 필요합니다.' vs '수있지만,우울증은치료를하면많은변화가있을수있습니다.우울증인경우약물치료가필요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,849 >> Unable to find text: '##면 . . . 우울증 가능성도 있습니다' in '보인다면...우울증 가능성도 있습니다.성격적인'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,849 >> Unable to find text: '##면 . .' in '보인다면...우울증'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,849 >> Unable to find text: '##니다' in '있습니다.성격적인'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,853 >> Unable to find text: '##니다 .' in '않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,854 >> Unable to find text: '##니다' in '않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,856 >> Unable to find text: '##니다' in '괜찮습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,856 >> Unable to find text: '##합니다 . 불면증이 며칠밖에 되지 않았다면 좀 더 지켜보아도 괜찮습니다' in '발생합니다.불면증이 며칠밖에 되지 않았다면 좀 더 지켜보아도 괜찮습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,856 >> Unable to find text: '##합니다' in '발생합니다.불면증이'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,856 >> Unable to find text: '##니다 . 급성 스트레스로 인한 불면증은 2주 이상 지속되지 않습니다' in '괜찮습니다. 급성 스트레스로 인한 불면증은 2주 이상 지속되지 않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,857 >> Unable to find text: '##니다' in '않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,857 >> Unable to find text: '##니다 .' in '괜찮습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,858 >> Unable to find text: '##합니다 . 불면증이 며칠밖에 되지 않았다면 좀 더 지켜보아도 괜찮습니다 .' in '발생합니다.불면증이 며칠밖에 되지 않았다면 좀 더 지켜보아도 괜찮습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,858 >> Unable to find text: '##니다 . 만약 불면증이 2주 이상 지속된다면 검사 및 치료를 하는 것이 좋습니다' in '않습니다. 만약 불면증이 2주 이상 지속된다면 검사 및 치료를 하는 것이 좋습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,858 >> Unable to find text: '##합니다 .' in '발생합니다.불면증이'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,862 >> Unable to find text: '##합니다' in '권유합니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,862 >> Unable to find text: '##입니다 . 정신과 초진시 일반적으로 1시간 이상 자세한 면담을 하게 됩니다' in '없어보입니다.정신과 초진시 일반적으로 1시간 이상 자세한 면담을 하게 됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,863 >> Unable to find text: '##입니다 . 정신과 초진시 일반적으로 1시간 이상 자세한 면담을 하게 됩니다 . 많이 불편하시다면 정신과 진료를 권유합니다' in '없어보입니다.정신과 초진시 일반적으로 1시간 이상 자세한 면담을 하게 됩니다. 많이 불편하시다면 정신과 진료를 권유합니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,871 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,871 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,873 >> Unable to find text: '##니다 . 도움이 되셨으면 좋겠습니다' in '있습니다. 도움이 되셨으면 좋겠습니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,873 >> Unable to find text: '##니다 . 도움이 되셨으면 좋겠습니다 .' in '있습니다. 도움이 되셨으면 좋겠습니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,873 >> Unable to find text: '##니다 . 도움이 되셨으면 좋겠습니다 . 감사합니다' in '있습니다. 도움이 되셨으면 좋겠습니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,876 >> Unable to find text: '##고 검사 결과가 정상이라면 신경과에 방문해 보시는 것이 도움이 되고 직접 치료를 받아보시길 바랍니다 .' in '필요하고 검사 결과가 정상이라면 신경과에 방문해 보시는 것이 도움이 되고 직접 치료를 받아보시길 바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,876 >> Unable to find text: '##입니다 . 근육' in '박종원입니다. 근육이'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,877 >> Unable to find text: '##고 검사 결과가 정상이라면 신경과에 방문해 보시는 것이 도움이 되고 직접 치료를 받아보시길 바랍니다' in '필요하고 검사 결과가 정상이라면 신경과에 방문해 보시는 것이 도움이 되고 직접 치료를 받아보시길 바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,890 >> Unable to find text: '##입니다 . 안심하셔도 됩니다' in '때문입니다 . 안심하셔도 됩니다'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,890 >> Unable to find text: '##입니다 .' in '때문입니다 .'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,891 >> Unable to find text: '##입니다 . 안심하셔도 됩니다 .' in '때문입니다 . 안심하셔도 됩니다 .'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,892 >> Unable to find text: '##니다' in '있겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,892 >> Unable to find text: '##니다 .' in '있겠습니다.부정맥이'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,892 >> Unable to find text: '##니다 . 부정맥이 배제 된다면 심리적인 것을 우선적으로 생각해 볼 수 있겠습니다' in '있겠습니다.부정맥이 배제 된다면 심리적인 것을 우선적으로 생각해 볼 수 있겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,892 >> Unable to find text: '##니다 .' in '있겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,892 >> Unable to find text: '##니다 . 부정맥이 배제 된다면 심리적인 것을 우선적으로 생각해 볼 수 있겠습니다 .' in '있겠습니다.부정맥이 배제 된다면 심리적인 것을 우선적으로 생각해 볼 수 있겠습니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,893 >> Length not equal after stripping spaces: '24시간심전도등여러가지검사가있지만 증상이매일있지않은이상은확인하기어려울수있습니다.어떤' vs '24시간심전도등여러가지검사가있지만증상이매일있지않은이상은확인하기어려울수있습니다.어떤'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,893 >> Unable to find text: '##니다' in '있겠습니다.부정맥이'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,894 >> Length not equal after stripping spaces: '24시간심전도를수행하면서유발요인을자극해보는것이 부정맥여부진단에가장도움이될수있겠습니다.부정맥이' vs '24시간심전도를수행하면서유발요인을자극해보는것이부정맥여부진단에가장도움이될수있겠습니다.부정맥이'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,894 >> Length not equal after stripping spaces: '24시간심전도를수행하면서유발요인을자극해보는것이 부정맥여부진단에가장도움이될수있겠습니다.부정맥이' vs '24시간심전도를수행하면서유발요인을자극해보는것이부정맥여부진단에가장도움이될수있겠습니다.부정맥이'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,895 >> Unable to find text: '##요' in '좋겠네요'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,895 >> Unable to find text: '##겠네요' in '좋겠네요'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,895 >> Unable to find text: '##니다 . 정신건강의학과에서 꾸준한 치료를 받아보시는것이 좋겠네요' in '생각됩니다. 정신건강의학과에서 꾸준한 치료를 받아보시는것이 좋겠네요'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,896 >> Unable to find text: '##네요' in '좋겠네요'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,896 >> Unable to find text: '##것이 좋겠네요' in '받아보시는것이 좋겠네요'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,896 >> Unable to find text: '##것으로 생각됩니다 . 정신건강의학과에서 꾸준한 치료를 받아보시는것이 좋겠네요' in '있으신것으로 생각됩니다. 정신건강의학과에서 꾸준한 치료를 받아보시는것이 좋겠네요'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,896 >> Unable to find text: '##니다 .' in '생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,896 >> Unable to find text: '##입니다 . 수면주기가 무너지면서 불면증이 있으신것으로 생각됩니다 .' in '홍인표입니다. 수면주기가 무너지면서 불면증이 있으신것으로 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,896 >> Unable to find text: '##것으로 생각됩니다 .' in '있으신것으로 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,898 >> Unable to find text: '##요' in '이야기겠지요.그러므로,'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,898 >> Unable to find text: '##니다' in '판단하셔야겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,898 >> Unable to find text: '##니다' in '같습니다.그리고,'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,898 >> Unable to find text: '##니다 .' in '판단하셔야겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,898 >> Unable to find text: '##니다 .' in '같습니다.그리고,'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,899 >> Unable to find text: '##니다 . 그리고 , 강제로 입원을 시킨다고 해서 억지로 끌고가는 것만 상상하시며 곤란합니다' in '같습니다.그리고, 강제로 입원을 시킨다고 해서 억지로 끌고가는 것만 상상하시며 곤란합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,899 >> Unable to find text: '##합니다' in '곤란합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,899 >> Unable to find text: '##합니다 . 주변에 도움을 줄 다른 가족들 여러명이 족한 경우가 더 많습니다' in '곤란합니다. 주변에 도움을 줄 다른 가족들 여러명이 족한 경우가 더 많습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,899 >> Unable to find text: '##요 .' in '이야기겠지요.그러므로,'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,901 >> Unable to find text: '##요' in '있지요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,901 >> Unable to find text: '##입니다 . 맞습니다 . 하품이 나는 특이한 부작용이 있지요' in '약입니다. 맞습니다. 하품이 나는 특이한 부작용이 있지요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,901 >> Unable to find text: '##요 . 게다가 자연스러운 하품이 아니므로 , 평상시 하품 할때와 좀 기분이 다르니 불쾌하게 느껴지실 수도 있습니다' in '있지요. 게다가 자연스러운 하품이 아니므로, 평상시 하품 할때와 좀 기분이 다르니 불쾌하게 느껴지실 수도 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,901 >> Unable to find text: '##입니다' in '약입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,902 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,902 >> Unable to find text: '##합니다 .' in '할듯합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,903 >> Unable to find text: '##입니다 . 정신과' in '한재병입니다. 정신과'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,903 >> Unable to find text: '##합니다' in '할듯합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,903 >> Unable to find text: '##입니다 .' in '한재병입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,903 >> Unable to find text: '##입니다' in '한재병입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,904 >> Unable to find text: '##2' in '있을까요2'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,904 >> Unable to find text: '##도' in '했을때도'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,904 >> Unable to find text: '##입니다 . 정신과 선생님이 판단을 했을때도' in '한재병입니다. 정신과 선생님이 판단을 했을때도'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,904 >> Unable to find text: '##이 판단을 했을때도' in '선생님이 판단을 했을때도'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,907 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,908 >> Unable to find text: '##니다' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,908 >> Unable to find text: '##입니다 . 초로기 치매는 50대 초반 ( 40대에도 ) 올 수 있습니다' in '증상입니다. 초로기 치매는 50대 초반 (40대에도) 올 수 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,909 >> Unable to find text: '##니다 . 초로기 치매는 우울증으로 처음에 오인되기 쉽습니다' in '같습니다. 초로기 치매는 우울증으로 처음에 오인되기 쉽습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,909 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,910 >> Unable to find text: '##입니다 .' in '검사입니다.교수님'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,911 >> Unable to find text: '##입니다' in '검사입니다.교수님'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,924 >> Unable to find text: '##입니다 .' in '것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,924 >> Unable to find text: '##입니다' in '것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,925 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,925 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,926 >> Unable to find text: '##니다 . 도움이 되셨으면 좋겠습니다' in '있습니다. 도움이 되셨으면 좋겠습니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,926 >> Unable to find text: '##니다 . 도움이 되셨으면 좋겠습니다 . 감사합니다' in '있습니다. 도움이 되셨으면 좋겠습니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,926 >> Unable to find text: '##니다' in '좋겠습니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,927 >> Unable to find text: '##니다 . 도움이 되셨으면 좋겠습니다 .' in '있습니다. 도움이 되셨으면 좋겠습니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,927 >> Unable to find text: '##니다 . 도움이 되셨으면 좋겠습니다 . 감사합니다 .' in '있습니다. 도움이 되셨으면 좋겠습니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,928 >> Unable to find text: '##요' in '않고요.그러니'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,928 >> Unable to find text: '##니다 . 두께로는 구별하지 않고요' in '보시면됩니다. 두께로는 구별하지 않고요.그러니'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,928 >> Unable to find text: '##니다 .' in '보시면됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,929 >> Unable to find text: '##니다' in '보시면됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,930 >> Unable to find text: '##니다' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,948 >> Unable to find text: '##니다 . 하루 한 두잔 정도의 커피라면 현재 복용 중인 약물의 작용에도 크게 방해가 되지 않을 것 같습니다' in '같습니다. 하루 한 두잔 정도의 커피라면 현재 복용 중인 약물의 작용에도 크게 방해가 되지 않을 것 같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,948 >> Unable to find text: '##니다 .' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,948 >> Unable to find text: '##니다' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,948 >> Unable to find text: '##니다 . 하루 한 두잔 정도의 커피라면 현재 복용 중인 약물의 작용에도 크게 방해가 되지 않을 것 같습니다 .' in '같습니다. 하루 한 두잔 정도의 커피라면 현재 복용 중인 약물의 작용에도 크게 방해가 되지 않을 것 같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,949 >> Unable to find text: '##니다 .' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,950 >> Unable to find text: '##요 .' in '생각되네요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,951 >> Unable to find text: '##니다' in '받았습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,952 >> Unable to find text: '##니다 .' in '받았습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,953 >> Unable to find text: '##합니다 .' in '중요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,955 >> Unable to find text: '##입니다' in '의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,955 >> Unable to find text: '##합니다 . 즉 , 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다' in '발생합니다. 즉, 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,956 >> Unable to find text: '##합니다' in '발생합니다.규칙적인'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,956 >> Unable to find text: '##입니다 . 만약' in '의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,956 >> Unable to find text: '##합니다' in '권합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,956 >> Unable to find text: '##합니다 . 즉 , 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다 . 만약' in '발생합니다. 즉, 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,957 >> Unable to find text: '##합니다' in '발생합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,958 >> Unable to find text: '##니다 .' in '높습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,958 >> Unable to find text: '##나제팜은 약을 끊게 되면 잠을 잘 못잘 가능성이 높습니다 .' in '클로나제팜은 약을 끊게 되면 잠을 잘 못잘 가능성이 높습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,958 >> Unable to find text: '##합니다' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,959 >> Unable to find text: '##합니다 .' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,961 >> Unable to find text: '##입니다 .' in '것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,961 >> Unable to find text: '##입니다 . 자율' in '변기원입니다. 자율신경이란'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:14,961 >> Unable to find text: '##으로 자율' in '결론적으로 자율신경이'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:14,963 >> Length not equal after stripping spaces: '해봅니다. 그러한전환이나변화는하루아침에쉽게이루어지는것은아닙니다.하지만불가능하거나너무어려운것또한아니지요.' vs '해봅니다.그러한전환이나변화는하루아침에쉽게이루어지는것은아닙니다.하지만불가능하거나너무어려운것또한아니지요.'
# ...
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,464 >> Unable to find text: '##구요 . 빠른 쾌유를 기원해드립니다' in '보시구요. 빠른 쾌유를 기원해드립니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,464 >> Unable to find text: '##공황장애의 가능성도 생각해보셔야 합니다 .' in '있지만공황장애의 가능성도 생각해보셔야 합니다.그외'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,464 >> Length not equal after stripping spaces: '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,465 >> Length not equal after stripping spaces: '보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,465 >> Unable to find text: '##구요 . 빠른 쾌유를 기원해드립니다 . 감사합니다' in '보시구요. 빠른 쾌유를 기원해드립니다. 감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,465 >> Length not equal after stripping spaces: '빠른쾌유를기원해드립니다. 감사합니다.' vs '빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,465 >> Length not equal after stripping spaces: '기원해드립니다. 감사합니다.' vs '기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,465 >> Unable to find text: '##구요' in '보시구요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,466 >> Unable to find text: '##립니다' in '기원해드립니다. 감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,466 >> Length not equal after stripping spaces: '보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,466 >> Unable to find text: '##구요 . 빠른 쾌유를 기원해드립니다 .' in '보시구요. 빠른 쾌유를 기원해드립니다. 감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,466 >> Length not equal after stripping spaces: '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,466 >> Length not equal after stripping spaces: '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,467 >> Length not equal after stripping spaces: '빠른쾌유를기원해드립니다. 감사합니다.' vs '빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,467 >> Length not equal after stripping spaces: '보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,467 >> Unable to find text: '##구요 . 빠른 쾌유를 기원해드립니다 . 감사합니다 .' in '보시구요. 빠른 쾌유를 기원해드립니다. 감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,467 >> Length not equal after stripping spaces: '기원해드립니다. 감사합니다.' vs '기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,467 >> Length not equal after stripping spaces: '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,468 >> Unable to find text: '##립니다 . 감사합니다' in '기원해드립니다. 감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,468 >> Length not equal after stripping spaces: '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다. 감사합니다.' vs '합니다.그외심장의질환여부도다시보시구요.빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,468 >> Length not equal after stripping spaces: '빠른쾌유를기원해드립니다. 감사합니다.' vs '빠른쾌유를기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,468 >> Unable to find text: '##합니다' in '기원해드립니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,468 >> Unable to find text: '##공황장애의 가능성도 생각해보셔야 합니다 . 그외 심장의 질환 여부도 다시 보시구요' in '있지만공황장애의 가능성도 생각해보셔야 합니다.그외 심장의 질환 여부도 다시 보시구요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,471 >> Unable to find text: '##합니다 .' in '권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,471 >> Unable to find text: '##는 상태 파악이 어렵습니다만 , 제대로 된 수면이 힘든것으로 보아 우선 수면검사를 받아보시기를 권유합니다 .' in '증상만으로는 상태 파악이 어렵습니다만, 제대로 된 수면이 힘든것으로 보아 우선 수면검사를 받아보시기를 권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,477 >> Unable to find text: '##니다' in '생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,478 >> Unable to find text: '##니다 .' in '생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,481 >> Unable to find text: '##입니다' in '것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,481 >> Unable to find text: '##입니다' in '필요해보입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,481 >> Unable to find text: '##요 상황에 대한 대처법 등을 몸으로 체득하는 것입니다' in '방법인데요 상황에 대한 대처법 등을 몸으로 체득하는 것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,482 >> Unable to find text: '##입니다 . 매일 약하게라도 불안감이 올라오는거라면 렉사프로 이외의 다른 약물로 변경이 필요해보입니다' in '것입니다. 매일 약하게라도 불안감이 올라오는거라면 렉사프로 이외의 다른 약물로 변경이 필요해보입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,482 >> Unable to find text: '##입니다 . 매일 약하게라도 불안감이 올라오는거라면 렉사프로 이외의 다른 약물로 변경이 필요해보입니다 .' in '것입니다. 매일 약하게라도 불안감이 올라오는거라면 렉사프로 이외의 다른 약물로 변경이 필요해보입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,482 >> Unable to find text: '##입니다 .' in '것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,482 >> Unable to find text: '##입니다 .' in '필요해보입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,483 >> Unable to find text: '##갑니다 .' in '끊어갑니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,483 >> Unable to find text: '##요 상황에 대한 대처법 등을 몸으로 체득하는 것입니다 .' in '방법인데요 상황에 대한 대처법 등을 몸으로 체득하는 것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,484 >> Unable to find text: '##요' in '방법인데요'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,484 >> Unable to find text: '##갑니다 . 인지행동치료는 스스로가 치료자가 되는 방법인데요' in '끊어갑니다. 인지행동치료는 스스로가 치료자가 되는 방법인데요'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,485 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,486 >> Unable to find text: '##말씀하신거 처럼 목이마르거나 입안이 건조해 지는 증상이 생길 수 있습니다 .' in '있다면말씀하신거 처럼 목이마르거나 입안이 건조해 지는 증상이 생길 수 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,486 >> Unable to find text: '##가' in '싶습니다가래약이라'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,486 >> Unable to find text: '##가래약이라 하셨는데 ,' in '싶습니다가래약이라 하셨는데,'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,486 >> Unable to find text: '##입니다 . 이비' in '김정호입니다.이비인후과에서'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,486 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,487 >> Unable to find text: '##말씀하신거 처럼 목이마르거나 입안이 건조해 지는 증상이 생길 수 있습니다' in '있다면말씀하신거 처럼 목이마르거나 입안이 건조해 지는 증상이 생길 수 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,487 >> Unable to find text: '##니다' in '싶습니다가래약이라'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,487 >> Unable to find text: '##입니다 . 이비인후과에서 받으셨던 약이 무엇인지 알고 싶습니다' in '김정호입니다.이비인후과에서 받으셨던 약이 무엇인지 알고 싶습니다가래약이라'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,487 >> Unable to find text: '##니다가' in '싶습니다가래약이라'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,487 >> Unable to find text: '##입니다 .' in '김정호입니다.이비인후과에서'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,487 >> Unable to find text: '##입니다' in '김정호입니다.이비인후과에서'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,488 >> Unable to find text: '##후과에서 받으셨던 약이 무엇인지 알고 싶습니다' in '김정호입니다.이비인후과에서 받으셨던 약이 무엇인지 알고 싶습니다가래약이라'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,488 >> Unable to find text: '##인후과에서 받으셨던 약이 무엇인지 알고 싶습니다' in '김정호입니다.이비인후과에서 받으셨던 약이 무엇인지 알고 싶습니다가래약이라'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,488 >> Unable to find text: '##입니다 . 이비인후과에서 받으셨던 약이 무엇인지 알고 싶습니다가' in '김정호입니다.이비인후과에서 받으셨던 약이 무엇인지 알고 싶습니다가래약이라'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,489 >> Unable to find text: '##니다가래약이라 하셨는데 ,' in '싶습니다가래약이라 하셨는데,'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,489 >> Unable to find text: '##후과에서 받으셨던 약이 무엇인지 알고 싶습니다가' in '김정호입니다.이비인후과에서 받으셨던 약이 무엇인지 알고 싶습니다가래약이라'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,489 >> Unable to find text: '##인후과에서 받으셨던 약이 무엇인지 알고 싶습니다가' in '김정호입니다.이비인후과에서 받으셨던 약이 무엇인지 알고 싶습니다가래약이라'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,490 >> Unable to find text: '##입니다 . 이비인후과에서 받으셨던 약이 무엇인지 알고 싶습니다가래약이라 하셨는데 ,' in '김정호입니다.이비인후과에서 받으셨던 약이 무엇인지 알고 싶습니다가래약이라 하셨는데,'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,491 >> Unable to find text: '##합니다' in '발생합니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,492 >> Unable to find text: '##합니다 . 만약 불면증이 며칠밖에 되지 않았다면 좀 더 지켜보아도 괜찮습니다' in '발생합니다.만약 불면증이 며칠밖에 되지 않았다면 좀 더 지켜보아도 괜찮습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,492 >> Unable to find text: '##니다' in '괜찮습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,492 >> Unable to find text: '##니다 . 급성 스트레스로 인한 불면증은 2주 이상 지속되지 않습니다' in '괜찮습니다. 급성 스트레스로 인한 불면증은 2주 이상 지속되지 않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,492 >> Unable to find text: '##니다' in '않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,493 >> Unable to find text: '##합니다 .' in '발생합니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,493 >> Unable to find text: '##합니다 . 만약 불면증이 며칠밖에 되지 않았다면 좀 더 지켜보아도 괜찮습니다 .' in '발생합니다.만약 불면증이 며칠밖에 되지 않았다면 좀 더 지켜보아도 괜찮습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,494 >> Unable to find text: '##니다 .' in '괜찮습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,494 >> Unable to find text: '##니다 . 만약 불면증이 2주 이상 지속된다면 검사 및 치료를 하는 것이 좋습니다' in '않습니다. 만약 불면증이 2주 이상 지속된다면 검사 및 치료를 하는 것이 좋습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,496 >> Unable to find text: '##니다 .' in '편입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,496 >> Unable to find text: '##합니다 .' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,559 >> Unable to find text: '##합니다' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,559 >> Unable to find text: '##입니다 . 저' in '신광식입니다.저도'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,562 >> Unable to find text: '##니다' in '있습니다'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,563 >> Unable to find text: '##지만 졸립거나 눈이 침침해지거나 입이마르거나 하는 부작용이 좀더 자주 또는 심하게 나타날 가능성이 있습니다' in '되지만 졸립거나 눈이 침침해지거나 입이마르거나 하는 부작용이 좀더 자주 또는 심하게 나타날 가능성이 있습니다'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,564 >> Unable to find text: '##입니다 . 함께' in '홍인표입니다. 함께'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,564 >> Unable to find text: '##입니다 .' in '홍인표입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,574 >> Length not equal after stripping spaces: '하고요.  꼭' vs '하고요.꼭'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,575 >> Length not equal after stripping spaces: '있어요.  가끔가상의대화로혼잣말하고나면좀짜증나고약간' vs '있어요.가끔가상의대화로혼잣말하고나면좀짜증나고약간'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,575 >> Length not equal after stripping spaces: '있어요.  가끔' vs '있어요.가끔'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,576 >> Unable to find text: '##죠 . 그것이 축적되면 , 마치 일기장처럼 , 자신을 돌아볼 때에 도움이 되기도 하고요' in '것이죠.그것이 축적되면, 마치 일기장처럼, 자신을 돌아볼 때에 도움이 되기도 하고요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,576 >> Unable to find text: '##요' in '하고요.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,582 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,582 >> Unable to find text: '##니다 . 대개 1주일에 한 차례씩 정신과 전문의 선생님들이 무료로 상담을 해주십니다' in '있습니다. 대개 1주일에 한 차례씩 정신과 전문의 선생님들이 무료로 상담을 해주십니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,587 >> Unable to find text: '##니다' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,587 >> Unable to find text: '##니다 .' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,589 >> Unable to find text: '##니다 . 또한' in '같습니다. 또한'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,591 >> Unable to find text: '##합니다' in '정확합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,591 >> Unable to find text: '##합니다 . 증상이 지속된다면 가까운 영상의학과나 병원에서 검사를 하는 것이 좋습니다' in '정확합니다. 증상이 지속된다면 가까운 영상의학과나 병원에서 검사를 하는 것이 좋습니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,591 >> Unable to find text: '##니다' in '좋습니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,592 >> Unable to find text: '##니다 . 정확한 것은 MRI , CT 등의 검사를 하는 것이 정확합니다' in '어렵습니다. 정확한 것은 MRI, CT 등의 검사를 하는 것이 정확합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,593 >> Unable to find text: '##합니다 . 증상이 지속된다면 가까운 영상의학과나 병원에서 검사를 하는 것이 좋습니다 .' in '정확합니다. 증상이 지속된다면 가까운 영상의학과나 병원에서 검사를 하는 것이 좋습니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,593 >> Unable to find text: '##니다 .' in '좋습니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,593 >> Unable to find text: '##합니다 .' in '정확합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,595 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,596 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,601 >> Unable to find text: '##니다 . 증상 지속시 신경과 외래에 방문하셔서 상담하시기 바랍니다 .' in '있습니다.증상 지속시 신경과 외래에 방문하셔서 상담하시기 바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,602 >> Unable to find text: '##니다 .' in '있습니다.증상'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,608 >> Unable to find text: '##입니다' in '증거입니다.요즘'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,612 >> Unable to find text: '##입니다 . 요즘 건강염려증 환자분들 많습니다' in '증거입니다.요즘 건강염려증 환자분들 많습니다.너무'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,613 >> Unable to find text: '##다 . . 즉 심리적인 요인이 많다는 간접 증거입니다' in '없다..즉 심리적인 요인이 많다는 간접 증거입니다.요즘'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,615 >> Unable to find text: '##니다 .' in '있겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,615 >> Unable to find text: '##니다' in '있겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,616 >> Unable to find text: '##으므로 급격한 체중저하시에는 검사가 필요할 수 있겠습니다 .' in '있으므로 급격한 체중저하시에는 검사가 필요할 수 있겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,616 >> Unable to find text: '##으므로 급격한 체중저하시에는 검사가 필요할 수 있겠습니다' in '있으므로 급격한 체중저하시에는 검사가 필요할 수 있겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,620 >> Unable to find text: '##니다' in '있습니다.이러한'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,622 >> Unable to find text: '##니다 .' in '있습니다.이러한'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,625 >> Unable to find text: '##합니다' in '발생합니다.즉,'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,628 >> Unable to find text: '##합니다 . 즉 , 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다' in '발생합니다.즉, 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,629 >> Unable to find text: '##합니다 . 즉 , 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다 . 만약' in '발생합니다.즉, 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,630 >> Unable to find text: '##입니다' in '의미입니다.만약'
# [INFO|squad_metrics.py:314] 2023-06-05 03:31:20,631 >> Length not equal after stripping spaces: '되고, 불면증이나기면증과같은수면장애와함께우울증,만성피로,기억력저하등이함께발생합니다.규칙적인' vs '되고,불면증이나기면증과같은수면장애와함께우울증,만성피로,기억력저하등이함께발생합니다.규칙적인'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,635 >> Unable to find text: '##합니다' in '적당합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,635 >> Unable to find text: '##합니다 . 걱정이 되시는 부분에 대한 검사는 대학병원 신경과가 적당합니다' in '곤란합니다.걱정이 되시는 부분에 대한 검사는 대학병원 신경과가 적당합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,635 >> Unable to find text: '##합니다' in '곤란합니다.걱정이'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,636 >> Unable to find text: '##니다 . 1년에 2 - 3회 증상이 있으면 적극적인 치료가 곤란합니다' in '있습니다. 1년에 2-3회 증상이 있으면 적극적인 치료가 곤란합니다.걱정이'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,636 >> Unable to find text: '##합니다 .' in '적당합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,636 >> Unable to find text: '##합니다 . 걱정이 되시는 부분에 대한 검사는 대학병원 신경과가 적당합니다 .' in '곤란합니다.걱정이 되시는 부분에 대한 검사는 대학병원 신경과가 적당합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,637 >> Unable to find text: '##합니다 .' in '권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,638 >> Unable to find text: '##어 담당선생님과 충분한 상담을 권유합니다 .' in '있어 담당선생님과 충분한 상담을 권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,639 >> Unable to find text: '##합니다' in '권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,640 >> Unable to find text: '##어 담당선생님과 충분한 상담을 권유합니다' in '있어 담당선생님과 충분한 상담을 권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 03:31:20,641 >> Unable to find text: '##합니다 .' in '분인듯합니다.'
# 06/05/2023 03:31:22 - INFO - __main__ - Results: {'exact': 7.624309392265193, 'f1': 32.718450765277396, 'total': 2715, 'HasAns_exact': 7.624309392265193, 'HasAns_f1': 32.718450765277396, 'HasAns_total': 2715, 'best_exact': 7.624309392265193, 'best_exact_thresh': 0.0, 'best_f1': 32.718450765277396, 'best_f1_thresh': 0.0}

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## 경로 변경

# %%
import os
os.chdir('/content/drive/MyDrive/korquad/')
os.getcwd()
# Out:
# '/content/drive/MyDrive/korquad'

# %%
from __future__ import print_function
from collections import Counter
import string
import re
import argparse
import json
import sys
import os

import pandas as pd
from transformers import AutoTokenizer

'''KorQuAD v1.0에 대한 공식 평가 스크립트 '''
'''본 스크립트는 SQuAD v1.1 평가 스크립트 https://rajpurkar.github.io/SQuAD-explorer/ 를 바탕으로 작성됨.'''

def normalize_answer(s):    
    def remove_(text):
        ''' 불필요한 기호 제거 '''
        text = re.sub("'", " ", text)
        text = re.sub('"', " ", text)
        text = re.sub('《', " ", text)
        text = re.sub('》', " ", text)
        text = re.sub('<', " ", text)
        text = re.sub('>', " ", text) 
        text = re.sub('〈', " ", text)
        text = re.sub('〉', " ", text)   
        text = re.sub("\(", " ", text)
        text = re.sub("\)", " ", text)
        text = re.sub("‘", " ", text)
        text = re.sub("’", " ", text)      
        return text

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return ''.join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_punc(lower(remove_(s))))


def f1_score(prediction, ground_truth):
    prediction_tokens = normalize_answer(prediction).split()
    ground_truth_tokens = normalize_answer(ground_truth).split()
   
    #F1 by character
    prediction_Char = []
    for tok in prediction_tokens:
        now = [a for a in tok]
        prediction_Char.extend(now)
        
    ground_truth_Char = []
    for tok in ground_truth_tokens:
        now = [a for a in tok]
        ground_truth_Char.extend(now)   
        
    common = Counter(prediction_Char) & Counter(ground_truth_Char)
    num_same = sum(common.values())
    if num_same == 0:
        return 0
    
    precision = 1.0 * num_same / len(prediction_Char)
    recall = 1.0 * num_same / len(ground_truth_Char)
    f1 = (2 * precision * recall) / (precision + recall)
    
    return f1


def exact_match_score(prediction, ground_truth):
    return (normalize_answer(prediction) == normalize_answer(ground_truth))


def metric_max_over_ground_truths(metric_fn, prediction, ground_truths):
    scores_for_ground_truths = []
    for ground_truth in ground_truths:
        score = metric_fn(prediction, ground_truth)
        scores_for_ground_truths.append(score)
    return max(scores_for_ground_truths)


def evaluate(dataset, predictions):
    f1 = exact_match = total = 0
    for article in dataset:
        for paragraph in article['paragraphs']:
            for qa in paragraph['qas']:
                total += 1
                if qa['id'] not in predictions:
                    message = 'Unanswered question ' + qa['id'] + \
                              ' will receive score 0.'
                    print(message, file=sys.stderr)
                    continue
                ground_truths = list(map(lambda x: x['text'], qa['answers']))
                prediction = predictions[qa['id']]
                exact_match += metric_max_over_ground_truths(
                    exact_match_score, prediction, ground_truths)
                f1 += metric_max_over_ground_truths(
                    f1_score, prediction, ground_truths)

    exact_match = 100.0 * exact_match / total
    f1 = 100.0 * f1 / total
    return {'exact_match': exact_match, 'f1': f1}


def evaluate_result(dataset_file, prediction_file):
    
    with open(dataset_file, encoding="utf-8") as f:
        dataset_json = json.load(f)
        dataset = dataset_json['data']
    with open(prediction_file, encoding="utf-8") as f:
        predictions = json.load(f)
    return evaluate(dataset, predictions)

# %% [markdown]
# ## 성능 확인

# %%
dataset_file = './data/KMQA_dev_v5.1.json'
prediction_file = './koelectra-base-v3-KMQA/predictions_.json'
evaluate_result(dataset_file, prediction_file)
# Out:
# {'exact_match': 7.5963302752293576, 'f1': 39.20462478449297}
