# %%
# !pip3 install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 69.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 14.2 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 82.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.26.14)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.12.1 tokenizers-0.13.2 transformers-4.26.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/korquad/')
os.getcwd()
# Out:
# '/content/drive/MyDrive/korquad'

# %%
# !python ./run_korquad.py \
    --model_type bert \
    --model_name_or_path klue/bert-base \
    --output_dir klue_roberta \
    --data_dir data \
    --train_file KorQuAD_v1.0_train.json \
    --predict_file KorQuAD_v1.0_dev.json \
    --max_seq_length 512 \
    --doc_stride 128 \
    --max_query_length 64 \
    --do_train \
    --do_eval \
    --evaluate_during_training \
    --per_gpu_train_batch_size=16 \
    --per_gpu_eval_batch_size=8 \
    --learning_rate 5e-5 \
    --gradient_accumulation_steps 1 \
    --weight_decay 0.0 \
    --adam_epsilon 1e-8 \
    --max_grad_norm 1.0 \
    --num_train_epochs 3 \
    --max_steps -1 \
    --warmup_steps 0 \
    --n_best_size 20 \
    --max_answer_length 30 \
    --verbose_logging \
    --logging_steps 1000 \
    --save_steps 1000 \
    --eval_all_checkpoints \
    --overwrite_output_dir \
    --seed 42 \
    --local_rank -1 \
    --threads 4
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,618 >> Unable to find text: '##담을' in '단독면담을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,618 >> Unable to find text: '##담을 요구' in '단독면담을 요구하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,618 >> Unable to find text: '##담을 요구하였다 .' in '단독면담을 요구하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,619 >> Unable to find text: '##면담을' in '단독면담을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,619 >> Unable to find text: '##을' in '단독면담을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,619 >> Unable to find text: '##면담을 요구' in '단독면담을 요구하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,619 >> Unable to find text: '##을 요구' in '단독면담을 요구하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,619 >> Unable to find text: '##면담을 요구하였다 .' in '단독면담을 요구하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,619 >> Unable to find text: '##을 요구하였다 .' in '단독면담을 요구하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,620 >> Unable to find text: '##게 단독면담을' in '대통령에게 단독면담을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,621 >> Unable to find text: '##자 마산' in '않자 마산으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,622 >> Unable to find text: '##으로' in '마산으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,622 >> Unable to find text: '##으로 낙향' in '마산으로 낙향해'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,623 >> Unable to find text: '##원' in '최고위원은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,623 >> Unable to find text: '##향해 버렸고 , 김종필' in '낙향해 버렸고, 김종필'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,624 >> Unable to find text: '##향해 버렸고 , 김종필 최고위원' in '낙향해 버렸고, 김종필 최고위원은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,624 >> Unable to find text: '##은' in '최고위원은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,624 >> Unable to find text: '##원은' in '최고위원은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,624 >> Unable to find text: '##향해 버렸고 , 김종필 최고위원은' in '낙향해 버렸고, 김종필 최고위원은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,626 >> Unable to find text: '##면담을 요구하였다 . 그러나 노태우 대통령의 반응이 없고 , 사태 해결이 그의 의도대로 진행되지 않자 마산' in '단독면담을 요구하였다. 그러나 노태우 대통령의 반응이 없고, 사태 해결이 그의 의도대로 진행되지 않자 마산으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,626 >> Unable to find text: '##으로' in '마산으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,626 >> Unable to find text: '##으로 낙향' in '마산으로 낙향해'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,627 >> Unable to find text: '##으로 낙향해 버렸고 , 김종필 최고위원은 김영삼 대표의 이러한 행위를 공개적으로 비난하였다 .' in '마산으로 낙향해 버렸고, 김종필 최고위원은 김영삼 대표의 이러한 행위를 공개적으로 비난하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,627 >> Unable to find text: '##으로 낙' in '마산으로 낙향해'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,627 >> Unable to find text: '##향' in '낙향해'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,628 >> Unable to find text: '##원' in '최고위원은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,628 >> Unable to find text: '##향해 버렸고 , 김종필' in '낙향해 버렸고, 김종필'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,628 >> Unable to find text: '##향해 버렸고 , 김종필 최고위원' in '낙향해 버렸고, 김종필 최고위원은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,628 >> Unable to find text: '##은' in '최고위원은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,628 >> Unable to find text: '##원은' in '최고위원은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,629 >> Unable to find text: '##향해 버렸고 , 김종필 최고위원은' in '낙향해 버렸고, 김종필 최고위원은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,630 >> Unable to find text: '##병 윤석양' in '탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,630 >> Unable to find text: '##양' in '윤석양'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,630 >> Unable to find text: '##병 윤석양 이병' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,630 >> Unable to find text: '##양 이병' in '윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,630 >> Unable to find text: '##영병 윤석양' in '탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,631 >> Unable to find text: '##영병 윤석양 이병' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,631 >> Unable to find text: '##던 탈영병 윤석양' in '출신이었던 탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,631 >> Unable to find text: '##병 윤석양 이병의' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,631 >> Unable to find text: '##양 이병의' in '윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,631 >> Unable to find text: '##던 탈영병 윤석양 이병' in '출신이었던 탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,633 >> Unable to find text: '##병 윤석양' in '탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,633 >> Unable to find text: '##양' in '윤석양'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,633 >> Unable to find text: '##영병 윤석양' in '탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,633 >> Unable to find text: '##병 윤석양 이병' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,633 >> Unable to find text: '##양 이병' in '윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,633 >> Unable to find text: '##영병 윤석양 이병' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,633 >> Unable to find text: '##병' in '탈영병'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,634 >> Unable to find text: '##양' in '윤석양'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,635 >> Unable to find text: '##병 윤석양' in '탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,635 >> Unable to find text: '##영병 윤석양' in '탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,635 >> Unable to find text: '##양 이병' in '윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,635 >> Unable to find text: '##던 탈영병 윤석양' in '출신이었던 탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,635 >> Unable to find text: '##병 윤석양 이병' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,635 >> Unable to find text: '##련 출신이었던 탈영병 윤석양' in '민학투련 출신이었던 탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,635 >> Unable to find text: '##영병 윤석양 이병' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,636 >> Unable to find text: '##양 이병의' in '윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,636 >> Unable to find text: '##던 탈영병 윤석양 이병' in '출신이었던 탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,636 >> Unable to find text: '##병 윤석양 이병의' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,636 >> Unable to find text: '##영병 윤석양 이병의' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,638 >> Unable to find text: '##선언' in '「양심선언」을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,639 >> Unable to find text: '##사' in '평민당사를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,639 >> Unable to find text: '##당사' in '평민당사를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,639 >> Unable to find text: '##사를' in '평민당사를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,639 >> Unable to find text: '##당사를' in '평민당사를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,640 >> Unable to find text: '##당' in '평민당사를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,640 >> Unable to find text: '##사를 방문해 단식 중인 김대중 총재를 면회하였다 .' in '평민당사를 방문해 단식 중인 김대중 총재를 면회하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,640 >> Unable to find text: '##를' in '평민당사를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,640 >> Unable to find text: '##당사를 방문해 단식 중인 김대중 총재를 면회하였다 .' in '평민당사를 방문해 단식 중인 김대중 총재를 면회하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,640 >> Unable to find text: '##사를 방문해 단식 중인 김대중 총재' in '평민당사를 방문해 단식 중인 김대중 총재를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,640 >> Unable to find text: '##사를 방문' in '평민당사를 방문해'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,640 >> Unable to find text: '##사를 방문해 단식 중인 김대중' in '평민당사를 방문해 단식 중인 김대중'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,640 >> Unable to find text: '##사를 방문해 단식 중인 김대중 총재를 면회' in '평민당사를 방문해 단식 중인 김대중 총재를 면회하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,640 >> Unable to find text: '##당사를 방문해 단식 중인 김대중 총재' in '평민당사를 방문해 단식 중인 김대중 총재를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,640 >> Unable to find text: '##사를 방문해 단식 중인 김대중 총재를' in '평민당사를 방문해 단식 중인 김대중 총재를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,641 >> Unable to find text: '##당사를 방문' in '평민당사를 방문해'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,641 >> Unable to find text: '##사를 방문해 단식' in '평민당사를 방문해 단식'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,641 >> Unable to find text: '##당사를 방문해 단식 중인 김대중' in '평민당사를 방문해 단식 중인 김대중'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,641 >> Unable to find text: '##당사를 방문해 단식 중인 김대중 총재를 면회' in '평민당사를 방문해 단식 중인 김대중 총재를 면회하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,694 >> Unable to find text: '##당사를 방문해 단식 중인 김대중 총재를' in '평민당사를 방문해 단식 중인 김대중 총재를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,694 >> Unable to find text: '##당사를 방문해 단식' in '평민당사를 방문해 단식'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,694 >> Unable to find text: '##를 방문해 단식 중인 김대중 총재를 면회하였다 .' in '평민당사를 방문해 단식 중인 김대중 총재를 면회하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,694 >> Unable to find text: '##를 방문해 단식 중인 김대중 총재' in '평민당사를 방문해 단식 중인 김대중 총재를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,695 >> Unable to find text: '##양' in '윤석양'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,696 >> Unable to find text: '##양 이병' in '윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,696 >> Unable to find text: '##영병 윤석양' in '탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,696 >> Unable to find text: '##병 윤석양' in '탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,696 >> Unable to find text: '##련 출신이었던 탈영병 윤석양' in '민학투련 출신이었던 탈영병 윤석양'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,696 >> Unable to find text: '##양 이병의' in '윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,696 >> Unable to find text: '##영병 윤석양 이병' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,696 >> Unable to find text: '##병 윤석양 이병' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,697 >> Unable to find text: '##련 출신이었던 탈영병 윤석양 이병' in '민학투련 출신이었던 탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,697 >> Unable to find text: '##영병 윤석양 이병의' in '탈영병 윤석양 이병의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,698 >> Unable to find text: '##훈' in '이상훈'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,699 >> Unable to find text: '##훈 국방부장관' in '이상훈 국방부장관을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,699 >> Unable to find text: '##훈 국방부장관을 면담 , 항의하기도 했다 . 사찰 파장으로 국방부장관은 경질되었다 .' in '이상훈 국방부장관을 면담, 항의하기도 했다. 사찰 파장으로 국방부장관은 경질되었다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,699 >> Unable to find text: '##훈 국방부장관을 면담 , 항의하기도 했다 . 사찰 파장으로 국방부장관' in '이상훈 국방부장관을 면담, 항의하기도 했다. 사찰 파장으로 국방부장관은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,699 >> Unable to find text: '##훈 국방부장관을' in '이상훈 국방부장관을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,699 >> Unable to find text: '##훈 국방부' in '이상훈 국방부장관을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,700 >> Unable to find text: '##관' in '국방부장관을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,701 >> Unable to find text: '##용' in '정호용의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,701 >> Unable to find text: '##용이 그에 대한 지지를 촉구하여 일시적으로 봉합시키기도 했다 . 그러나 정호용' in '정호용이 그에 대한 지지를 촉구하여 일시적으로 봉합시키기도 했다. 그러나 정호용의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,702 >> Unable to find text: '##정권 인사 정호용이 그에 대한 지지를 촉구하여 일시적으로 봉합시키기도 했다 . 그러나 정호용' in '군사정권 인사 정호용이 그에 대한 지지를 촉구하여 일시적으로 봉합시키기도 했다. 그러나 정호용의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,702 >> Unable to find text: '##이 그에 대한 지지를 촉구하여 일시적으로 봉합시키기도 했다 . 그러나 정호용' in '정호용이 그에 대한 지지를 촉구하여 일시적으로 봉합시키기도 했다. 그러나 정호용의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,703 >> Unable to find text: '##년' in '1960년'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,704 >> Unable to find text: '##은 1960년' in '김영삼은 1960년'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,704 >> Unable to find text: '##년 자신의 어머니 박부련이 무장공비' in '1960년 자신의 어머니 박부련이 무장공비에게'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,704 >> Unable to find text: '##년 자신의 어머니 박부련' in '1960년 자신의 어머니 박부련이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,705 >> Unable to find text: '##당' in '민자당내'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,706 >> Unable to find text: '##당내' in '민자당내'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,708 >> Unable to find text: '##용' in '정호용이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,709 >> Unable to find text: '##정권 인사 정호용' in '군사정권 인사 정호용이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,709 >> Unable to find text: '##의 군사정권 인사 정호용' in '경북출신의 군사정권 인사 정호용이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,709 >> Unable to find text: '##정권 출신 세력은 김영삼의 지도권에 반발하였으나 , 대구 경북출신의 군사정권 인사 정호용' in '군사정권 출신 세력은 김영삼의 지도권에 반발하였으나, 대구 경북출신의 군사정권 인사 정호용이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,709 >> Unable to find text: '##용이 그에 대한 지지를 촉구하여 일시적으로 봉합시키기도 했다 . 그러나 정호용' in '정호용이 그에 대한 지지를 촉구하여 일시적으로 봉합시키기도 했다. 그러나 정호용의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,711 >> Unable to find text: '##과 김종필' in '지지층과 김종필'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,711 >> Unable to find text: '##은 김영삼 지지층과 김종필' in '세력은 김영삼 지지층과 김종필'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,712 >> Unable to find text: '##용' in '정호용이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,712 >> Unable to find text: '##정권 인사 정호용' in '군사정권 인사 정호용이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,713 >> Unable to find text: '##의 군사정권 인사 정호용' in '경북출신의 군사정권 인사 정호용이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,713 >> Unable to find text: '##신의 군사정권 인사 정호용' in '경북출신의 군사정권 인사 정호용이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,714 >> Unable to find text: '##련' in '박부련이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,715 >> Unable to find text: '##부련' in '박부련이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,715 >> Unable to find text: '##년 자신의 어머니 박부련' in '1960년 자신의 어머니 박부련이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,715 >> Unable to find text: '##련이' in '박부련이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,715 >> Unable to find text: '##부련이' in '박부련이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,715 >> Unable to find text: '##련이 무장공비에게 살해당한 점을 들어 위기를 모면하였다 .' in '박부련이 무장공비에게 살해당한 점을 들어 위기를 모면하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,715 >> Unable to find text: '##련이 무장' in '박부련이 무장공비에게'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,715 >> Unable to find text: '##이' in '박부련이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,718 >> Unable to find text: '##가' in '남이가"라는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,719 >> Unable to find text: '##가 남이가' in '"우리가 남이가"라는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,719 >> Unable to find text: '##가' in '남이가,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,720 >> Unable to find text: '##년' in '1992년'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,721 >> Unable to find text: '##년 14' in '1992년 14대'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,721 >> Unable to find text: '##년 14대' in '1992년 14대'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,721 >> Unable to find text: '##년 14대 대선' in '1992년 14대 대선'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,721 >> Unable to find text: '##년 14대 대선 당시 선거는 김영삼 , 김대중 , 정주영 후보의 3파전으로 격돌하였다 .' in '1992년 14대 대선 당시 선거는 김영삼, 김대중, 정주영 후보의 3파전으로 격돌하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,722 >> Unable to find text: '##년 14대 대선 당시 선거' in '1992년 14대 대선 당시 선거는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,723 >> Unable to find text: '##은 불법 도청' in '후보측은 불법 도청으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,724 >> Unable to find text: '##측은 불법 도청' in '후보측은 불법 도청으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,725 >> Unable to find text: '##표' in '영남표를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,726 >> Unable to find text: '##표를' in '영남표를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,729 >> Unable to find text: '##복집 사건' in '"초원복집 사건"으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,730 >> Unable to find text: '##집 사건' in '"초원복집 사건"으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,731 >> Unable to find text: '##리 양' in '가오리 양'의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,732 >> Unable to find text: '##신문' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,733 >> Unable to find text: '##매일신문' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,733 >> Unable to find text: '##일신문' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,733 >> Unable to find text: '##자 LA매일신문' in '20일자 LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,733 >> Unable to find text: '##신문에' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,734 >> Unable to find text: '##매일신문에' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,734 >> Unable to find text: '##에' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,734 >> Unable to find text: '##일신문에' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,734 >> Unable to find text: '##매일' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,734 >> Unable to find text: '##자 LA매일신문에' in '20일자 LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,734 >> Unable to find text: '##자 LA' in '20일자 LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,735 >> Unable to find text: '##일' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,736 >> Unable to find text: '##후보' in '대선후보'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,737 >> Unable to find text: '##신문' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,737 >> Unable to find text: '##매일신문' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,738 >> Unable to find text: '##일신문' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,738 >> Unable to find text: '##자 LA매일신문' in '20일자 LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,738 >> Unable to find text: '##신문에' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,738 >> Unable to find text: '##매일신문에' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,738 >> Unable to find text: '##에' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,739 >> Unable to find text: '##일신문에' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,739 >> Unable to find text: '##매일' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,739 >> Unable to find text: '##자 LA매일신문에' in '20일자 LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,739 >> Unable to find text: '##일' in 'LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,739 >> Unable to find text: '##자 LA' in '20일자 LA매일신문에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,741 >> Unable to find text: '##리' in '가오리,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,741 >> Unable to find text: '##리 ,' in '가오리,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,741 >> Unable to find text: '##리 양' in '가오리 양'의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,741 >> Unable to find text: '##리' in '가오리'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,743 >> Unable to find text: '##력' in '극우세력은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,743 >> Unable to find text: '##력의 김영삼에 대한 악감정을 촉발시키는 계기가 됐다 . 극우세력' in '극우세력의 김영삼에 대한 악감정을 촉발시키는 계기가 됐다. 극우세력은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,743 >> Unable to find text: '##세력' in '극우세력은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,743 >> Unable to find text: '##은' in '세력은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,744 >> Unable to find text: '##무' in '손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,745 >> Unable to find text: '##충무' in '손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,745 >> Unable to find text: '##무 기자' in '손충무 기자의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,745 >> Unable to find text: '##충무 기자' in '손충무 기자의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,745 >> Unable to find text: '##신문의 편집책임자인 극우 언론인 손충무' in 'LA매일신문의 편집책임자인 극우 언론인 손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,745 >> Unable to find text: '##일신문의 편집책임자인 극우 언론인 손충무' in 'LA매일신문의 편집책임자인 극우 언론인 손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,745 >> Unable to find text: '##매일신문의 편집책임자인 극우 언론인 손충무' in 'LA매일신문의 편집책임자인 극우 언론인 손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,746 >> Unable to find text: '##무 기자의' in '손충무 기자의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,747 >> Unable to find text: '##은' in '세력은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,749 >> Unable to find text: '##무' in '손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,749 >> Unable to find text: '##충무' in '손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,749 >> Unable to find text: '##무 기자' in '손충무 기자의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,749 >> Unable to find text: '##신문의 편집책임자인 극우 언론인 손충무' in 'LA매일신문의 편집책임자인 극우 언론인 손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,749 >> Unable to find text: '##매일신문의 편집책임자인 극우 언론인 손충무' in 'LA매일신문의 편집책임자인 극우 언론인 손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,750 >> Unable to find text: '##충무 기자' in '손충무 기자의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,750 >> Unable to find text: '##임자인 극우 언론인 손충무' in '편집책임자인 극우 언론인 손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,750 >> Unable to find text: '##인 극우 언론인 손충무' in '편집책임자인 극우 언론인 손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,750 >> Unable to find text: '##무 기자의' in '손충무 기자의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,751 >> Unable to find text: '##력' in '극우세력의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,751 >> Unable to find text: '##세력' in '극우세력의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,752 >> Unable to find text: '##력의' in '극우세력의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,752 >> Unable to find text: '##세력의' in '극우세력의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,753 >> Unable to find text: '##기와 과거사 청산을 발표 , 조선총독부' in '역사바로세우기와 과거사 청산을 발표, 조선총독부를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,754 >> Unable to find text: '##바로세우기와 과거사 청산을 발표 , 조선총독부' in '역사바로세우기와 과거사 청산을 발표, 조선총독부를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,754 >> Unable to find text: '##세우기와 과거사 청산을 발표 , 조선총독부' in '역사바로세우기와 과거사 청산을 발표, 조선총독부를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,754 >> Unable to find text: '##와 과거사 청산을 발표 , 조선총독부' in '역사바로세우기와 과거사 청산을 발표, 조선총독부를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,754 >> Unable to find text: '##을 발표 , 조선총독부' in '청산을 발표, 조선총독부를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,755 >> Unable to find text: '##를' in '조선총독부를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,755 >> Unable to find text: '##기와 과거사 청산을 발표 , 조선총독부를' in '역사바로세우기와 과거사 청산을 발표, 조선총독부를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,755 >> Unable to find text: '##바로세우기와 과거사 청산을 발표 , 조선총독부를' in '역사바로세우기와 과거사 청산을 발표, 조선총독부를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,796 >> Unable to find text: '##세우기와 과거사 청산을 발표 , 조선총독부를' in '역사바로세우기와 과거사 청산을 발표, 조선총독부를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,797 >> Unable to find text: '##무' in '손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,798 >> Unable to find text: '##충무' in '손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,798 >> Unable to find text: '##무 기자' in '손충무 기자의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,798 >> Unable to find text: '##신문의 편집책임자인 극우 언론인 손충무' in 'LA매일신문의 편집책임자인 극우 언론인 손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,798 >> Unable to find text: '##충무 기자' in '손충무 기자의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,798 >> Unable to find text: '##임자인 극우 언론인 손충무' in '편집책임자인 극우 언론인 손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,798 >> Unable to find text: '##인 극우 언론인 손충무' in '편집책임자인 극우 언론인 손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,799 >> Unable to find text: '##매일신문의 편집책임자인 극우 언론인 손충무' in 'LA매일신문의 편집책임자인 극우 언론인 손충무'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,799 >> Unable to find text: '##무 기자의' in '손충무 기자의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,799 >> Unable to find text: '##신문의 편집책임자인 극우 언론인 손충무 기자' in 'LA매일신문의 편집책임자인 극우 언론인 손충무 기자의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,802 >> Unable to find text: '##일' in '13일'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,803 >> Unable to find text: '##월 13일' in '5월 13일'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,803 >> Unable to find text: '##일 5 · 13 특별 담화' in '13일 5·13 특별 담화에서'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,804 >> Unable to find text: '##일' in '13일,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,804 >> Unable to find text: '##월 13일' in '3월 13일,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,805 >> Unable to find text: '##일 ,' in '13일,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,805 >> Unable to find text: '##월 13일 ,' in '3월 13일,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,805 >> Unable to find text: '##월' in '3월'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,805 >> Unable to find text: '##월 13' in '3월 13일,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,805 >> Unable to find text: '##일 , 언론에 위안부 문제에 대해 물질적 보상을 일본측에 요구하지 않을 방침이라고' in '13일, 언론에 위안부 문제에 대해 물질적 보상을 일본측에 요구하지 않을 방침이라고'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,806 >> Unable to find text: '##월 13일 , 언론에 위안부 문제에 대해 물질적 보상을 일본측에 요구하지 않을 방침이라고' in '3월 13일, 언론에 위안부 문제에 대해 물질적 보상을 일본측에 요구하지 않을 방침이라고'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,806 >> Unable to find text: '##일 , 언론에 위안부 문제에 대해 물질적 보상을 일본측에 요구하지 않을 방침이' in '13일, 언론에 위안부 문제에 대해 물질적 보상을 일본측에 요구하지 않을 방침이라고'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,806 >> Unable to find text: '##일 , 언론' in '13일, 언론에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,808 >> Unable to find text: '##화 운동' in '민주화 운동의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,811 >> Unable to find text: '##한 북 · 미 간에 제네바 합의' in '제외한 북·미 간에 제네바 합의가'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,814 >> Unable to find text: '##정책' in '포용정책을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,815 >> Unable to find text: '##정책을' in '포용정책을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,815 >> Unable to find text: '##을' in '포용정책을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,815 >> Unable to find text: '##정책을 주장' in '포용정책을 주장했던'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,816 >> Unable to find text: '##사건' in '침투사건'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,816 >> Unable to find text: '##년 북한 잠수함 침투사건' in '1996년 북한 잠수함 침투사건'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,818 >> Unable to find text: '##는 빌 클린턴' in '처음에는 빌 클린턴'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,819 >> Unable to find text: '##는 빌 클린턴 대통령' in '처음에는 빌 클린턴 대통령이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,820 >> Unable to find text: '##한 북 · 미 간에 제네바 합의' in '제외한 북·미 간에 제네바 합의가'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,821 >> Unable to find text: '##에 제네바 합의' in '간에 제네바 합의가'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,824 >> Unable to find text: '##의 성향' in '보수주의의 성향이었다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,824 >> Unable to find text: '##적으로 보수주의' in '현실적으로 보수주의의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,824 >> Unable to find text: '##은 현실적으로 보수주의' in '노선은 현실적으로 보수주의의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,827 >> Unable to find text: '##월 8일' in '7월 8일'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,827 >> Unable to find text: '##일' in '8일'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,827 >> Unable to find text: '##개월도 채 되기 전인 7월 8일' in '1개월도 채 되기 전인 7월 8일'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,828 >> Unable to find text: '##월도 채 되기 전인 7월 8일' in '1개월도 채 되기 전인 7월 8일'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,828 >> Unable to find text: '##월' in '7월'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,828 >> Unable to find text: '##월 8' in '7월 8일'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,828 >> Unable to find text: '##월 8일 김일성 주석이 갑자기 사망하면서 남북 정상회담은 무산되었다 .' in '7월 8일 김일성 주석이 갑자기 사망하면서 남북 정상회담은 무산되었다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,828 >> Unable to find text: '##월 8일 김일성 주석이 갑자기 사망' in '7월 8일 김일성 주석이 갑자기 사망하면서'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,828 >> Unable to find text: '##일 김일성 주석이 갑자기 사망하면서 남북 정상회담은 무산되었다 .' in '8일 김일성 주석이 갑자기 사망하면서 남북 정상회담은 무산되었다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,828 >> Unable to find text: '##월 8일 김일성' in '7월 8일 김일성'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,828 >> Unable to find text: '##일 김일성 주석이 갑자기 사망' in '8일 김일성 주석이 갑자기 사망하면서'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,828 >> Unable to find text: '##월 8일 김일성 주석' in '7월 8일 김일성 주석이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,830 >> Unable to find text: '##은 자유민주주의' in '정치철학은 자유민주주의에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,830 >> Unable to find text: '##학은 자유민주주의' in '정치철학은 자유민주주의에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,830 >> Unable to find text: '##철학은 자유민주주의' in '정치철학은 자유민주주의에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,830 >> Unable to find text: '##에' in '자유민주주의에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,831 >> Unable to find text: '##은 자유민주주의에' in '정치철학은 자유민주주의에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,831 >> Unable to find text: '##에 기반' in '자유민주주의에 기반하고'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,831 >> Unable to find text: '##학은 자유민주주의에' in '정치철학은 자유민주주의에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,831 >> Unable to find text: '##에 기반하고 있었다 . 그러나 그의 노선은 현실적으로 보수주의' in '자유민주주의에 기반하고 있었다. 그러나 그의 노선은 현실적으로 보수주의의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,831 >> Unable to find text: '##철학은 자유민주주의에' in '정치철학은 자유민주주의에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,834 >> Unable to find text: '##치' in '갈루치를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,834 >> Unable to find text: '##루치' in '갈루치를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,836 >> Unable to find text: '##공화국의 영변 원자로 시설' in '조선민주주의인민공화국의 영변 원자로 시설에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,836 >> Unable to find text: '##의 영변 원자로 시설' in '조선민주주의인민공화국의 영변 원자로 시설에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,836 >> Unable to find text: '##공화국의 영변' in '조선민주주의인민공화국의 영변'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,836 >> Unable to find text: '##의 영변' in '조선민주주의인민공화국의 영변'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,836 >> Unable to find text: '##민공화국의 영변 원자로 시설' in '조선민주주의인민공화국의 영변 원자로 시설에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,837 >> Unable to find text: '##민주주의인민공화국의 영변 원자로 시설' in '조선민주주의인민공화국의 영변 원자로 시설에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,838 >> Unable to find text: '##월 15일' in '4월 15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,838 >> Unable to find text: '##일' in '15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,838 >> Unable to find text: '##월 15일에는' in '4월 15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,838 >> Unable to find text: '##일에는' in '15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,838 >> Unable to find text: '##월' in '4월'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,838 >> Unable to find text: '##에는' in '15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,839 >> Unable to find text: '##일에는 3대 정치개혁 법안 ( 공직선거 및 선거부정방지법 , 정치자금법 개정안 , 지방자치법 개정안 )' in '15일에는 3대 정치개혁 법안(공직선거 및 선거부정방지법, 정치자금법 개정안, 지방자치법 개정안)에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,839 >> Unable to find text: '##월 15일에' in '4월 15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,839 >> Unable to find text: '##월 15' in '4월 15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,839 >> Unable to find text: '##는' in '15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,839 >> Unable to find text: '##일에는 3대 정치개혁 법안 ( 공직선거 및 선거부정방지법 , 정치자금법 개정안 , 지방자치법 개정안' in '15일에는 3대 정치개혁 법안(공직선거 및 선거부정방지법, 정치자금법 개정안, 지방자치법 개정안)에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,839 >> Unable to find text: '##일에' in '15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,839 >> Unable to find text: '##월 15일에는 3대 정치개혁 법안 ( 공직선거 및 선거부정방지법 , 정치자금법 개정안 ,' in '4월 15일에는 3대 정치개혁 법안(공직선거 및 선거부정방지법, 정치자금법 개정안,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,839 >> Unable to find text: '##일에는 3대 정치개혁 법안 ( 공직선거 및 선거부정방지법 , 정치자금법 개정안 ,' in '15일에는 3대 정치개혁 법안(공직선거 및 선거부정방지법, 정치자금법 개정안,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,840 >> Unable to find text: '##월 15일' in '4월 15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,840 >> Unable to find text: '##일' in '15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,841 >> Unable to find text: '##월 15일에는' in '4월 15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,841 >> Unable to find text: '##일에는' in '15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,841 >> Unable to find text: '##월 15' in '4월 15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,841 >> Unable to find text: '##월' in '4월'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,841 >> Unable to find text: '##월 15일에' in '4월 15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,841 >> Unable to find text: '##는' in '15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,841 >> Unable to find text: '##에는' in '15일에는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,842 >> Unable to find text: '##노해 · 김남주' in '박노해·김남주'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,843 >> Unable to find text: '##해 · 김남주' in '박노해·김남주'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,843 >> Unable to find text: '##주' in '박노해·김남주'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,844 >> Unable to find text: '##직할시장 , 도지사 , 및 시장 , 군수 등을 주민' in '특별시·광역시직할시장, 도지사, 및 시장, 군수 등을 주민이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,844 >> Unable to find text: '##시장 , 도지사 , 및 시장 , 군수 등을 주민' in '특별시·광역시직할시장, 도지사, 및 시장, 군수 등을 주민이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,845 >> Unable to find text: '##을 주민' in '등을 주민이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,847 >> Unable to find text: '##월' in '5월부터'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,847 >> Unable to find text: '##년 5월' in '1995년 5월부터'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,847 >> Unable to find text: '##년' in '1991년'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,847 >> Unable to find text: '##년' in '1995년'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,849 >> Unable to find text: '##던 지방 자치 제도' in '실시되던 지방 자치 제도를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,849 >> Unable to find text: '##년 이후 실시되던 지방 자치 제도' in '1991년 이후 실시되던 지방 자치 제도를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,849 >> Unable to find text: '##를' in '제도를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,850 >> Unable to find text: '##관' in '관리관으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,850 >> Unable to find text: '##급 관리관' in '1급 관리관으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,851 >> Unable to find text: '##관에서 1급 관리관' in '이사관에서 1급 관리관으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,851 >> Unable to find text: '##급 이사관에서 1급 관리관' in '2급 이사관에서 1급 관리관으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,851 >> Unable to find text: '##관으로' in '관리관으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,851 >> Unable to find text: '##급 관리관으로' in '1급 관리관으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,852 >> Unable to find text: '##동' in '박계동에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,854 >> Unable to find text: '##일' in '24일'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,854 >> Unable to find text: '##월 24일' in '11월 24일'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,855 >> Unable to find text: '##월 24' in '11월 24일'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,855 >> Unable to find text: '##월' in '11월'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,855 >> Unable to find text: '##일 김영삼' in '24일 김영삼은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,855 >> Unable to find text: '##일 김영삼은 대통령 명령으로 5 · 18 관련 특별법 제정을 지시하였다 .' in '24일 김영삼은 대통령 명령으로 5·18 관련 특별법 제정을 지시하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,855 >> Unable to find text: '##월 24일 김영삼' in '11월 24일 김영삼은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,898 >> Unable to find text: '##월 24일 김영삼은 대통령 명령으로 5 · 18 관련 특별법 제정을 지시하였다 .' in '11월 24일 김영삼은 대통령 명령으로 5·18 관련 특별법 제정을 지시하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,898 >> Unable to find text: '##일 김영삼은 대통령 명령' in '24일 김영삼은 대통령 명령으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,899 >> Unable to find text: '##천억 이상' in '4천억 이상의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,900 >> Unable to find text: '##이 4천억 이상' in '1인이 4천억 이상의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,900 >> Unable to find text: '##억 이상' in '4천억 이상의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,900 >> Unable to find text: '##인이 4천억 이상' in '1인이 4천억 이상의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,901 >> Unable to find text: '##군부 인사들' in '신군부 인사들을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,902 >> Unable to find text: '##군부 인사' in '신군부 인사들을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,902 >> Unable to find text: '##부 인사들' in '신군부 인사들을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,902 >> Unable to find text: '##부 인사' in '신군부 인사들을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,902 >> Unable to find text: '##들' in '인사들을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,902 >> Unable to find text: '##군부 인사들을' in '신군부 인사들을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,902 >> Unable to find text: '##부 인사의 혐의에 대해 반란죄 , 내란죄를 따지지 않고 신군부 인사들' in '신군부 인사의 혐의에 대해 반란죄,내란죄를 따지지 않고 신군부 인사들을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,903 >> Unable to find text: '##군부 인사의 혐의에 대해 반란죄 , 내란죄를 따지지 않고 신군부 인사들' in '신군부 인사의 혐의에 대해 반란죄,내란죄를 따지지 않고 신군부 인사들을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,903 >> Unable to find text: '##부 인사의 혐의에 대해 반란죄 , 내란죄를 따지지 않고 신군부 인사' in '신군부 인사의 혐의에 대해 반란죄,내란죄를 따지지 않고 신군부 인사들을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,904 >> Unable to find text: '##으로 5 · 18 관련 특별법' in '명령으로 5·18 관련 특별법'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,905 >> Unable to find text: '##설' in '비자금설이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,906 >> Unable to find text: '##천억 비자금설' in '4천억 비자금설이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,906 >> Unable to find text: '##억 비자금설' in '4천억 비자금설이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,906 >> Unable to find text: '##설이' in '비자금설이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,907 >> Unable to find text: '##천억' in '4천억'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,909 >> Unable to find text: '##환' in '김윤환'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,910 >> Unable to find text: '##환 고문' in '김윤환 고문은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,910 >> Unable to find text: '##환' in '김윤환'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,910 >> Unable to find text: '##환 신한국당 고문' in '김윤환 신한국당 고문도'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,912 >> Unable to find text: '##집행 정지' in '형집행 정지도'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,915 >> Unable to find text: '##원' in '2,295억원의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,917 >> Unable to find text: '##일' in '17일'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,917 >> Unable to find text: '##년 4월 17일' in '1997년 4월 17일'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,917 >> Unable to find text: '##월 17일' in '4월 17일'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,917 >> Unable to find text: '##년' in '1997년'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,926 >> Unable to find text: '##환' in '김윤환'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,926 >> Unable to find text: '##환' in '김윤환'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,927 >> Unable to find text: '##당의 김윤환' in '신한국당의 김윤환'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,927 >> Unable to find text: '##국당의 김윤환' in '신한국당의 김윤환'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,927 >> Unable to find text: '##의 김윤환' in '신한국당의 김윤환'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,927 >> Unable to find text: '##환' in '김윤환'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,927 >> Unable to find text: '##환 고문' in '김윤환 고문과'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,927 >> Unable to find text: '##환 고문' in '김윤환 고문은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,927 >> Unable to find text: '##당의 김윤환 고문' in '신한국당의 김윤환 고문과'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,927 >> Unable to find text: '##국당의 김윤환 고문' in '신한국당의 김윤환 고문과'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,927 >> Unable to find text: '##의 김윤환 고문' in '신한국당의 김윤환 고문과'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,927 >> Unable to find text: '##환 신한국당 고문' in '김윤환 신한국당 고문도'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,928 >> Unable to find text: '##환 고문은' in '김윤환 고문은'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,928 >> Unable to find text: '##환 고문과' in '김윤환 고문과'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,928 >> Unable to find text: '##환 신한국당 고문도' in '김윤환 신한국당 고문도'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,928 >> Unable to find text: '##당의 김윤' in '신한국당의 김윤환'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,928 >> Unable to find text: '##국당의 김윤' in '신한국당의 김윤환'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,928 >> Unable to find text: '##의 김윤' in '신한국당의 김윤환'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,932 >> Unable to find text: '##의' in '김대중의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,937 >> Unable to find text: '전두환 노태우 사면을 공약으로 내세우자 사회 각계에서도 개탄의 분위기가 [UNK] . 당시 김영삼대통령은 9월 12일 , 당초 전두환' in '전두환 노태우 사면을 공약으로 내세우자 사회 각계에서도 개탄의 분위기가 쏱아졌다. 당시 김영삼대통령은 9월 12일, 당초 전두환'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,941 >> Unable to find text: '##일' in '31일,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,941 >> Unable to find text: '##년 8월 31일' in '1997년 8월 31일,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,941 >> Unable to find text: '##월 31일' in '8월 31일,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,943 >> Unable to find text: '##자치단체장 선거' in '지방자치단체장 선거가'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,943 >> Unable to find text: '##장 선거' in '지방자치단체장 선거가'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,943 >> Unable to find text: '##월 전격 지방자치단체장 선거' in '7월 전격 지방자치단체장 선거가'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,945 >> Unable to find text: '##장' in '서울특별시장과'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,945 >> Unable to find text: '##급인 서울특별시장' in '차관급인 서울특별시장과'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,945 >> Unable to find text: '##인 서울특별시장' in '차관급인 서울특별시장과'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,945 >> Unable to find text: '##장과' in '서울특별시장과'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,945 >> Unable to find text: '##장과 1급 관리관이던 직할시장 , 도지사' in '서울특별시장과 1급 관리관이던 직할시장, 도지사,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,946 >> Unable to find text: '##급인 서울특별시' in '차관급인 서울특별시장과'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,946 >> Unable to find text: '##장과 1급 관리관이던 직할시장' in '서울특별시장과 1급 관리관이던 직할시장,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,946 >> Unable to find text: '##인 서울특별시' in '차관급인 서울특별시장과'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,946 >> Unable to find text: '##급인 서울특별시장과' in '차관급인 서울특별시장과'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,946 >> Unable to find text: '##과' in '서울특별시장과'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,946 >> Unable to find text: '##인 서울특별시장과' in '차관급인 서울특별시장과'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,946 >> Unable to find text: '##장과 1급 관리관' in '서울특별시장과 1급 관리관이던'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,946 >> Unable to find text: '##시장 , 도지사' in '직할시장, 도지사,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,948 >> Unable to find text: '##통령을 ) ' 바보 ' 로 취급하는 것 " 이라고 노무현' in '노대통령을) '바보'로 취급하는 것"이라고 노무현'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,950 >> Unable to find text: '##들이' in '어민들이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,951 >> Unable to find text: '##년' in '1996년'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,952 >> Unable to find text: '##년 당시' in '1996년 당시'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,954 >> Unable to find text: '##의' in '정권의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,959 >> Unable to find text: '##를 역사의 죄인으로 혹평하고 5 . 16 쿠데타가 없었다면 장면 정부가 나라를 잘 이끌었을 것이며 박정희' in '박정희를 역사의 죄인으로 혹평하고 5.16 쿠데타가 없었다면 장면 정부가 나라를 잘 이끌었을 것이며 박정희의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,959 >> Unable to find text: '##를' in '박정희를'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,961 >> Unable to find text: '##영' in '김일영'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,961 >> Unable to find text: '##학교 김일영' in '성균관대학교 김일영'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,961 >> Unable to find text: '##영 교수' in '김일영 교수와의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,961 >> Unable to find text: '##학교 김일영 교수' in '성균관대학교 김일영 교수와의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,961 >> Unable to find text: '##대학교 김일영' in '성균관대학교 김일영'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,963 >> Unable to find text: '##영' in '김일영'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,963 >> Unable to find text: '##학교 김일영' in '성균관대학교 김일영'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,963 >> Unable to find text: '##영 교수' in '김일영 교수와의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,966 >> Unable to find text: '##세' in '89세의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,967 >> Unable to find text: '##일 오전 0시 21분 32초에 병마를 물리치지 못하고 혈액 감염 의심으로 치료를 받던 중 향년 89세' in '22일 오전 0시 21분 32초에 병마를 물리치지 못하고 혈액 감염 의심으로 치료를 받던 중 향년 89세의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,967 >> Unable to find text: '##세의' in '89세의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,967 >> Unable to find text: '##의' in '89세의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,967 >> Unable to find text: '##세의 일기로' in '89세의 일기로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,967 >> Unable to find text: '##세의 일기' in '89세의 일기로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,968 >> Unable to find text: '##장' in '국가장으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,969 >> Unable to find text: '##일간 국가장' in '5일간 국가장으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,969 >> Unable to find text: '##간 국가장' in '5일간 국가장으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,970 >> Unable to find text: '##학교 병원' in '서울대학교 병원을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,971 >> Unable to find text: '##검진 차 서울대학교 병원' in '건강검진 차 서울대학교 병원을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,971 >> Unable to find text: '##학교' in '서울대학교'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,971 >> Unable to find text: '##을' in '병원을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,971 >> Unable to find text: '##학교 병원을' in '서울대학교 병원을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,972 >> Unable to find text: '##세' in '89세의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,973 >> Unable to find text: '##일 오전 0시 21분 32초에 병마를 물리치지 못하고 혈액 감염 의심으로 치료를 받던 중 향년 89세' in '22일 오전 0시 21분 32초에 병마를 물리치지 못하고 혈액 감염 의심으로 치료를 받던 중 향년 89세의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,973 >> Unable to find text: '##년 89세' in '향년 89세의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,973 >> Unable to find text: '##세의' in '89세의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,973 >> Unable to find text: '##세의 일기' in '89세의 일기로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,973 >> Unable to find text: '##세의 일기로' in '89세의 일기로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,973 >> Unable to find text: '##의' in '89세의'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,973 >> Unable to find text: '##세의 일기로 서거' in '89세의 일기로 서거하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,974 >> Unable to find text: '##세의 일기로 서거하였다 .' in '89세의 일기로 서거하였다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,975 >> Unable to find text: '##장' in '국가장으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,975 >> Unable to find text: '##간 국가장' in '5일간 국가장으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,975 >> Unable to find text: '##일간 국가장' in '5일간 국가장으로'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:33,976 >> Unable to find text: '##던 김영삼' in '않던 김영삼은'
# ...
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,778 >> Unable to find text: '통신 [UNK] 솔루션이 기본적으로 내장되어 있었으나 , 삼성 엑시노스 시리즈는 플래그십 AP로는 삼성 엑시노스 8890' in '통신 모뎀 솔루션이 기본적으로 내장되어 있었으나, 삼성 엑시노스 시리즈는 플래그십 AP로는 삼성 엑시노스 8890이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,778 >> Unable to find text: '[UNK]' in '모뎀'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,778 >> Unable to find text: '통신 [UNK] 솔루션이 기본적으로 내장되어 있었으나 , 삼성 엑시노스 시리즈' in '통신 모뎀 솔루션이 기본적으로 내장되어 있었으나, 삼성 엑시노스 시리즈는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,778 >> Unable to find text: '스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK] 솔루션' in '스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,778 >> Unable to find text: '[UNK] 솔루션이' in '모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,778 >> Unable to find text: '극소수를 제외하면 통신 [UNK] 솔루션' in '극소수를 제외하면 통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,779 >> Unable to find text: '퀄컴 스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK]' in '퀄컴 스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,779 >> Unable to find text: '퀄컴 스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK] 솔루션이' in '퀄컴 스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,779 >> Unable to find text: '[UNK] 솔루션이 기본적으로 내장' in '모뎀 솔루션이 기본적으로 내장되어'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,779 >> Unable to find text: '[UNK] 솔루션이 기본적으로 내장되어 있었으나 , 삼성 엑시노스 시리즈는 플래그십 AP로는 삼성 엑시노스 8890' in '모뎀 솔루션이 기본적으로 내장되어 있었으나, 삼성 엑시노스 시리즈는 플래그십 AP로는 삼성 엑시노스 8890이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,779 >> Unable to find text: '[UNK] 솔루션이 기본적으로 내장되어 있었으나 , 삼성 엑시노스 시리즈' in '모뎀 솔루션이 기본적으로 내장되어 있었으나, 삼성 엑시노스 시리즈는'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,780 >> Unable to find text: '스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK]' in '스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,781 >> Unable to find text: '##bps' in 'Mbps,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,781 >> Unable to find text: '##이 150 Mbps' in 'Cat.13이 150 Mbps,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,781 >> Unable to find text: '##at . 13이 150 Mbps' in 'Cat.13이 150 Mbps,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,781 >> Unable to find text: '##bps ,' in 'Mbps,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,783 >> Unable to find text: '##at . 12' in 'Cat.12가'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,785 >> Unable to find text: '##h' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,785 >> Unable to find text: '##Ah' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,785 >> Unable to find text: '##형 3600 mAh' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,785 >> Unable to find text: '##은 내장형 3600 mAh' in '용량은 내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,785 >> Unable to find text: '##h이다 .' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,785 >> Unable to find text: '##형 3600' in '내장형 3600'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,785 >> Unable to find text: '##Ah이다 .' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,786 >> Unable to find text: '##형 3600 mAh이다 .' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,787 >> Unable to find text: '##충전 기술' in '무선충전 기술까지'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,787 >> Unable to find text: '##충전' in '무선충전'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,789 >> Unable to find text: '##h' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,789 >> Unable to find text: '##Ah' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,789 >> Unable to find text: '##형 3600 mAh' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,789 >> Unable to find text: '##h이다 .' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,789 >> Unable to find text: '##Ah이다 .' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,789 >> Unable to find text: '##형 3600 mAh이다 .' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,790 >> Unable to find text: '##h이다' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,790 >> Unable to find text: '##이다 .' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,794 >> Unable to find text: '##h' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,794 >> Unable to find text: '##Ah' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,794 >> Unable to find text: '##형 3600 mAh' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,795 >> Unable to find text: '##h이다 .' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,795 >> Unable to find text: '##Ah이다 .' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,795 >> Unable to find text: '##h이다' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,795 >> Unable to find text: '##형 3600 mAh이다 .' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,797 >> Unable to find text: '##h' in 'mAh가량'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,800 >> Unable to find text: '##만' in '1,200만'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,800 >> Unable to find text: '##만 화소' in '1,200만 화소'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,803 >> Unable to find text: '##만' in '1,200만'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,803 >> Unable to find text: '##만 화소' in '1,200만 화소'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,804 >> Unable to find text: '##용하여 1 , 200만' in '혼용하여 1,200만'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,805 >> Unable to find text: '##튀' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,805 >> Unable to find text: '##툭튀' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,805 >> Unable to find text: '##튀 '' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,805 >> Unable to find text: '##툭튀 '' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,806 >> Unable to find text: '##튀 ' 도' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,808 >> Unable to find text: '##IS 기술' in 'OIS 기술이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,808 >> Unable to find text: '##IS' in 'OIS'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,808 >> Unable to find text: '##IS 기술이' in 'OIS 기술이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,808 >> Unable to find text: '##IS 기술이 적용' in 'OIS 기술이 적용된'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,809 >> Unable to find text: '##이' in '기술이'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,809 >> Unable to find text: '##IS 기술이 적용된 카메라 모듈' in 'OIS 기술이 적용된 카메라 모듈에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,810 >> Unable to find text: '##만 화소' in '1,200만 화소'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,810 >> Unable to find text: '##만' in '1,200만'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,814 >> Unable to find text: '##가 전작인 갤럭시 S6와 동일하게 후면 카메라 모듈 옆' in '센서가 전작인 갤럭시 S6와 동일하게 후면 카메라 모듈 옆에'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,815 >> Unable to find text: '##68' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,816 >> Unable to find text: '##68로' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,816 >> Unable to find text: '##68로 ,' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,816 >> Unable to find text: '##68로 , 이는 방진 등급으로나 방수 등급으로나 모두 최고레벨' in 'IP68로, 이는 방진 등급으로나 방수 등급으로나 모두 최고레벨이며'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,817 >> Unable to find text: '##로' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,817 >> Unable to find text: '##진' in '방진을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,818 >> Unable to find text: '##진을' in '방진을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,818 >> Unable to find text: '##을' in '방진을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,820 >> Unable to find text: '##68' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,821 >> Unable to find text: '##68로' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,821 >> Unable to find text: '##진을 다시 지원한다 . 등급은 IP68' in '방진을 다시 지원한다. 등급은 IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,821 >> Unable to find text: '##68로 , 이는 방진 등급으로나 방수 등급으로나 모두 최고레벨' in 'IP68로, 이는 방진 등급으로나 방수 등급으로나 모두 최고레벨이며'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,821 >> Unable to find text: '##68로 ,' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,824 >> Unable to find text: '##진' in '방진을'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,825 >> Unable to find text: '##진을 다시 지원' in '방진을 다시 지원한다.'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,825 >> Unable to find text: '##68' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,826 >> Unable to find text: '##68로' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,827 >> Unable to find text: '##68로 ,' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,827 >> Unable to find text: '##68로 , 이는 방진 등급으로나 방수 등급으로나 모두 최고레벨' in 'IP68로, 이는 방진 등급으로나 방수 등급으로나 모두 최고레벨이며'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,828 >> Unable to find text: '##7 엣지' in 'S7 엣지가'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,830 >> Unable to find text: '##월' in '6개월'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,830 >> Unable to find text: '##개월' in '6개월'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,830 >> Unable to find text: '##월 정도' in '6개월 정도가'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,830 >> Unable to find text: '##개월 정도' in '6개월 정도가'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,830 >> Unable to find text: '##7 엣지 출시 이후 6개월' in 'S7 엣지 출시 이후 6개월'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,831 >> Unable to find text: '##년' in '2016년'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,833 >> Unable to find text: '##년 9월 4일' in '2016년 9월 4일'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,833 >> Unable to find text: '##년 9월' in '2016년 9월'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,833 >> Unable to find text: '##년 9월 4' in '2016년 9월 4일'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,833 >> Unable to find text: '##일' in '4일'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,833 >> Unable to find text: '##년 9' in '2016년 9월'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,833 >> Unable to find text: '##년 9월 4일 중동 지역' in '2016년 9월 4일 중동 지역에서'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,833 >> Unable to find text: '##년 9월 4일 중동' in '2016년 9월 4일 중동'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,833 >> Unable to find text: '##년 9월 4일 중동 지역에서 갤럭시 S7 엣지가' in '2016년 9월 4일 중동 지역에서 갤럭시 S7 엣지가'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,837 >> Unable to find text: '##일 중동 지역' in '4일 중동 지역에서'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,837 >> Unable to find text: '##일 중동' in '4일 중동'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,837 >> Unable to find text: '##월 4일 중동 지역' in '9월 4일 중동 지역에서'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,837 >> Unable to find text: '##월 4일 중동' in '9월 4일 중동'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,838 >> Unable to find text: '##년 9월 4일 중동 지역' in '2016년 9월 4일 중동 지역에서'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,839 >> Unable to find text: '##일' in '18일만이며'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,839 >> Unable to find text: '##은 겨우 출시 18일' in '7은 겨우 출시 18일만이며'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,841 >> Unable to find text: '##년 9월 4일 중동 지역' in '2016년 9월 4일 중동 지역에서'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,841 >> Unable to find text: '##일 중동 지역' in '4일 중동 지역에서'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,841 >> Unable to find text: '##월 4일 중동 지역' in '9월 4일 중동 지역에서'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,841 >> Unable to find text: '##년 9월 4일 중동' in '2016년 9월 4일 중동'
# [INFO|squad_metrics.py:305] 2023-03-01 23:46:37,842 >> Unable to find text: '##일 중동' in '4일 중동'
# 03/01/2023 23:46:39 - INFO - __main__ - Results: {'exact_1000': 81.97090405264981, 'f1_1000': 87.89804487934052, 'total_1000': 5774, 'HasAns_exact_1000': 81.97090405264981, 'HasAns_f1_1000': 87.89804487934052, 'HasAns_total_1000': 5774, 'best_exact_1000': 81.97090405264981, 'best_exact_thresh_1000': 0.0, 'best_f1_1000': 87.89804487934052, 'best_f1_thresh_1000': 0.0, 'exact_10000': 84.48216141323172, 'f1_10000': 89.98783141013037, 'total_10000': 5774, 'HasAns_exact_10000': 84.48216141323172, 'HasAns_f1_10000': 89.98783141013037, 'HasAns_total_10000': 5774, 'best_exact_10000': 84.48216141323172, 'best_exact_thresh_10000': 0.0, 'best_f1_10000': 89.98783141013037, 'best_f1_thresh_10000': 0.0, 'exact_11000': 84.55143747835123, 'f1_11000': 89.99781013159978, 'total_11000': 5774, 'HasAns_exact_11000': 84.55143747835123, 'HasAns_f1_11000': 89.99781013159978, 'HasAns_total_11000': 5774, 'best_exact_11000': 84.55143747835123, 'best_exact_thresh_11000': 0.0, 'best_f1_11000': 89.99781013159978, 'best_f1_thresh_11000': 0.0, 'exact_12000': 84.74194665742986, 'f1_12000': 90.19284962045637, 'total_12000': 5774, 'HasAns_exact_12000': 84.74194665742986, 'HasAns_f1_12000': 90.19284962045637, 'HasAns_total_12000': 5774, 'best_exact_12000': 84.74194665742986, 'best_exact_thresh_12000': 0.0, 'best_f1_12000': 90.19284962045637, 'best_f1_thresh_12000': 0.0, 'exact_2000': 83.3044683062002, 'f1_2000': 88.81491733067784, 'total_2000': 5774, 'HasAns_exact_2000': 83.3044683062002, 'HasAns_f1_2000': 88.81491733067784, 'HasAns_total_2000': 5774, 'best_exact_2000': 83.3044683062002, 'best_exact_thresh_2000': 0.0, 'best_f1_2000': 88.81491733067784, 'best_f1_thresh_2000': 0.0, 'exact_3000': 83.47765846899897, 'f1_3000': 88.98369599728653, 'total_3000': 5774, 'HasAns_exact_3000': 83.47765846899897, 'HasAns_f1_3000': 88.98369599728653, 'HasAns_total_3000': 5774, 'best_exact_3000': 83.47765846899897, 'best_exact_thresh_3000': 0.0, 'best_f1_3000': 88.98369599728653, 'best_f1_thresh_3000': 0.0, 'exact_4000': 84.11846207135434, 'f1_4000': 89.75338434032604, 'total_4000': 5774, 'HasAns_exact_4000': 84.11846207135434, 'HasAns_f1_4000': 89.75338434032604, 'HasAns_total_4000': 5774, 'best_exact_4000': 84.11846207135434, 'best_exact_thresh_4000': 0.0, 'best_f1_4000': 89.75338434032604, 'best_f1_thresh_4000': 0.0, 'exact_5000': 84.03186698995498, 'f1_5000': 89.68581724579404, 'total_5000': 5774, 'HasAns_exact_5000': 84.03186698995498, 'HasAns_f1_5000': 89.68581724579404, 'HasAns_total_5000': 5774, 'best_exact_5000': 84.03186698995498, 'best_exact_thresh_5000': 0.0, 'best_f1_5000': 89.68581724579404, 'best_f1_thresh_5000': 0.0, 'exact_6000': 83.96259092483547, 'f1_6000': 89.57136847680688, 'total_6000': 5774, 'HasAns_exact_6000': 83.96259092483547, 'HasAns_f1_6000': 89.57136847680688, 'HasAns_total_6000': 5774, 'best_exact_6000': 83.96259092483547, 'best_exact_thresh_6000': 0.0, 'best_f1_6000': 89.57136847680688, 'best_f1_thresh_6000': 0.0, 'exact_7000': 84.39556633183236, 'f1_7000': 89.80651014319626, 'total_7000': 5774, 'HasAns_exact_7000': 84.39556633183236, 'HasAns_f1_7000': 89.80651014319626, 'HasAns_total_7000': 5774, 'best_exact_7000': 84.39556633183236, 'best_exact_thresh_7000': 0.0, 'best_f1_7000': 89.80651014319626, 'best_f1_thresh_7000': 0.0, 'exact_8000': 84.11846207135434, 'f1_8000': 89.68590592334982, 'total_8000': 5774, 'HasAns_exact_8000': 84.11846207135434, 'HasAns_f1_8000': 89.68590592334982, 'HasAns_total_8000': 5774, 'best_exact_8000': 84.11846207135434, 'best_exact_thresh_8000': 0.0, 'best_f1_8000': 89.68590592334982, 'best_f1_thresh_8000': 0.0, 'exact_9000': 84.4994804295116, 'f1_9000': 90.1460617952654, 'total_9000': 5774, 'HasAns_exact_9000': 84.4994804295116, 'HasAns_f1_9000': 90.1460617952654, 'HasAns_total_9000': 5774, 'best_exact_9000': 84.4994804295116, 'best_exact_thresh_9000': 0.0, 'best_f1_9000': 90.1460617952654, 'best_f1_thresh_9000': 0.0, 'exact_klue_bert': 84.74194665742986, 'f1_klue_bert': 90.19284962045637, 'total_klue_bert': 5774, 'Ha ...

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## 경로 변경

# %%
import os
os.chdir('/content/drive/MyDrive/korquad/')
os.getcwd()
# Out:
# '/content/drive/MyDrive/korquad'

# %% [markdown]
# ## 성능 확인

# %%
from __future__ import print_function
from collections import Counter
import string
import re
import argparse
import json
import sys
import os

import pandas as pd
from transformers import AutoTokenizer

'''KorQuAD v1.0에 대한 공식 평가 스크립트 '''
'''본 스크립트는 SQuAD v1.1 평가 스크립트 https://rajpurkar.github.io/SQuAD-explorer/ 를 바탕으로 작성됨.'''

def normalize_answer(s):    
    def remove_(text):
        ''' 불필요한 기호 제거 '''
        text = re.sub("'", " ", text)
        text = re.sub('"', " ", text)
        text = re.sub('《', " ", text)
        text = re.sub('》', " ", text)
        text = re.sub('<', " ", text)
        text = re.sub('>', " ", text) 
        text = re.sub('〈', " ", text)
        text = re.sub('〉', " ", text)   
        text = re.sub("\(", " ", text)
        text = re.sub("\)", " ", text)
        text = re.sub("‘", " ", text)
        text = re.sub("’", " ", text)      
        return text

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return ''.join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_punc(lower(remove_(s))))


def f1_score(prediction, ground_truth):
    prediction_tokens = normalize_answer(prediction).split()
    ground_truth_tokens = normalize_answer(ground_truth).split()
   
    #F1 by character
    prediction_Char = []
    for tok in prediction_tokens:
        now = [a for a in tok]
        prediction_Char.extend(now)
        
    ground_truth_Char = []
    for tok in ground_truth_tokens:
        now = [a for a in tok]
        ground_truth_Char.extend(now)   
        
    common = Counter(prediction_Char) & Counter(ground_truth_Char)
    num_same = sum(common.values())
    if num_same == 0:
        return 0
    
    precision = 1.0 * num_same / len(prediction_Char)
    recall = 1.0 * num_same / len(ground_truth_Char)
    f1 = (2 * precision * recall) / (precision + recall)
    
    return f1


def exact_match_score(prediction, ground_truth):
    return (normalize_answer(prediction) == normalize_answer(ground_truth))


def metric_max_over_ground_truths(metric_fn, prediction, ground_truths):
    scores_for_ground_truths = []
    for ground_truth in ground_truths:
        score = metric_fn(prediction, ground_truth)
        scores_for_ground_truths.append(score)
    return max(scores_for_ground_truths)


def evaluate(dataset, predictions):
    f1 = exact_match = total = 0
    for article in dataset:
        for paragraph in article['paragraphs']:
            for qa in paragraph['qas']:
                total += 1
                if qa['id'] not in predictions:
                    message = 'Unanswered question ' + qa['id'] + \
                              ' will receive score 0.'
                    print(message, file=sys.stderr)
                    continue
                ground_truths = list(map(lambda x: x['text'], qa['answers']))
                prediction = predictions[qa['id']]
                exact_match += metric_max_over_ground_truths(
                    exact_match_score, prediction, ground_truths)
                f1 += metric_max_over_ground_truths(
                    f1_score, prediction, ground_truths)

    exact_match = 100.0 * exact_match / total
    f1 = 100.0 * f1 / total
    return {'exact_match': exact_match, 'f1': f1}


def evaluate_result(dataset_file, prediction_file):
    
    with open(dataset_file, encoding="utf-8") as f:
        dataset_json = json.load(f)
        dataset = dataset_json['data']
    with open(prediction_file, encoding="utf-8") as f:
        predictions = json.load(f)
    return evaluate(dataset, predictions)

# %%
dataset_file = './data/KorQuAD_v1.0_dev.json'
prediction_file = './klue_bert/predictions_klue_bert.json'
evaluate_result(dataset_file, prediction_file)
# Out:
# {'exact_match': 84.89781780394874, 'f1': 93.44669302258944}
