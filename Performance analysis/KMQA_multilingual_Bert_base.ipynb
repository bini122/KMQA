# %%
# !pip3 install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Using cached transformers-4.29.2-py3-none-any.whl (7.1 MB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Using cached huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Using cached tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.15.1 tokenizers-0.13.3 transformers-4.29.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/korquad/')
os.getcwd()
# Out:
# '/content/drive/MyDrive/korquad'

# %%
# !python ./task_1/run_QA.py \
    --model_type bert \
    --model_name_or_path bert-base-multilingual-cased \
    --output_dir multilingual_bert-KMQA \
    --data_dir data \
    --data_name KMQA \
    --train_file KMQA_train_v5.1.json \
    --predict_file KMQA_dev_v5.1.json \
    --max_seq_length 512 \
    --doc_stride 128 \
    --max_query_length 64 \
    --do_train \
    --do_eval \
    --evaluate_during_training \
    --per_gpu_train_batch_size=16 \
    --per_gpu_eval_batch_size=8 \
    --learning_rate 5e-5 \
    --gradient_accumulation_steps 1 \
    --weight_decay 0.0 \
    --adam_epsilon 1e-8 \
    --max_grad_norm 1.0 \
    --num_train_epochs 3 \
    --max_steps -1 \
    --warmup_steps 0 \
    --n_best_size 20 \
    --max_answer_length 30 \
    --verbose_logging \
    --logging_steps 1000 \
    --save_steps 1000 \
    --eval_all_checkpoints \
    --overwrite_output_dir \
    --seed 42 \
    --local_rank -1 \
    --threads 4
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,672 >> Unable to find text: '짧게는 [UNK] 주사같은 부신피로회복 수액요법도효과가 있을 것으로 보이며 ,' in '짧게는 마이어스칵테일 주사같은 부신피로회복 수액요법도효과가 있을 것으로 보이며,'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,681 >> Unable to find text: '##요' in '같아요.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,683 >> Unable to find text: '##요 . 우선 어지럼증은 약을 먹고 나서 생긴 것이니까 부작용일 가능성이 높습니다' in '같아요. 우선 어지럼증은 약을 먹고 나서 생긴 것이니까 부작용일 가능성이 높습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,683 >> Unable to find text: '이해인 수녀님의 말씀처럼 단 1 % 의 차이로 우리는 불행하다고 느끼고 있는지 [UNK]' in '이해인 수녀님의 말씀처럼 단 1%의 차이로 우리는 불행하다고 느끼고 있는지 모릅니다.문의에'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,685 >> Unable to find text: '##니다 .' in '권유드립니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,685 >> Unable to find text: '##니다' in '권유드립니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,685 >> Unable to find text: '##니다 . 감사합니다' in '권유드립니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,685 >> Unable to find text: '##니다' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,685 >> Unable to find text: '##니다 . 감사합니다 .' in '권유드립니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,685 >> Unable to find text: '##니다 .' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,686 >> Unable to find text: '##니다 . 감' in '권유드립니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,686 >> Unable to find text: '아니면 그 때 받은 약을 자의적으로 필요시마다 [UNK]' in '궁금합니다.아니면 그 때 받은 약을 자의적으로 필요시마다 쪼개서'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,686 >> Unable to find text: '궁금합니다 . 아니면 그 때 받은 약을 자의적으로 필요시마다 [UNK]' in '궁금합니다.아니면 그 때 받은 약을 자의적으로 필요시마다 쪼개서'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,706 >> Unable to find text: '##요' in '않네요.중요한'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,706 >> Unable to find text: '##죠' in '이겨나가야죠.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,706 >> Unable to find text: '##니다 .' in '입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,706 >> Unable to find text: '##요' in '같아요.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,707 >> Unable to find text: '##죠 . 언젠가는 흥분되었던 신경들도 차츰차츰 균형을 찾아서 회복될 겁니다' in '이겨나가야죠. 언젠가는 흥분되었던 신경들도 차츰차츰 균형을 찾아서 회복될 겁니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,707 >> Unable to find text: '##니다' in '입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,707 >> Unable to find text: '##니다 . 행복한 하루 되세요' in '입니다. 행복한 하루 되세요.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,712 >> Unable to find text: '언급한 내용으로 단순한 불면증보다는 우울증과 같은 기분장애가 있을 가능성이 [UNK]' in '있습니다.언급한 내용으로 단순한 불면증보다는 우울증과 같은 기분장애가 있을 가능성이 추정됩니다.하지만'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,713 >> Unable to find text: '언급한 내용으로 단순한 불면증보다는 우울증과 같은 기분장애가 있을 가능성이 [UNK] .' in '있습니다.언급한 내용으로 단순한 불면증보다는 우울증과 같은 기분장애가 있을 가능성이 추정됩니다.하지만'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,714 >> Unable to find text: '단순한 불면증보다는 우울증과 같은 기분장애가 있을 가능성이 [UNK]' in '단순한 불면증보다는 우울증과 같은 기분장애가 있을 가능성이 추정됩니다.하지만'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,714 >> Unable to find text: '단순한 불면증보다는 우울증과 같은 기분장애가 있을 가능성이 [UNK] .' in '단순한 불면증보다는 우울증과 같은 기분장애가 있을 가능성이 추정됩니다.하지만'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,715 >> Unable to find text: '##니다' in '있습니다.한편'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,715 >> Unable to find text: '내용으로 단순한 불면증보다는 우울증과 같은 기분장애가 있을 가능성이 [UNK]' in '내용으로 단순한 불면증보다는 우울증과 같은 기분장애가 있을 가능성이 추정됩니다.하지만'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,715 >> Unable to find text: '##니다 . 한편 수면 문제는 다른 정신질환의 출현을 나타내는 신호 증상일 수도 있습니다' in '있습니다.한편 수면 문제는 다른 정신질환의 출현을 나타내는 신호 증상일 수도 있습니다.언급한'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,715 >> Unable to find text: '우울증과 같은 기분장애가 있을 가능성이 [UNK]' in '우울증과 같은 기분장애가 있을 가능성이 추정됩니다.하지만'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,716 >> Unable to find text: '##니다' in '있습니다.언급한'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,716 >> Unable to find text: '불면증보다는 우울증과 같은 기분장애가 있을 가능성이 [UNK]' in '불면증보다는 우울증과 같은 기분장애가 있을 가능성이 추정됩니다.하지만'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,718 >> Unable to find text: '물론 원칙적이고 약속을 잘 지키는 것이 나쁜 것은 [UNK] .' in '물론 원칙적이고 약속을 잘 지키는 것이 나쁜 것은 아닙니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,718 >> Unable to find text: '물론 원칙적이고 약속을 잘 지키는 것이 나쁜 것은 [UNK]' in '물론 원칙적이고 약속을 잘 지키는 것이 나쁜 것은 아닙니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,719 >> Unable to find text: '##니다 .' in '사람입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,719 >> Unable to find text: '원칙적이고 약속을 잘 지키는 것이 나쁜 것은 [UNK] .' in '원칙적이고 약속을 잘 지키는 것이 나쁜 것은 아닙니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,719 >> Unable to find text: '원칙적이고 약속을 잘 지키는 것이 나쁜 것은 [UNK]' in '원칙적이고 약속을 잘 지키는 것이 나쁜 것은 아닙니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,719 >> Unable to find text: '##니다 .' in '필요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,720 >> Unable to find text: '##니다 . 이런 사람들에게는 융통성이 가장 필요합니다 .' in '사람입니다. 이런 사람들에게는 융통성이 가장 필요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,722 >> Unable to find text: '##니다' in '좋겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,722 >> Unable to find text: '##니다 .' in '좋겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,723 >> Unable to find text: '##니다 . 문의에 도움이 되었으면 합니다' in '좋겠습니다. 문의에 도움이 되었으면 합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,723 >> Unable to find text: '##니다 .' in '중요합니다.강남에'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,723 >> Unable to find text: '##니다' in '합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,731 >> Unable to find text: '##니다' in '것입니다.다른분을'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,732 >> Unable to find text: '##니다 . 다른분을 위해서 희생을 해야하는 결혼은 피하는 것이 좋습니다' in '것입니다.다른분을 위해서 희생을 해야하는 결혼은 피하는 것이 좋습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,732 >> Unable to find text: '##니다' in '좋습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,735 >> Unable to find text: '##니다' in '좋겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,736 >> Unable to find text: '##니다 .' in '좋겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,736 >> Unable to find text: '##니다' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,737 >> Unable to find text: '##니다 . 감사합니다' in '좋겠습니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,737 >> Unable to find text: '##니다 .' in '효과적입니다.추후'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,741 >> Unable to find text: '##니다' in '있습니다.근본적으로'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,741 >> Unable to find text: '[UNK]' in '됩니다.과호흡이'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,742 >> Unable to find text: '##니다' in '합니다.술을'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,743 >> Unable to find text: '##니다' in '합니다. '
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,743 >> Unable to find text: '[UNK] .' in '됩니다.과호흡이'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,744 >> Unable to find text: '##니다 .' in '있습니다.근본적으로'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,744 >> Unable to find text: '##니다 .' in '합니다.술을'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,744 >> Unable to find text: '##니다 . 술은 당분간 드시지 마십시요' in '합니다.  술은 당분간 드시지 마십시요.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,750 >> Unable to find text: '[UNK]' in '어찌됬든,'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,750 >> Unable to find text: '그 원인이 [UNK]' in '그 원인이 어찌됬든,'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,750 >> Unable to find text: '원인이 [UNK]' in '원인이 어찌됬든,'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,750 >> Unable to find text: '오늘도 불안때문에 잠도 2시간밖에 [UNK] 점심때 발작오고 .' in '된다는겁니다.오늘도 불안때문에 잠도 2시간밖에 못잤고 점심때 발작오고...삶의'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,751 >> Unable to find text: '오늘도 불안때문에 잠도 2시간밖에 [UNK] 점심때 발작오고 . .' in '된다는겁니다.오늘도 불안때문에 잠도 2시간밖에 못잤고 점심때 발작오고...삶의'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,756 >> Unable to find text: '##요' in '것인데요.불안과'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,756 >> Unable to find text: '##니다' in '이유입니다.양약'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,756 >> Unable to find text: '##니다' in '방법입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,757 >> Unable to find text: '##니다 . 만약 이것으로도 부족하다면 한방치료를 받아보는 것을 권합니다' in '방법입니다. 만약 이것으로도 부족하다면 한방치료를 받아보는 것을 권합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,757 >> Unable to find text: '##니다 . 만약 이것으로도 부족하다면 한방치료를 받아보는 것을 권합니다 .' in '방법입니다. 만약 이것으로도 부족하다면 한방치료를 받아보는 것을 권합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,757 >> Unable to find text: '##니다 .' in '방법입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,757 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,758 >> Unable to find text: '##니다 .' in '이유입니다.양약'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,758 >> Unable to find text: '##요 .' in '것인데요.불안과'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,760 >> Unable to find text: '##니다 . 만약 이것으로도 부족하다면 한방치료를 받아보는 것을 권합니다 . 감사합니다' in '방법입니다. 만약 이것으로도 부족하다면 한방치료를 받아보는 것을 권합니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,765 >> Unable to find text: '##니다 . 스트레스가 없어야 하고 안정이 필요한데 그렇지 않아 보여 안타깝습니다' in '싶습니다.스트레스가 없어야 하고 안정이 필요한데 그렇지 않아 보여 안타깝습니다.진료'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,765 >> Unable to find text: '##니다' in '안타깝습니다.진료'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,766 >> Unable to find text: '##트레스가 없어야 하고 안정이 필요한데 그렇지 않아 보여 안타깝습니다' in '싶습니다.스트레스가 없어야 하고 안정이 필요한데 그렇지 않아 보여 안타깝습니다.진료'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,767 >> Unable to find text: '고혈압 , 협심증 , 심방세동 , 빈맥 , 크롬친화세포종 등의 치료에 [UNK] .' in '무엇입니까?고혈압, 협심증, 심방세동, 빈맥, 크롬친화세포종 등의 치료에 사용됩니다.이'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,768 >> Unable to find text: '고혈압 , 협심증 , 심방세동 , 빈맥 , 크롬친화세포종 등의 치료에 [UNK]' in '무엇입니까?고혈압, 협심증, 심방세동, 빈맥, 크롬친화세포종 등의 치료에 사용됩니다.이'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,774 >> Unable to find text: '##니다' in '바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,774 >> Unable to find text: '##니다 . 위 대장 혹은 소화기내과적 장기의 질환여부는 검사를 통해서 알아보셔야 합니다' in '바랍니다. 위 대장 혹은 소화기내과적 장기의 질환여부는 검사를 통해서 알아보셔야 합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,774 >> Unable to find text: '##니다' in '합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,775 >> Unable to find text: '##니다 . 단순한 질의에 의한 답변은 정확하지 않습니다' in '합니다. 단순한 질의에 의한 답변은 정확하지 않습니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,776 >> Unable to find text: '##니다' in '않습니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,777 >> Unable to find text: '##니다 . 단순한 질의에 의한 답변은 정확하지 않습니다 .' in '합니다. 단순한 질의에 의한 답변은 정확하지 않습니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,782 >> Unable to find text: '##니다' in '하겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,782 >> Unable to find text: '##니다' in '합니다.한'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,783 >> Unable to find text: '##니다 . 한 병원을 믿고 증상을 조절하는 것 만이 호전이 될 수 있는 방법 입니다' in '합니다.한 병원을 믿고 증상을 조절하는 것 만이 호전이 될 수 있는 방법 입니다.현재'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,783 >> Unable to find text: '##니다 .' in '합니다.한'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,783 >> Unable to find text: '##니다' in '입니다.현재'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,785 >> Unable to find text: '주치의 선생님께서는 그러한 맥락에서 약물 감량에 다소 부정적일 수 있다고 [UNK] .' in '주치의 선생님께서는 그러한 맥락에서 약물 감량에 다소 부정적일 수 있다고 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,785 >> Unable to find text: '주치의 선생님께서는 그러한 맥락에서 약물 감량에 다소 부정적일 수 있다고 [UNK]' in '주치의 선생님께서는 그러한 맥락에서 약물 감량에 다소 부정적일 수 있다고 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,785 >> Unable to find text: '그러한 맥락에서 약물 감량에 다소 부정적일 수 있다고 [UNK] .' in '그러한 맥락에서 약물 감량에 다소 부정적일 수 있다고 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,786 >> Unable to find text: '[UNK] .' in '생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,786 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,786 >> Unable to find text: '. 주치의 선생님께서는 그러한 맥락에서 약물 감량에 다소 부정적일 수 있다고 [UNK] .' in '있습니다. 주치의 선생님께서는 그러한 맥락에서 약물 감량에 다소 부정적일 수 있다고 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,786 >> Unable to find text: '약물 감량에 다소 부정적일 수 있다고 [UNK] .' in '약물 감량에 다소 부정적일 수 있다고 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,786 >> Unable to find text: '그러한 맥락에서 약물 감량에 다소 부정적일 수 있다고 [UNK]' in '그러한 맥락에서 약물 감량에 다소 부정적일 수 있다고 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,787 >> Unable to find text: '주치의 선생님께서는 그러한 맥락에서 약물 감량에 다소 부정적일 수 있다고 [UNK] . 더' in '주치의 선생님께서는 그러한 맥락에서 약물 감량에 다소 부정적일 수 있다고 생각됩니다. 더군다나'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,787 >> Unable to find text: '[UNK]' in '생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,788 >> Unable to find text: '##니다 . 주치의 선생님께서는 그러한 맥락에서 약물 감량에 다소 부정적일 수 있다고 [UNK]' in '있습니다. 주치의 선생님께서는 그러한 맥락에서 약물 감량에 다소 부정적일 수 있다고 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,788 >> Unable to find text: '. 주치의 선생님께서는 그러한 맥락에서 약물 감량에 다소 부정적일 수 있다고 [UNK]' in '있습니다. 주치의 선생님께서는 그러한 맥락에서 약물 감량에 다소 부정적일 수 있다고 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,788 >> Unable to find text: '약물 감량에 다소 부정적일 수 있다고 [UNK]' in '약물 감량에 다소 부정적일 수 있다고 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,789 >> Unable to find text: '##니다 .' in '좋습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,790 >> Unable to find text: '##니다 .' in '좋습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,791 >> Unable to find text: '##니다 . 잠시 벤치에 앉아서 쉬는게 좋습니다 .' in '김지우입니다. 잠시 벤치에 앉아서 쉬는게 좋습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,791 >> Unable to find text: '##입니다 . 잠시 벤치에 앉아서 쉬는게 좋습니다 .' in '김지우입니다. 잠시 벤치에 앉아서 쉬는게 좋습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,791 >> Unable to find text: '##니다' in '좋습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,792 >> Unable to find text: '##니다 . 잠' in '김지우입니다. 잠시'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,795 >> Unable to find text: '##니다' in '바랍니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,796 >> Unable to find text: '##니다 . 이런 경우에는 봉지호흡을 통하여 증상이 완화될 수 있습니다 .' in '여겨집니다.이런 경우에는 봉지호흡을 통하여 증상이 완화될 수 있습니다.다만'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,798 >> Unable to find text: '##니다 . 낫는데 걸리는 시간은 사람마다 다르겠지만 대부분은 완치가 가능합니다' in '합니다.낫는데 걸리는 시간은 사람마다 다르겠지만 대부분은 완치가 가능합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,799 >> Unable to find text: '##니다 . 낫는데 걸리는 시간은 사람마다 다르겠지만 대부분은 완치가 가능합니다 .' in '합니다.낫는데 걸리는 시간은 사람마다 다르겠지만 대부분은 완치가 가능합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,799 >> Unable to find text: '##니다' in '가능합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,799 >> Unable to find text: '##니다 .' in '가능합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,799 >> Unable to find text: '##니다 . 약물치료 ( 한약치료도 가능 ) 및 인지행동치료가 필요할 듯 합니다 .' in '보입니다.약물치료(한약치료도 가능) 및 인지행동치료가 필요할 듯 합니다.낫는데'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,800 >> Unable to find text: '##니다 .' in '합니다.낫는데'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,802 >> Unable to find text: '##니다 .' in '부분입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,806 >> Unable to find text: '다만 스틸녹스 1 / 3 정도면 양이 많지는 않은 것으로 [UNK]' in '좋습니다.다만 스틸녹스 1/3 정도면 양이 많지는 않은 것으로 생각됩니다.불면증은'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,807 >> Unable to find text: '스틸녹스 1 / 3 정도면 양이 많지는 않은 것으로 [UNK]' in '스틸녹스 1/3 정도면 양이 많지는 않은 것으로 생각됩니다.불면증은'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,807 >> Unable to find text: '##니다' in '발생합니다.구체적으로'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,807 >> Unable to find text: '[UNK] . 불면증은 근본적으로 수면과 각성을 조절하는 뇌 신경계의 기능이상으로 발생합니다' in '생각됩니다.불면증은 근본적으로 수면과 각성을 조절하는 뇌 신경계의 기능이상으로 발생합니다.구체적으로'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,808 >> Unable to find text: '##니다 . 다만 스틸녹스 1 / 3 정도면 양이 많지는 않은 것으로 [UNK]' in '좋습니다.다만 스틸녹스 1/3 정도면 양이 많지는 않은 것으로 생각됩니다.불면증은'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,808 >> Unable to find text: '##니다' in '좋습니다.다만'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,808 >> Unable to find text: '순차적으로 줄이는 것이 좋습니다 . 다만 스틸녹스 1 / 3 정도면 양이 많지는 않은 것으로 [UNK]' in '순차적으로 줄이는 것이 좋습니다.다만 스틸녹스 1/3 정도면 양이 많지는 않은 것으로 생각됩니다.불면증은'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,808 >> Unable to find text: '[UNK]' in '생각됩니다.불면증은'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,809 >> Unable to find text: '##니다 . 전문가의 조언아래 순차적으로 줄이는 것이 좋습니다' in '있습니다. 전문가의 조언아래 순차적으로 줄이는 것이 좋습니다.다만'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,809 >> Unable to find text: '##니다' in '발생합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,809 >> Unable to find text: '다만 스틸녹스 1 / 3 정도면 양이 많지는 않은 것으로 [UNK] .' in '좋습니다.다만 스틸녹스 1/3 정도면 양이 많지는 않은 것으로 생각됩니다.불면증은'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,809 >> Unable to find text: '##니다 . 수면제를 끊고 싶다면 기본적인 수면위생을 지키는 것이 중요합니다' in '발생합니다. 수면제를 끊고 싶다면 기본적인 수면위생을 지키는 것이 중요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,813 >> Unable to find text: '##니다' in '경우입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,814 >> Unable to find text: '##께서 잠을 못주무시는 큰 이유중에 하나는 불면증에 대한 공포 그 자체인것 같습니다' in '님께서 잠을 못주무시는 큰 이유중에 하나는 불면증에 대한 공포 그 자체인것 같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,815 >> Unable to find text: '##니다' in '약입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,818 >> Unable to find text: '##니다' in '권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,819 >> Unable to find text: '##니다 .' in '권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,819 >> Unable to find text: '##니다 .' in '불가능합니다.특히'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,821 >> Length not equal after stripping spaces: '것입니다.문의주신분의변화가필요합니다. 다른' vs '것입니다.문의주신분의변화가필요합니다.다른'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,821 >> Length not equal after stripping spaces: '근본적인원인이해결이안되었기때문일것입니다. ' vs '근본적인원인이해결이안되었기때문일것입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,821 >> Length not equal after stripping spaces: '남편은크게바뀌지는않을것입니다.문의주신분의변화가필요합니다. 다른' vs '남편은크게바뀌지는않을것입니다.문의주신분의변화가필요합니다.다른'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,822 >> Length not equal after stripping spaces: '우울증약의금단증상은보통2주안에는모두사라집니다. 가슴이' vs '우울증약의금단증상은보통2주안에는모두사라집니다.가슴이'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,822 >> Length not equal after stripping spaces: '것입니다.문의주신분의변화가필요합니다. 다른' vs '것입니다.문의주신분의변화가필요합니다.다른'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,822 >> Length not equal after stripping spaces: '합니다. 다른곳에서상담을받아보는것도도움이될수있습니다.문의에' vs '합니다.다른곳에서상담을받아보는것도도움이될수있습니다.문의에'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,822 >> Length not equal after stripping spaces: '남편은크게바뀌지는않을것입니다.문의주신분의변화가필요합니다. 다른' vs '남편은크게바뀌지는않을것입니다.문의주신분의변화가필요합니다.다른'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,823 >> Length not equal after stripping spaces: '근본적인원인이해결이안되었기때문일것입니다. ' vs '근본적인원인이해결이안되었기때문일것입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,823 >> Length not equal after stripping spaces: '합니다. 다른곳에서상담을받아보는것도도움이될수있습니다.문의에' vs '합니다.다른곳에서상담을받아보는것도도움이될수있습니다.문의에'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,823 >> Length not equal after stripping spaces: '우울증약의금단증상은보통2주안에는모두사라집니다. 가슴이' vs '우울증약의금단증상은보통2주안에는모두사라집니다.가슴이'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,823 >> Length not equal after stripping spaces: '주신분의변화가필요합니다. 다른' vs '주신분의변화가필요합니다.다른'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,824 >> Unable to find text: '##니다 . 근본적인 원인이 해결이 안 되었기 때문일 것 입니다' in '가까워 보입니다.  근본적인 원인이 해결이 안 되었기 때문일 것 입니다. '
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,824 >> Unable to find text: '##니다' in '입니다. '
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,824 >> Length not equal after stripping spaces: '주신분의변화가필요합니다. 다른곳에서상담을받아보는것도도움이될수있습니다.문의에' vs '주신분의변화가필요합니다.다른곳에서상담을받아보는것도도움이될수있습니다.문의에'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,824 >> Length not equal after stripping spaces: '가까워 보입니다. 근본적인원인이해결이안되었기때문일것입니다. ' vs '가까워보입니다.근본적인원인이해결이안되었기때문일것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,824 >> Unable to find text: '##니다 . 남편은 크게 바뀌지는 않을 것입니다 . 문의 주신 분의 변화가 필요 합니다' in '입니다.  남편은 크게 바뀌지는 않을 것입니다.문의 주신 분의 변화가 필요 합니다. 다른'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,861 >> Unable to find text: '##니다 . 남편은 크게 바뀌지는 않을 것입니다' in '입니다.  남편은 크게 바뀌지는 않을 것입니다.문의'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,862 >> Unable to find text: '##니다' in '합니다. 다른'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,862 >> Unable to find text: '##니다 . 문의 주신 분의 변화가 필요 합니다' in '것입니다.문의 주신 분의 변화가 필요 합니다. 다른'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,862 >> Unable to find text: '##니다' in '것입니다.문의'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,862 >> Length not equal after stripping spaces: '입니다. 남편은크게바뀌지는않을것입니다.문의주신분의변화가필요합니다. 다른' vs '입니다.남편은크게바뀌지는않을것입니다.문의주신분의변화가필요합니다.다른'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,863 >> Unable to find text: '##니다 . 다른 곳에서 상담을 받아 보는 것도 도움이 될 수 있습니다' in '합니다. 다른 곳에서 상담을 받아 보는 것도 도움이 될 수 있습니다.문의에'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,863 >> Length not equal after stripping spaces: '입니다. 남편은크게바뀌지는않을것입니다.문의' vs '입니다.남편은크게바뀌지는않을것입니다.문의'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,863 >> Unable to find text: '##니다' in '가까워 보입니다. '
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,863 >> Unable to find text: '##니다' in '있습니다.문의에'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,863 >> Length not equal after stripping spaces: '근본적인원인이해결이안되었기때문일것입니다. ' vs '근본적인원인이해결이안되었기때문일것입니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,863 >> Length not equal after stripping spaces: '주신분의변화가필요합니다. 다른' vs '주신분의변화가필요합니다.다른'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,863 >> Unable to find text: '##니다 . 다른 곳에서 상담을 받아 보는 것도 도움이 될 수 있습니다 .' in '합니다. 다른 곳에서 상담을 받아 보는 것도 도움이 될 수 있습니다.문의에'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,864 >> Unable to find text: '##니다 .' in '있습니다.문의에'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,866 >> Unable to find text: '##니다' in '보입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,869 >> Unable to find text: '[UNK]' in '됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,869 >> Unable to find text: '모두가 원인이 되며 생활 습관 개선 음식조절 전정기관의 재활을 통해 대부분 회복이 [UNK]' in '모두가 원인이 되며 생활 습관 개선 음식조절 전정기관의 재활을 통해 대부분 회복이 됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,869 >> Unable to find text: '[UNK]' in '됩니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,869 >> Unable to find text: '[UNK] .' in '됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,869 >> Unable to find text: '##니다 .' in '보입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,870 >> Unable to find text: '[UNK] .' in '됩니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,870 >> Unable to find text: '[UNK] . 감사합니다' in '됩니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,873 >> Unable to find text: '[UNK] . 감사합니다 .' in '됩니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,875 >> Unable to find text: '##니다' in '싶습니다'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,875 >> Unable to find text: '##니다' in '듯합니다'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,876 >> Unable to find text: '##니다 해당' in '듯합니다 해당'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,876 >> Unable to find text: '##니다' in '고시환입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,877 >> Unable to find text: '##니다 해당 내' in '듯합니다 해당 내용은'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,877 >> Unable to find text: '##니다 .' in '고시환입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,889 >> Unable to find text: '적절한 관리를 통해 증상의 쾌유를 빌겠습니다 . 도움이 되었길 바랍니다 . 쾌유를 [UNK]' in '적절한 관리를 통해 증상의 쾌유를 빌겠습니다. 도움이 되었길 바랍니다. 쾌유를 빕니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,891 >> Unable to find text: 'MRI 촬영도 좋겠지만 현재로서는 수면 자체의 이상에 대한 검사가 필요할 것으로 [UNK] .' in 'MRI 촬영도 좋겠지만 현재로서는 수면 자체의 이상에 대한 검사가 필요할 것으로 생각됩니다.신경과'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,891 >> Unable to find text: '##니다' in '가능합니다.정확한'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,892 >> Unable to find text: 'MRI 촬영도 좋겠지만 현재로서는 수면 자체의 이상에 대한 검사가 필요할 것으로 [UNK]' in 'MRI 촬영도 좋겠지만 현재로서는 수면 자체의 이상에 대한 검사가 필요할 것으로 생각됩니다.신경과'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,892 >> Unable to find text: 'MRI 촬영도 좋겠지만 현재로서는 수면 자체의 이상에 대한 검사가 필요할 것으로 [UNK] . 신' in 'MRI 촬영도 좋겠지만 현재로서는 수면 자체의 이상에 대한 검사가 필요할 것으로 생각됩니다.신경과'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,892 >> Unable to find text: '##니다' in '같습니다.MRI검사는'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,893 >> Unable to find text: '##니다 . MRI검사는 필요시 뇌의 이상여부를 감별해야 할 필요가 있다면 검사할 수도 있습니다' in '같습니다.MRI검사는 필요시 뇌의 이상여부를 감별해야 할 필요가 있다면 검사할 수도 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,893 >> Unable to find text: '현재로서는 수면 자체의 이상에 대한 검사가 필요할 것으로 [UNK] .' in '현재로서는 수면 자체의 이상에 대한 검사가 필요할 것으로 생각됩니다.신경과'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,893 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,893 >> Unable to find text: '##니다 .' in '같습니다.MRI검사는'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,893 >> Unable to find text: '##니다 .' in '가능합니다.정확한'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,893 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,893 >> Unable to find text: '촬영도 좋겠지만 현재로서는 수면 자체의 이상에 대한 검사가 필요할 것으로 [UNK] .' in '촬영도 좋겠지만 현재로서는 수면 자체의 이상에 대한 검사가 필요할 것으로 생각됩니다.신경과'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,894 >> Unable to find text: '[UNK] .' in '생각됩니다.신경과'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,894 >> Unable to find text: '. MRI 촬영도 좋겠지만 현재로서는 수면 자체의 이상에 대한 검사가 필요할 것으로 [UNK] .' in '입니다. MRI 촬영도 좋겠지만 현재로서는 수면 자체의 이상에 대한 검사가 필요할 것으로 생각됩니다.신경과'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,895 >> Unable to find text: '##I 촬영도 좋겠지만 현재로서는 수면 자체의 이상에 대한 검사가 필요할 것으로 [UNK] .' in 'MRI 촬영도 좋겠지만 현재로서는 수면 자체의 이상에 대한 검사가 필요할 것으로 생각됩니다.신경과'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,895 >> Unable to find text: '수면 자체의 이상에 대한 검사가 필요할 것으로 [UNK] .' in '수면 자체의 이상에 대한 검사가 필요할 것으로 생각됩니다.신경과'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,896 >> Unable to find text: '##니다 .' in '필요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,897 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,897 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,898 >> Unable to find text: '##니다' in '필요합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,900 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,900 >> Unable to find text: '##니다 . 2' in '있습니다. 2.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,901 >> Unable to find text: '##니다 . 1' in '배성범입니다.1.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,903 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,903 >> Unable to find text: '##니다 . 2' in '있습니다. 2.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,906 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,906 >> Unable to find text: '##니다 . 2' in '있습니다. 2.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,916 >> Unable to find text: '만약 그 기계가 [UNK] 효과를 입증 받으면 식약청에서 의료기기로 허가가 될 것입니다' in '같습니다.만약 그 기계가 객좐적인 효과를 입증 받으면 식약청에서 의료기기로 허가가 될 것입니다.좀'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,916 >> Unable to find text: '만약 그 기계가 [UNK] 효과를 입증 받으면 식약청에서 의료기기로 허가가 될 것입니다 .' in '같습니다.만약 그 기계가 객좐적인 효과를 입증 받으면 식약청에서 의료기기로 허가가 될 것입니다.좀'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,916 >> Unable to find text: '##니다' in '가능합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,916 >> Unable to find text: '알파스팀 ( 인테넷에 [UNK] 알파스팀 [UNK] 이라고 입력하면 자세한 설명이 나옴 ) 2' in '알파스팀(인테넷에 `알파스팀`이라고 입력하면 자세한 설명이 나옴)2.기'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,919 >> Unable to find text: '##요' in '받아보세요.증상은'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,920 >> Unable to find text: '##요 . 증상은 달라도 같은 질환일 수 있습니다' in '받아보세요.증상은 달라도 같은 질환일 수 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,920 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,920 >> Unable to find text: '##요 .' in '받아보세요.증상은'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,921 >> Unable to find text: '##요 . 증상은 달라도 같은 질환일 수 있습니다 .' in '받아보세요.증상은 달라도 같은 질환일 수 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,921 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,921 >> Unable to find text: '##니다 .' in '않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,925 >> Unable to find text: '너무 걱정안하셔도 [UNK] .' in '너무 걱정안하셔도 됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,926 >> Unable to find text: '[UNK] . 건강에 대한 걱정이나 불안이 있으신가요 ?' in '동반됩니다. 건강에 대한 걱정이나 불안이 있으신가요?'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,926 >> Unable to find text: '[UNK] .' in '동반됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,926 >> Unable to find text: '너무 걱정안하셔도 [UNK]' in '너무 걱정안하셔도 됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,926 >> Unable to find text: '[UNK] . 건강에 대한 걱정이나 불안이 있으신가요' in '동반됩니다. 건강에 대한 걱정이나 불안이 있으신가요?'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,926 >> Unable to find text: '##요 ?' in '있으신가요?'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,927 >> Unable to find text: '. 너무 걱정안하셔도 [UNK] .' in '홍인표입니다. 너무 걱정안하셔도 됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,927 >> Unable to find text: '##요' in '있으신가요?'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,927 >> Unable to find text: '##니다 . 너무 걱정안하셔도 [UNK] .' in '홍인표입니다. 너무 걱정안하셔도 됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,927 >> Unable to find text: '[UNK]' in '동반됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,927 >> Unable to find text: '[UNK] .' in '됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,927 >> Unable to find text: '##입니다 . 너무 걱정안하셔도 [UNK] .' in '홍인표입니다. 너무 걱정안하셔도 됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,928 >> Unable to find text: '. 너무 걱정안하셔도 [UNK]' in '홍인표입니다. 너무 걱정안하셔도 됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,928 >> Unable to find text: '##니다 . 너' in '홍인표입니다. 너무'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,928 >> Unable to find text: '##니다' in '홍인표입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,929 >> Unable to find text: '심장에 이상은 없는지 검사를 받아보시는 것이 좋을 것으로 [UNK] .' in '심장에 이상은 없는지 검사를 받아보시는 것이 좋을 것으로 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,929 >> Unable to find text: '[UNK] .' in '생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,930 >> Unable to find text: '전에도 이런 증상이 있었나요 ? 심장에 이상은 없는지 검사를 받아보시는 것이 좋을 것으로 [UNK] .' in '전에도 이런 증상이 있었나요? 심장에 이상은 없는지 검사를 받아보시는 것이 좋을 것으로 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,930 >> Unable to find text: '? 심장에 이상은 없는지 검사를 받아보시는 것이 좋을 것으로 [UNK] .' in '있었나요? 심장에 이상은 없는지 검사를 받아보시는 것이 좋을 것으로 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,930 >> Unable to find text: '검사를 받아보시는 것이 좋을 것으로 [UNK] .' in '검사를 받아보시는 것이 좋을 것으로 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,933 >> Unable to find text: '이상은 없는지 검사를 받아보시는 것이 좋을 것으로 [UNK] .' in '이상은 없는지 검사를 받아보시는 것이 좋을 것으로 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,933 >> Unable to find text: '심장에 이상은 없는지 검사를 받아보시는 것이 좋을 것으로 [UNK]' in '심장에 이상은 없는지 검사를 받아보시는 것이 좋을 것으로 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,933 >> Unable to find text: '[UNK]' in '생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,934 >> Unable to find text: '전에도 이런 증상이 있었나요 ? 심장에 이상은 없는지 검사를 받아보시는 것이 좋을 것으로 [UNK]' in '전에도 이런 증상이 있었나요? 심장에 이상은 없는지 검사를 받아보시는 것이 좋을 것으로 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,934 >> Unable to find text: '##니다 . 많이 놀라셨죠 ? 전에도 이런 증상이 있었나요 ?' in '홍인표입니다.많이 놀라셨죠? 전에도 이런 증상이 있었나요?'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,934 >> Unable to find text: '? 심장에 이상은 없는지 검사를 받아보시는 것이 좋을 것으로 [UNK]' in '있었나요? 심장에 이상은 없는지 검사를 받아보시는 것이 좋을 것으로 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,935 >> Unable to find text: '##입니다 . 많이 놀라셨죠 ? 전에도 이런 증상이 있었나요 ?' in '홍인표입니다.많이 놀라셨죠? 전에도 이런 증상이 있었나요?'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,935 >> Unable to find text: '검사를 받아보시는 것이 좋을 것으로 [UNK]' in '검사를 받아보시는 것이 좋을 것으로 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,935 >> Unable to find text: '이상은 없는지 검사를 받아보시는 것이 좋을 것으로 [UNK]' in '이상은 없는지 검사를 받아보시는 것이 좋을 것으로 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,935 >> Unable to find text: '##니다' in '홍인표입니다.많이'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,935 >> Unable to find text: '##닥 가정의학과 상담의 홍인표입니다 . 많이 놀라셨죠 ? 전에도 이런 증상이 있었나요 ?' in '하이닥 가정의학과 상담의 홍인표입니다.많이 놀라셨죠? 전에도 이런 증상이 있었나요?'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,962 >> Unable to find text: '##입니다' in '홍인표입니다.많이'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,969 >> Unable to find text: '주어진 내용에서 최근 상태의 확인이 어렵고 우선순위의 문제는 아닐 것으로 [UNK]' in '주어진 내용에서 최근 상태의 확인이 어렵고 우선순위의 문제는 아닐 것으로 사료됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,970 >> Unable to find text: '주어진 내용에서 최근 상태의 확인이 어렵고 우선순위의 문제는 아닐 것으로 [UNK] .' in '주어진 내용에서 최근 상태의 확인이 어렵고 우선순위의 문제는 아닐 것으로 사료됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,970 >> Unable to find text: '내용에서 최근 상태의 확인이 어렵고 우선순위의 문제는 아닐 것으로 [UNK]' in '내용에서 최근 상태의 확인이 어렵고 우선순위의 문제는 아닐 것으로 사료됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,970 >> Unable to find text: '##니다 . 주어진 내용에서 최근 상태의 확인이 어렵고 우선순위의 문제는 아닐 것으로 [UNK]' in '합니다. 주어진 내용에서 최근 상태의 확인이 어렵고 우선순위의 문제는 아닐 것으로 사료됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,970 >> Unable to find text: '[UNK]' in '사료됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,971 >> Unable to find text: '내용에서 최근 상태의 확인이 어렵고 우선순위의 문제는 아닐 것으로 [UNK] .' in '내용에서 최근 상태의 확인이 어렵고 우선순위의 문제는 아닐 것으로 사료됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,971 >> Unable to find text: '##니다 .' in '합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,971 >> Unable to find text: '##니다 . 주어진 내용에서 최근 상태의 확인이 어렵고 우선순위의 문제는 아닐 것으로 [UNK] .' in '합니다. 주어진 내용에서 최근 상태의 확인이 어렵고 우선순위의 문제는 아닐 것으로 사료됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,971 >> Unable to find text: '[UNK] .' in '사료됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,972 >> Unable to find text: '주어진 내용에서 최근 상태의 확인이 어렵고 우선순위의 문제는 아닐 것으로 [UNK] . AD' in '주어진 내용에서 최근 상태의 확인이 어렵고 우선순위의 문제는 아닐 것으로 사료됩니다. ADHD'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,972 >> Unable to find text: '##니다' in '합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,974 >> Length not equal after stripping spaces: '특징입니다. 하지불안증후군의주요증상 1.' vs '특징입니다.하지불안증후군의주요증상1.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,974 >> Length not equal after stripping spaces: '주요증상 1.' vs '주요증상1.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,975 >> Length not equal after stripping spaces: '특징입니다. 하지불안증후군의주요증상 1.' vs '특징입니다.하지불안증후군의주요증상1.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,975 >> Length not equal after stripping spaces: '않으나1. 뇌의도파민시스템의불균형이관련된것으로추측2.' vs '않으나1.뇌의도파민시스템의불균형이관련된것으로추측2.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,976 >> Length not equal after stripping spaces: '특징입니다. 하지불안증후군의주요증상 1.별다른이상없이다리에불쾌감이나타난다.2.' vs '특징입니다.하지불안증후군의주요증상1.별다른이상없이다리에불쾌감이나타난다.2.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,976 >> Length not equal after stripping spaces: '임신및호르몬변화 등이유발에기인하고있는것으로추정되고있습니다.하지불안' vs '임신및호르몬변화등이유발에기인하고있는것으로추정되고있습니다.하지불안'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,976 >> Length not equal after stripping spaces: '특징입니다. 하지불안증후군의주요증상 1.별다른이상없이다리에불쾌감이나타난다.2.' vs '특징입니다.하지불안증후군의주요증상1.별다른이상없이다리에불쾌감이나타난다.2.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,976 >> Length not equal after stripping spaces: '않으나1. 뇌의도파민시스템의불균형이관련된것으로추측2.유전3.스트레스4.' vs '않으나1.뇌의도파민시스템의불균형이관련된것으로추측2.유전3.스트레스4.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,977 >> Unable to find text: '##4' in '스트레스4.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,977 >> Length not equal after stripping spaces: '않으나1. 뇌의도파민시스템의불균형이관련된것으로추측2.유전3.' vs '않으나1.뇌의도파민시스템의불균형이관련된것으로추측2.유전3.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,977 >> Length not equal after stripping spaces: '특징입니다. 하지불안증후군의주요증상 1.별다른이상없이다리에불쾌감이나타난다.2.' vs '특징입니다.하지불안증후군의주요증상1.별다른이상없이다리에불쾌감이나타난다.2.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,978 >> Unable to find text: '##니다 . 하지불안증후군 의 주요증상 1' in '특징입니다. 하지불안증후군 의 주요증상 1.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,979 >> Length not equal after stripping spaces: '주요증상 1.별다른이상없이다리에불쾌감이나타난다.2.' vs '주요증상1.별다른이상없이다리에불쾌감이나타난다.2.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,984 >> Length not equal after stripping spaces: '있습니다. 진단이내려지고그에따른치료를받으시면회복이되실것입니다.우울증은' vs '있습니다.진단이내려지고그에따른치료를받으시면회복이되실것입니다.우울증은'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,984 >> Length not equal after stripping spaces: '있습니다. 진단이내려지고그에따른치료를받으시면회복이되실것입니다.우울증은' vs '있습니다.진단이내려지고그에따른치료를받으시면회복이되실것입니다.우울증은'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,985 >> Length not equal after stripping spaces: '감기가폐렴으로진행되면치료가더어렵고오래걸립니다.님께서 인터넷' vs '감기가폐렴으로진행되면치료가더어렵고오래걸립니다.님께서인터넷'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:25,986 >> Length not equal after stripping spaces: '님께서 인터넷' vs '님께서인터넷'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,988 >> Unable to find text: '[UNK]' in '홍인표입니다.쿵하는'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,989 >> Unable to find text: '##니다 .' in '좋겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,989 >> Unable to find text: '##니다' in '좋겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,989 >> Unable to find text: '[UNK] .' in '판단됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,989 >> Unable to find text: '[UNK] . 심하면 약을 좀 드시거나 검사를 다시 받아보시는 것이 좋겠습니다 .' in '판단됩니다. 심하면 약을 좀 드시거나 검사를 다시 받아보시는 것이 좋겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,989 >> Unable to find text: '[UNK] . 심하면 약을 좀 드시거나 검사를 다시 받아보시는 것이 좋겠습니다' in '판단됩니다. 심하면 약을 좀 드시거나 검사를 다시 받아보시는 것이 좋겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,990 >> Unable to find text: '[UNK] 느' in '홍인표입니다.쿵하는 느낌이'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,990 >> Unable to find text: '[UNK] 느낌이 있으시면 부정맥이 있을 가능성이 높은데' in '홍인표입니다.쿵하는 느낌이 있으시면 부정맥이 있을 가능성이 높은데'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,990 >> Unable to find text: '홀터검사 시에 [UNK] 느낌이 없다면 검사 중에는 부정맥이 나타나지않은 것으로 [UNK] .' in '홀터검사 시에 쿵하는 느낌이 없다면 검사 중에는 부정맥이 나타나지않은 것으로 판단됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,990 >> Unable to find text: '. [UNK]' in '홍인표입니다.쿵하는'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,991 >> Unable to find text: '##니다 . [UNK]' in '홍인표입니다.쿵하는'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,991 >> Unable to find text: '[UNK]' in '판단됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,991 >> Unable to find text: '##입니다 . [UNK]' in '홍인표입니다.쿵하는'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,991 >> Unable to find text: '홀터검사 시에 [UNK] 느낌이 없다면 검사 중에는 부정맥이 나타나지않은 것으로 [UNK]' in '홀터검사 시에 쿵하는 느낌이 없다면 검사 중에는 부정맥이 나타나지않은 것으로 판단됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,992 >> Unable to find text: '[UNK] . 심하면 약을 좀 드시거나 검사를 다시 받아보시는 것이 좋겠습' in '판단됩니다. 심하면 약을 좀 드시거나 검사를 다시 받아보시는 것이 좋겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,992 >> Unable to find text: '##니다' in '홍인표입니다.쿵하는'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,992 >> Unable to find text: '. [UNK] 느' in '홍인표입니다.쿵하는 느낌이'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,995 >> Unable to find text: '##니다 .' in '않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,996 >> Unable to find text: '##니다 .' in '않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,996 >> Unable to find text: '##반적인 녹내장은 단기간 무슨 이벤트로 갑자기 생기거나 하지는 않습니다 .' in '일반적인 녹내장은 단기간 무슨 이벤트로 갑자기 생기거나 하지는 않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,996 >> Unable to find text: '##적인 녹내장은 단기간 무슨 이벤트로 갑자기 생기거나 하지는 않습니다 .' in '일반적인 녹내장은 단기간 무슨 이벤트로 갑자기 생기거나 하지는 않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,997 >> Unable to find text: '##니다' in '않습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:25,999 >> Unable to find text: '[UNK] 예전 학교 다닐 때 제 모습을 보는 것 같습니다 .' in '힘드시겠네요...ㅠ 예전 학교 다닐 때 제 모습을 보는 것 같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,000 >> Unable to find text: '너무 힘드시겠네요 . . . [UNK] 예전 학교 다닐 때 제 모습을 보는 것 같습니다 .' in '홍인표입니다.너무 힘드시겠네요...ㅠ 예전 학교 다닐 때 제 모습을 보는 것 같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,000 >> Unable to find text: '[UNK] 예전 학교 다닐 때 제 모습을 보는 것 같습니다' in '힘드시겠네요...ㅠ 예전 학교 다닐 때 제 모습을 보는 것 같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,000 >> Unable to find text: '너무 힘드시겠네요 . . . [UNK] 예전 학교 다닐 때 제 모습을 보는 것 같습니다' in '홍인표입니다.너무 힘드시겠네요...ㅠ 예전 학교 다닐 때 제 모습을 보는 것 같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,001 >> Unable to find text: '[UNK]' in '힘드시겠네요...ㅠ'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,001 >> Unable to find text: '너무 힘드시겠네요 . . . [UNK]' in '홍인표입니다.너무 힘드시겠네요...ㅠ'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,001 >> Unable to find text: '##니다 . 너무 힘드시겠네요 . .' in '홍인표입니다.너무 힘드시겠네요...ㅠ'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,001 >> Unable to find text: '. . [UNK] 예전 학교 다닐 때 제 모습을 보는 것 같습니다 .' in '힘드시겠네요...ㅠ 예전 학교 다닐 때 제 모습을 보는 것 같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,002 >> Unable to find text: '##요 . .' in '힘드시겠네요...ㅠ'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,002 >> Unable to find text: '. . . [UNK] 예전 학교 다닐 때 제 모습을 보는 것 같습니다 .' in '힘드시겠네요...ㅠ 예전 학교 다닐 때 제 모습을 보는 것 같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,002 >> Unable to find text: '##니다 .' in '권합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,002 >> Unable to find text: '. . [UNK] 예전 학교 다닐 때 제 모습을 보는 것 같습니다' in '힘드시겠네요...ㅠ 예전 학교 다닐 때 제 모습을 보는 것 같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,017 >> Unable to find text: '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고 , 의견이 같을 경우 입원이 [UNK]' in '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고, 의견이 같을 경우 입원이 유지됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,020 >> Unable to find text: '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고 , 의견이 같을 경우 입원이 [UNK] .' in '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고, 의견이 같을 경우 입원이 유지됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,036 >> Unable to find text: '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고 , 의견이 같을 경우 입원이 [UNK]' in '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고, 의견이 같을 경우 입원이 유지됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,041 >> Unable to find text: '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고 , 의견이 같을 경우 입원이 [UNK] .' in '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고, 의견이 같을 경우 입원이 유지됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,056 >> Unable to find text: '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고 , 의견이 같을 경우 입원이 [UNK]' in '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고, 의견이 같을 경우 입원이 유지됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,057 >> Unable to find text: '다른 정신과 전문의의 의견을 확인하여 의견이 일치해야 입원이 [UNK] .' in '다른 정신과 전문의의 의견을 확인하여 의견이 일치해야 입원이 유지됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,076 >> Unable to find text: '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고 , 의견이 같을 경우 입원이 [UNK]' in '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고, 의견이 같을 경우 입원이 유지됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,080 >> Unable to find text: '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고 , 의견이 같을 경우 입원이 [UNK] .' in '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고, 의견이 같을 경우 입원이 유지됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,094 >> Unable to find text: '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고 , 의견이 같을 경우 입원이 [UNK]' in '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고, 의견이 같을 경우 입원이 유지됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,096 >> Unable to find text: '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고 , 의견이 같을 경우 입원이 [UNK] .' in '두 번째 전문의 의견이 담당 의사와 다를 경우 퇴원하게 되고, 의견이 같을 경우 입원이 유지됩니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,100 >> Length not equal after stripping spaces: '질문자님을불편하게하는행동을멈출수있는마음이어떤마음인지를알수있을겁니다. ' vs '질문자님을불편하게하는행동을멈출수있는마음이어떤마음인지를알수있을겁니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,100 >> Length not equal after stripping spaces: '없지요. 님의경우도마찬가지라고생각합니다. 지금' vs '없지요.님의경우도마찬가지라고생각합니다.지금'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,100 >> Length not equal after stripping spaces: '저는상담을권합니다. 일반적으로' vs '저는상담을권합니다.일반적으로'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,101 >> Length not equal after stripping spaces: '질문자님을불편하게하는행동을멈출수있는마음이어떤마음인지를알수있을겁니다. ' vs '질문자님을불편하게하는행동을멈출수있는마음이어떤마음인지를알수있을겁니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,101 >> Length not equal after stripping spaces: '김진입니다.올려주신글잘보았습니다. 제가' vs '김진입니다.올려주신글잘보았습니다.제가'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,101 >> Length not equal after stripping spaces: '보았습니다. 제가' vs '보았습니다.제가'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,101 >> Length not equal after stripping spaces: '저는상담을권합니다. 일반적으로' vs '저는상담을권합니다.일반적으로'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,102 >> Length not equal after stripping spaces: '김진입니다.올려주신글잘보았습니다. 제가' vs '김진입니다.올려주신글잘보았습니다.제가'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,102 >> Length not equal after stripping spaces: '보았습니다. 제가별로좋아하지않는말중에[마음편히먹으라]는말이있습니다. 마음을' vs '보았습니다.제가별로좋아하지않는말중에[마음편히먹으라]는말이있습니다.마음을'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,103 >> Length not equal after stripping spaces: '신..이지요. 그리고정말그렇게할수있다면치료를받거나상담을할이유도없지요. 님의' vs '신..이지요.그리고정말그렇게할수있다면치료를받거나상담을할이유도없지요.님의'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,103 >> Length not equal after stripping spaces: '보았습니다. 제가별로좋아하지않는말중에[마음편히먹으라]는말이있습니다. 마음을' vs '보았습니다.제가별로좋아하지않는말중에[마음편히먹으라]는말이있습니다.마음을'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,103 >> Length not equal after stripping spaces: '김진입니다.올려주신글잘보았습니다. 제가' vs '김진입니다.올려주신글잘보았습니다.제가'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,103 >> Length not equal after stripping spaces: '없지요. 님의경우도마찬가지라고생각합니다. 지금' vs '없지요.님의경우도마찬가지라고생각합니다.지금'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,104 >> Length not equal after stripping spaces: '어떤마음이길래그런행동이반복되는지를알아야할때인것같습니다. 그래야' vs '어떤마음이길래그런행동이반복되는지를알아야할때인것같습니다.그래야'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,104 >> Length not equal after stripping spaces: '어떤마음이길래그런행동이반복되는지를알아야할때인것같습니다. 그래야' vs '어떤마음이길래그런행동이반복되는지를알아야할때인것같습니다.그래야'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,105 >> Length not equal after stripping spaces: '신..이지요. 그리고정말그렇게할수있다면치료를받거나상담을할이유도없지요. 님의' vs '신..이지요.그리고정말그렇게할수있다면치료를받거나상담을할이유도없지요.님의'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,105 >> Unable to find text: '##니다' in '생각합니다. 지금'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,105 >> Length not equal after stripping spaces: '가장마음에맞는곳을선택하셔서방문해보시길권합니다. 감사합니다.' vs '가장마음에맞는곳을선택하셔서방문해보시길권합니다.감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,106 >> Length not equal after stripping spaces: '가장마음에맞는곳을선택하셔서방문해보시길권합니다. 감사합니다.' vs '가장마음에맞는곳을선택하셔서방문해보시길권합니다.감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,106 >> Length not equal after stripping spaces: '권합니다. 감사합니다.' vs '권합니다.감사합니다.'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,106 >> Length not equal after stripping spaces: '없지요. 님의경우도마찬가지라고생각합니다. 지금' vs '없지요.님의경우도마찬가지라고생각합니다.지금'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,106 >> Unable to find text: '##니다 .' in '생각합니다. 지금'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,107 >> Length not equal after stripping spaces: '먹어지나요? 자신이원하는대로마음을먹을수있다면그건사람이아니라신..이지요. 그리고' vs '먹어지나요?자신이원하는대로마음을먹을수있다면그건사람이아니라신..이지요.그리고'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,107 >> Length not equal after stripping spaces: '별로좋아하지않는말중에[마음편히먹으라]는말이있습니다. 마음을' vs '별로좋아하지않는말중에[마음편히먹으라]는말이있습니다.마음을'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,107 >> Length not equal after stripping spaces: '별로좋아하지않는말중에[마음편히먹으라]는말이있습니다. 마음을' vs '별로좋아하지않는말중에[마음편히먹으라]는말이있습니다.마음을'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,108 >> Length not equal after stripping spaces: '먹어지나요? 자신이원하는대로마음을먹을수있다면그건사람이아니라신..이지요. 그리고' vs '먹어지나요?자신이원하는대로마음을먹을수있다면그건사람이아니라신..이지요.그리고'
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:26,108 >> Length not equal after stripping spaces: '김진입니다.올려주신글잘보았습니다. 제가' vs '김진입니다.올려주신글잘보았습니다.제가'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,108 >> Unable to find text: '##니다 . 올려주신 글 잘 보았습니다 . 제' in '김진입니다.올려주신 글 잘 보았습니다. 제가'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,108 >> Unable to find text: '##니다 . 지' in '생각합니다. 지금'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,108 >> Unable to find text: '##니다 . 올' in '김진입니다.올려주신'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:26,109 >> Unable to find text: '##입니다 . 올려주신 글 잘 보았습니다 . 제' in '김진입니다.올려주신 글 잘 보았습니다. 제가'
# ...
# [INFO|squad_metrics.py:314] 2023-06-05 04:49:31,529 >> Length not equal after stripping spaces: '기원해드립니다. 감사합니다.' vs '기원해드립니다.감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,530 >> Unable to find text: '##니다 .' in '권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,530 >> Unable to find text: '##대로 된 수면이 힘든것으로 보아 우선 수면검사를 받아보시기를 권유합니다 .' in '제대로 된 수면이 힘든것으로 보아 우선 수면검사를 받아보시기를 권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,531 >> Unable to find text: '##니다 . 현재' in '한재병입니다. 현재'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,533 >> Unable to find text: '불안한 중상이 심해지고 신체적인 현상을 경험하는 상태라고 [UNK] .' in '불안한 중상이 심해지고 신체적인 현상을 경험하는 상태라고 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,533 >> Unable to find text: '오랫동안 참기보다는 적절한 급성기 치료를 받으시는 것이 좋지 않을까 [UNK]' in '오랫동안 참기보다는 적절한 급성기 치료를 받으시는 것이 좋지 않을까 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,534 >> Unable to find text: '이런 상태로 오랫동안 참기보다는 적절한 급성기 치료를 받으시는 것이 좋지 않을까 [UNK]' in '이런 상태로 오랫동안 참기보다는 적절한 급성기 치료를 받으시는 것이 좋지 않을까 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,534 >> Unable to find text: '불안한 중상이 심해지고 신체적인 현상을 경험하는 상태라고 [UNK]' in '불안한 중상이 심해지고 신체적인 현상을 경험하는 상태라고 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,534 >> Unable to find text: '[UNK]' in '생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,534 >> Unable to find text: '오랫동안 참기보다는 적절한 급성기 치료를 받으시는 것이 좋지 않을까 [UNK] .' in '오랫동안 참기보다는 적절한 급성기 치료를 받으시는 것이 좋지 않을까 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,535 >> Unable to find text: '##니다' in '것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,537 >> Unable to find text: '##니다' in '것입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,538 >> Unable to find text: '##니다 . 인지행동치료는 스스로가 치료자가 되는 방법인데요' in '끊어갑니다. 인지행동치료는 스스로가 치료자가 되는 방법인데요'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,539 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,539 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,539 >> Unable to find text: '##니다 .' in '김정호입니다.이비인후과에서'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,539 >> Unable to find text: '##니다' in '김정호입니다.이비인후과에서'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,540 >> Unable to find text: '##니다 . 이' in '김정호입니다.이비인후과에서'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,540 >> Unable to find text: '##비인후과에서 받으셨던 약이 무엇인지 알고 싶습니다가래약이라 하셨는데 ,' in '김정호입니다.이비인후과에서 받으셨던 약이 무엇인지 알고 싶습니다가래약이라 하셨는데,'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,540 >> Unable to find text: '##입니다 .' in '김정호입니다.이비인후과에서'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,540 >> Unable to find text: '##입니다' in '김정호입니다.이비인후과에서'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,543 >> Unable to find text: '##니다 .' in '합니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,543 >> Unable to find text: '##니다 .' in '발생합니다.구체적으로'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,544 >> Unable to find text: '##니다 .' in '편입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,544 >> Unable to find text: '##니다 .' in '없었습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,544 >> Unable to find text: '##니다 . 제' in '편입니다. 제'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,544 >> Unable to find text: '##니다' in '없었습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,544 >> Unable to find text: '##니다' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,545 >> Unable to find text: '##니다 .' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,545 >> Unable to find text: '##니다' in '편입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,545 >> Unable to find text: '##니다 . 감사합니다' in '없었습니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,545 >> Unable to find text: '##니다 . 감사합니다 .' in '없었습니다. 감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,546 >> Unable to find text: '##니다' in '있습니다'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,546 >> Unable to find text: '##니다 . 함께' in '홍인표입니다. 함께'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,546 >> Unable to find text: '##입니다 . 함께' in '홍인표입니다. 함께'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,546 >> Unable to find text: '##표입니다 . 함께' in '홍인표입니다. 함께'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,546 >> Unable to find text: '##인표입니다 . 함께' in '홍인표입니다. 함께'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,547 >> Unable to find text: '##니다' in '홍인표입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,547 >> Unable to find text: '##니다 .' in '홍인표입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,547 >> Unable to find text: '##입니다' in '홍인표입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,547 >> Unable to find text: '##표입니다' in '홍인표입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,547 >> Unable to find text: '##인표입니다' in '홍인표입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,547 >> Unable to find text: '##입니다 .' in '홍인표입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,547 >> Unable to find text: '##표입니다 .' in '홍인표입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,547 >> Unable to find text: '##인표입니다 .' in '홍인표입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,548 >> Unable to find text: '##폰정 ( 10 ~ 15mg ) 과 수면유도제 (' in '에나폰정 (10~15mg)과 수면유도제 (쿨드림-디펜히드라민염산염'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,551 >> Unable to find text: '위험한 것은 , 주로 환청에 반응해서 하는 [UNK] . 환청은 , 아닌 듯 한데요' in '^^위험한 것은, 주로 환청에 반응해서 하는 혼잣말입니다.환청은, 아닌 듯 한데요.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,552 >> Unable to find text: '이런 환청에 대해 대답하는 [UNK] 병적인 [UNK]' in '이런 환청에 대해 대답하는 혼잣말이 병적인 혼잣말입니다.혼자하는'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,552 >> Unable to find text: '위험한 것은 , 주로 환청에 반응해서 하는 [UNK]' in '^^위험한 것은, 주로 환청에 반응해서 하는 혼잣말입니다.환청은,'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,552 >> Unable to find text: '위험한 것은 , 주로 환청에 반응해서 하는 [UNK] .' in '^^위험한 것은, 주로 환청에 반응해서 하는 혼잣말입니다.환청은,'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,553 >> Unable to find text: '이런 환청에 대해 대답하는 [UNK] 병적인 [UNK] . 혼자하는 말이 [UNK] 다 병이 아니라는 뜻입니다' in '이런 환청에 대해 대답하는 혼잣말이 병적인 혼잣말입니다.혼자하는 말이 혼잣말이 다 병이 아니라는 뜻입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,553 >> Unable to find text: '혼자하는 말이 [UNK] 다 병이 아니라는 뜻입니다' in '혼잣말입니다.혼자하는 말이 혼잣말이 다 병이 아니라는 뜻입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,553 >> Unable to find text: '정상적으로도 화장실에 오래 앉아 있을 때에 [UNK] 많이 하게 된다고 하더군요' in '정상적으로도 화장실에 오래 앉아 있을 때에 혼잣말을 많이 하게 된다고 하더군요.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,557 >> Unable to find text: '##니다' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,557 >> Unable to find text: '##니다 . 무조건 부모님의 동의를 구해서 꼭 정신과 전문의를 만나보시기 바랍니다' in '보입니다. 무조건 부모님의 동의를 구해서 꼭 정신과 전문의를 만나보시기 바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,557 >> Unable to find text: '##니다' in '바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,626 >> Unable to find text: '##니다 .' in '같습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,629 >> Unable to find text: '##니다' in '정확합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,630 >> Unable to find text: '##니다 . 정확한 것은 MRI , CT 등의 검사를 하는 것이 정확합니다' in '어렵습니다. 정확한 것은 MRI, CT 등의 검사를 하는 것이 정확합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,630 >> Unable to find text: '##니다 . 증상이 지속된다면 가까운 영상의학과나 병원에서 검사를 하는 것이 좋습니다' in '정확합니다. 증상이 지속된다면 가까운 영상의학과나 병원에서 검사를 하는 것이 좋습니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,631 >> Unable to find text: '##니다' in '좋습니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,631 >> Unable to find text: '##니다 .' in '정확합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,631 >> Unable to find text: '##니다 . 증상이 지속된다면 가까운 영상의학과나 병원에서 검사를 하는 것이 좋습니다 .' in '정확합니다. 증상이 지속된다면 가까운 영상의학과나 병원에서 검사를 하는 것이 좋습니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,632 >> Unable to find text: '##니다 . 정확한 것은 MRI , CT 등의 검사를 하는 것이 정확합니다 .' in '어렵습니다. 정확한 것은 MRI, CT 등의 검사를 하는 것이 정확합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,632 >> Unable to find text: '##니다 .' in '좋습니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,632 >> Unable to find text: '##니다' in '감사합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,632 >> Unable to find text: '##니다 . 왼쪽 다리에만 힘이 빠진다고 해서 모두 뇌졸중이라고 말하기는 어렵습니다 .' in '말합니다.왼쪽 다리에만 힘이 빠진다고 해서 모두 뇌졸중이라고 말하기는 어렵습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,634 >> Unable to find text: '전문적인 평가 등도 중요할 것으로 [UNK]' in '전문적인 평가 등도 중요할 것으로 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,634 >> Unable to find text: '전문적인 평가 등도 중요할 것으로 [UNK] .' in '전문적인 평가 등도 중요할 것으로 생각됩니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,639 >> Unable to find text: '##니다 .' in '바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,639 >> Unable to find text: '##니다 .' in '있습니다.증상'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,639 >> Unable to find text: '##니다 . 증상 지속시 신경과 외래에 방문하셔서 상담하시기 바랍니다 .' in '있습니다.증상 지속시 신경과 외래에 방문하셔서 상담하시기 바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,639 >> Unable to find text: '##니다' in '바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,640 >> Unable to find text: '##니다 . 증상 지속시 신경과 외래에 방문하셔서 상담하시기 바랍니다' in '있습니다.증상 지속시 신경과 외래에 방문하셔서 상담하시기 바랍니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,645 >> Unable to find text: '##니다 . 좋아졌다 나빠졌다 한다는 얘기는 기질적인 문제가 없다 .' in '않습니다.좋아졌다 나빠졌다 한다는 얘기는 기질적인 문제가 없다..즉'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,648 >> Unable to find text: '##니다' in '있겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,649 >> Unable to find text: '##니다 .' in '있겠습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,651 >> Unable to find text: '수면 중 구호흡이 입마름의 원인이 [UNK] .' in '정규화입니다.수면 중 구호흡이 입마름의 원인이 됩니다.위에'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,651 >> Unable to find text: '위에 언급하신 질환들도 수면장애의 원인이 [UNK] .' in '됩니다.위에 언급하신 질환들도 수면장애의 원인이 됩니다.구강'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,651 >> Unable to find text: '위에 언급하신 질환들도 수면장애의 원인이 [UNK]' in '됩니다.위에 언급하신 질환들도 수면장애의 원인이 됩니다.구강'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,651 >> Unable to find text: '수면 중 구호흡이 입마름의 원인이 [UNK]' in '정규화입니다.수면 중 구호흡이 입마름의 원인이 됩니다.위에'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,652 >> Unable to find text: '수면 중 구호흡이 입마름의 원인이 [UNK] . 위에' in '정규화입니다.수면 중 구호흡이 입마름의 원인이 됩니다.위에'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,652 >> Unable to find text: '##니다' in '있습니다.이러한'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,652 >> Unable to find text: '[UNK] .' in '됩니다.구강'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,652 >> Unable to find text: '[UNK]' in '됩니다.구강'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,652 >> Unable to find text: '[UNK] .' in '됩니다.위에'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,652 >> Unable to find text: '[UNK] . 위에 언급하신 질환들도 수면장애의 원인이 [UNK] .' in '됩니다.위에 언급하신 질환들도 수면장애의 원인이 됩니다.구강'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,652 >> Unable to find text: '[UNK] . 위에 언급하신 질환들도 수면장애의 원인이 [UNK]' in '됩니다.위에 언급하신 질환들도 수면장애의 원인이 됩니다.구강'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,652 >> Unable to find text: '구호흡이 입마름의 원인이 [UNK] .' in '구호흡이 입마름의 원인이 됩니다.위에'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,653 >> Unable to find text: '. 위에 언급하신 질환들도 수면장애의 원인이 [UNK] .' in '됩니다.위에 언급하신 질환들도 수면장애의 원인이 됩니다.구강'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,653 >> Unable to find text: '구호흡이 입마름의 원인이 [UNK] . 위에 언급하신 질환들도 수면장애의 원인이 [UNK] .' in '구호흡이 입마름의 원인이 됩니다.위에 언급하신 질환들도 수면장애의 원인이 됩니다.구강'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,653 >> Unable to find text: '언급하신 질환들도 수면장애의 원인이 [UNK] .' in '언급하신 질환들도 수면장애의 원인이 됩니다.구강'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,653 >> Unable to find text: '. 수면 중 구호흡이 입마름의 원인이 [UNK] .' in '정규화입니다.수면 중 구호흡이 입마름의 원인이 됩니다.위에'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,653 >> Unable to find text: '. 위에 언급하신 질환들도 수면장애의 원인이 [UNK]' in '됩니다.위에 언급하신 질환들도 수면장애의 원인이 됩니다.구강'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,654 >> Unable to find text: '구호흡이 입마름의 원인이 [UNK] . 위에 언급하신 질환들도 수면장애의 원인이 [UNK]' in '구호흡이 입마름의 원인이 됩니다.위에 언급하신 질환들도 수면장애의 원인이 됩니다.구강'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,654 >> Unable to find text: '언급하신 질환들도 수면장애의 원인이 [UNK]' in '언급하신 질환들도 수면장애의 원인이 됩니다.구강'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,654 >> Unable to find text: '##니다 .' in '있습니다.이러한'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,655 >> Unable to find text: '위에 언급하신 질환들도 수면장애의 원인이 [UNK] . 구' in '됩니다.위에 언급하신 질환들도 수면장애의 원인이 됩니다.구강'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,658 >> Unable to find text: '[UNK] 바로 잠이 든다면 아직은 큰 문제는 아닌 것으로 보입니다 .' in '입니다.깼다가 바로 잠이 든다면 아직은 큰 문제는 아닌 것으로 보입니다.다만'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,658 >> Unable to find text: '[UNK]' in '입니다.깼다가'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,659 >> Unable to find text: '[UNK] 바로 잠이 든다면 아직은 큰 문제는 아닌 것으로 보입니다' in '입니다.깼다가 바로 잠이 든다면 아직은 큰 문제는 아닌 것으로 보입니다.다만'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,659 >> Unable to find text: '##니다' in '의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,659 >> Unable to find text: '[UNK] 바로 잠이 든다면 아직은 큰 문제는 아닌 것으로 보입니다 . 다만' in '입니다.깼다가 바로 잠이 든다면 아직은 큰 문제는 아닌 것으로 보입니다.다만'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,659 >> Unable to find text: '##니다' in '발생합니다.즉,'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,660 >> Unable to find text: '##니다 . 불면증은 근본적으로 수면과 각성을 조절하는 뇌 신경계의 기능이상으로 발생합니다' in '보입니다.불면증은 근본적으로 수면과 각성을 조절하는 뇌 신경계의 기능이상으로 발생합니다.즉,'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,660 >> Unable to find text: '##니다 . 즉 , 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다' in '발생합니다.즉, 잠을 조절하는 중추가 우리의 뇌에 있다는 의미입니다.만약'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,660 >> Unable to find text: '##니다' in '보입니다.불면증은'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,660 >> Unable to find text: '##니다' in '발생합니다.규칙적인'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,661 >> Unable to find text: '[UNK] 원인을 찾기 위해 수면다원검사를 해보시는 것도 좋은 방법입니다 .' in '깬다면 원인을 찾기 위해 수면다원검사를 해보시는 것도 좋은 방법입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,661 >> Unable to find text: '자주 [UNK] 원인을 찾기 위해 수면다원검사를 해보시는 것도 좋은 방법입니다 .' in '자주 깬다면 원인을 찾기 위해 수면다원검사를 해보시는 것도 좋은 방법입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,661 >> Unable to find text: '[UNK] 원인을 찾기 위해 수면다원검사를 해보시는 것도 좋은 방법입니다' in '깬다면 원인을 찾기 위해 수면다원검사를 해보시는 것도 좋은 방법입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,662 >> Unable to find text: '자주 [UNK] 원인을 찾기 위해 수면다원검사를 해보시는 것도 좋은 방법입니다' in '자주 깬다면 원인을 찾기 위해 수면다원검사를 해보시는 것도 좋은 방법입니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,666 >> Unable to find text: '##니다' in '곤란합니다.걱정이'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,667 >> Unable to find text: '##니다 . 1년에 2 - 3회 증상이 있으면 적극적인 치료가 곤란합니다' in '있습니다. 1년에 2-3회 증상이 있으면 적극적인 치료가 곤란합니다.걱정이'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,667 >> Unable to find text: '##니다 . 걱정이 되시는 부분에 대한 검사는 대학병원 신경과가 적당합니다' in '곤란합니다.걱정이 되시는 부분에 대한 검사는 대학병원 신경과가 적당합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,667 >> Unable to find text: '##니다 . 기립성 저혈압이나자율신경 기능이상이 기저에 있는 경우들이 있습니다 .' in '합니다. 기립성 저혈압이나자율신경 기능이상이 기저에 있는 경우들이 있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,667 >> Unable to find text: '##니다 .' in '곤란합니다.걱정이'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,667 >> Unable to find text: '##니다 .' in '있습니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,668 >> Unable to find text: '##니다 .' in '권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,669 >> Unable to find text: '##니다' in '권유합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,669 >> Unable to find text: '##니다 .' in '분인듯합니다.'
# [INFO|squad_metrics.py:305] 2023-06-05 04:49:31,669 >> Unable to find text: '##니다 . 불안장애가 있으신 분인듯합니다 .' in '한재병입니다. 불안장애가 있으신 분인듯합니다.'
# 06/05/2023 04:49:32 - INFO - __main__ - Results: {'exact': 6.151012891344383, 'f1': 31.492365994416904, 'total': 2715, 'HasAns_exact': 6.151012891344383, 'HasAns_f1': 31.492365994416904, 'HasAns_total': 2715, 'best_exact': 6.151012891344383, 'best_exact_thresh': 0.0, 'best_f1': 31.492365994416904, 'best_f1_thresh': 0.0}

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## 경로 변경

# %%
import os
os.chdir('/content/drive/MyDrive/korquad/')
os.getcwd()
# Out:
# '/content/drive/MyDrive/korquad'

# %%
from __future__ import print_function
from collections import Counter
import string
import re
import argparse
import json
import sys
import os

import pandas as pd
from transformers import AutoTokenizer

'''KorQuAD v1.0에 대한 공식 평가 스크립트 '''
'''본 스크립트는 SQuAD v1.1 평가 스크립트 https://rajpurkar.github.io/SQuAD-explorer/ 를 바탕으로 작성됨.'''

def normalize_answer(s):    
    def remove_(text):
        ''' 불필요한 기호 제거 '''
        text = re.sub("'", " ", text)
        text = re.sub('"', " ", text)
        text = re.sub('《', " ", text)
        text = re.sub('》', " ", text)
        text = re.sub('<', " ", text)
        text = re.sub('>', " ", text) 
        text = re.sub('〈', " ", text)
        text = re.sub('〉', " ", text)   
        text = re.sub("\(", " ", text)
        text = re.sub("\)", " ", text)
        text = re.sub("‘", " ", text)
        text = re.sub("’", " ", text)      
        return text

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return ''.join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_punc(lower(remove_(s))))


def f1_score(prediction, ground_truth):
    prediction_tokens = normalize_answer(prediction).split()
    ground_truth_tokens = normalize_answer(ground_truth).split()
   
    #F1 by character
    prediction_Char = []
    for tok in prediction_tokens:
        now = [a for a in tok]
        prediction_Char.extend(now)
        
    ground_truth_Char = []
    for tok in ground_truth_tokens:
        now = [a for a in tok]
        ground_truth_Char.extend(now)   
        
    common = Counter(prediction_Char) & Counter(ground_truth_Char)
    num_same = sum(common.values())
    if num_same == 0:
        return 0
    
    precision = 1.0 * num_same / len(prediction_Char)
    recall = 1.0 * num_same / len(ground_truth_Char)
    f1 = (2 * precision * recall) / (precision + recall)
    
    return f1


def exact_match_score(prediction, ground_truth):
    return (normalize_answer(prediction) == normalize_answer(ground_truth))


def metric_max_over_ground_truths(metric_fn, prediction, ground_truths):
    scores_for_ground_truths = []
    for ground_truth in ground_truths:
        score = metric_fn(prediction, ground_truth)
        scores_for_ground_truths.append(score)
    return max(scores_for_ground_truths)


def evaluate(dataset, predictions):
    f1 = exact_match = total = 0
    for article in dataset:
        for paragraph in article['paragraphs']:
            for qa in paragraph['qas']:
                total += 1
                if qa['id'] not in predictions:
                    message = 'Unanswered question ' + qa['id'] + \
                              ' will receive score 0.'
                    print(message, file=sys.stderr)
                    continue
                ground_truths = list(map(lambda x: x['text'], qa['answers']))
                prediction = predictions[qa['id']]
                exact_match += metric_max_over_ground_truths(
                    exact_match_score, prediction, ground_truths)
                f1 += metric_max_over_ground_truths(
                    f1_score, prediction, ground_truths)

    exact_match = 100.0 * exact_match / total
    f1 = 100.0 * f1 / total
    return {'exact_match': exact_match, 'f1': f1}


def evaluate_result(dataset_file, prediction_file):
    
    with open(dataset_file, encoding="utf-8") as f:
        dataset_json = json.load(f)
        dataset = dataset_json['data']
    with open(prediction_file, encoding="utf-8") as f:
        predictions = json.load(f)
    return evaluate(dataset, predictions)

# %% [markdown]
# ## 성능 확인

# %%
dataset_file = './data/KMQA_dev_v5.1.json'
prediction_file = './multilingual_bert-KMQA/predictions_.json'
evaluate_result(dataset_file, prediction_file)
# Out:
# {'exact_match': 6.128440366972477, 'f1': 38.724818641596684}
