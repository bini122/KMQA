# %%
# !pip3 install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.0-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 46.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.2-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 14.7 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 61.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.2 tokenizers-0.13.2 transformers-4.27.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/korquad/')
os.getcwd()
# Out:
# '/content/drive/MyDrive/korquad'

# %%
# !python ./run_QA.py \
    --model_type bert \
    --model_name_or_path bert-base-multilingual-cased \
    --output_dir multilingual_bert-korquad \
    --data_dir data \
    --data_name KorQuAD \
    --train_file KorQuAD_v1.0_train.json \
    --predict_file KorQuAD_v1.0_dev.json \
    --max_seq_length 512 \
    --doc_stride 128 \
    --max_query_length 64 \
    --do_train \
    --do_eval \
    --evaluate_during_training \
    --per_gpu_train_batch_size=16 \
    --per_gpu_eval_batch_size=8 \
    --learning_rate 5e-5 \
    --gradient_accumulation_steps 1 \
    --weight_decay 0.0 \
    --adam_epsilon 1e-8 \
    --max_grad_norm 1.0 \
    --num_train_epochs 3 \
    --max_steps -1 \
    --warmup_steps 0 \
    --n_best_size 20 \
    --max_answer_length 30 \
    --verbose_logging \
    --logging_steps 1000 \
    --save_steps 1000 \
    --eval_all_checkpoints \
    --overwrite_output_dir \
    --seed 42 \
    --local_rank -1 \
    --threads 4
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,671 >> Unable to find text: '[UNK] 국체 논쟁' in '‘국체 논쟁’은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,671 >> Unable to find text: '국체 논쟁 [UNK]' in '‘국체 논쟁’은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,671 >> Unable to find text: '국체 관념이 없다 [UNK] 고 비난했다 . 국가의 주권이 어디에 있는지를 두고 벌어진 [UNK] 국체 논쟁' in '“국체 관념이 없다”고 비난했다. 국가의 주권이 어디에 있는지를 두고 벌어진 ‘국체 논쟁’은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,671 >> Unable to find text: '국체 논쟁 [UNK] 은' in '‘국체 논쟁’은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,671 >> Unable to find text: '##쟁' in '논쟁’은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,672 >> Unable to find text: '국체 [UNK] 논쟁' in '‘국체’ 논쟁은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,672 >> Unable to find text: '벌어진 [UNK] 국체 논쟁' in '벌어진 ‘국체 논쟁’은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,672 >> Unable to find text: '국가의 주권이 어디에 있는지를 두고 벌어진 [UNK] 국체 논쟁' in '국가의 주권이 어디에 있는지를 두고 벌어진 ‘국체 논쟁’은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,672 >> Unable to find text: '[UNK] 국체 [UNK] 논쟁' in '‘국체’ 논쟁은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,672 >> Unable to find text: '주권이 어디에 있는지를 두고 벌어진 [UNK] 국체 논쟁' in '주권이 어디에 있는지를 두고 벌어진 ‘국체 논쟁’은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,672 >> Unable to find text: '두고 벌어진 [UNK] 국체 논쟁' in '두고 벌어진 ‘국체 논쟁’은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,673 >> Unable to find text: '국체 논쟁 [UNK] 은 히로히토의 대리청정 기간에 일본에서 매우 중요한 논쟁거리였다 . 하지만 이러한 [UNK]' in '‘국체 논쟁’은 히로히토의 대리청정 기간에 일본에서 매우 중요한 논쟁거리였다. 하지만 이러한 ‘국체’'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,675 >> Unable to find text: '어디에 있는지를 두고 벌어진 [UNK] 국체 논쟁' in '어디에 있는지를 두고 벌어진 ‘국체 논쟁’은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,675 >> Unable to find text: '[UNK] 국체 논쟁 [UNK]' in '‘국체 논쟁’은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,675 >> Unable to find text: '[UNK] 국체' in '‘국체'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,675 >> Unable to find text: '국체 관념이 없다 [UNK] 고 비난했다 . 국가의 주권이 어디에 있는지를 두고 벌어진 [UNK] 국체' in '“국체 관념이 없다”고 비난했다. 국가의 주권이 어디에 있는지를 두고 벌어진 ‘국체'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,675 >> Unable to find text: '[UNK] 국체 논쟁 [UNK] 은' in '‘국체 논쟁’은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,676 >> Unable to find text: '[UNK] 국' in '‘국체'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,676 >> Unable to find text: '[UNK] 국체' in '‘국체’'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,676 >> Unable to find text: '국체 [UNK]' in '‘국체’'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,676 >> Unable to find text: '##쟁 [UNK]' in '논쟁’은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,676 >> Unable to find text: '국체 관념이 없다 [UNK] 고 비난했다 . 국가의 주권이 어디에 있는지를 두고 벌어진 [UNK] 국' in '“국체 관념이 없다”고 비난했다. 국가의 주권이 어디에 있는지를 두고 벌어진 ‘국체'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,676 >> Unable to find text: '국체 문제 [UNK] 로 규탄하면서 와카쓰키 총리가 [UNK] 국체' in '‘국체 문제’로 규탄하면서 와카쓰키 총리가 “국체'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,678 >> Unable to find text: '쇼와 [UNK] ( 昭 和 )' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,678 >> Unable to find text: '[UNK] 쇼와' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,678 >> Unable to find text: '쇼와 [UNK]' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,678 >> Unable to find text: '쇼와 [UNK] ( 昭 和 ) 라고 12월 26일에 대외에 공식 발표하였다 . 쇼와' in '‘쇼와’(昭和)라고 12월 26일에 대외에 공식 발표하였다. 쇼와(소화)란'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,678 >> Unable to find text: '쇼와 [UNK] ( 昭 和 ) 라고' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,678 >> Unable to find text: '쇼와 [UNK] ( 昭 和 ) 라고 12월 26일에 대외에 공식 발표하였다 . 쇼와 ( 소화' in '‘쇼와’(昭和)라고 12월 26일에 대외에 공식 발표하였다. 쇼와(소화)란'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,679 >> Unable to find text: '[UNK] 쇼와 [UNK] ( 昭 和 )' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,679 >> Unable to find text: '[UNK] 쇼와 [UNK]' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,679 >> Unable to find text: '[UNK] 쇼와 [UNK] ( 昭 和 ) 라고 12월 26일에 대외에 공식 발표하였다 . 쇼와' in '‘쇼와’(昭和)라고 12월 26일에 대외에 공식 발표하였다. 쇼와(소화)란'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,679 >> Unable to find text: '##와' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,679 >> Unable to find text: '쇼와 [UNK] (' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,679 >> Unable to find text: '[UNK] 쇼와 [UNK] ( 昭 和 ) 라고' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,680 >> Unable to find text: '[UNK] 쇼와 [UNK] ( 昭 和 ) 라고 12월 26일에 대외에 공식 발표하였다 . 쇼와 ( 소화' in '‘쇼와’(昭和)라고 12월 26일에 대외에 공식 발표하였다. 쇼와(소화)란'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,680 >> Unable to find text: '쇼와 [UNK] ( 昭 和' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,680 >> Unable to find text: '천황의 새로운 연호를 [UNK] 쇼와' in '천황의 새로운 연호를 ‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,680 >> Unable to find text: '쇼와 [UNK] ( 昭 和 ) 라고 12월 26일에 대외에 공식 발표하였다 . 쇼' in '‘쇼와’(昭和)라고 12월 26일에 대외에 공식 발표하였다. 쇼와(소화)란'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,680 >> Unable to find text: '연호를 [UNK] 쇼와' in '연호를 ‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,681 >> Unable to find text: '##와 [UNK] ( 昭 和 )' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,681 >> Unable to find text: '쇼와 [UNK] ( 昭 和 ) 라고 12월 26일에 대외에 공식 발표하였다 . 쇼와 ( 소화 )' in '‘쇼와’(昭和)라고 12월 26일에 대외에 공식 발표하였다. 쇼와(소화)란'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,681 >> Unable to find text: '고분 [UNK] ( 廣 文 )' in '‘고분’(廣文)이라는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,681 >> Unable to find text: '[UNK] 쇼' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,681 >> Unable to find text: '고분 [UNK] ( 廣 文 ) 이라는 연호를 쓰게 될 것이라고 보도했으나 , 추밀원은 천황의 새로운 연호를 [UNK] 쇼' in '‘고분’(廣文)이라는 연호를 쓰게 될 것이라고 보도했으나, 추밀원은 천황의 새로운 연호를 ‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,681 >> Unable to find text: '천황의 새로운 연호를 [UNK] 쇼와 [UNK] ( 昭 和 )' in '천황의 새로운 연호를 ‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,682 >> Unable to find text: '##와 [UNK]' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,682 >> Unable to find text: '[UNK]' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,682 >> Unable to find text: '고분 [UNK]' in '‘고분’(廣文)이라는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,682 >> Unable to find text: '[UNK] 쇼와 [UNK] (' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,682 >> Unable to find text: '##와 [UNK] ( 昭 和 ) 라고 12월 26일에 대외에 공식 발표하였다 . 쇼와' in '‘쇼와’(昭和)라고 12월 26일에 대외에 공식 발표하였다. 쇼와(소화)란'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,682 >> Unable to find text: '[UNK] ( 昭 和 )' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,683 >> Unable to find text: '고분 [UNK] ( 廣 文 ) 이라는 연호를 쓰게 될 것이라고 보도했으나 , 추밀원은 천황의 새로운 연호를 [UNK]' in '‘고분’(廣文)이라는 연호를 쓰게 될 것이라고 보도했으나, 추밀원은 천황의 새로운 연호를 ‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,683 >> Unable to find text: '연호를 [UNK] 쇼와 [UNK] ( 昭 和 )' in '연호를 ‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,683 >> Unable to find text: '[UNK] 쇼와 [UNK] ( 昭 和' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,683 >> Unable to find text: '[UNK] 고분' in '‘고분’(廣文)이라는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,683 >> Unable to find text: '천황의 새로운 연호를 [UNK] 쇼와 [UNK]' in '천황의 새로운 연호를 ‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,683 >> Unable to find text: '##와 [UNK] ( 昭 和 ) 라고' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,684 >> Unable to find text: '천황의 새로운 연호를 [UNK] 쇼와 [UNK] ( 昭 和 ) 라고 12월 26일에 대외에 공식 발표하였다 . 쇼와' in '천황의 새로운 연호를 ‘쇼와’(昭和)라고 12월 26일에 대외에 공식 발표하였다. 쇼와(소화)란'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,688 >> Unable to find text: '##와 [UNK] ( 昭 和 ) 라고 12월 26일에 대외에 공식 발표하였다 . 쇼와 ( 소화' in '‘쇼와’(昭和)라고 12월 26일에 대외에 공식 발표하였다. 쇼와(소화)란'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,688 >> Unable to find text: '[UNK] 쇼와 [UNK] ( 昭 和 ) 라고 12월 26일에 대외에 공식 발표하였다 . 쇼' in '‘쇼와’(昭和)라고 12월 26일에 대외에 공식 발표하였다. 쇼와(소화)란'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,689 >> Unable to find text: '쇼와 ( 소화 ) 란 [UNK] 밝은 조화' in '쇼와(소화)란 ‘밝은 조화’,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,689 >> Unable to find text: '[UNK]' in '‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,689 >> Unable to find text: '연호를 [UNK] 쇼와 [UNK]' in '연호를 ‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,689 >> Unable to find text: '[UNK] ( 昭 和 ) 라고 12월 26일에 대외에 공식 발표하였다 . 쇼와' in '‘쇼와’(昭和)라고 12월 26일에 대외에 공식 발표하였다. 쇼와(소화)란'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,690 >> Unable to find text: '천황의 새로운 연호를 [UNK] 쇼와 [UNK] ( 昭 和 ) 라고' in '천황의 새로운 연호를 ‘쇼와’(昭和)라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,690 >> Unable to find text: '[UNK] 쇼와 [UNK] ( 昭 和 ) 라고 12월 26일에 대외에 공식 발표하였다 . 쇼와 ( 소화 )' in '‘쇼와’(昭和)라고 12월 26일에 대외에 공식 발표하였다. 쇼와(소화)란'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,690 >> Unable to find text: '연호를 [UNK] 쇼와 [UNK] ( 昭 和 ) 라고 12월 26일에 대외에 공식 발표하였다 . 쇼와' in '연호를 ‘쇼와’(昭和)라고 12월 26일에 대외에 공식 발표하였다. 쇼와(소화)란'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,690 >> Unable to find text: '[UNK] 고분 [UNK] ( 廣 文 )' in '‘고분’(廣文)이라는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,692 >> Unable to find text: '##토' in '교토로'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,692 >> Unable to find text: '##에는 교토' in '10일에는 교토로'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,693 >> Unable to find text: '##토로' in '교토로'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,693 >> Unable to find text: '##년 11월 10일에는 교토' in '1928년 11월 10일에는 교토로'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,693 >> Unable to find text: '##토로 행차' in '교토로 행차하여'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,694 >> Unable to find text: '##로' in '교토로'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,694 >> Unable to find text: '##에는 교토로' in '10일에는 교토로'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,702 >> Unable to find text: '##지는' in '사이온지는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,703 >> Unable to find text: '##이온지는' in '사이온지는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,704 >> Unable to find text: '##와 마키노' in '사이온지와 마키노는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,706 >> Unable to find text: '##년' in '1927년'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,707 >> Unable to find text: '##는 1927년' in '의회는 1927년'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,708 >> Unable to find text: '##년 1월 18일' in '1927년 1월 18일에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,708 >> Unable to find text: '##년 1월 18일에' in '1927년 1월 18일에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,708 >> Unable to find text: '##년 1월 18일에 다시 열렸다 .' in '1927년 1월 18일에 다시 열렸다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,708 >> Unable to find text: '##년 1월' in '1927년 1월'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,714 >> Unable to find text: '##치' in '기이치'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,715 >> Unable to find text: '##치 내각' in '기이치 내각이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,715 >> Unable to find text: '##나카 기이치' in '다나카 기이치'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,715 >> Unable to find text: '##카 기이치' in '다나카 기이치'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,717 >> Unable to find text: '##오' in '도메오가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,718 >> Unable to find text: '##오가' in '도메오가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,721 >> Unable to find text: '##치를' in '오사치를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,721 >> Unable to find text: '##구치 오사치를' in '하마구치 오사치를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,729 >> Unable to find text: '##년' in '1931년'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,731 >> Unable to find text: '##년 9월 18일' in '1931년 9월 18일'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,732 >> Unable to find text: '##년 9월' in '1931년 9월'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,732 >> Unable to find text: '##년 9월 18일 밤' in '1931년 9월 18일 밤,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,732 >> Unable to find text: '##년 9월 18일 밤 ,' in '1931년 9월 18일 밤,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,732 >> Unable to find text: '##년 9월 18일 밤 , 만주 사변' in '1931년 9월 18일 밤, 만주 사변이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,732 >> Unable to find text: '##년 9월 18일 밤 , 만주' in '1931년 9월 18일 밤, 만주'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,734 >> Unable to find text: '##습' in '공습은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,767 >> Unable to find text: '##저우 공중 폭격을 재가했다 . 진저우 공습' in '진저우 공중 폭격을 재가했다. 진저우 공습은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,768 >> Unable to find text: '##저우 공습' in '진저우 공습은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,768 >> Unable to find text: '##우 공습' in '진저우 공습은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,770 >> Unable to find text: '##국' in '중화민국이라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,771 >> Unable to find text: '##화민국' in '중화민국이라고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,776 >> Unable to find text: '##파' in '황도파(皇道派)였고,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,777 >> Unable to find text: '##파 ( 皇 道 派 )' in '황도파(皇道派)였고,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,777 >> Unable to find text: '##파' in '황도파는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,778 >> Unable to find text: '##도파' in '황도파(皇道派)였고,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,780 >> Unable to find text: '##회를' in '벚꽃회를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,780 >> Unable to find text: '##꽃회를' in '벚꽃회를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,781 >> Unable to find text: '##회를 이' in '벚꽃회를 이끌고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,783 >> Unable to find text: '##군이' in '관동군이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,785 >> Unable to find text: '##군이 내각의 명령을 무시하고 진저우를 점령했다 . 미국 , 영국 , 프랑스는 관동군의' in '관동군이 내각의 명령을 무시하고 진저우를 점령했다. 미국, 영국, 프랑스는 관동군의'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,786 >> Unable to find text: '##이를' in '푸이를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,787 >> Unable to find text: '##였던 선통제 푸이를' in '황제였던 선통제 푸이를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,790 >> Unable to find text: '##단의' in '혈맹단의'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,790 >> Unable to find text: '##인 혈맹단의' in '결사단체인 혈맹단의'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,792 >> Unable to find text: '##토' in '사이토는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,793 >> Unable to find text: '##이토 마코토를 지명했다 . 사이토' in '사이토 마코토를 지명했다. 사이토는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,793 >> Unable to find text: '##토 마코토를 지명했다 . 사이토' in '사이토 마코토를 지명했다. 사이토는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,796 >> Unable to find text: '##명을' in '1,400명을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,797 >> Unable to find text: '##명이 제1사단 휘하 3개 연대와 근위보병연대의 무장 병사들 1 , 400명을' in '22명이 제1사단 휘하 3개 연대와 근위보병연대의 무장 병사들 1,400명을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,798 >> Unable to find text: '##명이' in '22명이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,799 >> Unable to find text: '##명이' in '5명이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,800 >> Unable to find text: '##관 5명이' in '경찰관 5명이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,800 >> Unable to find text: '##으로 경찰관 5명이' in '사건으로 경찰관 5명이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,800 >> Unable to find text: '##찰관 5명이' in '경찰관 5명이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,801 >> Unable to find text: '##관 5' in '경찰관 5명이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,801 >> Unable to find text: '##명이 죽' in '5명이 죽었으며,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,801 >> Unable to find text: '##으로 경찰관 5' in '사건으로 경찰관 5명이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,802 >> Unable to find text: '##관 5명이 죽' in '경찰관 5명이 죽었으며,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,802 >> Unable to find text: '##명이 죽었으며' in '5명이 죽었으며,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,803 >> Unable to find text: '##토' in '아키히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,804 >> Unable to find text: '##키히토' in '아키히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,804 >> Unable to find text: '##히토' in '아키히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,805 >> Unable to find text: '##코는 1933년 12월 23일 , 지금의 천황이 되는 첫째 아들 아키히토' in '나가코는 1933년 12월 23일, 지금의 천황이 되는 첫째 아들 아키히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,805 >> Unable to find text: '##토를' in '아키히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,807 >> Unable to find text: '##의' in '본의》라는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,809 >> Unable to find text: '##의 》' in '본의》라는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,810 >> Unable to find text: '##년' in '1937년'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,812 >> Unable to find text: '##년 7월 8일' in '1937년 7월 8일,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,813 >> Unable to find text: '##년 7월' in '1937년 7월'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,813 >> Unable to find text: '##년 7월 8일 ,' in '1937년 7월 8일,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,813 >> Unable to find text: '##년 7월 8일 , 루거우차오 사건이 일어났다 .' in '1937년 7월 8일, 루거우차오 사건이 일어났다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,813 >> Unable to find text: '##년 7월 8일 , 루거우차오 사건' in '1937년 7월 8일, 루거우차오 사건이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,813 >> Unable to find text: '##년 7월 8일 , 루거우차오 사건이 일어났다' in '1937년 7월 8일, 루거우차오 사건이 일어났다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,813 >> Unable to find text: '##년 7월 8일 , 루거우차오' in '1937년 7월 8일, 루거우차오'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,813 >> Unable to find text: '##년 7월 8일 , 루거우차오 사건이' in '1937년 7월 8일, 루거우차오 사건이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,814 >> Unable to find text: '##년 7월 8일 , 루' in '1937년 7월 8일, 루거우차오'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,814 >> Unable to find text: '##년 7월 8일 , 루거우차오 사건이 일' in '1937년 7월 8일, 루거우차오 사건이 일어났다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,817 >> Unable to find text: '##토' in '고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,817 >> Unable to find text: '##노미야 고토히토' in '간인노미야 고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,818 >> Unable to find text: '##토히토' in '고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,818 >> Unable to find text: '##인노미야 고토히토' in '간인노미야 고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,818 >> Unable to find text: '##미야 고토히토' in '간인노미야 고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,818 >> Unable to find text: '##히토' in '고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,818 >> Unable to find text: '##야 고토히토' in '간인노미야 고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,818 >> Unable to find text: '##장이었던 간인노미야 고토히토' in '참모총장이었던 간인노미야 고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,818 >> Unable to find text: '##토를' in '고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,819 >> Unable to find text: '##노미야 고토히토를' in '간인노미야 고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,819 >> Unable to find text: '##토히토를' in '고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,819 >> Unable to find text: '##인노미야 고토히토를' in '간인노미야 고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,819 >> Unable to find text: '##를' in '고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,819 >> Unable to find text: '##미야 고토히토를' in '간인노미야 고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,819 >> Unable to find text: '##히토를' in '고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,819 >> Unable to find text: '##야 고토히토를' in '간인노미야 고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,820 >> Unable to find text: '##장이었던 간인노미야 고토히토를' in '참모총장이었던 간인노미야 고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,820 >> Unable to find text: '##노미야 고토히' in '간인노미야 고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,820 >> Unable to find text: '##토히' in '고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,820 >> Unable to find text: '##노미야' in '간인노미야'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,820 >> Unable to find text: '##인노미야 고토히' in '간인노미야 고토히토를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,822 >> Unable to find text: '대본영정부연락회의 [UNK]' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,822 >> Unable to find text: '[UNK] 대본영정부연락회의' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,822 >> Unable to find text: '대본영정부연락회의 [UNK] 가' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,822 >> Unable to find text: '##회의' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,822 >> Unable to find text: '##정부연락회의' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,822 >> Unable to find text: '##본영정부연락회의' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,822 >> Unable to find text: '##영정부연락회의' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,823 >> Unable to find text: '내각과 군을 이어주는 [UNK] 대본영정부연락회의' in '내각과 군을 이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,823 >> Unable to find text: '이어주는 [UNK] 대본영정부연락회의' in '이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,823 >> Unable to find text: '[UNK] 대본영정부연락회의 [UNK]' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,823 >> Unable to find text: '대본영정부연락회의 [UNK] 가 조직됐다 .' in '‘대본영정부연락회의’가 조직됐다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,823 >> Unable to find text: '##부연락회의' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,823 >> Unable to find text: '##연락회의' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,824 >> Unable to find text: '[UNK] 대본영정부연락회의 [UNK] 가' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,824 >> Unable to find text: '대본영정부연락회의 [UNK] 가 조직' in '‘대본영정부연락회의’가 조직됐다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,824 >> Unable to find text: '##회의 [UNK]' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,824 >> Unable to find text: '[UNK] 대' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,824 >> Unable to find text: '[UNK] 대본영정부연락' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,824 >> Unable to find text: '##정부연락회의 [UNK]' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,824 >> Unable to find text: '##본영정부연락회의 [UNK]' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,825 >> Unable to find text: '##영정부연락회의 [UNK]' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,825 >> Unable to find text: '내각과 군을 이어주는 [UNK] 대본영정부연락회의 [UNK]' in '내각과 군을 이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,825 >> Unable to find text: '[UNK]' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,825 >> Unable to find text: '##회의 [UNK] 가' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,825 >> Unable to find text: '이어주는 [UNK] 대본영정부연락회의 [UNK]' in '이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,825 >> Unable to find text: '[UNK]' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,825 >> Unable to find text: '[UNK] 대본영정부' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,825 >> Unable to find text: '##부연락회의 [UNK]' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,825 >> Unable to find text: '##정부연락회의 [UNK] 가' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,826 >> Unable to find text: '##본영정부연락회의 [UNK] 가' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,826 >> Unable to find text: '##영정부연락회의 [UNK] 가' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,826 >> Unable to find text: '[UNK] 대본영정부연락회의 [UNK] 가 조직됐다 .' in '‘대본영정부연락회의’가 조직됐다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,826 >> Unable to find text: '내각과 군을 이어주는 [UNK] 대본영정부연락회의 [UNK] 가' in '내각과 군을 이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,826 >> Unable to find text: '##연락회의 [UNK]' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,826 >> Unable to find text: '이어주는 [UNK] 대본영정부연락회의 [UNK] 가' in '이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,826 >> Unable to find text: '[UNK] 대본영정부연' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,826 >> Unable to find text: '[UNK] 대본영' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,826 >> Unable to find text: '[UNK] 가' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,827 >> Unable to find text: '[UNK] 대본' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,827 >> Unable to find text: '[UNK] 대본영정부연락회의 [UNK] 가 조직' in '‘대본영정부연락회의’가 조직됐다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,827 >> Unable to find text: '[UNK] 대본영정' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,827 >> Unable to find text: '##부연락회의 [UNK] 가' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,827 >> Unable to find text: '내각과 군을 이어주는 [UNK] 대' in '내각과 군을 이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,827 >> Unable to find text: '##연락회의 [UNK] 가' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,827 >> Unable to find text: '##정부연락' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,827 >> Unable to find text: '이어주는 [UNK] 대' in '이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,827 >> Unable to find text: '##본영정부연락' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,828 >> Unable to find text: '##영정부연락' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,828 >> Unable to find text: '내각과 군을 이어주는 [UNK] 대본영정부연락' in '내각과 군을 이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,828 >> Unable to find text: '이어주는 [UNK] 대본영정부연락' in '이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,828 >> Unable to find text: '##회의 [UNK] 가 조직됐다 .' in '‘대본영정부연락회의’가 조직됐다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,828 >> Unable to find text: '내각과 군을 이어주는 [UNK]' in '내각과 군을 이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,829 >> Unable to find text: '대본영을 궁중에 다시 설치하도록 명령했다 . 11월 19일에는 내각과 군을 이어주는 [UNK] 대' in '대본영을 궁중에 다시 설치하도록 명령했다. 11월 19일에는 내각과 군을 이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,869 >> Unable to find text: '이어주는 [UNK]' in '이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,869 >> Unable to find text: '##정부' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,869 >> Unable to find text: '##본영정부' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,870 >> Unable to find text: '##부연락' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,870 >> Unable to find text: '##회의 [UNK] 가 조직' in '‘대본영정부연락회의’가 조직됐다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,870 >> Unable to find text: '##영정부' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,870 >> Unable to find text: '내각과 군을 이어주는 [UNK] 대본영정부' in '내각과 군을 이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,870 >> Unable to find text: '대본영을 궁중에 다시 설치하도록 명령했다 . 11월 19일에는 내각과 군을 이어주는 [UNK]' in '대본영을 궁중에 다시 설치하도록 명령했다. 11월 19일에는 내각과 군을 이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,871 >> Unable to find text: '##정부연락회의 [UNK] 가 조직됐다 .' in '‘대본영정부연락회의’가 조직됐다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,871 >> Unable to find text: '##본영정부연락회의 [UNK] 가 조직됐다 .' in '‘대본영정부연락회의’가 조직됐다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,871 >> Unable to find text: '##연락' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,871 >> Unable to find text: '이어주는 [UNK] 대본영정부' in '이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,871 >> Unable to find text: '##영정부연락회의 [UNK] 가 조직됐다 .' in '‘대본영정부연락회의’가 조직됐다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,871 >> Unable to find text: '내각과 군을 이어주는 [UNK] 대본영정부연락회의 [UNK] 가 조직됐다 .' in '내각과 군을 이어주는 ‘대본영정부연락회의’가 조직됐다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,871 >> Unable to find text: '##정부연' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,872 >> Unable to find text: '##본영정부연' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,872 >> Unable to find text: '이어주는 [UNK] 대본영정부연락회의 [UNK] 가 조직됐다 .' in '이어주는 ‘대본영정부연락회의’가 조직됐다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,873 >> Unable to find text: '사변 [UNK] 을 해결하는 것이라 부르거나 , 성전' in '‘사변’을 해결하는 것이라 부르거나, 성전(聖戰,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,874 >> Unable to find text: '사변 [UNK] 을 해결하는 것이라 부르거나 , 성전 ( 聖 戰 , 성스러운 전쟁' in '‘사변’을 해결하는 것이라 부르거나, 성전(聖戰, 성스러운 전쟁)으로'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,874 >> Unable to find text: '##전' in '성전(聖戰,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,874 >> Unable to find text: '[UNK] 사변 [UNK] 을 해결하는 것이라 부르거나 , 성전' in '‘사변’을 해결하는 것이라 부르거나, 성전(聖戰,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,875 >> Unable to find text: '중국 침략 행위를 [UNK] 사변 [UNK] 을 해결하는 것이라 부르거나 , 성전' in '중국 침략 행위를 ‘사변’을 해결하는 것이라 부르거나, 성전(聖戰,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,875 >> Unable to find text: '사변 [UNK] 을 해결하는 것이라 부르거나 , 성전 ( 聖 戰 , 성스러운 전쟁 )' in '‘사변’을 해결하는 것이라 부르거나, 성전(聖戰, 성스러운 전쟁)으로'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,875 >> Unable to find text: '##전 ( 聖 戰 , 성스러운 전쟁' in '성전(聖戰, 성스러운 전쟁)으로'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,875 >> Unable to find text: '##거나 , 성전' in '부르거나, 성전(聖戰,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,876 >> Unable to find text: '[UNK] 사변 [UNK] 을 해결하는 것이라 부르거나 , 성전 ( 聖 戰 , 성스러운 전쟁' in '‘사변’을 해결하는 것이라 부르거나, 성전(聖戰, 성스러운 전쟁)으로'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,883 >> Unable to find text: '##문' in '신문에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,883 >> Unable to find text: '##치 신문' in '도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,883 >> Unable to find text: '중국인 100명 목 베기 시합 [UNK] 은 도쿄니치니치 신문' in '‘중국인 100명 목 베기 시합’은 도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,884 >> Unable to find text: '##니치니치 신문' in '도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,884 >> Unable to find text: '##치니치 신문' in '도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,884 >> Unable to find text: '일본 육군 소위 두 명이 저지른 [UNK] 중국인 100명 목 베기 시합 [UNK] 은 도쿄니치니치 신문' in '일본 육군 소위 두 명이 저지른 ‘중국인 100명 목 베기 시합’은 도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,884 >> Unable to find text: '두 명이 저지른 [UNK] 중국인 100명 목 베기 시합 [UNK] 은 도쿄니치니치 신문' in '두 명이 저지른 ‘중국인 100명 목 베기 시합’은 도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,885 >> Unable to find text: '저지른 [UNK] 중국인 100명 목 베기 시합 [UNK] 은 도쿄니치니치 신문' in '저지른 ‘중국인 100명 목 베기 시합’은 도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,885 >> Unable to find text: '[UNK] 중국인 100명 목 베기 시합 [UNK] 은 도쿄니치니치 신문' in '‘중국인 100명 목 베기 시합’은 도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,886 >> Unable to find text: '##게미쓰 마모루' in '시게미쓰 마모루는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,886 >> Unable to find text: '##루' in '마모루는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,887 >> Unable to find text: '##미쓰 마모루' in '시게미쓰 마모루는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,887 >> Unable to find text: '##렀던 시게미쓰 마모루' in '머물렀던 시게미쓰 마모루는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,887 >> Unable to find text: '##쓰 마모루' in '시게미쓰 마모루는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,887 >> Unable to find text: '시게미쓰 마모루는 [UNK]' in '시게미쓰 마모루는 “난징'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,888 >> Unable to find text: '##게미쓰 마모루는' in '시게미쓰 마모루는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,888 >> Unable to find text: '##루는' in '마모루는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,888 >> Unable to find text: '##미쓰 마모루는' in '시게미쓰 마모루는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,888 >> Unable to find text: '##는' in '마모루는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,890 >> Unable to find text: '##스는' in '빅스는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,890 >> Unable to find text: '##버트 빅스는' in '허버트 빅스는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,891 >> Unable to find text: '##미쓰 마모루' in '시게미쓰 마모루는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,891 >> Unable to find text: '##게미쓰 마모루' in '시게미쓰 마모루는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,891 >> Unable to find text: '##버트' in '허버트'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,891 >> Unable to find text: '##버트 빅' in '허버트 빅스는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,891 >> Unable to find text: '##스는 당시 일본군의 지휘명령 계통의 정점에 서서 모든 동정을 상세히 쫓고 있었던 쇼와' in '빅스는 당시 일본군의 지휘명령 계통의 정점에 서서 모든 동정을 상세히 쫓고 있었던 쇼와'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,898 >> Unable to find text: '##년' in '1940년'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,899 >> Unable to find text: '##년부터 이미 창씨개명을 시행해 조선인들에게 일본식 이름의 사용을 강요하기 시작했으며 , 1940년' in '1939년부터 이미 창씨개명을 시행해 조선인들에게 일본식 이름의 사용을 강요하기 시작했으며, 1940년'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,900 >> Unable to find text: '##했으며 , 1940년' in '시작했으며, 1940년'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,901 >> Unable to find text: '##년 8월 10일' in '1940년 8월 10일에는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,904 >> Unable to find text: '##호' in '제458호》를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,907 >> Unable to find text: '고노에 내각은 교토에서 기자회견을 열어 [UNK] 미국' in '고노에 내각은 교토에서 기자회견을 열어 “미국이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,908 >> Unable to find text: '대정익찬회 [UNK]' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,909 >> Unable to find text: '[UNK] 대정익찬회' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,909 >> Unable to find text: '대정익찬회 [UNK] 라' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,909 >> Unable to find text: '##회' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,909 >> Unable to find text: '대정익찬회 [UNK] 라 불리는 단일 정당을 통해 일당' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,909 >> Unable to find text: '대정익찬회 [UNK] 라 불리는 단일 정당을 통해 일당 독재 체제를' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당 독재 체제를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,910 >> Unable to find text: '대정익찬회 [UNK] 라 불리는 단일 정당을 통해 일당 독재' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당 독재'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,910 >> Unable to find text: '[UNK] 대정익찬회 [UNK]' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,910 >> Unable to find text: '##정익찬회' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,910 >> Unable to find text: '대정익찬회 [UNK] 라 불리는 단일 정당' in '‘대정익찬회’라 불리는 단일 정당을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,910 >> Unable to find text: '대정익찬회 [UNK] 라 불' in '‘대정익찬회’라 불리는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,910 >> Unable to find text: '대정익찬회 [UNK] 라 불리는' in '‘대정익찬회’라 불리는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,910 >> Unable to find text: '대정익찬회 [UNK] 라 불리는 단일 정당을 통해 일당 독재 체제를 세웠다 .' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당 독재 체제를 세웠다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,910 >> Unable to find text: '##익찬회' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,911 >> Unable to find text: '신체제 운동 [UNK] 을 주창하며 , 군부의 힘으로 의회를 강제로 폐쇄하고 [UNK] 대정익찬회' in '‘신체제 운동’을 주창하며, 군부의 힘으로 의회를 강제로 폐쇄하고 ‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,911 >> Unable to find text: '대정익찬회 [UNK] 라 불리는 단일 정당을 통해 일당 독재 체' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당 독재 체제를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,912 >> Unable to find text: '##찬회' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,912 >> Unable to find text: '[UNK] 대정익찬회 [UNK] 라' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,912 >> Unable to find text: '[UNK] 신체제 운동 [UNK] 을 주창하며 , 군부의 힘으로 의회를 강제로 폐쇄하고 [UNK] 대정익찬회' in '‘신체제 운동’을 주창하며, 군부의 힘으로 의회를 강제로 폐쇄하고 ‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,912 >> Unable to find text: '대정익찬회 [UNK] 라 불리는 단일' in '‘대정익찬회’라 불리는 단일'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,912 >> Unable to find text: '##회 [UNK]' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,912 >> Unable to find text: '[UNK] 대정익찬회 [UNK] 라 불리는 단일 정당을 통해 일당' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,912 >> Unable to find text: '[UNK] 대' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,912 >> Unable to find text: '[UNK] 대정익찬회 [UNK] 라 불리는 단일 정당을 통해 일당 독재 체제를' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당 독재 체제를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,913 >> Unable to find text: '[UNK] 대정익찬' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,913 >> Unable to find text: '##회 [UNK] 라' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,913 >> Unable to find text: '[UNK] 대정익찬회 [UNK] 라 불리는 단일 정당을 통해 일당 독재' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당 독재'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,913 >> Unable to find text: '[UNK]' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,913 >> Unable to find text: '##회 [UNK] 라 불리는 단일 정당을 통해 일당' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,913 >> Unable to find text: '##정익찬회 [UNK]' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,913 >> Unable to find text: '[UNK] 대정익' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,913 >> Unable to find text: '##회 [UNK] 라 불리는 단일 정당을 통해 일당 독재 체제를' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당 독재 체제를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,913 >> Unable to find text: '[UNK]' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,914 >> Unable to find text: '[UNK] 대정익찬회 [UNK] 라 불리는 단일 정당' in '‘대정익찬회’라 불리는 단일 정당을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,914 >> Unable to find text: '[UNK] 대정익찬회 [UNK] 라 불' in '‘대정익찬회’라 불리는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,914 >> Unable to find text: '##익찬회 [UNK]' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,914 >> Unable to find text: '신체제 운동 [UNK] 을 주창하며 , 군부의 힘으로 의회를 강제로 폐쇄하고 [UNK] 대정익찬회 [UNK]' in '‘신체제 운동’을 주창하며, 군부의 힘으로 의회를 강제로 폐쇄하고 ‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,914 >> Unable to find text: '##회 [UNK] 라 불리는 단일 정당을 통해 일당 독재' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당 독재'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,914 >> Unable to find text: '[UNK] 대정익찬회 [UNK] 라 불리는' in '‘대정익찬회’라 불리는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,914 >> Unable to find text: '[UNK] 대정익찬회 [UNK] 라 불리는 단일 정당을 통해 일당 독재 체제를 세웠다 .' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당 독재 체제를 세웠다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,914 >> Unable to find text: '##찬회 [UNK]' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,915 >> Unable to find text: '[UNK] 대정익찬회 [UNK] 라 불리는 단일 정당을 통해 일당 독재 체' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당 독재 체제를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,915 >> Unable to find text: '[UNK] 대정' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,915 >> Unable to find text: '[UNK] 신체제 운동 [UNK] 을 주창하며 , 군부의 힘으로 의회를 강제로 폐쇄하고 [UNK] 대정익찬회 [UNK]' in '‘신체제 운동’을 주창하며, 군부의 힘으로 의회를 강제로 폐쇄하고 ‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,915 >> Unable to find text: '##정익찬회 [UNK] 라' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,915 >> Unable to find text: '[UNK] 대정익찬회 [UNK] 라 불리는 단일' in '‘대정익찬회’라 불리는 단일'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,915 >> Unable to find text: '[UNK] 라' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,918 >> Unable to find text: '##년' in '1941년,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,918 >> Unable to find text: '##년 ,' in '1941년,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,921 >> Unable to find text: '##년 , 나치 독일' in '1941년, 나치 독일은'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,921 >> Unable to find text: '##년 , 나치' in '1941년, 나치'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,970 >> Unable to find text: '##년 , 나치 독일은 바르바로사 작전을 개시하여 소련을 침공했다 .' in '1941년, 나치 독일은 바르바로사 작전을 개시하여 소련을 침공했다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,971 >> Unable to find text: '##년 , 나치 독일은 바르바로사 작전을' in '1941년, 나치 독일은 바르바로사 작전을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,971 >> Unable to find text: '##년 , 나치 독일은 바르바로사 작전을 개시' in '1941년, 나치 독일은 바르바로사 작전을 개시하여'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,973 >> Unable to find text: '##에' in '미국에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,975 >> Unable to find text: '##키' in '히데키를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,975 >> Unable to find text: '##데키' in '히데키를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,976 >> Unable to find text: '##키를' in '히데키를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,977 >> Unable to find text: '##리를' in '시게노리를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,978 >> Unable to find text: '##고 시게노리를' in '도고 시게노리를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,978 >> Unable to find text: '##은 가야 오키노리를 대장대신으로 , 도고 시게노리를' in '내각은 가야 오키노리를 대장대신으로, 도고 시게노리를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,978 >> Unable to find text: '##노리를' in '시게노리를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,978 >> Unable to find text: '##게노리를' in '시게노리를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,981 >> Unable to find text: '##로' in '기치사부로'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,983 >> Unable to find text: '##미' in '오사미와'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,988 >> Unable to find text: '##빌 섬' in '부건빌 섬까지'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,988 >> Unable to find text: '##인 부건빌 섬' in '섬인 부건빌 섬까지'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,988 >> Unable to find text: '##건빌 섬' in '부건빌 섬까지'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,989 >> Unable to find text: '##빌' in '부건빌'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,989 >> Unable to find text: '##인 부건빌' in '섬인 부건빌'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,989 >> Unable to find text: '##도에서 가장 큰 섬인 부건빌 섬' in '제도에서 가장 큰 섬인 부건빌 섬까지'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,989 >> Unable to find text: '##건빌' in '부건빌'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,990 >> Unable to find text: '##빌 섬까지' in '부건빌 섬까지'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,990 >> Unable to find text: '##인 부건빌 섬까지' in '섬인 부건빌 섬까지'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,991 >> Unable to find text: '##명의' in '8,000명의'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,993 >> Unable to find text: '##대를' in '특공대를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,994 >> Unable to find text: '##리틀 특공대를' in '둘리틀 특공대를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,994 >> Unable to find text: '##틀 특공대를' in '둘리틀 특공대를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,994 >> Unable to find text: '##으로 둘리틀 특공대를' in '보복으로 둘리틀 특공대를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,995 >> Unable to find text: '##은 보복으로 둘리틀 특공대를' in '미국은 보복으로 둘리틀 특공대를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,995 >> Unable to find text: '##공대를' in '특공대를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,995 >> Unable to find text: '##리틀' in '둘리틀'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,995 >> Unable to find text: '##틀' in '둘리틀'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,995 >> Unable to find text: '##으로 둘리틀' in '보복으로 둘리틀'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,997 >> Unable to find text: '##명을' in '104명을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:51,997 >> Unable to find text: '##과 조종사 104명을' in '척과 조종사 104명을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,001 >> Unable to find text: '##양함 네 척' in '중순양함 네 척을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,002 >> Unable to find text: '##방' in '연방에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,003 >> Unable to find text: '##비에트 연방' in '소비에트 연방에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,004 >> Unable to find text: '##이 소비에트 연방' in '독일이 소비에트 연방에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,004 >> Unable to find text: '##트 연방' in '소비에트 연방에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,004 >> Unable to find text: '##에트 연방' in '소비에트 연방에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,004 >> Unable to find text: '##에서 나치 독일이 소비에트 연방' in '전투에서 나치 독일이 소비에트 연방에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,006 >> Unable to find text: '##날' in '과달카날에서'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,007 >> Unable to find text: '##달카날' in '과달카날에서'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,007 >> Unable to find text: '##날에서' in '과달카날에서'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,009 >> Unable to find text: '##메' in '하지메를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,010 >> Unable to find text: '##기야마 하지메' in '스기야마 하지메를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,010 >> Unable to find text: '##야마 하지메' in '스기야마 하지메를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,010 >> Unable to find text: '##어 스기야마 하지메' in '얻어 스기야마 하지메를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,011 >> Unable to find text: '##메를' in '하지메를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,013 >> Unable to find text: '##로' in '시게타로'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,013 >> Unable to find text: '##마다 시게타로' in '시마다 시게타로'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,014 >> Unable to find text: '##타로' in '시게타로'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,016 >> Unable to find text: '##대를' in '395대를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,017 >> Unable to find text: '##기 395대를' in '전투기 395대를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,022 >> Unable to find text: '##이소 구니아키' in '고이소 구니아키를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,022 >> Unable to find text: '##키' in '구니아키를'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,022 >> Unable to find text: '##사직' in '총사직했다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,022 >> Unable to find text: '##사' in '총사직했다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,023 >> Unable to find text: '##직' in '총사직했다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,023 >> Unable to find text: '##은 총사직' in '내각은 총사직했다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,024 >> Unable to find text: '##에 후미마로는' in '고노에 후미마로는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,026 >> Unable to find text: '##에 후미마로는 당시 미국이 폭격을 하지 않기로 했던 교토에 있던 다카마쓰노미야 고토히토' in '고노에 후미마로는 당시 미국이 폭격을 하지 않기로 했던 교토에 있던 다카마쓰노미야 고토히토'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,027 >> Unable to find text: '##닌' in '유닌(裕仁)을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,028 >> Unable to find text: '##닌 ( 裕 仁 )' in '유닌(裕仁)을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,033 >> Unable to find text: '[UNK] 결호 작전' in '‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,034 >> Unable to find text: '결호 작전 [UNK]' in '‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,034 >> Unable to find text: '결호 작전 [UNK] 을' in '‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,034 >> Unable to find text: '일억총옥쇄 [UNK] 의 일환으로 [UNK] 결호 작전' in '‘일억총옥쇄’의 일환으로 ‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,034 >> Unable to find text: '##전' in '작전’을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,034 >> Unable to find text: '결호 작전 [UNK] 을 시행' in '‘결호 작전’을 시행했다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,034 >> Unable to find text: '[UNK] 일억총옥쇄 [UNK] 의 일환으로 [UNK] 결호 작전' in '‘일억총옥쇄’의 일환으로 ‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,034 >> Unable to find text: '결호 작전 [UNK] 을 시행했다 .' in '‘결호 작전’을 시행했다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,035 >> Unable to find text: '##은 [UNK] 일억총옥쇄 [UNK] 의 일환으로 [UNK] 결호 작전' in '내각은 ‘일억총옥쇄’의 일환으로 ‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,035 >> Unable to find text: '[UNK] 결호' in '‘결호'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,035 >> Unable to find text: '스즈키 간타로 내각은 [UNK] 일억총옥쇄 [UNK] 의 일환으로 [UNK] 결호 작전' in '스즈키 간타로 내각은 ‘일억총옥쇄’의 일환으로 ‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:52,035 >> Unable to find text: '[UNK] 결호 작전 [UNK]' in '‘결호 작전’을'
# ...
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,874 >> Unable to find text: '통신 [UNK]' in '통신 모뎀'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,874 >> Unable to find text: '통신 [UNK] 솔루션이 모바일 AP' in '통신 모뎀 솔루션이 모바일 AP에'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,875 >> Unable to find text: '[UNK] 솔루션' in '모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,876 >> Unable to find text: '##ps' in 'Mbps,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,882 >> Unable to find text: '##0 mAh' in '3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,882 >> Unable to find text: '##0' in '3600'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,883 >> Unable to find text: '##h' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,883 >> Unable to find text: '##Ah' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,886 >> Unable to find text: '##술' in '기술까지'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,888 >> Unable to find text: '##h' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,888 >> Unable to find text: '##0 mAh' in '3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,888 >> Unable to find text: '##Ah' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,889 >> Unable to find text: '##장형 3600 mAh' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,889 >> Unable to find text: '##형 3600 mAh' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,889 >> Unable to find text: '##h이다 .' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,890 >> Unable to find text: '##0' in '3600'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,896 >> Unable to find text: '##h' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,896 >> Unable to find text: '##0 mAh' in '3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,896 >> Unable to find text: '##Ah' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,896 >> Unable to find text: '##장형 3600 mAh' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,897 >> Unable to find text: '##형 3600 mAh' in '내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,897 >> Unable to find text: '##h이다 .' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,897 >> Unable to find text: '##0' in '3600'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,899 >> Unable to find text: '##h' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,900 >> Unable to find text: '##0 mAh' in '3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,900 >> Unable to find text: '##Ah' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,903 >> Unable to find text: '##만' in '1,200만'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,904 >> Unable to find text: '##시' in '플래시''
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,904 >> Unable to find text: '##래시' in '플래시''
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,905 >> Unable to find text: '##시 ' 기능' in '플래시' 기능이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,906 >> Unable to find text: '##만' in '1,200만'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,906 >> Unable to find text: '##만 화소' in '1,200만 화소'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,907 >> Unable to find text: '[UNK]' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,907 >> Unable to find text: '' [UNK]' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,907 >> Unable to find text: '[UNK] '' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,907 >> Unable to find text: '[UNK] ' 도' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,907 >> Unable to find text: '일명 ' [UNK]' in '일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,907 >> Unable to find text: '' [UNK] '' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,907 >> Unable to find text: '돌출되는 일명 ' [UNK]' in '돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,908 >> Unable to find text: '[UNK] ' 도 대폭 개선' in ''카툭튀'도 대폭 개선되고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,908 >> Unable to find text: '카메라 모듈이 돌출되는 일명 ' [UNK]' in '카메라 모듈이 돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,908 >> Unable to find text: '##되는 일명 ' [UNK]' in '돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,908 >> Unable to find text: '##출되는 일명 ' [UNK]' in '돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,908 >> Unable to find text: '' [UNK] ' 도' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,908 >> Unable to find text: '[UNK] ' 도 대' in ''카툭튀'도 대폭'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,908 >> Unable to find text: '[UNK] ' 도 대폭' in ''카툭튀'도 대폭'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,908 >> Unable to find text: '##이 돌출되는 일명 ' [UNK]' in '모듈이 돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,908 >> Unable to find text: '[UNK] ' 도 대폭 개선되고 센서' in ''카툭튀'도 대폭 개선되고 센서'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,908 >> Unable to find text: '##듈이 돌출되는 일명 ' [UNK]' in '모듈이 돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,909 >> Unable to find text: '[UNK] ' 도 대폭 개선되고' in ''카툭튀'도 대폭 개선되고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,909 >> Unable to find text: '일명 ' [UNK] '' in '일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,909 >> Unable to find text: '[UNK] ' 도 대폭 개' in ''카툭튀'도 대폭 개선되고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,909 >> Unable to find text: '돌출되는 일명 ' [UNK] '' in '돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,909 >> Unable to find text: '' [UNK] ' 도 대폭 개선' in ''카툭튀'도 대폭 개선되고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,909 >> Unable to find text: '카메라 모듈이 돌출되는 일명 ' [UNK] '' in '카메라 모듈이 돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,909 >> Unable to find text: '##되는 일명 ' [UNK] '' in '돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,909 >> Unable to find text: '##출되는 일명 ' [UNK] '' in '돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,910 >> Unable to find text: '' [UNK] ' 도 대' in ''카툭튀'도 대폭'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,910 >> Unable to find text: '일명 ' [UNK] ' 도' in '일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,910 >> Unable to find text: '' [UNK] ' 도 대폭' in ''카툭튀'도 대폭'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,910 >> Unable to find text: '돌출되는 일명 ' [UNK] ' 도' in '돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,910 >> Unable to find text: '' [UNK] ' 도 대폭 개선되고 센서' in ''카툭튀'도 대폭 개선되고 센서'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,910 >> Unable to find text: '##이 돌출되는 일명 ' [UNK] '' in '모듈이 돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,910 >> Unable to find text: '' [UNK] ' 도 대폭 개선되고' in ''카툭튀'도 대폭 개선되고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,910 >> Unable to find text: '##듈이 돌출되는 일명 ' [UNK] '' in '모듈이 돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,910 >> Unable to find text: '' [UNK] ' 도 대폭 개' in ''카툭튀'도 대폭 개선되고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,911 >> Unable to find text: '카메라 모듈이 돌출되는 일명 ' [UNK] ' 도' in '카메라 모듈이 돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,911 >> Unable to find text: '일명 ' [UNK] ' 도 대폭 개선' in '일명 '카툭튀'도 대폭 개선되고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,911 >> Unable to find text: '##되는 일명 '' in '돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,911 >> Unable to find text: '##되는 일명 ' [UNK] ' 도' in '돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,911 >> Unable to find text: '##출되는 일명 '' in '돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,911 >> Unable to find text: '##출되는 일명 ' [UNK] ' 도' in '돌출되는 일명 '카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,911 >> Unable to find text: '돌출되는 일명 ' [UNK] ' 도 대폭 개선' in '돌출되는 일명 '카툭튀'도 대폭 개선되고'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,914 >> Unable to find text: '##IS 기술' in 'OIS 기술이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,914 >> Unable to find text: '##술' in '기술이'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,914 >> Unable to find text: '##IS' in 'OIS'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,916 >> Unable to find text: '##만 화소' in '1,200만 화소'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,916 >> Unable to find text: '##소' in '화소'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,916 >> Unable to find text: '##만' in '1,200만'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,917 >> Unable to find text: '##시' in '플래시''
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,918 >> Unable to find text: '##피 플래시' in ''셀피 플래시''
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,918 >> Unable to find text: '##래시' in '플래시''
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,920 >> Unable to find text: '##8' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,921 >> Unable to find text: '##68' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,921 >> Unable to find text: '##8로 ,' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,922 >> Unable to find text: '##8로 , 이는' in 'IP68로, 이는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,922 >> Unable to find text: '##68로 ,' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,922 >> Unable to find text: '##진' in '방진을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,923 >> Unable to find text: '##되었던 방수 방진' in '삭제되었던 방수 방진을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,926 >> Unable to find text: '##8' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,926 >> Unable to find text: '##68' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,927 >> Unable to find text: '##8로 ,' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,927 >> Unable to find text: '##8로 , 이는' in 'IP68로, 이는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,927 >> Unable to find text: '##68로 ,' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,928 >> Unable to find text: '##서' in '센서가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,930 >> Unable to find text: '##진' in '방진을'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,931 >> Unable to find text: '##8' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,931 >> Unable to find text: '##68' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,932 >> Unable to find text: '##8로 ,' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,934 >> Unable to find text: '##지가' in '엣지가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,935 >> Unable to find text: '##월' in '6개월'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,935 >> Unable to find text: '##개월' in '6개월'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,935 >> Unable to find text: '##월 정도' in '6개월 정도가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,936 >> Unable to find text: '##개월 정도' in '6개월 정도가'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,938 >> Unable to find text: '##자' in '삼성전자'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,939 >> Unable to find text: '##전자' in '삼성전자'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,939 >> Unable to find text: '##자 측' in '삼성전자 측에서는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,939 >> Unable to find text: '##전자 측' in '삼성전자 측에서는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,940 >> Unable to find text: '##자 측에서는' in '삼성전자 측에서는'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,941 >> Unable to find text: '##동' in '중동'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,941 >> Unable to find text: '##동 지역' in '중동 지역에서'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,943 >> Unable to find text: '##은 겨우 출시 18일' in '7은 겨우 출시 18일만이며'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,944 >> Unable to find text: '##만' in '18일만이며'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,945 >> Unable to find text: '##동' in '중동'
# [INFO|squad_metrics.py:305] 2023-03-16 00:29:55,966 >> Unable to find text: '##동 지역' in '중동 지역에서'
# 03/16/2023 00:29:57 - INFO - __main__ - Results: {'exact_1000': 65.13682022861101, 'f1_1000': 72.87108928865057, 'total_1000': 5774, 'HasAns_exact_1000': 65.13682022861101, 'HasAns_f1_1000': 72.87108928865057, 'HasAns_total_1000': 5774, 'best_exact_1000': 65.13682022861101, 'best_exact_thresh_1000': 0.0, 'best_f1_1000': 72.87108928865057, 'best_f1_thresh_1000': 0.0, 'exact_10000': 69.27606511950121, 'f1_10000': 76.75878349414889, 'total_10000': 5774, 'HasAns_exact_10000': 69.27606511950121, 'HasAns_f1_10000': 76.75878349414889, 'HasAns_total_10000': 5774, 'best_exact_10000': 69.27606511950121, 'best_exact_thresh_10000': 0.0, 'best_f1_10000': 76.75878349414889, 'best_f1_thresh_10000': 0.0, 'exact_11000': 69.62244544509872, 'f1_11000': 76.97136754635889, 'total_11000': 5774, 'HasAns_exact_11000': 69.62244544509872, 'HasAns_f1_11000': 76.97136754635889, 'HasAns_total_11000': 5774, 'best_exact_11000': 69.62244544509872, 'best_exact_thresh_11000': 0.0, 'best_f1_11000': 76.97136754635889, 'best_f1_thresh_11000': 0.0, 'exact_12000': 69.44925528229996, 'f1_12000': 76.97014190646905, 'total_12000': 5774, 'HasAns_exact_12000': 69.44925528229996, 'HasAns_f1_12000': 76.97014190646905, 'HasAns_total_12000': 5774, 'best_exact_12000': 69.44925528229996, 'best_exact_thresh_12000': 0.0, 'best_f1_12000': 76.97014190646905, 'best_f1_thresh_12000': 0.0, 'exact_2000': 65.44856252164877, 'f1_2000': 73.76257733722217, 'total_2000': 5774, 'HasAns_exact_2000': 65.44856252164877, 'HasAns_f1_2000': 73.76257733722217, 'HasAns_total_2000': 5774, 'best_exact_2000': 65.44856252164877, 'best_exact_thresh_2000': 0.0, 'best_f1_2000': 73.76257733722217, 'best_f1_thresh_2000': 0.0, 'exact_3000': 66.33183235192242, 'f1_3000': 74.3127569617004, 'total_3000': 5774, 'HasAns_exact_3000': 66.33183235192242, 'HasAns_f1_3000': 74.3127569617004, 'HasAns_total_3000': 5774, 'best_exact_3000': 66.33183235192242, 'best_exact_thresh_3000': 0.0, 'best_f1_3000': 74.3127569617004, 'best_f1_thresh_3000': 0.0, 'exact_4000': 66.98995497055768, 'f1_4000': 75.04107186736206, 'total_4000': 5774, 'HasAns_exact_4000': 66.98995497055768, 'HasAns_f1_4000': 75.04107186736206, 'HasAns_total_4000': 5774, 'best_exact_4000': 66.98995497055768, 'best_exact_thresh_4000': 0.0, 'best_f1_4000': 75.04107186736206, 'best_f1_thresh_4000': 0.0, 'exact_5000': 67.73467267059232, 'f1_5000': 75.47844508183951, 'total_5000': 5774, 'HasAns_exact_5000': 67.73467267059232, 'HasAns_f1_5000': 75.47844508183951, 'HasAns_total_5000': 5774, 'best_exact_5000': 67.73467267059232, 'best_exact_thresh_5000': 0.0, 'best_f1_5000': 75.47844508183951, 'best_f1_thresh_5000': 0.0, 'exact_6000': 68.5140284031867, 'f1_6000': 76.12680049812025, 'total_6000': 5774, 'HasAns_exact_6000': 68.5140284031867, 'HasAns_f1_6000': 76.12680049812025, 'HasAns_total_6000': 5774, 'best_exact_6000': 68.5140284031867, 'best_exact_thresh_6000': 0.0, 'best_f1_6000': 76.12680049812025, 'best_f1_thresh_6000': 0.0, 'exact_7000': 68.5833044683062, 'f1_7000': 75.93183929952204, 'total_7000': 5774, 'HasAns_exact_7000': 68.5833044683062, 'HasAns_f1_7000': 75.93183929952204, 'HasAns_total_7000': 5774, 'best_exact_7000': 68.5833044683062, 'best_exact_thresh_7000': 0.0, 'best_f1_7000': 75.93183929952204, 'best_f1_thresh_7000': 0.0, 'exact_8000': 68.99896085902321, 'f1_8000': 76.4270626229407, 'total_8000': 5774, 'HasAns_exact_8000': 68.99896085902321, 'HasAns_f1_8000': 76.4270626229407, 'HasAns_total_8000': 5774, 'best_exact_8000': 68.99896085902321, 'best_exact_thresh_8000': 0.0, 'best_f1_8000': 76.4270626229407, 'best_f1_thresh_8000': 0.0, 'exact_9000': 68.84308971250432, 'f1_9000': 76.41277842351614, 'total_9000': 5774, 'HasAns_exact_9000': 68.84308971250432, 'HasAns_f1_9000': 76.41277842351614, 'HasAns_total_9000': 5774, 'best_exact_9000': 68.84308971250432, 'best_exact_thresh_9000': 0.0, 'best_f1_9000': 76.41277842351614, 'best_f1_thresh_9000': 0.0, 'exact_korquad': 69.58780741253896, 'f1_korquad': 77.0656913036546, 'total_korquad': 5774, 'HasAns_exact ...

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## 경로 변경

# %%
import os
os.chdir('/content/drive/MyDrive/korquad/')
os.getcwd()
# Out:
# '/content/drive/MyDrive/korquad'

# %%
from __future__ import print_function
from collections import Counter
import string
import re
import argparse
import json
import sys
import os

import pandas as pd
from transformers import AutoTokenizer

'''KorQuAD v1.0에 대한 공식 평가 스크립트 '''
'''본 스크립트는 SQuAD v1.1 평가 스크립트 https://rajpurkar.github.io/SQuAD-explorer/ 를 바탕으로 작성됨.'''

def normalize_answer(s):    
    def remove_(text):
        ''' 불필요한 기호 제거 '''
        text = re.sub("'", " ", text)
        text = re.sub('"', " ", text)
        text = re.sub('《', " ", text)
        text = re.sub('》', " ", text)
        text = re.sub('<', " ", text)
        text = re.sub('>', " ", text) 
        text = re.sub('〈', " ", text)
        text = re.sub('〉', " ", text)   
        text = re.sub("\(", " ", text)
        text = re.sub("\)", " ", text)
        text = re.sub("‘", " ", text)
        text = re.sub("’", " ", text)      
        return text

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return ''.join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_punc(lower(remove_(s))))


def f1_score(prediction, ground_truth):
    prediction_tokens = normalize_answer(prediction).split()
    ground_truth_tokens = normalize_answer(ground_truth).split()
   
    #F1 by character
    prediction_Char = []
    for tok in prediction_tokens:
        now = [a for a in tok]
        prediction_Char.extend(now)
        
    ground_truth_Char = []
    for tok in ground_truth_tokens:
        now = [a for a in tok]
        ground_truth_Char.extend(now)   
        
    common = Counter(prediction_Char) & Counter(ground_truth_Char)
    num_same = sum(common.values())
    if num_same == 0:
        return 0
    
    precision = 1.0 * num_same / len(prediction_Char)
    recall = 1.0 * num_same / len(ground_truth_Char)
    f1 = (2 * precision * recall) / (precision + recall)
    
    return f1


def exact_match_score(prediction, ground_truth):
    return (normalize_answer(prediction) == normalize_answer(ground_truth))


def metric_max_over_ground_truths(metric_fn, prediction, ground_truths):
    scores_for_ground_truths = []
    for ground_truth in ground_truths:
        score = metric_fn(prediction, ground_truth)
        scores_for_ground_truths.append(score)
    return max(scores_for_ground_truths)


def evaluate(dataset, predictions):
    f1 = exact_match = total = 0
    for article in dataset:
        for paragraph in article['paragraphs']:
            for qa in paragraph['qas']:
                total += 1
                if qa['id'] not in predictions:
                    message = 'Unanswered question ' + qa['id'] + \
                              ' will receive score 0.'
                    print(message, file=sys.stderr)
                    continue
                ground_truths = list(map(lambda x: x['text'], qa['answers']))
                prediction = predictions[qa['id']]
                exact_match += metric_max_over_ground_truths(
                    exact_match_score, prediction, ground_truths)
                f1 += metric_max_over_ground_truths(
                    f1_score, prediction, ground_truths)

    exact_match = 100.0 * exact_match / total
    f1 = 100.0 * f1 / total
    return {'exact_match': exact_match, 'f1': f1}


def evaluate_result(dataset_file, prediction_file):
    
    with open(dataset_file, encoding="utf-8") as f:
        dataset_json = json.load(f)
        dataset = dataset_json['data']
    with open(prediction_file, encoding="utf-8") as f:
        predictions = json.load(f)
    return evaluate(dataset, predictions)

# %% [markdown]
# ## 성능 확인

# %%
dataset_file = './data/KorQuAD_v1.0_dev.json'
prediction_file = './multilingual_distilkobert-KorQuAD/predictions_KorQuAD.json'
evaluate_result(dataset_file, prediction_file)
# Out:
# {'exact_match': 12.825278810408921, 'f1': 41.678862837522175}
