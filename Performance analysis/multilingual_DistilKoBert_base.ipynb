# %%
# !pip3 install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.1-py3-none-any.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 34.3 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.2-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.25.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 45.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (4.0.0)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.2 tokenizers-0.13.2 transformers-4.27.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/korquad/')
os.getcwd()
# Out:
# '/content/drive/MyDrive/korquad'

# %%
# !python ./run_QA.py \
    --model_type distilbert \
    --model_name_or_path distilbert-base-multilingual-cased\
    --output_dir multilingual_distilkobert-KorQuAD \
    --data_dir data \
    --data_name KorQuAD \
    --train_file KorQuAD_v1.0_train.json \
    --predict_file KorQuAD_v1.0_dev.json \
    --max_seq_length 512 \
    --doc_stride 128 \
    --max_query_length 64 \
    --do_train \
    --do_eval \
    --evaluate_during_training \
    --per_gpu_train_batch_size=16 \
    --per_gpu_eval_batch_size=8 \
    --learning_rate 5e-5 \
    --gradient_accumulation_steps 1 \
    --weight_decay 0.0 \
    --adam_epsilon 1e-8 \
    --max_grad_norm 1.0 \
    --num_train_epochs 3 \
    --max_steps -1 \
    --warmup_steps 0 \
    --n_best_size 20 \
    --max_answer_length 30 \
    --verbose_logging \
    --logging_steps 1000 \
    --save_steps 1000 \
    --eval_all_checkpoints \
    --overwrite_output_dir \
    --seed 42 \
    --local_rank -1 \
    --threads 4
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,766 >> Unable to find text: '##본' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,766 >> Unable to find text: '##영정부연락' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,766 >> Unable to find text: '##본영정부연락회의 [UNK] 가 조직' in '‘대본영정부연락회의’가 조직됐다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,766 >> Unable to find text: '##본영정부연락회의 [UNK] 가 조직됐다 . 육해군의' in '‘대본영정부연락회의’가 조직됐다. 육해군의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,766 >> Unable to find text: '##부' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,766 >> Unable to find text: '##정부' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,766 >> Unable to find text: '##본영정부연' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,766 >> Unable to find text: '##락회의 [UNK] 가 조직' in '‘대본영정부연락회의’가 조직됐다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,766 >> Unable to find text: '##락회의 [UNK] 가 조직됐다 . 육해군의' in '‘대본영정부연락회의’가 조직됐다. 육해군의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,766 >> Unable to find text: '##부연락' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,767 >> Unable to find text: '##정부연락' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,767 >> Unable to find text: '대본영을 궁중에 다시 설치하도록 명령했다 . 11월 19일에는 내각과 군을 이어주는 [UNK] 대본영정' in '대본영을 궁중에 다시 설치하도록 명령했다. 11월 19일에는 내각과 군을 이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,767 >> Unable to find text: '대본영을 궁중에 다시 설치하도록 명령했다 . 11월 19일에는 내각과 군을 이어주는 [UNK]' in '대본영을 궁중에 다시 설치하도록 명령했다. 11월 19일에는 내각과 군을 이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,767 >> Unable to find text: '##연락회의 [UNK] 가 조직' in '‘대본영정부연락회의’가 조직됐다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,767 >> Unable to find text: '##연락회의 [UNK] 가 조직됐다 . 육해군의' in '‘대본영정부연락회의’가 조직됐다. 육해군의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,767 >> Unable to find text: '##영정' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,768 >> Unable to find text: '대본영을 궁중에 다시 설치하도록 명령했다 . 11월 19일에는 내각과 군을 이어주는 [UNK] 대본' in '대본영을 궁중에 다시 설치하도록 명령했다. 11월 19일에는 내각과 군을 이어주는 ‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,768 >> Unable to find text: '일본 정부는 이러한 중국 침략 행위를 [UNK] 사변 [UNK] 을 해결하는 것이라 부르거나 , 성전' in '일본 정부는 이러한 중국 침략 행위를 ‘사변’을 해결하는 것이라 부르거나, 성전(聖戰,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,768 >> Unable to find text: '##연' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,768 >> Unable to find text: '[UNK] 가 조직' in '‘대본영정부연락회의’가 조직됐다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,768 >> Unable to find text: '[UNK] 가 조직됐다 . 육해군의' in '‘대본영정부연락회의’가 조직됐다. 육해군의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,768 >> Unable to find text: '##영정부연락회의 [UNK] 가 조직' in '‘대본영정부연락회의’가 조직됐다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,768 >> Unable to find text: '##영정부연락회의 [UNK] 가 조직됐다 . 육해군의' in '‘대본영정부연락회의’가 조직됐다. 육해군의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,768 >> Unable to find text: '##정' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,768 >> Unable to find text: '##영정부연' in '‘대본영정부연락회의’가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,769 >> Unable to find text: '사변 [UNK] 을 해결하는 것이라 부르거나 , 성전' in '‘사변’을 해결하는 것이라 부르거나, 성전(聖戰,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,770 >> Unable to find text: '[UNK] 사변 [UNK] 을 해결하는 것이라 부르거나 , 성전' in '‘사변’을 해결하는 것이라 부르거나, 성전(聖戰,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,770 >> Unable to find text: '사변 [UNK] 을 해결하는 것이라 부르거나 , 성전 ( 聖 戰 , 성스러운 전쟁 )' in '‘사변’을 해결하는 것이라 부르거나, 성전(聖戰, 성스러운 전쟁)으로'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,770 >> Unable to find text: '##전' in '성전(聖戰,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,770 >> Unable to find text: '사변 [UNK] 을 해결하는 것이라 부르거나 , 성전 ( 聖 戰 , 성스러운 전쟁' in '‘사변’을 해결하는 것이라 부르거나, 성전(聖戰, 성스러운 전쟁)으로'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,770 >> Unable to find text: '[UNK] 사변' in '‘사변’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,770 >> Unable to find text: '사변 [UNK] 을 해결하는 것이라 부르거나 , 성' in '‘사변’을 해결하는 것이라 부르거나, 성전(聖戰,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,770 >> Unable to find text: '사변 [UNK] 을 해결' in '‘사변’을 해결하는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,771 >> Unable to find text: '##변 [UNK] 을 해결하는 것이라 부르거나 , 성전' in '‘사변’을 해결하는 것이라 부르거나, 성전(聖戰,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,771 >> Unable to find text: '사변 [UNK] 을 해결하는 것이라 부르거나 , 성전 ( 聖 戰 , 성스러운 전쟁 ) 으로 미화' in '‘사변’을 해결하는 것이라 부르거나, 성전(聖戰, 성스러운 전쟁)으로 미화했다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,771 >> Unable to find text: '사변 [UNK]' in '‘사변’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,771 >> Unable to find text: '사변 [UNK] 을 해결하는 것이라 부르거나 , 성전 ( 聖 戰 , 성스러운 전쟁 ) 으로' in '‘사변’을 해결하는 것이라 부르거나, 성전(聖戰, 성스러운 전쟁)으로'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,771 >> Unable to find text: '사변 [UNK] 을 해결하는 것이라' in '‘사변’을 해결하는 것이라'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,771 >> Unable to find text: '사변 [UNK] 을 해결하는 것이' in '‘사변’을 해결하는 것이라'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,771 >> Unable to find text: '사변 [UNK] 을' in '‘사변’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,771 >> Unable to find text: '##변' in '‘사변’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,772 >> Unable to find text: '사변 [UNK] 을 해결하는 것이라 부르거나 , 성전 ( 聖 戰 , 성스러운 전쟁 ) 으로 미화했다 .' in '‘사변’을 해결하는 것이라 부르거나, 성전(聖戰, 성스러운 전쟁)으로 미화했다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,772 >> Unable to find text: '[UNK] 사변 [UNK] 을 해결하는 것이라 부르거나 , 성전 ( 聖 戰 , 성스러운 전쟁 )' in '‘사변’을 해결하는 것이라 부르거나, 성전(聖戰, 성스러운 전쟁)으로'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,774 >> Unable to find text: '##문' in '신문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,774 >> Unable to find text: '##니치니치 신문' in '도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,774 >> Unable to find text: '##치니치 신문' in '도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,774 >> Unable to find text: '##니치 신문' in '도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,775 >> Unable to find text: '##치 신문' in '도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,775 >> Unable to find text: '##니치니치' in '도쿄니치니치'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,775 >> Unable to find text: '##치니치' in '도쿄니치니치'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,775 >> Unable to find text: '##니치' in '도쿄니치니치'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,775 >> Unable to find text: '일본 육군 소위 두 명이 저지른 [UNK] 중국인 100명 목 베기 시합 [UNK] 은 도쿄니치니치 신문' in '일본 육군 소위 두 명이 저지른 ‘중국인 100명 목 베기 시합’은 도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,775 >> Unable to find text: '[UNK] 중국인 100명 목 베기 시합 [UNK] 은 도쿄니치니치 신문' in '‘중국인 100명 목 베기 시합’은 도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,775 >> Unable to find text: '##치' in '도쿄니치니치'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,775 >> Unable to find text: '##문에' in '신문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,776 >> Unable to find text: '##니치니치 신문에' in '도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,776 >> Unable to find text: '중국인 100명 목 베기 시합 [UNK] 은 도쿄니치니치 신문' in '‘중국인 100명 목 베기 시합’은 도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,776 >> Unable to find text: '[UNK] 은 도쿄니치니치 신문' in '시합’은 도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,776 >> Unable to find text: '##치니치 신문에' in '도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,776 >> Unable to find text: '##에' in '신문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,776 >> Unable to find text: '##니치 신문에' in '도쿄니치니치 신문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,776 >> Unable to find text: '일본 육군 소위 두 명이 저지른 [UNK] 중국인 100명 목 베기 시합 [UNK] 은 도쿄니치니치' in '일본 육군 소위 두 명이 저지른 ‘중국인 100명 목 베기 시합’은 도쿄니치니치'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,777 >> Unable to find text: '##루' in '마모루는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,777 >> Unable to find text: '##게미쓰 마모루' in '시게미쓰 마모루는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,777 >> Unable to find text: '##미쓰 마모루' in '시게미쓰 마모루는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,777 >> Unable to find text: '##모루' in '마모루는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,777 >> Unable to find text: '##쓰 마모루' in '시게미쓰 마모루는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,778 >> Unable to find text: '##루는' in '마모루는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,778 >> Unable to find text: '##게미쓰 마모루는' in '시게미쓰 마모루는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,778 >> Unable to find text: '##미쓰 마모루는' in '시게미쓰 마모루는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,778 >> Unable to find text: '##모루는' in '마모루는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,778 >> Unable to find text: '##게미쓰' in '시게미쓰'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,865 >> Unable to find text: '##는' in '마모루는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,865 >> Unable to find text: '##쓰 마모루는' in '시게미쓰 마모루는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,865 >> Unable to find text: '##미쓰' in '시게미쓰'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,865 >> Unable to find text: '##쓰' in '시게미쓰'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,867 >> Unable to find text: '##버트 빅스는' in '허버트 빅스는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,867 >> Unable to find text: '##스는' in '빅스는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,867 >> Unable to find text: '##트 빅스는' in '허버트 빅스는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,868 >> Unable to find text: '##버트' in '허버트'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,868 >> Unable to find text: '##루' in '마모루는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,868 >> Unable to find text: '##게미쓰 마모루' in '시게미쓰 마모루는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,868 >> Unable to find text: '##트' in '허버트'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,868 >> Unable to find text: '##버트 빅스는 당시' in '허버트 빅스는 당시'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,868 >> Unable to find text: '##스는 당시' in '빅스는 당시'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,868 >> Unable to find text: '##버트 빅' in '허버트 빅스는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,869 >> Unable to find text: '##트 빅스는 당시' in '허버트 빅스는 당시'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,870 >> Unable to find text: '##년' in '1940년'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,872 >> Unable to find text: '##년 8월 10일에는' in '1940년 8월 10일에는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,872 >> Unable to find text: '##년 8월 10일' in '1940년 8월 10일에는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,873 >> Unable to find text: '##년 8월' in '1940년 8월'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,873 >> Unable to find text: '##년 8월 10일에는 조선총독부 점령 지역의 조선일보 , 동아일보' in '1940년 8월 10일에는 조선총독부 점령 지역의 조선일보, 동아일보를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,873 >> Unable to find text: '##에는' in '10일에는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,873 >> Unable to find text: '##년 8월 10일에는 조선총독부 점령 지역의 조선일보' in '1940년 8월 10일에는 조선총독부 점령 지역의 조선일보,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,873 >> Unable to find text: '##년 8월 10일에는 조선총독부 점령 지역의 조선일보 , 동아일보를 모두 폐간' in '1940년 8월 10일에는 조선총독부 점령 지역의 조선일보, 동아일보를 모두 폐간했다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,873 >> Unable to find text: '##년 8월 10일에는 조선총독부 점령 지역의' in '1940년 8월 10일에는 조선총독부 점령 지역의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,873 >> Unable to find text: '##년 8월 10일에는 조선총독부 점령 지역의 조선일보 , 동아일보를 모두 폐간했다 .' in '1940년 8월 10일에는 조선총독부 점령 지역의 조선일보, 동아일보를 모두 폐간했다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,874 >> Unable to find text: '##년 8월 10일에는 조선총독부 점령 지역의 조선일보 , 동아일보를 모두' in '1940년 8월 10일에는 조선총독부 점령 지역의 조선일보, 동아일보를 모두'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,875 >> Unable to find text: '##륙명 제458호' in '《대륙명 제458호》를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,878 >> Unable to find text: '삼국은 과감히 맞서 싸우겠다 [UNK] 는 내용을 담은 성명을 발표했다 . 일본의' in '삼국은 과감히 맞서 싸우겠다”는 내용을 담은 성명을 발표했다. 일본의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,878 >> Unable to find text: '##군의' in '중국군의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,880 >> Unable to find text: '대정익찬회 [UNK] 라 불리는 단일 정당을 통해 일당' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,880 >> Unable to find text: '대정익찬회 [UNK] 라 불리는 단일 정당' in '‘대정익찬회’라 불리는 단일 정당을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,880 >> Unable to find text: '대정익찬회 [UNK] 라 불리는 단일 정당을 통해 일당 독재 체제를' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당 독재 체제를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,880 >> Unable to find text: '대정익찬회 [UNK] 라 불리는 단일 정당을 통해 일당 독재' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당 독재'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,880 >> Unable to find text: '[UNK] 대정익찬회' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,881 >> Unable to find text: '##회' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,881 >> Unable to find text: '신체제 운동 [UNK] 을 주창하며 , 군부의 힘으로 의회를 강제로 폐쇄하고 [UNK] 대정익찬회' in '‘신체제 운동’을 주창하며, 군부의 힘으로 의회를 강제로 폐쇄하고 ‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,881 >> Unable to find text: '대정익찬회 [UNK] 라 불리는 단일' in '‘대정익찬회’라 불리는 단일'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,881 >> Unable to find text: '대정익찬회 [UNK]' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,881 >> Unable to find text: '##찬회' in '‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,881 >> Unable to find text: '대정익찬회 [UNK] 라 불리는' in '‘대정익찬회’라 불리는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,881 >> Unable to find text: '대정익찬회 [UNK] 라 불리는 단일 정당을' in '‘대정익찬회’라 불리는 단일 정당을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,882 >> Unable to find text: '대정익찬회 [UNK] 라 불리는 단일 정당을 통해 일' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,882 >> Unable to find text: '대정익찬회 [UNK] 라 불리는 단일 정당을 통해 일당 독재 체제를 세웠다 .' in '‘대정익찬회’라 불리는 단일 정당을 통해 일당 독재 체제를 세웠다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,882 >> Unable to find text: '대정익찬회 [UNK] 라 불리는 단일 정당을 통해' in '‘대정익찬회’라 불리는 단일 정당을 통해'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,882 >> Unable to find text: '[UNK] 신체제 운동 [UNK] 을 주창하며 , 군부의 힘으로 의회를 강제로 폐쇄하고 [UNK] 대정익찬회' in '‘신체제 운동’을 주창하며, 군부의 힘으로 의회를 강제로 폐쇄하고 ‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,882 >> Unable to find text: '군부의 힘으로 의회를 강제로 폐쇄하고 [UNK] 대정익찬회' in '군부의 힘으로 의회를 강제로 폐쇄하고 ‘대정익찬회’라'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,884 >> Unable to find text: '##년' in '1941년,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,884 >> Unable to find text: '##년 ,' in '1941년,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,885 >> Unable to find text: '##년 , 나치' in '1941년, 나치'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,885 >> Unable to find text: '##년 , 나치 독일은 바르바로사 작전을 개시하여 소련' in '1941년, 나치 독일은 바르바로사 작전을 개시하여 소련을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,886 >> Unable to find text: '##년 , 나치 독일' in '1941년, 나치 독일은'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,886 >> Unable to find text: '##년 , 나치 독일은' in '1941년, 나치 독일은'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,886 >> Unable to find text: '##년 , 나치 독일은 바' in '1941년, 나치 독일은 바르바로사'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,886 >> Unable to find text: '##년 , 나' in '1941년, 나치'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,886 >> Unable to find text: '##년 , 나치 독일은 바르바로사 작전을 개시하여 소련을 침공' in '1941년, 나치 독일은 바르바로사 작전을 개시하여 소련을 침공했다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,886 >> Unable to find text: '##년 , 나치 독일은 바르바로사' in '1941년, 나치 독일은 바르바로사'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,886 >> Unable to find text: '##년 , 나치 독일은 바르바로사 작전을' in '1941년, 나치 독일은 바르바로사 작전을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,886 >> Unable to find text: '##년 , 나치 독일은 바르바로사 작전을 개시' in '1941년, 나치 독일은 바르바로사 작전을 개시하여'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,888 >> Unable to find text: '##린의 대일본 수출 금지 조치를 내렸다 . 일본은 당시 석유 수입량의 약 80 % 를 미국' in '가솔린의 대일본 수출 금지 조치를 내렸다. 일본은 당시 석유 수입량의 약 80%를 미국에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,889 >> Unable to find text: '##린의 대일본 수출 금지 조치를 내렸다 . 일본은 당시 석유 수입량의 약 80 % 를 미국에' in '가솔린의 대일본 수출 금지 조치를 내렸다. 일본은 당시 석유 수입량의 약 80%를 미국에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,892 >> Unable to find text: '##키' in '히데키를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,892 >> Unable to find text: '##데키' in '히데키를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,893 >> Unable to find text: '##리를' in '시게노리를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,893 >> Unable to find text: '##노리를' in '시게노리를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,893 >> Unable to find text: '##게노리를' in '시게노리를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,894 >> Unable to find text: '##고 시게노리를' in '도고 시게노리를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,894 >> Unable to find text: '##리를 대장대신으로 , 도고 시게노리를' in '오키노리를 대장대신으로, 도고 시게노리를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,897 >> Unable to find text: '##미' in '오사미와'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,897 >> Unable to find text: '##노 오사미' in '나가노 오사미와'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,897 >> Unable to find text: '##가노 오사미' in '나가노 오사미와'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,897 >> Unable to find text: '##사미' in '오사미와'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,898 >> Unable to find text: '##령' in '포르투갈령'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,900 >> Unable to find text: '##빌 섬' in '부건빌 섬까지'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,900 >> Unable to find text: '##건빌 섬' in '부건빌 섬까지'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,900 >> Unable to find text: '##빌' in '부건빌'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,900 >> Unable to find text: '##건빌' in '부건빌'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,901 >> Unable to find text: '##빌 섬까지' in '부건빌 섬까지'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,902 >> Unable to find text: '##명의' in '8,000명의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,903 >> Unable to find text: '##만 8 , 000명의' in '7만 8,000명의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,904 >> Unable to find text: '##틀 특공대를' in '둘리틀 특공대를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,904 >> Unable to find text: '##대를' in '특공대를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,904 >> Unable to find text: '##공대를' in '특공대를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,905 >> Unable to find text: '##틀' in '둘리틀'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,906 >> Unable to find text: '##명을' in '104명을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,906 >> Unable to find text: '##명을' in '121명을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,906 >> Unable to find text: '##명을 비롯한 3000명의' in '121명을 비롯한 3000명의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,907 >> Unable to find text: '##명의' in '3000명의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,909 >> Unable to find text: '##방' in '연방에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,910 >> Unable to find text: '##방에 대패' in '연방에 대패하면서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,910 >> Unable to find text: '[UNK] 열도의' in '알류샨 열도의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,911 >> Unable to find text: '##날' in '과달카날에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,911 >> Unable to find text: '##달카날' in '과달카날에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,911 >> Unable to find text: '##카날' in '과달카날에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,911 >> Unable to find text: '##달카' in '과달카날에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,912 >> Unable to find text: '##날에서' in '과달카날에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,912 >> Unable to find text: '##카' in '과달카날에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,912 >> Unable to find text: '##달카날에서' in '과달카날에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,912 >> Unable to find text: '##카날에서' in '과달카날에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,912 >> Unable to find text: '##에서' in '과달카날에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,912 >> Unable to find text: '##날에서 일본군의 철수를 명령했다 . 일본군은 솔로몬 제도에서도' in '과달카날에서 일본군의 철수를 명령했다. 일본군은 솔로몬 제도에서도'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,912 >> Unable to find text: '##달' in '과달카날에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,912 >> Unable to find text: '##달카날에서 일본군의 철수를 명령했다 . 일본군은 솔로몬 제도에서도' in '과달카날에서 일본군의 철수를 명령했다. 일본군은 솔로몬 제도에서도'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,912 >> Unable to find text: '##날에서 일본군의 철수를 명령했다 . 일본군은 솔로몬' in '과달카날에서 일본군의 철수를 명령했다. 일본군은 솔로몬'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,913 >> Unable to find text: '##카날에서 일본군의 철수를 명령했다 . 일본군은 솔로몬 제도에서도' in '과달카날에서 일본군의 철수를 명령했다. 일본군은 솔로몬 제도에서도'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,913 >> Unable to find text: '##에서 일본군의 철수를 명령했다 . 일본군은 솔로몬 제도에서도' in '과달카날에서 일본군의 철수를 명령했다. 일본군은 솔로몬 제도에서도'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,913 >> Unable to find text: '##날에서 일본군의' in '과달카날에서 일본군의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,913 >> Unable to find text: '[UNK] 열도의 애투 섬' in '알류샨 열도의 애투 섬의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,913 >> Unable to find text: '##날에서 일본군의 철수를 명령했다 . 일본군은 솔로몬 제도에서도 연합군의' in '과달카날에서 일본군의 철수를 명령했다. 일본군은 솔로몬 제도에서도 연합군의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,913 >> Unable to find text: '##달카날에서 일본군의 철수를 명령했다 . 일본군은 솔로몬' in '과달카날에서 일본군의 철수를 명령했다. 일본군은 솔로몬'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,915 >> Unable to find text: '##메' in '하지메를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,916 >> Unable to find text: '##로' in '시게타로'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,917 >> Unable to find text: '##로 해군대신' in '시게타로 해군대신은'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,917 >> Unable to find text: '##타로' in '시게타로'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,964 >> Unable to find text: '##게타로' in '시게타로'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,966 >> Unable to find text: '##대를' in '395대를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,967 >> Unable to find text: '##척과 전투기 395대를' in '3척과 전투기 395대를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,968 >> Unable to find text: '##키' in '구니아키를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,968 >> Unable to find text: '##니아키' in '구니아키를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,968 >> Unable to find text: '##이소 구니아키' in '고이소 구니아키를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,969 >> Unable to find text: '##소 구니아키' in '고이소 구니아키를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,969 >> Unable to find text: '##황' in '천황은'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,969 >> Unable to find text: '##키를' in '구니아키를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,969 >> Unable to find text: '##니아키를' in '구니아키를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,971 >> Unable to find text: '교토 닌나지 ( 仁 和 寺 ) 에 들어가 [UNK] 참회청문승' in '교토 닌나지(仁和寺)에 들어가 ‘참회청문승’이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,972 >> Unable to find text: '##닌' in '유닌(裕仁)을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,972 >> Unable to find text: '##닌 ( 裕 仁 )' in '유닌(裕仁)을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,972 >> Unable to find text: '##닌 ( 裕 仁 ) 을' in '유닌(裕仁)을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,974 >> Unable to find text: '일본의 항복은 일본인이 말살당하거나 미국의 노예가 되는 것이 아니라는 [UNK] 성명을 내며 일본의' in '“일본의 항복은 일본인이 말살당하거나 미국의 노예가 되는 것이 아니라는” 성명을 내며 일본의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,974 >> Unable to find text: '일본의 무조건 항복을 요구했으며 , 신임 미국 대통령 해리 트루먼 은 [UNK]' in '일본의 무조건 항복을 요구했으며, 신임 미국 대통령 해리 트루먼 은 “일본의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,974 >> Unable to find text: '일본의 무조건 항복을 요구했으며 , 신임 미국 대통령 해리 트루먼 은 [UNK] 일본의' in '일본의 무조건 항복을 요구했으며, 신임 미국 대통령 해리 트루먼 은 “일본의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,974 >> Unable to find text: '[UNK] 일본의 항복은 일본인이 말살당하거나 미국의 노예가 되는 것이 아니라는 [UNK] 성명을 내며 일본의' in '“일본의 항복은 일본인이 말살당하거나 미국의 노예가 되는 것이 아니라는” 성명을 내며 일본의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,975 >> Unable to find text: '일본인이 말살당하거나 미국의 노예가 되는 것이 아니라는 [UNK] 성명을 내며 일본의' in '일본인이 말살당하거나 미국의 노예가 되는 것이 아니라는” 성명을 내며 일본의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,975 >> Unable to find text: '[UNK]' in '“일본의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,975 >> Unable to find text: '[UNK] 일본의' in '“일본의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,975 >> Unable to find text: '미국의 노예가 되는 것이 아니라는 [UNK] 성명을 내며 일본의' in '미국의 노예가 되는 것이 아니라는” 성명을 내며 일본의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,976 >> Unable to find text: '[UNK] 결호 작전' in '‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,976 >> Unable to find text: '일억총옥쇄 [UNK] 의 일환으로 [UNK] 결호 작전' in '‘일억총옥쇄’의 일환으로 ‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,976 >> Unable to find text: '##전' in '작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,976 >> Unable to find text: '결호 작전 [UNK]' in '‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,976 >> Unable to find text: '결호 작전 [UNK] 을 시행' in '‘결호 작전’을 시행했다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,977 >> Unable to find text: '결호 작전 [UNK] 을' in '‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,977 >> Unable to find text: '[UNK] 일억총옥쇄 [UNK] 의 일환으로 [UNK] 결호 작전' in '‘일억총옥쇄’의 일환으로 ‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,977 >> Unable to find text: '[UNK] 결호' in '‘결호'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,977 >> Unable to find text: '##호 작전' in '‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,977 >> Unable to find text: '결호 작전 [UNK] 을 시행했다 . 이것은 가미카제 특공대뿐만 아니라 인간 어뢰' in '‘결호 작전’을 시행했다. 이것은 가미카제 특공대뿐만 아니라 인간 어뢰,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,977 >> Unable to find text: '일억총옥쇄 [UNK] 의 일환으로 [UNK] 결호' in '‘일억총옥쇄’의 일환으로 ‘결호'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,977 >> Unable to find text: '결호 작전 [UNK] 을 시행했다 . 이것은 가미카제 특공대' in '‘결호 작전’을 시행했다. 이것은 가미카제 특공대뿐만'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,977 >> Unable to find text: '결호 작전 [UNK] 을 시행했다 .' in '‘결호 작전’을 시행했다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,977 >> Unable to find text: '[UNK] 결' in '‘결호'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,978 >> Unable to find text: '일억총옥쇄 [UNK] 의 일환으로 [UNK] 결' in '‘일억총옥쇄’의 일환으로 ‘결호'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,978 >> Unable to find text: '[UNK] 결호 작전 [UNK]' in '‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,978 >> Unable to find text: '[UNK] 일억총옥쇄 [UNK] 의 일환으로 [UNK] 결호' in '‘일억총옥쇄’의 일환으로 ‘결호'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,978 >> Unable to find text: '[UNK] 결호 작' in '‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,978 >> Unable to find text: '[UNK] 결호 작전 [UNK] 을 시행' in '‘결호 작전’을 시행했다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,978 >> Unable to find text: '일억총옥쇄 [UNK] 의 일환으로 [UNK] 결호 작전 [UNK]' in '‘일억총옥쇄’의 일환으로 ‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,978 >> Unable to find text: '[UNK] 결호 작전 [UNK] 을' in '‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,978 >> Unable to find text: '일억총옥쇄 [UNK] 의 일환으로 [UNK] 결호 작' in '‘일억총옥쇄’의 일환으로 ‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,978 >> Unable to find text: '일억총옥쇄 [UNK] 의 일환으로 [UNK] 결호 작전 [UNK] 을 시행' in '‘일억총옥쇄’의 일환으로 ‘결호 작전’을 시행했다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,978 >> Unable to find text: '일억총옥쇄 [UNK] 의 일환으로 [UNK] 결호 작전 [UNK] 을' in '‘일억총옥쇄’의 일환으로 ‘결호 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,978 >> Unable to find text: '##호' in '‘결호'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,979 >> Unable to find text: '[UNK] 일억총옥쇄' in '‘일억총옥쇄’의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,979 >> Unable to find text: '[UNK] 일억총옥쇄 [UNK] 의 일환으로 [UNK] 결' in '‘일억총옥쇄’의 일환으로 ‘결호'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,979 >> Unable to find text: '##전 [UNK]' in '작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,979 >> Unable to find text: '##전 [UNK] 을 시행' in '작전’을 시행했다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,979 >> Unable to find text: '[UNK] 결호 작전 [UNK] 을 시행했다 . 이것은 가미카제 특공대뿐만 아니라 인간 어뢰' in '‘결호 작전’을 시행했다. 이것은 가미카제 특공대뿐만 아니라 인간 어뢰,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,979 >> Unable to find text: '고이소를 이어 새로 발족한 스즈키 간타로 내각은 [UNK] 일억총옥쇄' in '고이소를 이어 새로 발족한 스즈키 간타로 내각은 ‘일억총옥쇄’의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,979 >> Unable to find text: '##전 [UNK] 을' in '작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,979 >> Unable to find text: '[UNK] 결호 작전 [UNK] 을 시행했다 . 이것은 가미카제 특공대' in '‘결호 작전’을 시행했다. 이것은 가미카제 특공대뿐만'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,979 >> Unable to find text: '[UNK] 결호 작전 [UNK] 을 시행했다 .' in '‘결호 작전’을 시행했다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,980 >> Unable to find text: '일억총옥쇄 [UNK] 의 일환으로 [UNK] 결호 작전 [UNK] 을 시행했다 . 이것은 가미카제 특공대' in '‘일억총옥쇄’의 일환으로 ‘결호 작전’을 시행했다. 이것은 가미카제 특공대뿐만'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,981 >> Unable to find text: '##사키' in '나가사키에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,981 >> Unable to find text: '##사키에서 원자 폭탄이 터지고 소비에트 연방이 만주' in '나가사키에서 원자 폭탄이 터지고 소비에트 연방이 만주를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,981 >> Unable to find text: '##가사키' in '나가사키에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,982 >> Unable to find text: '##키' in '나가사키에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,982 >> Unable to find text: '##가사키에서 원자 폭탄이 터지고 소비에트 연방이 만주' in '나가사키에서 원자 폭탄이 터지고 소비에트 연방이 만주를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,983 >> Unable to find text: '##언' in '선언을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,983 >> Unable to find text: '##츠담 선언' in '포츠담 선언을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,983 >> Unable to find text: '##담 선언' in '포츠담 선언을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,983 >> Unable to find text: '##츠담' in '포츠담'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,983 >> Unable to find text: '##언을 받아들이기로' in '선언을 받아들이기로'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,983 >> Unable to find text: '##츠담 선언을 받아들이기로' in '포츠담 선언을 받아들이기로'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,983 >> Unable to find text: '##담' in '포츠담'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,984 >> Unable to find text: '##언을' in '선언을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,984 >> Unable to find text: '##츠담 선언을' in '포츠담 선언을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,984 >> Unable to find text: '##을 받아들이기로' in '선언을 받아들이기로'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,984 >> Unable to find text: '##담 선언을 받아들이기로' in '포츠담 선언을 받아들이기로'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,984 >> Unable to find text: '##을' in '선언을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,984 >> Unable to find text: '##담 선언을' in '포츠담 선언을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,984 >> Unable to find text: '##기로' in '받아들이기로'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,987 >> Unable to find text: '##년' in '4년이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,987 >> Unable to find text: '##은 4년' in '전쟁은 4년이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,987 >> Unable to find text: '##년이' in '4년이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,988 >> Unable to find text: '##은 4년이' in '전쟁은 4년이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,988 >> Unable to find text: '##은 4' in '전쟁은 4년이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,988 >> Unable to find text: '##이' in '4년이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,988 >> Unable to find text: '##년이 지' in '4년이 지나면서,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,988 >> Unable to find text: '##년이 지나' in '4년이 지나면서,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,988 >> Unable to find text: '##년이 지나면서' in '4년이 지나면서,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,988 >> Unable to find text: '##은 4년이 지' in '전쟁은 4년이 지나면서,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,988 >> Unable to find text: '##년이 지나면서 ,' in '4년이 지나면서,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,988 >> Unable to find text: '##은 4년이 지나' in '전쟁은 4년이 지나면서,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,990 >> Unable to find text: '##체' in '궁정체였기'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,990 >> Unable to find text: '##정체' in '궁정체였기'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,990 >> Unable to find text: '##체였기 때문에' in '궁정체였기 때문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,991 >> Unable to find text: '##였기 때문에' in '궁정체였기 때문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,991 >> Unable to find text: '##체였기' in '궁정체였기'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,991 >> Unable to find text: '##정체였기 때문에' in '궁정체였기 때문에'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,991 >> Unable to find text: '##체였기 때문에 국민들에게 쇼와 천황의 뜻을 전달하기가 어려웠다 .' in '궁정체였기 때문에 국민들에게 쇼와 천황의 뜻을 전달하기가 어려웠다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,992 >> Unable to find text: '##타' in '노부카타가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,992 >> Unable to find text: '##부카타' in '노부카타가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,992 >> Unable to find text: '##카타' in '노부카타가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,993 >> Unable to find text: '와다 노부카타가 조서 전문을 해설을 덧붙여 풀어서 읽었다 . 와다는 [UNK] 천황 폐하' in '와다 노부카타가 조서 전문을 해설을 덧붙여 풀어서 읽었다. 와다는 “천황 폐하께서는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,993 >> Unable to find text: '와다 노부카타가 조서 전문을 해설을 덧붙여 풀어서 읽었다 . 와다는 [UNK]' in '와다 노부카타가 조서 전문을 해설을 덧붙여 풀어서 읽었다. 와다는 “천황'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,993 >> Unable to find text: '##다 노부카타' in '와다 노부카타가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,993 >> Unable to find text: '##타가' in '노부카타가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,993 >> Unable to find text: '노부카타가 조서 전문을 해설을 덧붙여 풀어서 읽었다 . 와다는 [UNK] 천황 폐하' in '노부카타가 조서 전문을 해설을 덧붙여 풀어서 읽었다. 와다는 “천황 폐하께서는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,994 >> Unable to find text: '##제스' in '장제스에게'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,994 >> Unable to find text: '##스' in '장제스에게'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,995 >> Unable to find text: '##제스에게' in '장제스에게'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,995 >> Unable to find text: '##스에게' in '장제스에게'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,995 >> Unable to find text: '##제' in '장제스에게'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,996 >> Unable to find text: '##라' in '다케토라를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,997 >> Unable to find text: '##토라' in '다케토라를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,997 >> Unable to find text: '##가타 다케토라' in '오가타 다케토라를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,997 >> Unable to find text: '##라를' in '다케토라를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,997 >> Unable to find text: '##토라를' in '다케토라를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,998 >> Unable to find text: '##라를 내각서기관장으로 임명해 쇼와 천황' in '다케토라를 내각서기관장으로 임명해 쇼와 천황의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,998 >> Unable to find text: '##가타 다케토라를' in '오가타 다케토라를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,999 >> Unable to find text: '특수위안시설협회 [UNK] ( RAA )' in '‘특수위안시설협회’(RAA)는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,999 >> Unable to find text: '[UNK] 특수위안시설협회' in '‘특수위안시설협회’(RAA)는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,999 >> Unable to find text: '특수위안시설협회 [UNK]' in '‘특수위안시설협회’(RAA)는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:47,999 >> Unable to find text: '특수위안시설협회 [UNK] ( RAA' in '‘특수위안시설협회’(RAA)는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,001 >> Unable to find text: '블랙리스트 작전 [UNK] 을 계획' in '‘블랙리스트 작전’을 계획하고'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,068 >> Unable to find text: '[UNK] 블랙리스트 작전' in '‘블랙리스트 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,068 >> Unable to find text: '##전' in '작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,068 >> Unable to find text: '블랙리스트 작전 [UNK]' in '‘블랙리스트 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,068 >> Unable to find text: '블랙리스트 작전 [UNK] 을' in '‘블랙리스트 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,068 >> Unable to find text: '##랙리스트 작전' in '‘블랙리스트 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,069 >> Unable to find text: '일본 국민들을 원활하게 통치한다는 [UNK] 블랙리스트 작전' in '일본 국민들을 원활하게 통치한다는 ‘블랙리스트 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,069 >> Unable to find text: '블랙리스트 작전 [UNK] 을 계획하고 있었다 . 9월 27일 , 쇼와 천황은 서양식 예복 차림' in '‘블랙리스트 작전’을 계획하고 있었다. 9월 27일, 쇼와 천황은 서양식 예복 차림으로'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,069 >> Unable to find text: '[UNK] 블랙리스트' in '‘블랙리스트'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,069 >> Unable to find text: '[UNK] 블랙리스트 작전 [UNK] 을 계획' in '‘블랙리스트 작전’을 계획하고'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,069 >> Unable to find text: '##전 [UNK] 을 계획' in '작전’을 계획하고'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,069 >> Unable to find text: '[UNK] 블' in '‘블랙리스트'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,070 >> Unable to find text: '[UNK] 블랙리스트 작전 [UNK]' in '‘블랙리스트 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,070 >> Unable to find text: '##전 [UNK]' in '작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,070 >> Unable to find text: '[UNK] 블랙리스트 작전 [UNK] 을' in '‘블랙리스트 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,070 >> Unable to find text: '[UNK] 블랙리스트 작' in '‘블랙리스트 작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,070 >> Unable to find text: '##전 [UNK] 을' in '작전’을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,070 >> Unable to find text: '##랙리스트' in '‘블랙리스트'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,070 >> Unable to find text: '##랙리스트 작전 [UNK] 을 계획' in '‘블랙리스트 작전’을 계획하고'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,070 >> Unable to find text: '작전 [UNK] 을 계획' in '작전’을 계획하고'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,070 >> Unable to find text: '일본 국민들을 원활하게 통치한다는 [UNK] 블랙리스트' in '일본 국민들을 원활하게 통치한다는 ‘블랙리스트'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,071 >> Unable to find text: '일본 국민들을 원활하게 통치한다는 [UNK] 블랙리스트 작전 [UNK] 을 계획' in '일본 국민들을 원활하게 통치한다는 ‘블랙리스트 작전’을 계획하고'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,073 >> Unable to find text: '##글러스 맥아더' in '더글러스 맥아더가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,073 >> Unable to find text: '##더' in '맥아더가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,073 >> Unable to find text: '##러스 맥아더' in '더글러스 맥아더가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,073 >> Unable to find text: '##스 맥아더' in '더글러스 맥아더가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,073 >> Unable to find text: '##글러스 맥아더가' in '더글러스 맥아더가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,073 >> Unable to find text: '##더가' in '맥아더가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,073 >> Unable to find text: '##러스 맥아더가' in '더글러스 맥아더가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,073 >> Unable to find text: '##스 맥아더가' in '더글러스 맥아더가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,074 >> Unable to find text: '##글러스' in '더글러스'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,074 >> Unable to find text: '##러스' in '더글러스'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,074 >> Unable to find text: '##스' in '더글러스'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,074 >> Unable to find text: '##글러스 맥' in '더글러스 맥아더가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,074 >> Unable to find text: '##러스 맥' in '더글러스 맥아더가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,075 >> Unable to find text: '##스 맥' in '더글러스 맥아더가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,077 >> Unable to find text: '##다' in '이렇다》라는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,079 >> Unable to find text: '##사를' in '통신사를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,079 >> Unable to find text: '##신사를' in '통신사를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,080 >> Unable to find text: '##사를 통해' in '통신사를 통해'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,081 >> Unable to find text: '##지' in '조지와'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,081 >> Unable to find text: '##쓰모토 조지' in '마쓰모토 조지와'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,082 >> Unable to find text: '##모토 조지' in '마쓰모토 조지와'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,082 >> Unable to find text: '##지와' in '조지와'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,082 >> Unable to find text: '##쓰모토 조지와' in '마쓰모토 조지와'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,084 >> Unable to find text: '[UNK] 전쟁 포기' in '‘전쟁 포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,084 >> Unable to find text: '일본의 [UNK] 전쟁 포기' in '일본의 ‘전쟁 포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,084 >> Unable to find text: '##기' in '포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,084 >> Unable to find text: '전쟁 포기 [UNK] 를' in '‘전쟁 포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,084 >> Unable to find text: '전쟁 포기 [UNK]' in '‘전쟁 포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,084 >> Unable to find text: '헌법 기초자들은 일본의 [UNK] 전쟁 포기' in '헌법 기초자들은 일본의 ‘전쟁 포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,085 >> Unable to find text: '전쟁 포기 [UNK] 를 선언' in '‘전쟁 포기’를 선언하는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,085 >> Unable to find text: '[UNK] 전쟁' in '‘전쟁'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,085 >> Unable to find text: '일본의 [UNK] 전쟁' in '일본의 ‘전쟁'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,085 >> Unable to find text: '전쟁 포기 [UNK] 를 선언하는 조항' in '‘전쟁 포기’를 선언하는 조항을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,085 >> Unable to find text: '기초자들은 일본의 [UNK] 전쟁 포기' in '기초자들은 일본의 ‘전쟁 포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,085 >> Unable to find text: '[UNK] 전쟁 포기 [UNK] 를' in '‘전쟁 포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,085 >> Unable to find text: '[UNK] 전쟁 포기 [UNK]' in '‘전쟁 포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,085 >> Unable to find text: '국사 행위에 참여하는 것만 허용케 했다 . 그 다음 , 헌법 기초자들은 일본의 [UNK] 전쟁 포기' in '국사 행위에 참여하는 것만 허용케 했다. 그 다음, 헌법 기초자들은 일본의 ‘전쟁 포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,086 >> Unable to find text: '포기 [UNK] 를' in '포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,086 >> Unable to find text: '일본의 [UNK] 전쟁 포기 [UNK] 를' in '일본의 ‘전쟁 포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,086 >> Unable to find text: '포기 [UNK]' in '포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,086 >> Unable to find text: '일본의 [UNK] 전쟁 포기 [UNK]' in '일본의 ‘전쟁 포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,086 >> Unable to find text: '##기 [UNK] 를' in '포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,086 >> Unable to find text: '헌법 기초자들은 일본의 [UNK] 전쟁' in '헌법 기초자들은 일본의 ‘전쟁'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,086 >> Unable to find text: '##기 [UNK]' in '포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,086 >> Unable to find text: '[UNK] 전쟁 포' in '‘전쟁 포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,086 >> Unable to find text: '헌법 기초자들은 일본의 [UNK] 전쟁 포기 [UNK] 를' in '헌법 기초자들은 일본의 ‘전쟁 포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,086 >> Unable to find text: '일본의 [UNK] 전쟁 포' in '일본의 ‘전쟁 포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,087 >> Unable to find text: '헌법 기초자들은 일본의 [UNK] 전쟁 포기 [UNK]' in '헌법 기초자들은 일본의 ‘전쟁 포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,087 >> Unable to find text: '[UNK] 전쟁 포기 [UNK] 를 선언' in '‘전쟁 포기’를 선언하는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,087 >> Unable to find text: '[UNK]' in '‘전쟁'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,087 >> Unable to find text: '포기 [UNK] 를 선언' in '포기’를 선언하는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,087 >> Unable to find text: '일본의 [UNK] 전쟁 포기 [UNK] 를 선언' in '일본의 ‘전쟁 포기’를 선언하는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,087 >> Unable to find text: '일본의 [UNK]' in '일본의 ‘전쟁'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,087 >> Unable to find text: '##기 [UNK] 를 선언' in '포기’를 선언하는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,087 >> Unable to find text: '헌법 기초자들은 일본의 [UNK] 전쟁 포' in '헌법 기초자들은 일본의 ‘전쟁 포기’를'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,088 >> Unable to find text: '##년' in '1947년'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,089 >> Unable to find text: '일본국 헌법 [UNK] 으로 공포돼 이듬해인 1947년' in '‘일본국 헌법’으로 공포돼 이듬해인 1947년'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,089 >> Unable to find text: '[UNK] 일본국 헌법 [UNK] 으로 공포돼 이듬해인 1947년' in '‘일본국 헌법’으로 공포돼 이듬해인 1947년'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,089 >> Unable to find text: '헌법 [UNK] 으로 공포돼 이듬해인 1947년' in '헌법’으로 공포돼 이듬해인 1947년'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,089 >> Unable to find text: '##인 1947년' in '이듬해인 1947년'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,090 >> Unable to find text: '##년 5월 3일부터' in '1947년 5월 3일부터'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,090 >> Unable to find text: '일본국 헌법 [UNK] 으로 공포돼 이듬해인 1947' in '‘일본국 헌법’으로 공포돼 이듬해인 1947년'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,090 >> Unable to find text: '[UNK] 일본국 헌법 [UNK] 으로 공포돼 이듬해인 1947' in '‘일본국 헌법’으로 공포돼 이듬해인 1947년'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,090 >> Unable to find text: '##년 5월 3일부터 시행' in '1947년 5월 3일부터 시행됐다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,090 >> Unable to find text: '헌법 [UNK] 으로 공포돼 이듬해인 1947' in '헌법’으로 공포돼 이듬해인 1947년'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,091 >> Unable to find text: '##년 5월 3일부터 시행됐다 .' in '1947년 5월 3일부터 시행됐다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,091 >> Unable to find text: '##인 1947' in '이듬해인 1947년'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,091 >> Unable to find text: '##년 5월 3일' in '1947년 5월 3일부터'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,091 >> Unable to find text: '##년 5월 3일부터 시' in '1947년 5월 3일부터 시행됐다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,091 >> Unable to find text: '##년 5월 3일부터 시행됐다' in '1947년 5월 3일부터 시행됐다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,091 >> Unable to find text: '##년 5월 3일부터 시행됐다 . 새 헌법으로 쇼와 천황은 정치적인 권력을 빼앗겼으며 ,' in '1947년 5월 3일부터 시행됐다. 새 헌법으로 쇼와 천황은 정치적인 권력을 빼앗겼으며,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,091 >> Unable to find text: '일본국 헌법 [UNK] 으로 공포돼 이듬해인 1947년 5월 3일부터' in '‘일본국 헌법’으로 공포돼 이듬해인 1947년 5월 3일부터'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,092 >> Unable to find text: '[UNK] 일본국 헌법 [UNK] 으로 공포돼 이듬해인 1947년 5월 3일부터' in '‘일본국 헌법’으로 공포돼 이듬해인 1947년 5월 3일부터'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,092 >> Unable to find text: '헌법 [UNK] 으로 공포돼 이듬해인 1947년 5월 3일부터' in '헌법’으로 공포돼 이듬해인 1947년 5월 3일부터'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,092 >> Unable to find text: '##부터' in '3일부터'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,093 >> Unable to find text: '##토시' in '히토시'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,093 >> Unable to find text: '##시다 히토시' in '아시다 히토시'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,093 >> Unable to find text: '##시' in '히토시'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,094 >> Unable to find text: '##다 히토시' in '아시다 히토시'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,094 >> Unable to find text: '##토시 위원장이' in '히토시 위원장이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,094 >> Unable to find text: '##시다 히토시 위원장이' in '아시다 히토시 위원장이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,094 >> Unable to find text: '##시 위원장이' in '히토시 위원장이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,095 >> Unable to find text: '##시다' in '아시다'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,096 >> Unable to find text: '##국' in '국제검찰국을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,097 >> Unable to find text: '##검찰국' in '국제검찰국을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,098 >> Unable to find text: '##찰국' in '국제검찰국을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,098 >> Unable to find text: '##국을 설치하였으며 , 이어 11개국의 재판관과 검사들이 모일 극동 국제 군사 재판소' in '국제검찰국을 설치하였으며, 이어 11개국의 재판관과 검사들이 모일 극동 국제 군사 재판소의'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,099 >> Unable to find text: '##스는' in '펠러스는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,099 >> Unable to find text: '##너 펠러스는' in '보너 펠러스는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:48,099 >> Unable to find text: '##러스는' in '펠러스는'
# ...
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,795 >> Unable to find text: '통신 [UNK] 솔루션' in '통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,795 >> Unable to find text: '스마트폰은 극소수를 제외하면 통신 [UNK] 솔루션' in '스마트폰은 극소수를 제외하면 통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,796 >> Unable to find text: '[UNK] 솔루션' in '모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,796 >> Unable to find text: '갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK] 솔루션' in '갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,796 >> Unable to find text: '통신 [UNK]' in '통신 모뎀'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,796 >> Unable to find text: '[UNK] 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK] 솔루션' in '스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,796 >> Unable to find text: '통신 [UNK] 솔루션이' in '통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,796 >> Unable to find text: '통신 [UNK] 솔루션이 기본적으로 내장되어 있었으나 , 삼성 엑시노스 시리즈' in '통신 모뎀 솔루션이 기본적으로 내장되어 있었으나, 삼성 엑시노스 시리즈는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,796 >> Unable to find text: '통신 [UNK] 솔루션이 기본적으로 내장되어 있었으나 , 삼성 엑시노스' in '통신 모뎀 솔루션이 기본적으로 내장되어 있었으나, 삼성 엑시노스'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,796 >> Unable to find text: '[UNK] [UNK] 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰' in '퀄컴 스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,797 >> Unable to find text: '기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 [UNK] 솔루션' in '기존 갤럭시 S 시리즈 스마트폰은 극소수를 제외하면 통신 모뎀 솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,797 >> Unable to find text: '통신 [UNK] 솔루션이 기본적으로 내장되어 있었으나 , 삼성 엑시노스 시리즈는 플래그십 AP' in '통신 모뎀 솔루션이 기본적으로 내장되어 있었으나, 삼성 엑시노스 시리즈는 플래그십 AP로는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,797 >> Unable to find text: '##션' in '솔루션이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,797 >> Unable to find text: '스마트폰은 극소수를 제외하면 통신 [UNK]' in '스마트폰은 극소수를 제외하면 통신 모뎀'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,797 >> Unable to find text: '[UNK]' in '모뎀'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,797 >> Unable to find text: '[UNK] 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰' in '스냅드래곤 시리즈를 탑재한 기존 갤럭시 S 시리즈 스마트폰은'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,801 >> Unable to find text: '##0' in '3600'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,801 >> Unable to find text: '##0 mAh' in '3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,802 >> Unable to find text: '##h' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,802 >> Unable to find text: '##Ah' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,802 >> Unable to find text: '##0 m' in '3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,802 >> Unable to find text: '##0 mA' in '3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,802 >> Unable to find text: '##0 mAh이다 .' in '3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,802 >> Unable to find text: '##0 mAh이다' in '3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,803 >> Unable to find text: '##술' in '기술까지'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,804 >> Unable to find text: '##전 기술' in '무선충전 기술까지'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,804 >> Unable to find text: '##충전 기술' in '무선충전 기술까지'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,804 >> Unable to find text: '##선충전 기술' in '무선충전 기술까지'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,804 >> Unable to find text: '##속 무선충전 기술' in '고속 무선충전 기술까지'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,804 >> Unable to find text: '##전' in '무선충전'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,805 >> Unable to find text: '##h' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,806 >> Unable to find text: '##0 mAh' in '3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,839 >> Unable to find text: '##Ah' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,840 >> Unable to find text: '##은 내장형 3600 mAh' in '용량은 내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,842 >> Unable to find text: '##h' in 'mAh가량'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,844 >> Unable to find text: '##h' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,845 >> Unable to find text: '##0 mAh' in '3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,845 >> Unable to find text: '##Ah' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,845 >> Unable to find text: '##0' in '3600'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,845 >> Unable to find text: '##은 내장형 3600 mAh' in '용량은 내장형 3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,846 >> Unable to find text: '##Ah' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,846 >> Unable to find text: '##h' in 'mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,846 >> Unable to find text: '##0 mAh' in '3600 mAh이다.'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,849 >> Unable to find text: '##만' in '1,200만'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,849 >> Unable to find text: '##만' in '500만'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,850 >> Unable to find text: '##만 화소' in '1,200만 화소'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,851 >> Unable to find text: '##시' in '플래시''
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,851 >> Unable to find text: '##피 플래시' in ''셀피 플래시''
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,851 >> Unable to find text: '##시 ' 기능' in '플래시' 기능이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,852 >> Unable to find text: '##만' in '1,200만'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,853 >> Unable to find text: '##만 화소' in '1,200만 화소'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,854 >> Unable to find text: '[UNK]' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,854 >> Unable to find text: '[UNK] '' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,854 >> Unable to find text: '[UNK] ' 도 대폭 개선' in ''카툭튀'도 대폭 개선되고'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,854 >> Unable to find text: '' [UNK]' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,854 >> Unable to find text: '[UNK] ' 도' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,854 >> Unable to find text: '' [UNK] '' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,855 >> Unable to find text: '[UNK] ' 도 대폭 개선되고' in ''카툭튀'도 대폭 개선되고'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,855 >> Unable to find text: '[UNK] ' 도 대폭 개선되고 센서 면적도 전작인 갤럭시 S6 엣지' in ''카툭튀'도 대폭 개선되고 센서 면적도 전작인 갤럭시 S6 엣지나'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,855 >> Unable to find text: '' [UNK] ' 도 대폭 개선' in ''카툭튀'도 대폭 개선되고'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,855 >> Unable to find text: '[UNK] ' 도 대폭' in ''카툭튀'도 대폭'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,855 >> Unable to find text: '' [UNK] ' 도' in ''카툭튀'도'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,855 >> Unable to find text: '' [UNK] ' 도 대폭 개선되고' in ''카툭튀'도 대폭 개선되고'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,855 >> Unable to find text: '' [UNK] ' 도 대폭 개선되고 센서 면적도 전작인 갤럭시 S6 엣지' in ''카툭튀'도 대폭 개선되고 센서 면적도 전작인 갤럭시 S6 엣지나'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,855 >> Unable to find text: '' [UNK] ' 도 대폭' in ''카툭튀'도 대폭'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,858 >> Unable to find text: '##IS 기술' in 'OIS 기술이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,858 >> Unable to find text: '##술' in '기술이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,858 >> Unable to find text: '##IS' in 'OIS'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,859 >> Unable to find text: '##IS 기술이' in 'OIS 기술이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,859 >> Unable to find text: '##술이' in '기술이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,860 >> Unable to find text: '##만 화소' in '1,200만 화소'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,860 >> Unable to find text: '##만' in '1,200만'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,860 >> Unable to find text: '##소' in '화소'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,861 >> Unable to find text: '##만 화' in '1,200만 화소'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,862 >> Unable to find text: '##시' in '플래시''
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,862 >> Unable to find text: '##피 플래시' in ''셀피 플래시''
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,862 >> Unable to find text: '##시 ' 기능' in '플래시' 기능이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,862 >> Unable to find text: '##피 플래시 ' 기능' in ''셀피 플래시' 기능이'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,866 >> Unable to find text: '##벨' in '최고레벨이며'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,866 >> Unable to find text: '##진' in '방진을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,867 >> Unable to find text: '##수 방진' in '방수 방진을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,867 >> Unable to find text: '##진을' in '방진을'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,869 >> Unable to find text: '##8' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,869 >> Unable to find text: '##68' in 'IP68로,'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,869 >> Unable to find text: '##8로 , 이는 방진 등급으로나 방수 등급으로나 모두 최고레벨' in 'IP68로, 이는 방진 등급으로나 방수 등급으로나 모두 최고레벨이며'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,871 >> Unable to find text: '##서' in '센서가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,874 >> Unable to find text: '##벨' in '최고레벨이며'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,874 >> Unable to find text: '##레벨' in '최고레벨이며'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,874 >> Unable to find text: '##8로 , 이는 방진 등급으로나 방수 등급으로나 모두 최고레벨' in 'IP68로, 이는 방진 등급으로나 방수 등급으로나 모두 최고레벨이며'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,877 >> Unable to find text: '##럭시 S7 엣지가' in '갤럭시 S7 엣지가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,877 >> Unable to find text: '##지가' in '엣지가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,878 >> Unable to find text: '##월' in '6개월'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,878 >> Unable to find text: '##개월' in '6개월'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,878 >> Unable to find text: '##월 정도' in '6개월 정도가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,879 >> Unable to find text: '##월 정도가' in '6개월 정도가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,879 >> Unable to find text: '##개월 정도' in '6개월 정도가'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,882 >> Unable to find text: '##자' in '삼성전자'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,882 >> Unable to find text: '##전자' in '삼성전자'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,882 >> Unable to find text: '##성전자' in '삼성전자'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,883 >> Unable to find text: '##자 측' in '삼성전자 측에서는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,883 >> Unable to find text: '##성' in '삼성전자'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,883 >> Unable to find text: '##전자 측' in '삼성전자 측에서는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,883 >> Unable to find text: '##성전자 측' in '삼성전자 측에서는'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,884 >> Unable to find text: '##동 지역' in '중동 지역에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,884 >> Unable to find text: '##동' in '중동'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,885 >> Unable to find text: '##동 지역에서' in '중동 지역에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,885 >> Unable to find text: '##에서' in '지역에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,887 >> Unable to find text: '##만' in '18일만이며'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,887 >> Unable to find text: '##은 겨우 출시 18일' in '7은 겨우 출시 18일만이며'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,888 >> Unable to find text: '##동 지역' in '중동 지역에서'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,888 >> Unable to find text: '##동' in '중동'
# [INFO|squad_metrics.py:305] 2023-03-13 08:25:51,889 >> Unable to find text: '##동 지역에서' in '중동 지역에서'
# 03/13/2023 08:25:53 - INFO - __main__ - Results: {'exact_1000': 50.727398683754764, 'f1_1000': 59.95126385756773, 'total_1000': 5774, 'HasAns_exact_1000': 50.727398683754764, 'HasAns_f1_1000': 59.95126385756773, 'HasAns_total_1000': 5774, 'best_exact_1000': 50.727398683754764, 'best_exact_thresh_1000': 0.0, 'best_f1_1000': 59.95126385756773, 'best_f1_thresh_1000': 0.0, 'exact_10000': 65.06754416349152, 'f1_10000': 72.964393997575, 'total_10000': 5774, 'HasAns_exact_10000': 65.06754416349152, 'HasAns_f1_10000': 72.964393997575, 'HasAns_total_10000': 5774, 'best_exact_10000': 65.06754416349152, 'best_exact_thresh_10000': 0.0, 'best_f1_10000': 72.964393997575, 'best_f1_thresh_10000': 0.0, 'exact_11000': 65.25805334257014, 'f1_11000': 72.92900293333253, 'total_11000': 5774, 'HasAns_exact_11000': 65.25805334257014, 'HasAns_f1_11000': 72.92900293333253, 'HasAns_total_11000': 5774, 'best_exact_11000': 65.25805334257014, 'best_exact_thresh_11000': 0.0, 'best_f1_11000': 72.92900293333253, 'best_f1_thresh_11000': 0.0, 'exact_12000': 65.08486317977139, 'f1_12000': 72.84222003220943, 'total_12000': 5774, 'HasAns_exact_12000': 65.08486317977139, 'HasAns_f1_12000': 72.84222003220943, 'HasAns_total_12000': 5774, 'best_exact_12000': 65.08486317977139, 'best_exact_thresh_12000': 0.0, 'best_f1_12000': 72.84222003220943, 'best_f1_thresh_12000': 0.0, 'exact_2000': 58.78074125389678, 'f1_2000': 67.22004893463134, 'total_2000': 5774, 'HasAns_exact_2000': 58.78074125389678, 'HasAns_f1_2000': 67.22004893463134, 'HasAns_total_2000': 5774, 'best_exact_2000': 58.78074125389678, 'best_exact_thresh_2000': 0.0, 'best_f1_2000': 67.22004893463134, 'best_f1_thresh_2000': 0.0, 'exact_3000': 60.73779009352269, 'f1_3000': 69.02467472940563, 'total_3000': 5774, 'HasAns_exact_3000': 60.73779009352269, 'HasAns_f1_3000': 69.02467472940563, 'HasAns_total_3000': 5774, 'best_exact_3000': 60.73779009352269, 'best_exact_thresh_3000': 0.0, 'best_f1_3000': 69.02467472940563, 'best_f1_thresh_3000': 0.0, 'exact_4000': 61.53446484239695, 'f1_4000': 70.15664828186453, 'total_4000': 5774, 'HasAns_exact_4000': 61.53446484239695, 'HasAns_f1_4000': 70.15664828186453, 'HasAns_total_4000': 5774, 'best_exact_4000': 61.53446484239695, 'best_exact_thresh_4000': 0.0, 'best_f1_4000': 70.15664828186453, 'best_f1_thresh_4000': 0.0, 'exact_5000': 63.12781434014548, 'f1_5000': 71.25561320486818, 'total_5000': 5774, 'HasAns_exact_5000': 63.12781434014548, 'HasAns_f1_5000': 71.25561320486818, 'HasAns_total_5000': 5774, 'best_exact_5000': 63.12781434014548, 'best_exact_thresh_5000': 0.0, 'best_f1_5000': 71.25561320486818, 'best_f1_thresh_5000': 0.0, 'exact_6000': 63.578108763422236, 'f1_6000': 71.86799037855472, 'total_6000': 5774, 'HasAns_exact_6000': 63.578108763422236, 'HasAns_f1_6000': 71.86799037855472, 'HasAns_total_6000': 5774, 'best_exact_6000': 63.578108763422236, 'best_exact_thresh_6000': 0.0, 'best_f1_6000': 71.86799037855472, 'best_f1_thresh_6000': 0.0, 'exact_7000': 64.27086941461725, 'f1_7000': 72.09136060798666, 'total_7000': 5774, 'HasAns_exact_7000': 64.27086941461725, 'HasAns_f1_7000': 72.09136060798666, 'HasAns_total_7000': 5774, 'best_exact_7000': 64.27086941461725, 'best_exact_thresh_7000': 0.0, 'best_f1_7000': 72.09136060798666, 'best_f1_thresh_7000': 0.0, 'exact_8000': 65.27537235885002, 'f1_8000': 72.8367319283493, 'total_8000': 5774, 'HasAns_exact_8000': 65.27537235885002, 'HasAns_f1_8000': 72.8367319283493, 'HasAns_total_8000': 5774, 'best_exact_8000': 65.27537235885002, 'best_exact_thresh_8000': 0.0, 'best_f1_8000': 72.8367319283493, 'best_f1_thresh_8000': 0.0, 'exact_9000': 65.18877727745064, 'f1_9000': 72.81527472642797, 'total_9000': 5774, 'HasAns_exact_9000': 65.18877727745064, 'HasAns_f1_9000': 72.81527472642797, 'HasAns_total_9000': 5774, 'best_exact_9000': 65.18877727745064, 'best_exact_thresh_9000': 0.0, 'best_f1_9000': 72.81527472642797, 'best_f1_thresh_9000': 0.0, 'exact_KorQuAD': 65.32732940768965, 'f1_KorQuAD': 73.03646384291855, 'total_KorQuAD': 5774, 'Ha ...

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## 경로 변경

# %%
import os
os.chdir('/content/drive/MyDrive/korquad/')
os.getcwd()
# Out:
# '/content/drive/MyDrive/korquad'

# %%
from __future__ import print_function
from collections import Counter
import string
import re
import argparse
import json
import sys
import os

import pandas as pd
from transformers import AutoTokenizer

'''KorQuAD v1.0에 대한 공식 평가 스크립트 '''
'''본 스크립트는 SQuAD v1.1 평가 스크립트 https://rajpurkar.github.io/SQuAD-explorer/ 를 바탕으로 작성됨.'''

def normalize_answer(s):    
    def remove_(text):
        ''' 불필요한 기호 제거 '''
        text = re.sub("'", " ", text)
        text = re.sub('"', " ", text)
        text = re.sub('《', " ", text)
        text = re.sub('》', " ", text)
        text = re.sub('<', " ", text)
        text = re.sub('>', " ", text) 
        text = re.sub('〈', " ", text)
        text = re.sub('〉', " ", text)   
        text = re.sub("\(", " ", text)
        text = re.sub("\)", " ", text)
        text = re.sub("‘", " ", text)
        text = re.sub("’", " ", text)      
        return text

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return ''.join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_punc(lower(remove_(s))))


def f1_score(prediction, ground_truth):
    prediction_tokens = normalize_answer(prediction).split()
    ground_truth_tokens = normalize_answer(ground_truth).split()
   
    #F1 by character
    prediction_Char = []
    for tok in prediction_tokens:
        now = [a for a in tok]
        prediction_Char.extend(now)
        
    ground_truth_Char = []
    for tok in ground_truth_tokens:
        now = [a for a in tok]
        ground_truth_Char.extend(now)   
        
    common = Counter(prediction_Char) & Counter(ground_truth_Char)
    num_same = sum(common.values())
    if num_same == 0:
        return 0
    
    precision = 1.0 * num_same / len(prediction_Char)
    recall = 1.0 * num_same / len(ground_truth_Char)
    f1 = (2 * precision * recall) / (precision + recall)
    
    return f1


def exact_match_score(prediction, ground_truth):
    return (normalize_answer(prediction) == normalize_answer(ground_truth))


def metric_max_over_ground_truths(metric_fn, prediction, ground_truths):
    scores_for_ground_truths = []
    for ground_truth in ground_truths:
        score = metric_fn(prediction, ground_truth)
        scores_for_ground_truths.append(score)
    return max(scores_for_ground_truths)


def evaluate(dataset, predictions):
    f1 = exact_match = total = 0
    for article in dataset:
        for paragraph in article['paragraphs']:
            for qa in paragraph['qas']:
                total += 1
                if qa['id'] not in predictions:
                    message = 'Unanswered question ' + qa['id'] + \
                              ' will receive score 0.'
                    print(message, file=sys.stderr)
                    continue
                ground_truths = list(map(lambda x: x['text'], qa['answers']))
                prediction = predictions[qa['id']]
                exact_match += metric_max_over_ground_truths(
                    exact_match_score, prediction, ground_truths)
                f1 += metric_max_over_ground_truths(
                    f1_score, prediction, ground_truths)

    exact_match = 100.0 * exact_match / total
    f1 = 100.0 * f1 / total
    return {'exact_match': exact_match, 'f1': f1}


def evaluate_result(dataset_file, prediction_file):
    
    with open(dataset_file, encoding="utf-8") as f:
        dataset_json = json.load(f)
        dataset = dataset_json['data']
    with open(prediction_file, encoding="utf-8") as f:
        predictions = json.load(f)
    return evaluate(dataset, predictions)

# %% [markdown]
# ## 성능 확인

# %%
dataset_file = './data/KorQuAD_v1.0_dev.json'
prediction_file = './multilingual_bert-korquad/predictions_korquad.json'
evaluate_result(dataset_file, prediction_file)
# Out:
# {'exact_match': 69.72635954277797, 'f1': 89.67988604194674}
